# %% [markdown]
# # Named Entity Recognition
#
# Two different Natural Language Processing libraries are going to be applied for the purpose of identifying entities in out dataset (considering as dataset the questions extracted from the LC-QuAD dataset and the corresponding entities for each question as the real labels).

# %% [markdown]
# ## Flair

# %%
#import sys
#!{sys.executable} -m pip install flair

from flair.data import Sentence
from flair.models import SequenceTagger

tagger = SequenceTagger.load('ner')
tagger2 = SequenceTagger.load('ner-ontonotes')
tagger3 = SequenceTagger.load('por')
tagger4 = SequenceTagger.load('frame')

sentence = Sentence('George went to Washington .')

# predict NER tags
tagger.predict(sentence)

# print sentence with predicted tags
print(sentence.to_tagged_string())

tagger2.predict(sentence)
print(sentence.to_tagged_string())
# Out:
# C:\Users\agui\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# George <S-PER> went to Washington <S-LOC> .
# George <S-PERSON> went to Washington <S-GPE> .

# %%
import re

reg1 = re.compile(r' <B-\w+> ')
reg2 = re.compile(r' <E-\w+>')
reg3 = re.compile(r' <I-\w+> ')


#ofile = open('results/NER.txt', 'wt', encoding='utf-8')

tags = []

with open('sqa_questions_index.txt', 'rt', encoding='utf-8') as f:
    questions = f.read().splitlines()

for question in questions:
    idx, question = question.split(',', 1)
    sentence = Sentence(question.replace('?', '').strip())
    # predict NER tags
    tagger.predict(sentence)
        
    for entity in sentence.get_spans('ner'):
        tag, _ = str(entity).split('-',1)
        if tag not in tags:
            tags.append(tag)
        _, ent = str(entity).split(']: \"')
        ent = ent.replace('\"', '')
        #ofile.writelines(idx + ',' + ent +'\n')
        
print(tags)        
#ofile.close()

# %%
### S - Single,   B - Begin,   E - End,   I - Intermediate
### PER: Person,    LOC: Location,    ORG: Organization,    MISC: Miscelaneous

# %%
import re

reg1 = re.compile(r' <B-\w+> ')
reg2 = re.compile(r' <E-\w+>')
reg3 = re.compile(r' <I-\w+> ')


#ofile = open('results/NER12.txt', 'wt', encoding='utf-8')

tags = []

with open('sqa_questions_index.txt', 'rt', encoding='utf-8') as f:
    questions = f.read().splitlines()

for question in questions:
    idx, question = question.split(',', 1)
    sentence = Sentence(question.replace('?', '').strip())
    # predict NER tags
    tagger2.predict(sentence)
        
    for entity in sentence.get_spans('ner'):
        tag, _ = str(entity).split('-',1)
        if tag not in tags:
            tags.append(tag)
        _, ent = str(entity).split(']: \"')
        ent = ent.replace('\"', '')
        #ofile.writelines(idx + ',' + ent +'\n')
        
print(tags)        
#ofile.close()

# %%
### both tags together

import re

reg1 = re.compile(r' <B-\w+> ')
reg2 = re.compile(r' <E-\w+>')
reg3 = re.compile(r' <I-\w+> ')


ofile1 = open('results/NER_tags_2.txt', 'wt', encoding='utf-8')
ofile2 = open('results/NER12_tags_2.txt', 'wt', encoding='utf-8')

rem_tags = ['CARDINAL','ORDINAL','DATE']
# We exclude these types to exclude wrong identification of entities in the questions
# Example: 514,What is the agency name of the Ministry of Information and Communication Technology (Thailand)
#          and distribution region  of the Channel 9 MCOT HD ?
# In this question, '9' would be identified as a cardinal entity, but the real entity in this case is 'Channel 9 MCOT HD',
# so excluding the cardinal type we allow the model to identify the full compound entity.

with open('sqa_questions_index.txt', 'rt', encoding='utf-8') as f:
    questions = f.read().splitlines()

remove = ['What is ', 'What are ', 'Which ', 'Who is ', 'Who were ', 'Who ', 'Was ', 'How many ', 'How much ',
              'has been ', 'Do ', 'Does ', 'How ', 'Where ', 'go ']    

questions_cleaned = []

for question in questions:
    for rem in remove:
        if rem in question:
            question = question.replace(rem,'')

    questions_cleaned.append(question)

for question in questions_cleaned:
    idx, question = question.split(',', 1)
    try:
        sentence = Sentence(question.replace('?', '').replace('Name ','').strip())
        sentence2 = Sentence(question.replace('?', '').replace('Name ','').strip())
    except:
        print(question)
    # predict NER tags
    tagger.predict(sentence)
    tagger2.predict(sentence2)
        
    for entity in sentence.get_spans('ner'):
        tag, _ = str(entity).split('-',1)
        _, ent = str(entity).split(']: \"')
        ent = ent.replace('\"', '')
        ofile1.writelines(idx + ',' + ent +'\n')           
            
    for entity in sentence2.get_spans('ner'):
        tag, _ = str(entity).split('-',1)
        if tag not in rem_tags:
            _, ent = str(entity).split(']: \"')
            ent = ent.replace('\"', '')
            ofile2.writelines(idx + ',' + ent +'\n')

ofile1.close()
ofile2.close()

# %%
with open('results/NER_tags_2.txt', 'rt', encoding='utf-8') as f:
    entities_ner = f.read().splitlines()
    
with open('results/NER12_tags_2.txt', 'rt', encoding='utf-8') as f:
    entities_ner12 = f.read().splitlines()

# %%
print(entities_ner[0:10])
print(entities_ner12[0:10])
# Out:
# ['0,Bill Finger', '1,winston churchill', '1,Selwyn Lloyd', '2,Gestapo', '3,Mumbai North', '4,Roberto Clemente Bridge', '5,Theos Philopator', '5,Cleopatra', '6,Li Si', '7,PAvel Moroz']
# ['0,Bill Finger', '1,winston churchill', '1,Selwyn Lloyd', '2,Gestapo', '3,Mumbai North', '4,Roberto Clemente Bridge', '6,Li Si', '7,PAvel Moroz', '7,Yakov Estrin', '8,Broadmeadows, Victoria']

# %%
n = 5000

ner = [['']]*n
ner12 = [['']]*n

# store the entities identified by each Flair NER model
for entity in entities_ner:
    idx, ent = entity.split(',', 1)
    if ner[int(idx)] == ['']:
        ner[int(idx)] = [entity]
    else:
        ner[int(idx)].append(entity)
        
for entity in entities_ner12:
    idx, ent = entity.split(',', 1)
    entity = entity.replace('the ','')
    if ner12[int(idx)] == ['']:
        ner12[int(idx)] = [entity]
    else:
        ner12[int(idx)].append(entity)

# %%
ner[0:20]
# Out:
# [['0,Bill Finger'],
#  ['1,winston churchill', '1,Selwyn Lloyd'],
#  ['2,Gestapo'],
#  ['3,Mumbai North'],
#  ['4,Roberto Clemente Bridge'],
#  ['5,Theos Philopator', '5,Cleopatra'],
#  ['6,Li Si'],
#  ['7,PAvel Moroz', '7,Yakov Estrin'],
#  ['8,Broadmeadows, Victoria'],
#  ['9,ASC Creative Services'],
#  ['10,Ernest Rutherford', '10,Charles Drummond Ellis'],
#  ['11,REP Parasol'],
#  ["12,Monroe Carell Jr. Children's Hospital",
#   '12,Vanderbilt',
#   '12,Duncan U. Fletcher'],
#  ['13,Nader Guirat,', '13,Josef Johansson'],
#  [''],
#  ['15,HBO'],
#  ['16,Nikolai Morozov', '16,Stanislav Morozov'],
#  ['17,Abhijit Kunte', '17,Kasparov'],
#  ['18,MSX Basics'],
#  ['19,Ronaldo']]

# %%
ner12[0:20]
# Out:
# [['0,Bill Finger'],
#  ['1,winston churchill', '1,Selwyn Lloyd'],
#  ['2,Gestapo'],
#  ['3,Mumbai North'],
#  ['4,Roberto Clemente Bridge'],
#  [''],
#  ['6,Li Si'],
#  ['7,PAvel Moroz', '7,Yakov Estrin'],
#  ['8,Broadmeadows, Victoria'],
#  ['9,ASC Creative Services'],
#  ['10,Ernest Rutherford', '10,Charles Drummond Ellis'],
#  ['11,REP Parasol'],
#  ["12,Monroe Carell Jr. Children's Hospital",
#   '12,Vanderbilt',
#   '12,Duncan U. Fletcher'],
#  ['13,Nader Guirat,', '13,Josef Johansson'],
#  ['14,sarah jane'],
#  ['15,HBO'],
#  ['16,Nikolai Morozov', '16,Stanislav Morozov'],
#  ['17,Abhijit Kunte', '17,Kasparov'],
#  [''],
#  ['19,Ronaldo']]

# %%
ner_ner12[0:20]
# Out:
# [['0,Bill Finger'],
#  ['1,winston churchill', '1,Selwyn Lloyd'],
#  ['2,Gestapo'],
#  ['3,Mumbai North'],
#  ['4,Roberto Clemente Bridge'],
#  ['5,Theos Philopator', '5,Cleopatra'],
#  ['6,Li Si'],
#  ['7,PAvel Moroz', '7,Yakov Estrin'],
#  ['8,Broadmeadows, Victoria'],
#  ['9,ASC Creative Services'],
#  ['10,Ernest Rutherford', '10,Charles Drummond Ellis'],
#  ['11,REP Parasol'],
#  ["12,Monroe Carell Jr. Children's Hospital",
#   '12,Vanderbilt',
#   '12,Duncan U. Fletcher'],
#  ['13,Nader Guirat,', '13,Josef Johansson'],
#  ['14,sarah jane'],
#  ['15,HBO'],
#  ['16,Nikolai Morozov', '16,Stanislav Morozov'],
#  ['17,Abhijit Kunte', '17,Kasparov'],
#  [''],
#  ['19,Ronaldo']]

# %%
#combine the entities identified by each model
ner_ner12 = ['']*n

for i in range(0, n):
    if len(ner[i])==len(ner12[i]):
        if all(elem in ner12[i] for elem in ner[i]) == True:   # when both models identify the same entities
            ner_ner12[i] = ner[i]
        else:
            if ner[i] == ['']:     # when first model doesn't identify any entitiy but the second does
                ner_ner12[i] = ner12[i]            
            else:
                inter = list(set(ner[i]) & set(ner12[i]))
                dif = list(set(ner12[i]) - set(ner[i]))
                ner_ner12[i] = inter+dif          
    elif len(ner[i])<len(ner12[i]):
        if all(elem in ner12[i] for elem in ner[i]) == True:     # when second model identifies more entities and the ones
            ner_ner12[i] = ner12[i]                              # identified by the first model are included there
        else:
            if ner[i] == ['']:
                ner_ner12[i] = ner12[i]            
            else:
                inter = list(set(ner[i]) & set(ner12[i]))
                dif = list(set(ner[i]) - set(ner12[i]))
                ner_ner12[i] = inter+dif
                # when some entity is compound by more than one word, it might happen that one of the models identifies it as 
                # separate entities, so this is done to just consider the longer one, which is the actual entity.
                # Example: 45,Which shareholder of Dagenham wind turbines is also the parent company of the Ford Falcon Cobra?
                # In this question the ner model identifies as entities "Dagenham" and "Ford Falcon Cobra", but the ner12
                # identifies as entities "Dagenham", "Ford" and "Falcon Cobra", which is not correct in this case. This way,
                # we exclude the entities "Ford" and "Falcon Cobra", because they are included in the entity "Ford Falcon Cobra".
                
    elif len(ner[i])>len(ner12[i]):
        if all(elem in ner[i] for elem in ner12[i]) == True:
            ner_ner12[i] = ner[i]
        else:
            if ner12[i] == ['']:
                ner_ner12[i] = ner[i]
            else:
                inter = list(set(ner[i]) & set(ner12[i]))
                dif = list(set(ner12[i]) - set(ner[i]))
                ner_ner12[i] = inter+dif

# %%
with open('sqa_entities_labels_index.txt', 'rt', encoding='utf-8') as f:
    real_entities = f.read().replace('\ufeff', '').splitlines()

real = [['']]*n

for entity in real_entities:
    idx, ent = entity.split(',', 1)
    if real[int(idx)] == ['']:
        real[int(idx)] = [entity]
    else:
        real[int(idx)].append(entity)

# %%
real[0:10]
# Out:
# [['0,Bill Finger'],
#  ['1,Selwyn Lloyd', '1,Winston Churchill'],
#  ['2,Gestapo'],
#  ['3,Mumbai North'],
#  ['4,Roberto Clemente Bridge'],
#  ['5,Ptolemy XIII Theos Philopator', '5,Cleopatra V'],
#  ['6,Li Si'],
#  ['7,Pavel Moroz', '7,Yakov Estrin'],
#  ['8,Broadmeadows, Victoria'],
#  ['9,ASC Creative Services']]

# %%
print(len(ner))
print(len(ner12))
print(len(real))
# Out:
# 5000
# 5000
# 5000

# %%
def compare_predictions(real, ner_pred):
    match = 0
    partial = 0
    less = 0
    more = 0
    none_match = 0
    none_less = 0
    none_more = 0
    predicted = 0

    nonpredicted = []
    same_true = []
    same_pred = []


    from sklearn.metrics import f1_score

    for i in range(0,n):
        true = [x.lower() for x in real[i]]
        pred = [x.lower() for x in ner_pred[i]]
        lt = len(true)
        lp = len(pred)

        if lt == lp:
            matching = [p for p in pred if p in true]
            if matching == pred or matching == true:
                match+=1
                predicted+=len(pred)
            else:
                if matching != []:
                    partial+=1
                    predicted+=len(pred)
                else:
                    none_match+=1
                    nonpredicted.append(pred)               

            same_true.append(true)
            same_pred.append(pred)

        elif lt > lp:
            matching = [p for p in pred if p in true]
            if matching != []:
                less+=1
                predicted+=len(pred)
            else:
                none_less+=1
                nonpredicted.append(pred)
        else:
            matching = [p for p in pred if p in true]
            if matching != []:
                more+=1
                predicted+=len(true)
            else:
                none_more+=1
                nonpredicted.append(pred)
                
    return match, partial, less, more, none_match, none_less, none_more, predicted

# %%
### compare only ner predictions
match, partial, less, more, none_match, none_less, none_more, predicted = compare_predictions(real, ner)
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# 3199
# 337
# 158
# 132
# 948
# 116
# 110
# 5122
# 0.7711532670882264

# %%
### compare only ner12 predictions
match, partial, less, more, none_match, none_less, none_more, predicted = compare_predictions(real, ner12)
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# 3034
# 262
# 191
# 151
# 1043
# 150
# 169
# 4886
# 0.7356218006624511

# %%
### compare ner+ner12 combined predictions

match, partial, less, more, none_match, none_less, none_more, predicted = compare_predictions(real, ner_ner12)
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# 3172
# 315
# 116
# 130
# 1047
# 133
# 87
# 5075
# 0.7640770852152966

# %% [markdown]
# ## spaCy

# %%
# !{sys.executable} -m pip install spacy download en_core_web_md

import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm, en_core_web_md
nlp = en_core_web_sm.load()
nlp2 = en_core_web_md.load()

# %%
with open('sqa_questions_index.txt', 'rt', encoding='utf-8') as f:
    questions = f.read().splitlines()


ofile = open('results/NER_spacy_2.txt', 'wt', encoding='utf-8')

remove = ['What is ', 'What are ', 'Which ', 'Who is ', 'Who were', 'Who ', 'Was ', 'How many ', 'How much ',
          'has been ', 'Do ', 'Does ', 'How ', 'Where ', 'Name ']


questions_cleaned = []

for question in questions:
    for rem in remove:
        if rem in question:
            question = question.replace(rem,'')
            
    questions_cleaned.append(question)    
    
entities = []
    
for question in questions_cleaned:    
    idx, question = question.split(',',1)
    doc = nlp2(question.replace('?', '').strip())
    [entities.append(ent.text) for ent in doc.ents]
    try:    
        for entity in entities:
            ofile.writelines(idx + ',' + entity +'\n')
    except:
        ofile.writelines(idx + ',' +'\n')
    entities = []
    
ofile.close()
# Out:
# 0 ['Bill Finger']
# 1 ['Selwyn Lloyd']
# 2 ['Gestapo']
# 3 ['Mumbai']
# 4 ['Roberto Clemente Bridge']
# 5 ['ptolemy XIII Theos Philopator', 'Cleopatra V']
# 6 ['Li Si']
# 7 ['PAvel Moroz', 'Yakov Estrin']
# 8 ['Broadmeadows, Victoria']
# 9 ['ASC Creative Services']
# 10 ['Ernest Rutherford', 'Charles Drummond Ellis']
# 11 ['REP']
# 12 ["the Monroe Carell Jr. Children's Hospital", 'Vanderbilt', 'the Duncan U. Fletcher']
# 13 ['Nader Guirat', 'Josef Johansson']
# 14 []
# 15 ['HBO']
# 16 ['Nikolai Morozov', 'Stanislav Morozov']
# 17 ['Abhijit Kunte', 'Kasparov']
# 18 []
# 19 ['seasons', 'Ronaldo']
# 20 ['SamurAbsheron', 'Anar Salmanov']
# 21 ['2nd Foreign Infantry Regiment']
# 22 ['3Sub']
# 23 ['Kevin Jonas', 'Joe Jonas']
# 24 ['Timm Gunn', 'Sunrise', 'HIMYM']
# 25 ['O.co Coliseum']
# 26 ['Rishkiesh']
# 27 []
# 28 ['PhDs', 'National Medal of Science']
# 29 ['Aston Villa 2000-02 season', 'Middlesbrough F.C.', '2009']
# 30 ['William Harper']
# 31 ['PCL']
# 32 ['Kevin Jonas', 'Jonas']
# 33 ['Sagan']
# 34 ['Rosemont', 'Illinois']
# 35 ['Greenup County High School']
# 36 ['Bobby Hoppe']
# 37 ['Second']
# 38 ['Miguel de Cervantes']
# 39 []
# 40 ['Berkshire']
# 41 ['Crystal Harris']
# 42 ['Essex county']
# 43 ['Niederkirchnerstrae']
# 44 ['Steven Moffat']
# 45 ['Dagenham', 'Ford Falcon Cobra']
# 46 ['San Francisco International Airport']
# 47 ['San Diego']
# 48 ['the Trinity School', 'Brentwood', 'Sarah Walker']
# 49 []
# 50 ['Johann Gottfired', 'Urbain Le']
# 51 ['Elmer Burkett']
# 52 ['Hensley Meulens', 'Steve Ontiveros']
# 53 ['Lucy Sullivan']
# 54 ['Society Islands', 'Faaa']
# 55 ['1997', '94']
# 56 ['Richard Winn']
# 57 ['Sherlock', 'Arthur Levinson']
# 58 ['the Master Card', 'Sam Carrrick']
# 59 ['Fremantle Media']
# 60 ['South Loop Printing', 'House District']
# 61 ['Visual Studio']
# 62 ['Croatia']
# 63 ['Newin Chidchob']
# 64 ['Dave Bing', 'Ron Reed']
# 65 ['Galileo Galilei']
# 66 []
# 67 ['Elizabeth']
# 68 ['OneDrive']
# 69 ['Washington, D.C.']
# 70 ['Jordan', 'one']
# 71 ['Robert Witherspoon']
# 72 []
# 73 ['Oj']
# 74 ['Allen Walker']
# 75 ['Publius Servilius Vatia Isauricus', 'Marcus Calpurnius Bibulus']
# 76 ['chowdhury']
# 77 ['Mount Hoffmann']
# 78 ['Indiana']
# 79 []
# 80 ['the North Country', 'the Moondog Matinee']
# 81 ['April', 'Stewart', 'Mona Marshall']
# 82 ['Freedom of the City', 'Trinity House']
# 83 ['Reza Amrollahi', 'Iran']
# 84 ['Zaman Shah Durrani', 'Salahuddin']
# 85 ['Roh Tae Woo', 'Lee Leffingwell']
# 86 ['Rosemarie DeWitt']
# 87 ['Sapindales']
# 88 ['Lewis Hamilton']
# 89 ['Giorgos Kaminis']
# 90 ['Michael hahn']
# 91 ['Berlin']
# 92 ['India']
# 93 ['The Simpsons Ride']
# 94 ['O.co Coliseum']
# 95 ['Mams']
# 96 ['Playboy Enterprises']
# 97 ['Gwo Ka', 'Western Africa']
# 98 []
# 99 ['Visual Studio']
# 100 ['Roundhead (Wyandot']
# 101 ['the Michigan Stadium']
# 102 ['David Johnston']
# 103 ['Francois Marie', 'Le Marchand de Lignery']
# 104 ['Myntdu']
# 105 ['London']
# 106 ['Al Gore', '2000', 'Ann Lewis']
# 107 ['Darius']
# 108 ['Kim Sawchuk', 'the Airtours International Airways']
# 109 ['Antonio Giannini']
# 110 ['David Scherman']
# 111 ['Outlook.com', 'OneDrive']
# 112 ['Rouen Business School']
# 113 ['the Korean Minjoo Party']
# 114 ['one', 'McDonnell Aircraft']
# 115 ['Gales Ferry', 'Connecticut']
# 116 ['Detroit', 'MI']
# 117 ['english', 'under twenty']
# 118 ['Helsinki', 'one', 'Danish']
# 119 ['Timmy Time']
# 120 ['Fort Heath']
# 121 ['Harding', 'Lyons']
# 122 ['Rosario', 'Santa Fe']
# 123 []
# 124 ['Chris Myers', 'New Jersey', 'Oahu Railway and Land Company']
# 125 []
# 126 ['Brian Graden', 'Isaac Hayes']
# 127 []
# 128 ['Steve Sampson', 'Santa Clara']
# 129 ['Schibsted']
# 130 ['WPC Dynamo Moscow', 'Tigran Petrosian >']
# 131 ['Joan Laporta']
# 132 ['four']
# 133 ['Pong Pha']
# 134 ['the Angela Trusty', 'Charles Ayres']
# 135 ['Conglomerate']
# 136 ['Lagnacha Dhumdhadaka']
# 137 ['English']
# 138 ['El Sobrante', 'California']
# 139 [' ', "Daniel O'Regan"]
# 140 ['Solidus']
# 141 []
# 142 []
# 143 ['Tim Gunn', 'The Broken Code']
# 144 ['Shallot']
# 145 ['Oktoc', 'Mississippi']
# 146 ['Nord']
# 147 ['Tirana', 'Albania']
# 148 ['Fr Agnel', 'Multipurpose School', 'Vishwajyot High School']
# 149 []
# 150 ['the CBS Corporation']
# 151 ['Taguig']
# 152 ['Joe Hahn']
# 153 ['Isaac hayes']
# 154 ['Raymond Johansen']
# 155 ['Ikaros Smederna']
# 156 []
# 157 []
# 158 ['Washington DC']
# 159 ['Temenos Group']
# 160 []
# 161 ['Spain']
# 162 ['Chris Marve', 'Neria Douglass']
# 163 ['Monticello', 'Maine']
# 164 ['Josiah Idowu-Fearon', 'Damasucs']
# 165 ['Judy Hart Angelo', 'Paramount Television']
# 166 ['Caspian']
# 167 ['Arlington County', 'Virginia', 'United States Department of Defense']
# 168 ['Thongsuk Samdaengpan']
# 169 []
# 170 ['NCAA']
# 171 ['Queen Latifah', 'Afrika', 'Baby Bam']
# 172 ['Kazuo Hirai']
# 173 ['PATTS College of Aeronautics']
# 174 ['Dan Shamash']
# 175 ['Thanong Bidaya']
# 176 ['the San Marcos River']
# 177 []
# 178 ['Bogumilus']
# 179 ['Henry E. Catto']
# 180 ['Pope Gregory']
# 181 ['Cambodian']
# 182 ['Czech', 'Extraliga']
# 183 ['the Croix de guerre']
# 184 ['Azam F.C.']
# 185 ['INKAS', 'T.I.', 'Kumasi']
# 186 ['Rome', 'Mausoleum']
# 187 ['1st Free French Division']
# 188 ['the Mediterranean Sea']
# 189 ['Zambia', 'Ikelenge  District']
# 190 ['Royal Society']
# 191 []
# 192 ['Filipinos']
# 193 ['Neil Brown', 'Andrew Peacock']
# 194 ['Into the Dalek', 'Wizards']
# 195 ['Charles Pinckney']
# 196 ['US']
# 197 ['Tessa Dahl']
# 198 ['EU Broadcasting Union']
# 199 ['Jack Ryan', 'US Senate']
# 200 ['Ananda College']
# 201 ['Mediterranean Sea', 'Panionios G.S.S.']
# 202 ['Cowombat  Flat', 'Murray Mouth']
# 203 ['WBCQ', 'SW']
# 204 ['2015', 'Argentine Primera Division']
# 205 ['Florida']
# 206 ['New Zealand']
# 207 ['Jordan Cronenweth', 'Vangelis']
# 208 ['the Klang Valley']
# 209 ['Discovery Communications']
# 210 []
# 211 ['Oregon']
# 212 ['Paramount Domestic Television']
# 213 ['City of New Orleans']
# 214 ['Get TV', 'Galleria']
# 215 ['Madagascar', 'Penguin', 'Pirate']
# 216 ['Goran Cengic']
# 217 ['Zhorstoke nebo']
# 218 ['Louis Dunbar', 'Jeff Munn']
# 219 ['Populous']
# 220 []
# 221 ['pavel Moroz', 'Helena', 'Moscow']
# 222 ['J. Michael Stracznski', 'Christopher Franke']
# 223 ['a Cy-Fair High School']
# 224 ['Senser']
# 225 ['Blayse', 'Teddy Riley']
# 226 ['To You Are']
# 227 []
# 228 ['Wilton', 'Connecticut']
# 229 ['Ontarians']
# 230 ['Fox  ', 'Ryan Seacrest']
# 231 ['Box Girder']
# 232 []
# 233 ['Western Australian Public Transport Authority']
# 234 ['Thomas Meehan']
# 235 []
# 236 ['Jacques-Dsir', 'Laval']
# 237 ['Mecklenburg-Vorpommern']
# 238 ['Herzogenaurach']
# 239 ['Lucy Sullivan']
# 240 ['Blizzard Entertainment']
# 241 ['Alexander Downer', 'Neil Brown']
# 242 ['Costa Rica']
# 243 ['Amitava Datta']
# 244 ['Londo Mollari']
# 245 []
# 246 ['Rashid Behbudov State Song Theatre', 'Baku Puppet Theatre']
# 247 ['Liudmila Privivkova', 'Qadir Huseynov']
# 248 ['Cadillac', 'Fleetwood']
# 249 ['CDTV']
# 250 ['Mark Johnson']
# 251 ['Canary Islands']
# 252 ['Fusil Gras Mile', '1874']
# 253 ['Ralph Flanders', 'Claiborne Pell']
# 254 ['Ontario']
# 255 ['US', '281', 'San Antonio']
# 256 ['CNN']
# 257 ['Norfolk Southern Railway']
# 258 ['one', 'Pixar Image Computer', 'one', 'Edwin Catmull']
# 259 ['Beverly Hills', 'Colts Neck Township']
# 260 ['Rome']
# 261 ['Rhode Island Route 15']
# 262 ['Trump Productions']
# 263 ['KOMC-FM', 'KOMC (AM']
# 264 ['Jeju']
# 265 ['Swedish Academy']
# 266 ['Tennessee State Museum']
# 267 ['Ishir Honda']
# 268 ['1964', 'Winter Olympics']
# 269 []
# 270 []
# 271 ['Dowra']
# 272 []
# 273 ['Simon Fuller']
# 274 ['the The Producers (', '2005']
# 275 ['Henry Ford']
# 276 ['Dragons']
# 277 ['Providence', 'Charlwood', 'the Joseph Case High School']
# 278 ['John Robert Woodyard', 'Norbert Wiener', 'Social and Professional Responsibility']
# 279 ['George Siebels jr', 'Leroy Collins']
# 280 ['Germany']
# 281 ['Downtown Athletic Club', 'Yale Club NYCity']
# 282 ['Victor Hope', '2nd', 'Marquess', 'Linlithgow']
# 283 ['Ashton Historic']
# 284 ['Napanee']
# 285 []
# 286 ['Vagif Aliyev']
# 287 ['US', 'OneDrive']
# 288 ['James L. McConaughy']
# 289 ['one', 'Catwoman']
# 290 []
# 291 ['Bacteria']
# 292 ['French']
# 293 ['Baraily', 'Jowai']
# 294 []
# 295 ['Germanic']
# 296 ['Duanne Allman', 'the Les Paul']
# 297 ['tanzanian']
# 298 ['Bloomberg Markets']
# 299 []
# 300 ['Linda Hogan', 'Holmes Colbert']
# 301 ['Jon Speelman']
# 302 ['Ella Loves Cole']
# 303 ['Prime Time Entertainment Network']
# 304 ['Auto Shankar']
# 305 ['Burr Truss']
# 306 []
# 307 ['Cheryl Teigs']
# 308 ['Ndonga Mianga']
# 309 ['Papeete']
# 310 ['Lake Victoria']
# 311 ['Domenico Modugno']
# 312 ['Grameen Bank']
# 313 ['Benjamin Franklin Terry', 'US Route 59']
# 314 ['James Langer']
# 315 ['John Trumbull']
# 316 ['Peter-John Vettese']
# 317 ['Edwin Catmull']
# 318 ['Eric roth']
# 319 ['Martin Molony', 'Coneygree']
# 320 ['Dallas']
# 321 ['the Royal Society']
# 322 ['Stephen Law']
# 323 ['Gervase Helwys']
# 324 ['Raamlaxman']
# 325 ['Jose Cha Cha Jimenez']
# 326 ['RKO Pictures', 'Bernard Herrmann']
# 327 []
# 328 ['Celal Bayer', 'Presbyterian Theological Seminar']
# 329 ['quarters', 'Hamline Avenue']
# 330 ['Yasmin Paige']
# 331 ['Heinz Kokott', 'Nazi Army']
# 332 ['Jann Wenner', 'Ralph J. Gleason']
# 333 ['Sierra Nevada', 'U.S.', 'Nevado de Toluca']
# 334 ['BBC HD']
# 335 ['Sings Kristofferson', 'Milk Cow Blues']
# 336 ['Thesaban']
# 337 ['Micronesia']
# 338 ['Stephen E. Ambrose']
# 339 ['Central European', 'Summer Time']
# 340 ['The Best of Both Worlds', 'Steven Peterman']
# 341 ['Ralph J. Gleason']
# 342 ['Paul Morphy']
# 343 ['Thames Estuary', 'North Sea']
# 344 ['Ganefo']
# 345 ['Matt Williams']
# 346 ['Samuel W. McCall', 'Massachusetts House of Representatives']
# 347 ['the Golden Globe']
# 348 ['Jim']
# 349 []
# 350 ['one']
# 351 ['Joe Purcell', 'Winston Bryant']
# 352 ['Jim Harris']
# 353 ['Corringham']
# 354 []
# 355 ['Emanuel de Guzman']
# 356 ['Al Khaleejiya', '100.9 play']
# 357 ['the Harvest Christian Center']
# 358 ["Master's Sun>"]
# 359 ['Fr Agnel School', 'Jr', 'Virtual Kasparov']
# 360 ['Colts Neck Township', 'Beverly Hills']
# 361 ['Blizzard']
# 362 ['Shannon Pot', 'Limerick']
# 363 ['Gloucestershire']
# 364 ['Gelnhausen', 'Pepperdine University']
# 365 ['Frontaccounting', 'nUbuntu']
# 366 ['Brian Graden']
# 367 ['Fort Barrancas', 'Gadsden']
# 368 ['Richard H Immerman', 'Franklin W Olin']
# 369 ['Japan']
# 370 ['Monrow', 'Carell Jr Children Hospital', 'Vanderbilt University Medical Center']
# 371 ['GM']
# 372 ['Texas']
# 373 ['Counterpoint']
# 374 ['9800']
# 375 ['Anglo']
# 376 ['Tony Bennett']
# 377 ['Charles Willing Byrd', 'North Bend', 'Ohio']
# 378 ['Novelas']
# 379 ['anne spielberg']
# 380 ['NBC', 'Fraiser']
# 381 ['washington', 'the CTA Blue Line']
# 382 ['one', 'Janata Party']
# 383 ['Ford Theatre']
# 384 []
# 385 ['Arlington County', 'Virginia']
# 386 ['Ivan III', 'Russia']
# 387 ['Fusajiro Yamauchi', 'Nintendo Network']
# 388 ['Oddamavadi']
# 389 ['David']
# 390 ['Den', 'Bank']
# 391 []
# 392 ['US']
# 393 ['Random House']
# 394 ['Lori Black', 'Henry E. Catto Jr']
# 395 ['Arizona', 'Sun Devils']
# 396 ['Wyoming']
# 397 ['William Luther Hill', 'Claiborne Pell']
# 398 ['Ridley Scott', 'Vangelis']
# 399 ['Jeffrey Werleman', 'American Mediterranean Sea']
# 400 ['the Khmer Issarak']
# 401 ['2013']
# 402 ['Celluloid Records and Victor Entertainment']
# 403 ['Lahpet']
# 404 ['New Sanno Hotel', 'Gary Holder-Winfield']
# 405 ['Europe']
# 406 ['Long Island']
# 407 ['Jason Hayne']
# 408 ["the St George's Hospital"]
# 409 ['Russian', 'Premier League']
# 410 ['Trier']
# 411 []
# 412 ['1211', 'Americas']
# 413 ['Gregg Toland']
# 414 ['Freedom of the City']
# 415 ['Chris-Craft Industries']
# 416 []
# 417 ['Lightning McQueen']
# 418 ['Strontium 90']
# 419 ['Blodpalt']
# 420 ['Caroline Augusta', 'Foley Rhys Davids', 'Buddhism']
# 421 ['Bengali']
# 422 ['Nebraska']
# 423 ['First Church of Christ']
# 424 ['Thomas Secunda']
# 425 []
# 426 ['2001', 'Speedway Ekstraliga']
# 427 ['Cam Plante', 'MasterCard']
# 428 ['one', 'Raptors', '905']
# 429 ['Carmel Winery']
# 430 ['Irishmen']
# 431 []
# 432 ['Ingmar bergman', "James O'Brien"]
# 433 ['Militia']
# 434 ['Toronto']
# 435 ['Mike Salmon']
# 436 ['Kingship', 'Julius Caesar']
# 437 ['Mary Poppins']
# 438 ['Macmillan', 'Mikhail Pashnin']
# 439 ['US']
# 440 ['Indian Ocean', 'Zambia']
# 441 ['Panathinaikos FC']
# 442 ['Clamp']
# 443 ['Raymond Conner']
# 444 ['Dominican Republic']
# 445 ['the Elbieta Czartoryska', 'the Charles Journet']
# 446 ['Olin Corporation']
# 447 ['Philippe']
# 448 ['US']
# 449 ['Jim Dooley']
# 450 ['Ethopia']
# 451 ['Arkansas']
# 452 ['Mario Olivero']
# 453 ['Joker']
# 454 ['St. Viator High School']
# 455 [' Ali Habib Mahmud']
# 456 ['Outlawz']
# 457 ['Boston Bruins']
# 458 ['Vitis Vinifera']
# 459 ['Karakuri Dji Ultimo']
# 460 ['Mediterranean']
# 461 ['2d Command', 'Control Squadron', 'Colorado']
# 462 ['Manchester']
# 463 ['Camp Nou']
# 464 ['Hohenau', 'Paraguay']
# 465 []
# 466 ['American Hockey League']
# 467 ['1951', 'Asian Games']
# 468 ['WXXV-DT2']
# 469 ['GazaIsrael', 'Qaqun']
# 470 ['Delhi']
# 471 ['the Gatwick Airport']
# 472 []
# 473 ['Faisal Aman Khan']
# 474 ['NatGeo']
# 475 ['Italians']
# 476 ['Oliver Boulay']
# 477 ['Hyundai Lavita', 'Malaysia']
# 478 ['Brian', 'James']
# 479 []
# 480 ['John Fanning']
# 481 ['Aegean Sea']
# 482 ['Ponza']
# 483 ['Whichi  ', 'the Henri', 'Rohan', 'Michel Frutschi']
# 484 ['Dalilah Sappenfield']
# 485 ['Morphine']
# 486 ['Chordate']
# 487 ['London']
# 488 ['Cardinal', 'Jim Wylie']
# 489 ['Southwest African']
# 490 ['Ursula Hanle']
# 491 ['Williams Grand Prix Engineering', 'first']
# 492 ['Corps']
# 493 ['Schibsted', 'Swedish']
# 494 []
# 495 ['the Palang Dharma Party', 'Inthakin']
# 496 ['Fort Lauderdale Strikers', 'season', '16']
# 497 []
# 498 ['one', 'Joe Green']
# 499 ['Mike Babcock', 'Toronto']
# 500 []
# 501 ['United States House of Representatives', '1788', '1789']
# 502 ['Iyasu II']
# 503 ['Audie Murphy', 'Arlington']
# 504 ['Reigh Count']
# 505 ['the Tokyo Broadcasting System']
# 506 ['Daine Disney Miller']
# 507 ['Raptors 905']
# 508 ['George Beauchamp']
# 509 ['Lauren Briggs']
# 510 ['St lawrence', 'Kingston', 'Ontario']
# 511 ['MTR']
# 512 ['Vestigial Peter']
# 513 []
# 514 ['the Ministry of Information and Communication Technology (Thailand', 'the Channel 9 MCOT HD']
# 515 ['Kumta']
# 516 ['Mac OS 9', 'Tiny Tower']
# 517 ['VDE-Gallo Records']
# 518 ['the Electric Lady Studios']
# 519 []
# 520 ['Crusade (TV series', 'J. Michael Straczynski']
# 521 ['Ridgewood', 'New Jersey']
# 522 ['the MSX BASIC', 'Laura K. Ipsen']
# 523 ['Fusajiro Yamauchi']
# 524 ['Willie Nelson', 'Family']
# 525 ['Dan Otero']
# 526 ['POD', 'Pmare']
# 527 ['Captain EO']
# 528 ['Nairobi']
# 529 []
# 530 ['Luke List', 'K. Terry Dornbush']
# 531 ['Philip Novak']
# 532 ['Westchester Avenue', 'Bronx']
# 533 ['C++', 'Microsoft', 'Windows']
# 534 []
# 535 ['NOAAS Davidson', '331', 'Seattle']
# 536 ['Daund Junction', '99', '2009']
# 537 ['the PM House', 'Colombo']
# 538 ['Alta Mesa Memorial', 'adrian A. Basora']
# 539 ['Monty Python', 'Cinema International Corporation']
# 540 ['Charles Willing', 'Siege of Fort Recovery']
# 541 ['WTJC']
# 542 ['Evraz']
# 543 ['Panki']
# 544 ['Edsel', 'first', '1967']
# 545 ['Boeing', 'Vertol', 'CH-46 Sea Knight']
# 546 []
# 547 ['Clan McDuck', 'American']
# 548 ['Persian']
# 549 ['Vadodara', 'Pawan Hans']
# 550 ['5.1']
# 551 ['Korean Peninsula', 'Sodagreen']
# 552 ['Kelsey Creek']
# 553 ['Gary Portnoy', 'Frasier']
# 554 ['Lewis Stuyvesant Chanler']
# 555 ['Levon Ashotovich Grigorian']
# 556 ['Mediolanum and History of Trier']
# 557 ['Joel Schumacher']
# 558 ['Metro']
# 559 ['Saumarez']
# 560 ['Compaq']
# 561 ['Bob C Riley']
# 562 ['BMW', 'M40']
# 563 ['Naval Air', 'Adak', 'New Sanno Hotel']
# 564 ['Alabama']
# 565 ['Oskar Blues']
# 566 ['World Ski Championship', '1950', 'Colorado']
# 567 ['Congo River']
# 568 ['BBC HD']
# 569 ['Clinton Foundation', 'Jim Sasser']
# 570 []
# 571 ['Brockport Golden Eagles']
# 572 ['Ramiro Pea', 'Bruce Bochy']
# 573 ['Jeff Conaway', 'TNT']
# 574 []
# 575 ['John Tory']
# 576 ['North Caucasus']
# 577 ['etienne bieler\\xc9tienne_Bi\\xe9ler']
# 578 ['London']
# 579 ['Muhammad Yunus']
# 580 ['Hayden, Stone & Co.']
# 581 []
# 582 ['ITV(TV']
# 583 ['Ron Grainer', 'BBC HD']
# 584 ['J P', 'Paris', 'Bert McCaffrey']
# 585 ['LA']
# 586 ['Thomas Helwys']
# 587 ['England']
# 588 ['Los Angeles International Airport', 'San Francisco International Airport']
# 589 ['Tom Perriello']
# 590 ['Waterfall']
# 591 []
# 592 ['Plymouth Savoy', '26']
# 593 ['the Newark Station']
# 594 ['George Madison', 'United States House of Representatives', '1788', '1789']
# 595 ['Bill Clements']
# 596 ['National Archaeological Museum', 'Chimera of Arezzo']
# 597 ['Dalma Kovcs']
# 598 ['Whichd', 'North Bend', 'Indiana']
# 599 ['Oamr D Conger', 'Jack Ryan']
# 600 ['Blade Runner 2', 'The Edge of Human']
# 601 ['Vadodara', 'Mathura Vadodara']
# 602 ['Ghana']
# 603 ['Battle of the Thames']
# 604 ['Solon', 'Spencer Beman']
# 605 ['Royal Society', 'Georg Meissner']
# 606 ['Battle of Brownstown']
# 607 ['Malaysian', 'Chinese']
# 608 []
# 609 ['Rob Pike']
# 610 ['Peter Thorneycroft']
# 611 ['Terry Pratchett']
# 612 ['James belford']
# 613 ['Stockholm']
# 614 ['Lance Adams-Schneider', "Daniel O'Regan"]
# 615 ['C++']
# 616 ['Jim Harris']
# 617 ['Denton county', 'Texas']
# 618 ['SFOR']
# 619 ['the Life of the Marionettes']
# 620 []
# 621 []
# 622 ['Jerry Seinfeld', 'Larry David']
# 623 ['SF']
# 624 ['Playtone', 'Erik Jendresen']
# 625 ['Virginia', 'Dolley Madison']
# 626 ['Rodrigues']
# 627 ['Waxiang']
# 628 ['Bogdanua', 'Upper Neretva']
# 629 ['Charles Drummond Ellis', 'PhD']
# 630 ['Chevrolet']
# 631 ['Martin Pugh', 'Alana Stewert']
# 632 ['the Pepsi Center']
# 633 []
# 634 ['US', 'Alfred Phillips', 'William Smith']
# 635 ['Michael Jeffery', 'Williuam Deane']
# 636 ['Richard Winn']
# 637 ['Neil Brown']
# 638 []
# 639 ['Mount Hoffmann']
# 640 ['Agalga']
# 641 ['LG Optimus Vu', 'Manu Cornet']
# 642 ['Edsel']
# 643 ['Menora']
# 644 ['Cape Town', 'the Royal Astronomical Society']
# 645 ['John McEwen', 'Phm Vn']
# 646 []
# 647 []
# 648 ['the Caspian Sea']
# 649 ['Congress of Industrial Organizations']
# 650 ['Catarina Lindgren']
# 651 ['John of Damascus']
# 652 ['the West Berkshire Council']
# 653 ['Hank Williams Jr.']
# 654 ['Pixar Canada', 'Pixar']
# 655 ['Indian']
# 656 ['NYC FC']
# 657 ['Tony Bennett']
# 658 ['English']
# 659 ['Sarah Jane', 'Ron Grainer']
# 660 ['David Isaacs']
# 661 []
# 662 ['Brazil', '2']
# 663 ['Tirana']
# 664 ['Jon', 'Vangelis']
# 665 []
# 666 ['Marika Gombitov']
# 667 ['9TV']
# 668 ['the Army Air Corps', 'Iraq']
# 669 ['North Fort Myers High School']
# 670 ['Fred Hoiberg']
# 671 ['the Turkish Handball Super League']
# 672 ['Broadcast Syndication']
# 673 ['the Battle of the Bulge']
# 674 ['Czechoslovakia']
# 675 ['One']
# 676 ['Bob Adams', 'American']
# 677 ['2008', '400 metre']
# 678 ['Newell']
# 679 ['Birdman']
# 680 ['Mariveles', 'Bataan']
# 681 ['Dan Shamash', 'John Estes']
# 682 ['Toronto']
# 683 ['the Grand Canyon']
# 684 ['Jack Mcgregor']
# 685 ['the Royal Thai Army']
# 686 ['Words of Gold']
# 687 ['Manthena Venkata Raju', ' B. Shiva Rao']
# 688 ['Barq']
# 689 ['House']
# 690 ['Plum Asangas']
# 691 ['East Tilbury']
# 692 ['Kennedy']
# 693 []
# 694 ['GM', 'Albania']
# 695 ['Joel Quenneville']
# 696 ['the Lula J. Davis', 'the John McTaggart']
# 697 ['US']
# 698 []
# 699 ['James H. Fields']
# 700 ['Julia Gillard', 'elizabeth 2']
# 701 ['Big Creek', 'Texas']
# 702 ['INKAS', 'Jojo Chintoh']
# 703 []
# 704 ['Hillary Clinton']
# 705 ["Jacques Van't Hart"]
# 706 ['Daniel Gibson']
# 707 ['Upper Neretva']
# 708 ['English American']
# 709 ['Penny Lancaster', 'Alana Stewart']
# 710 ['Nguendula Filipe']
# 711 ['Iqbal Singh', 'B Shiva Rao']
# 712 ['65th Regiment of Foot']
# 713 ['Brian Dunkleman', 'Harry Connick']
# 714 ['Ella Fitzgerald', 'Mickey Roker']
# 715 ['Russell T Davis']
# 716 ['Cascade Airways', 'Seattle']
# 717 []
# 718 ['Blytheville']
# 719 []
# 720 ['Onedrive']
# 721 ['Monty Python', 'Geoffrey Burgon']
# 722 ['Vitis Vinifera']
# 723 ['Hackweiser']
# 724 ['the National Capital Region Athletic Association']
# 725 ['Tiffany Villarreal']
# 726 ['Juhu Aerodrome']
# 727 ['Unitary']
# 728 ['Indiana', 'Kaplan, Inc.']
# 729 ['Mikhail Pashnin', 'Robin Kovacs']
# 730 ["Jacques Van't Hart"]
# 731 ['Liv Ullmann']
# 732 ['Foxconn']
# 733 ['Gibby Haynes']
# 734 ['Stanley Kubrick']
# 735 []
# 736 ['first', 'Scuderia Ferrari', 'first']
# 737 ["Tommy Tucker's", 'Walt Disney']
# 738 ['Wickramabahu Central College (National School']
# 739 ['Manchester']
# 740 ['QDT']
# 741 ['Albert Kwesi Ocran', 'Jojo Chintoh']
# 742 ['Sony', 'PlayStation 2']
# 743 ['Stone Canoe', 'Michael Powell']
# 744 []
# 745 ['Joel Schumacher']
# 746 ['the Cobham Training Centre']
# 747 ['Regiment of Mounted Grenadiers']
# 748 ['Israel']
# 749 ['Richard Stites']
# 750 ['Semani']
# 751 ['Australian']
# 752 ['The Times']
# 753 ['Baikal Mountains', 'Arctic Ocean']
# 754 ['Robert Carr', 'Earl', 'Somerset']
# 755 ['(United States']
# 756 ['one', 'Louis D. Astorino']
# 757 ['Toronto']
# 758 ['German', 'Europe']
# 759 ['RenderMan']
# 760 ['Beverly Hills', 'California']
# 761 ['Thomas bryan Martin', 'Carmichael']
# 762 ['Fuountain Lake Farm']
# 763 ['Cape Canaveral Air Force Station']
# 764 ['Larry David']
# 765 ['Cline Buckens']
# 766 ['Cliff Burton', 'Metallica']
# 767 ['BBC Two']
# 768 ["the Prime Time Entertainment Network's", 'Artist', 'Christopher Franke']
# 769 ['Harry Connick', 'Ryan Seacrest']
# 770 ['Amiga']
# 771 ['Michael Schumacher', 'first', '1994']
# 772 ['333']
# 773 ['Paud']
# 774 ['the Gimhae International Airport']
# 775 ['Winston Bryant', 'Joseph Stiglitz']
# 776 ['Jeevan Mrityu']
# 777 ['Nathaniel P. Hill']
# 778 ['James', 'Tom Maniatis']
# 779 ['Becket']
# 780 ['Winston Bryant', 'Joe Purcell']
# 781 ['first', 'Scuderia Ferrari']
# 782 ['Olivier Boulay']
# 783 []
# 784 []
# 785 ['Brunei']
# 786 ['Avalon', 'John mcGuinness']
# 787 ['the American Revolutionary War']
# 788 ['Clark Daniel Stearns']
# 789 ['Coneygree', 'Fergie Sutherland']
# 790 ['John Betts', 'Connecticut']
# 791 ['Samuel Isham']
# 792 ['Canidae']
# 793 ['Kharghar']
# 794 ['Henry Cluney']
# 795 ['A J Clark']
# 796 ['Tamon Ohta']
# 797 ['Chester Bennington']
# 798 ['Ramiro Pea']
# 799 ['Russell Davies']
# 800 ['Erich Kempka']
# 801 []
# 802 ['Oscar', 'Lucinda']
# 803 ['Daund Junction']
# 804 ['Broca', 'Brain']
# 805 ['the Maharashtra Chess Association', 'Abhijit']
# 806 ['Paramount Television', 'Cheers Beacon']
# 807 ['Dolley Madison']
# 808 ['CBS']
# 809 ['Shay']
# 810 ['Brian Dunkleman', 'Simon Fuller']
# 811 []
# 812 []
# 813 ['British']
# 814 ['Timeform']
# 815 ['Charles', 'Wales']
# 816 ['John O Moseley']
# 817 ["Henry McDaniel's"]
# 818 ['Zabbaleen']
# 819 ['Elders']
# 820 ['Mel Brooks']
# 821 ['the Manhatten Project']
# 822 ['Mauritius Broadcasting Corporation', 'Michael Medor']
# 823 ['Chandra Shekhar', 'Datl Satyanarayana Raju']
# 824 ['NBC']
# 825 ['Kingston Ontario']
# 826 ['Lancy', 'Esther Alder']
# 827 ['Douglas Netter']
# 828 ['Whihc', 'David Scherman']
# 829 ['FremantleMedia']
# 830 ['Philippine Ports Authority', 'Ruben J. Villote']
# 831 ['Willian Menalaus']
# 832 ['Sirius XM Holdings']
# 833 ['Joe Schilling', 'Nick Diaz']
# 834 ['Martin Pugh']
# 835 ['Willard Fiske']
# 836 ['James Hetfield', 'Metallica']
# 837 ['Bruce Bochy']
# 838 ['Ralf Schumacher', 'Mick Schumacher']
# 839 ['Hafthor Julius Bjornsson']
# 840 []
# 841 ['Stuart Alan Jones']
# 842 ['Sleepy-Time Squirrel']
# 843 ['Andre Bourgeois']
# 844 ['Arunachal Pradesh Legislative Assembly', '2014', 'Rishikesh']
# 845 ['The Comedy Central']
# 846 ['Stephen Urban', 'Ali Habib Mahmud']
# 847 ['Mirabilis']
# 848 ['Whitney Wistert']
# 849 ['Kirk Hammett', 'Gibson Flying V']
# 850 ['Hampton Roads Rhinos']
# 851 ['Utopian']
# 852 ['Sturm College of Law']
# 853 ['WWTR']
# 854 ['Ciao Zanardi']
# 855 ['Dragon', 'Den']
# 856 []
# 857 ['Alexandre Tichonov']
# 858 ['The Dragons of Eden']
# 859 ['Egypt']
# 860 ['Richard Coke']
# 861 ['Carl Sagan']
# 862 ['US']
# 863 ['the John Kotelawala', 'the Sanath Weerakoon']
# 864 ['Gary Kubaik']
# 865 ['Eric Schiller', 'Craig Van Tibury']
# 866 ['US', 'Arthur Bagby', 'Thomas H']
# 867 ['Clamp']
# 868 ['Hagta', 'Guam']
# 869 ['Bengalis']
# 870 ['Indian', '2004', 'Andhra Pradesh']
# 871 ['Drawings', 'Bob Dylan']
# 872 ['Motorpsycho Nitemare']
# 873 []
# 874 []
# 875 ['Batman Live']
# 876 ['National Park Service']
# 877 []
# 878 ['Ron Grainer', '2016']
# 879 ['Interplay Entertainment']
# 880 ['GPL']
# 881 ['Artisan Entertainment']
# 882 ['Balgowan']
# 883 ['Ingmar Bergman', 'Laemmle Theatres']
# 884 []
# 885 ['Bill Murphy', 'Jean Segura']
# 886 ['Gene Conley']
# 887 ['Marquette Golden Eagles', 'Virginia Tech Hokies']
# 888 ['AH141']
# 889 []
# 890 ['Georgina Theodora Wood']
# 891 []
# 892 ['Eric Schiller']
# 893 ['Walt Disney Studio']
# 894 ['Jurgens Site', 'Jimmie Heuga']
# 895 []
# 896 ['one', 'Wisconsin']
# 897 ['Kriminalpolizei', 'Ordnungspolizei']
# 898 ['vance johnson']
# 899 ['Virendra Kataria']
# 900 ['US']
# 901 ['Pioneer Corporation']
# 902 ['WMDN']
# 903 ['Linda Hogan', 'Riley Reid']
# 904 ['Costanzo Preve']
# 905 ['Arthur Ross', 'Edward Niesen']
# 906 ['Tony Ramo']
# 907 ['Tremont Avenue', 'Ron Galotti']
# 908 ['1931', 'Staten Island Stapletons season']
# 909 ['Heroman']
# 910 ['Jerome B. Chaffee']
# 911 ['Joseph Clay', 'William Cushing']
# 912 ['Zambezi', 'zambia']
# 913 ['Cathedral Peak (California']
# 914 ['WRVU', 'Vanderbilt']
# 915 ['The Haunted House']
# 916 ['Turin']
# 917 ['Douglas']
# 918 ['tampa']
# 919 ['Phish']
# 920 ['Musee']
# 921 ['Bill Clinton']
# 922 ['GNOWSYS', 'GNU TeXmacs']
# 923 ['Liberty Bell']
# 924 ['the Gibson Guitar Corporation']
# 925 ['the The Skeleton Dance', 'Mickey', 'Mellerdrammer']
# 926 ['2013', 'Copa Centroamericana']
# 927 ['Brian Dunkleman']
# 928 ['Craig Robinson']
# 929 ['Frasier', 'Gary Portnoy']
# 930 ['Lebrsnik']
# 931 ['Lima']
# 932 []
# 933 ['America']
# 934 ['Breann McGregor', 'Frank Thorne']
# 935 ['Ford', 'Chiva']
# 936 ['Mount Moosilauke']
# 937 ['Thud', 'Jon Speelman']
# 938 ['the Ford Kansas City Assembly Plant', 'Ford', 'Y-']
# 939 ['Ekstraliga']
# 940 ['Aaround Van Heemstra']
# 941 ['Igor Shpillband']
# 942 ['Burbank', 'California']
# 943 ['Kakae']
# 944 ['Vadodara']
# 945 ['Salford City F.C']
# 946 ['Doug Acomb']
# 947 ['US', 'the East Whiteland Township', 'Pennsylvania']
# 948 ['Birmingham']
# 949 ['Pioneer']
# 950 ['Oldsmobile', '88']
# 951 ['Indiana']
# 952 ['Le Gibloux']
# 953 ['Marvell Technology Group']
# 954 ['Worcester', 'Oxford']
# 955 ['John Tower']
# 956 ['FC', 'Barcelona']
# 957 ['Bremerton']
# 958 []
# 959 ['Kevin Tsujihara']
# 960 ['Robert De Niro']
# 961 ['Quagmire', 'Quagmire']
# 962 ['MasterCard Centre']
# 963 ['United World College', 'Costa Rica']
# 964 []
# 965 ['Orson Welles', 'Bernard Herrmann']
# 966 ['Dragimir', 'Travunia']
# 967 []
# 968 []
# 969 ['James F Obrien', 'Laemmle Theatres']
# 970 ['Dinamo Krasnodar']
# 971 ['Alexius Meinong']
# 972 ['Wuropean School', 'Karlsruhe']
# 973 []
# 974 ['97.1', 'WASH FM']
# 975 ['the Paul Demiville', 'Koay Teng Hai']
# 976 []
# 977 ['Erik Jendresen']
# 978 ['Hearth and Home']
# 979 ['Mike Shinoda']
# 980 ['United States House of Representatives', 'ohn Drayton']
# 981 ['Mercedes Benz Superdome']
# 982 ['Chatumongol Sonakul']
# 983 []
# 984 ['Bowlby']
# 985 ['Oddworld']
# 986 ['Josep Maria Bartomeu']
# 987 ['Peter Piper Pizza']
# 988 ['arequipa']
# 989 ['Emel']
# 990 []
# 991 []
# 992 []
# 993 []
# 994 ['Le Gibloux']
# 995 ['Metro Transit', 'Minnesota']
# 996 ['Peter Crouch', 'Stoke City FC']
# 997 ['Lloyd  Nosler']
# 998 ['one']
# 999 ['Harriet Andersson']
# 1000 ['Thesaban']
# 1001 ['Rising Star', 'Brad Paisley']
# 1002 ['Insects']
# 1003 ['Oliver Sacks', 'the Columbia University']
# 1004 ['one', 'Classic']
# 1005 ['Christian Nation']
# 1006 []
# 1007 ['Darcs']
# 1008 []
# 1009 ['Science Fiction']
# 1010 ['the Brockport Golden Eagles']
# 1011 ['Quest VI']
# 1012 ['Limited']
# 1013 ['Miami']
# 1014 ['Japan']
# 1015 ['Herald india', 'Kumta']
# 1016 ['Southend', 'Essex']
# 1017 ['Zurich Affoltern', 'Albis Zug']
# 1018 ['California']
# 1019 ['Johnny Cash']
# 1020 ['Helen Getachew', 'Haile Selassie Gugsa']
# 1021 ['Australian', 'Alps']
# 1022 ['the J. T. Krogh', 'Camilla Martin']
# 1023 ['china', '2008']
# 1024 ['Canada', 'Benedict XVI']
# 1025 ['C. E. Webber', 'Murray Gold']
# 1026 ['Lampedusa']
# 1027 []
# 1028 ['Pius X']
# 1029 ['Dolley Madison']
# 1030 ['Kakae', 'the Robert William Wilcox']
# 1031 ['Richard Taylor']
# 1032 ['Halyna Kukhar', 'Stanislav Morozov']
# 1033 []
# 1034 ['Ziggi Recado']
# 1035 ['Urban Areas']
# 1036 ['Kiki Cutter']
# 1037 ['Emma', 'Jane Austen', 'Manhatten']
# 1038 ['Robert T. Herres']
# 1039 ['Bucyrus']
# 1040 ['Jacob', 'Abraham']
# 1041 ['Google Cloud Connect']
# 1042 ['Jean Marc Germain']
# 1043 ['Outlook.com', 'Microsoft Azure']
# 1044 ['geoffrey Rush', 'Laemmle Theatres']
# 1045 ['Microsoft']
# 1046 ['Ron Cyrus']
# 1047 []
# 1048 ['Royal Society', 'Franz Brentano']
# 1049 ['the Norwalk Trainband']
# 1050 ['Newin Chidchob', 'Ajahn Sao Kantaslo']
# 1051 ['BAFTA']
# 1052 ['Microsoft', 'C++']
# 1053 ['Picasso']
# 1054 ['Toronto Argonauts']
# 1055 ['John Kotelawala']
# 1056 ['Marika Gombitova']
# 1057 ['Chandra Shekhar', 'Govinda']
# 1058 ['the Christopher Daz Figuero', 'Cruce', 'Nado Internacional']
# 1059 ['Jamiatu', 'Muslim', 'Mindanao']
# 1060 ['London']
# 1061 ['Alexandre Tichonov', 'Valentin Muratov']
# 1062 ['US Congress', 'the Kansas Legislature']
# 1063 ['the Pulau Ubin', 'Nicole Lai']
# 1064 ['Thomas Darden', 'Edwin F. Hunter']
# 1065 ['Vanderbilt', 'Commodores']
# 1066 ['Switzerland', '2004', '2008 summer', 'Olympics']
# 1067 ['Roger Barton']
# 1068 ['Darren McNamara']
# 1069 []
# 1070 ['Louisa Hill', 'American Football Wellington']
# 1071 ['the US Senate']
# 1072 ['Connick', 'Fox Broadcasting Company']
# 1073 ['Riddim Ribbon']
# 1074 ['McDonnell Douglas']
# 1075 ['Boga']
# 1076 ['Henry Clay', 'William Luther Hill']
# 1077 ['one', 'Chris DuBois']
# 1078 ['Estadio Nacional de Costa Rica', 'Xianren Cave']
# 1079 []
# 1080 []
# 1081 ['Merritt Paulson']
# 1082 ['Karl Ewald Hasse', 'Georg Meissner']
# 1083 ['Erik Jendresen']
# 1084 ['Charles Edward Magoon']
# 1085 ['Bangkok']
# 1086 ['Nehru']
# 1087 ['american']
# 1088 ['Wayne Allard']
# 1089 ['Rishang Keishing', 'Manendragarh']
# 1090 ['Emmett Hughes']
# 1091 ['Robert William Wilcox']
# 1092 ['Karakuri Dji Ultimo']
# 1093 [' Laurie Johnson', 'Anthony Harvey']
# 1094 ['Tendring']
# 1095 ['NTSC', '5.1']
# 1096 ['Bacilli']
# 1097 ['Metropolitan City of Venice', 'Luigi Brugnaro']
# 1098 ['Thelred']
# 1099 ['April', 'Stewart']
# 1100 ['Sony', 'Asus']
# 1101 []
# 1102 []
# 1103 ['Craig van Tilbury', 'The Chess Monthyl']
# 1104 ['NBA']
# 1105 ['Senate']
# 1106 ['2004-05', 'FC']
# 1107 []
# 1108 ['Audenried']
# 1109 []
# 1110 ['Hotchkiss']
# 1111 ['Melbourne', 'VCA', 'MCM']
# 1112 ['Charles Plosser']
# 1113 ['Temptation Waits']
# 1114 ['Panthera']
# 1115 ['The Trumpet Kings', 'Joe Turner']
# 1116 ['1989', 'Portuguese Grand Prix']
# 1117 []
# 1118 ['Azerbaijan']
# 1119 ['Tabriz']
# 1120 ['Primus', 'Isaac Hayes']
# 1121 ['Bruce Harrell']
# 1122 ['Toll Global Express', 'LPGA']
# 1123 ['Glasgow']
# 1124 ['Moskovsky']
# 1125 ['Band of Brothers']
# 1126 ['12th Field Artillery Regiment', 'colorado']
# 1127 ['William Deaner', 'Latham']
# 1128 ['Westmeath']
# 1129 ['Patterson Houses']
# 1130 ['Levi Lincoln']
# 1131 ['Gareth Southgate', 'Middlesbrough F.C.']
# 1132 ['Martin', 'FSG1']
# 1133 []
# 1134 ['Pope Gregory 1', 'Edwin']
# 1135 ['Bogdanua', 'the Croatian Inline']
# 1136 ['Sam Loyd', 'Eric Schiller']
# 1137 ['Janta Dal']
# 1138 ['Lousana', 'Alberta Highway 42']
# 1139 ['United States', 'John Adams']
# 1140 ['England']
# 1141 ['Hank Brown']
# 1142 ['Greek']
# 1143 ['Larry J. Franco']
# 1144 ['the Jump Square Magazine']
# 1145 ['Kelly Brook']
# 1146 []
# 1147 ['Indian', 'English']
# 1148 ['Chordate', 'Diprotodontia']
# 1149 ['Dennis DeConcini', 'Scott Berkun']
# 1150 ['John A Danaher III']
# 1151 ['First Church of Christ', 'Pittsburgh']
# 1152 ['Colin Powell', 'Jaber Al-Ahmad Al-Sabah']
# 1153 ['MacKenzie Miller']
# 1154 ['Fairmount', 'Indiana']
# 1155 ['Letitia MacTavish Hargrave', 'Martino Martini']
# 1156 ['George Lucas', '6']
# 1157 ['Amblin Television']
# 1158 ['Levant']
# 1159 ['Beeleigh Abbey']
# 1160 ['Auckland']
# 1161 []
# 1162 ['Jamiatu', 'Muslim', 'Mindanao']
# 1163 ['Laozi']
# 1164 ['Tales of Suspense']
# 1165 ['Te Deum', 'Charpentier']
# 1166 ['SFOR']
# 1167 ['the Harward Medical School']
# 1168 ['Reading Berkshire', 'Essex']
# 1169 ['Demis Roussos']
# 1170 ['Ivory Coast']
# 1171 ['Balangir', 'Amaravila', 'india']
# 1172 ['PATTS', 'Jamiatu']
# 1173 ['one', 'Steven Moffat']
# 1174 ['Season 1', 'Pioneer Corporation']
# 1175 []
# 1176 ['Semnani', 'Assyrian Neo-Aramaic']
# 1177 ['Massimo Liverani', 'Abarth']
# 1178 ['Clan McDuck', 'Ludwig Von Draken']
# 1179 ['Foxconn', 'OS', 'PlayStation 3']
# 1180 ['Island of Bayou']
# 1181 ['Alexander Magleby', 'Dartmouth College']
# 1182 ['Thomy Bourdelle']
# 1183 ['Geneva']
# 1184 []
# 1185 ['WCSE-LP']
# 1186 ['Bangkok']
# 1187 ['400', 'Leona Baumgarter']
# 1188 ['Merritt Paulson']
# 1189 ['the BBC Multimedia', 'the The Last Resort (Doctor']
# 1190 ['Terry Gou']
# 1191 ['Rishikesh', 'Govinda']
# 1192 ['C++', 'Mac OS']
# 1193 ['Leonid Fedun']
# 1194 []
# 1195 ['Indianapolis', 'Colts', 'Carolina Panthers']
# 1196 ['David Ian Salter']
# 1197 ['Ivanpah Solar Power Facility']
# 1198 ['Nebraskan']
# 1199 ['The National Herald']
# 1200 ['Swedish']
# 1201 ['the Oahu Railway and Land Company', 'Jimmy Quillen']
# 1202 []
# 1203 ['Essex']
# 1204 ['Adam Ludwik Czartoryski']
# 1205 ['Hardie Gramatky']
# 1206 ['Splash', 'Rita Wilson']
# 1207 []
# 1208 ['Los Angeles Angels', 'Anaheim']
# 1209 ['New York']
# 1210 ['BBC']
# 1211 ['Hamas']
# 1212 []
# 1213 ['Chidambaram Subramaniam']
# 1214 ['Bacilli']
# 1215 ['Victor Hope', '2nd', 'Marquess', 'Linlithgow', 'British Gazette']
# 1216 []
# 1217 ['Clan McDuck']
# 1218 ['Scotland']
# 1219 ['Warner Bros.', 'Ridley Scott']
# 1220 ['Frank Thorne', 'Playboy']
# 1221 ['Kentaro Takekuma']
# 1222 ['Operation Autumn Clouds']
# 1223 ['Kiev']
# 1224 ['George Washington']
# 1225 ['Apple Productivity Experience Group']
# 1226 ['CTV']
# 1227 []
# 1228 ['Newman Haynes Clanton']
# 1229 ['Nevado de Toluca']
# 1230 ['India']
# 1231 ['Kaptaan', 'the Orient News']
# 1232 ['Gaza Strip', 'Operation Autumn Clouds']
# 1233 ['Henry E. Catto', 'Adrian A. Basora']
# 1234 ['Cascade Airways']
# 1235 ['Frank R', 'Lillie House', 'Chicago']
# 1236 []
# 1237 ['the SF Board of Supervisors']
# 1238 ['Tonight']
# 1239 ['the Boeing Field']
# 1240 ['Indiana', 'Iowa']
# 1241 ['the Bazaars of Hyderabad']
# 1242 ['Juelz Santana']
# 1243 ['2015', 'MLS', 'All-Star Game']
# 1244 ['Pontiac']
# 1245 ['News Corp.']
# 1246 ['Jonas Gahr Stre']
# 1247 ['Quezon']
# 1248 ['Lennon Legend', 'The Very Best of', 'John Lennon', 'DVD']
# 1249 ['Benjamin Spock']
# 1250 ['Atlant Moscow Oblast']
# 1251 ['BBC']
# 1252 ['Janaka Thissakuttiarachchi', 'Atisa Srijnana']
# 1253 []
# 1254 []
# 1255 ['E W Kemble']
# 1256 ['South']
# 1257 ['Battle of Fort stephenson']
# 1258 ['the American Mediterranean Sea', 'Entronque de Herradura']
# 1259 ["the Brown's Corners", 'Toronto', 'the George Karrys']
# 1260 ['Alcal de Henares']
# 1261 ['Guatemala']
# 1262 []
# 1263 ['Provisional Government of Saskatchewan']
# 1264 ['The Farmer Wants a Wife']
# 1265 ['Kentucky']
# 1266 ['US']
# 1267 []
# 1268 ['Jon Curran']
# 1269 ['Vietnam Airlines']
# 1270 ['Dartington College of Arts']
# 1271 ['New Yorker']
# 1272 ['Comcast SportsNet']
# 1273 []
# 1274 []
# 1275 ['PopCon', 'Louis Le Cocqq']
# 1276 ['Cyrus Mann']
# 1277 ['William Cushing']
# 1278 ["Filbert's Old Time Root Beer"]
# 1279 ['Primus', 'Comedy Central']
# 1280 ['Stars']
# 1281 []
# 1282 ['International Union of Anarchists']
# 1283 ['Hugh Hefner']
# 1284 ['WGBC']
# 1285 []
# 1286 ['Lancy', 'Geneva']
# 1287 []
# 1288 ['Ringgold High School', 'Pennsylvania']
# 1289 []
# 1290 ['Miguel de Cervantes', 'Francisco de Robles']
# 1291 ['Sino French War', 'Raoul Magrin-Vernerey']
# 1292 ['Honeybuns']
# 1293 ['Willis Sharpe Kilmer']
# 1294 ['Labour Party', 'Norway']
# 1295 ['Little Easton']
# 1296 ['Bellaire', 'Ohio']
# 1297 ['Fr.', 'Orlando']
# 1298 [' Mona Marshall']
# 1299 ['Warner Bros.', 'Christopher Franke', 'one']
# 1300 ['Memphis', 'Tenessee']
# 1301 ['Frontaccounting', 'GNU']
# 1302 ['Ralph']
# 1303 []
# 1304 ['Fr.', 'Agnel Stadium']
# 1305 ['Midhurst']
# 1306 ['the Location of the Peetz Table Wind Energy Center', 'Ben Nighthorse Campbell']
# 1307 ['Sarah Kazemy', 'the Cervelle de canut']
# 1308 ['Marv McFadden']
# 1309 ['Anne Hidalgo']
# 1310 []
# 1311 ['Poland']
# 1312 ['Ferris']
# 1313 ['Bob MacMillan']
# 1314 ['Luzhniki Stadium']
# 1315 ['Susanna Clarke', 'Northanger Abbey']
# 1316 ['Fergie Sutherland']
# 1317 ['Caterpillar', '797']
# 1318 []
# 1319 ['Breann McGregor']
# 1320 ['Pole', '1992', 'Canadian']
# 1321 ['the Democratic Party of US']
# 1322 ['Sentinel High School']
# 1323 ['Andrew Economos', 'Jerrel Jackson', 'first']
# 1324 ['OS']
# 1325 ['Monty Python']
# 1326 ['Columbus Crew SC']
# 1327 ['BBC News']
# 1328 ['Massachusetts']
# 1329 ['Alex Chalk']
# 1330 ['Theme Time Radio Hour', 'the The Times']
# 1331 ['Alexander Magleby']
# 1332 ['Montauk State Park']
# 1333 ['Maharashtra']
# 1334 ['Gyrfalcon', 'Michelle D. Johnson']
# 1335 ['Ike Clanton', 'Billy Clanton']
# 1336 ['Classical League', 'Probus']
# 1337 ['the National Collegiate Athletic Association']
# 1338 ['South Thailand']
# 1339 ['Edsel']
# 1340 ['CW']
# 1341 ['the Modoc plateau']
# 1342 ['Henry Morton Dexter', 'Jack McGregor']
# 1343 ['Jill Krementz', 'Edith Vonnegut']
# 1344 ['Toronto']
# 1345 ['Martin Molony']
# 1346 ['the Philip Novak', 'Timothy Morton']
# 1347 ['Yabanc Damat', 'UAE']
# 1348 []
# 1349 []
# 1350 ['Raymond Conner', 'Dennis Muilenburg']
# 1351 ['Jon Speelman', 'Karen Grigorian']
# 1352 []
# 1353 ['Zambia', 'North-Western Province', 'Zambia']
# 1354 []
# 1355 ['Franois Beauchemin', 'Nathan Dempsey']
# 1356 ['Hopje']
# 1357 ['Saint Joseph', 'Mary']
# 1358 ['Game Time']
# 1359 ['Desilu Productions']
# 1360 ['BMW']
# 1361 ['Samsu']
# 1362 ['Miluk']
# 1363 ['Simon Ferro']
# 1364 ['NYC']
# 1365 ['Camp Nou']
# 1366 []
# 1367 ['Humes High School']
# 1368 ['Edinburgh']
# 1369 ['Cologny', 'Geneva']
# 1370 []
# 1371 ['Dane County', 'Wisconsin']
# 1372 ['Sicklefin']
# 1373 ['Liverpool Institute High School for Boys']
# 1374 ['the Kira Plastinina', 'Sergey Ryazansky']
# 1375 ['Digitalb']
# 1376 ['Church of England']
# 1377 []
# 1378 ['Buccinidae', 'Buccinoidea']
# 1379 ['Steve Burke']
# 1380 ['Neil Cross']
# 1381 ['Plymouth Savoy']
# 1382 ['Nintendo Entertainment Planning & Development']
# 1383 ['first', 'Damon Hill']
# 1384 []
# 1385 ['the Model K', 'Herny Ford']
# 1386 ['Buckhurst Hill County High School', 'Elizabeth Rhuddlan']
# 1387 ['Queen Latifah', 'Arctic Tale']
# 1388 ['Kazuo Hirai']
# 1389 ['one', 'Benu']
# 1390 ['one', "St. Takla Haymanot's"]
# 1391 ['Dallas']
# 1392 ['Chordate']
# 1393 ['S. H. Kapadia']
# 1394 ['Garden', "L'Enfant"]
# 1395 ['Charles Willing Byrd']
# 1396 ['Ford F-Series', 'first']
# 1397 ['Omaha']
# 1398 ['Steven Palazzo']
# 1399 ["CTV Network's"]
# 1400 ['William Anthony', 'Philip W Pillsbury']
# 1401 ['Old Saybrook', 'Connecticut']
# 1402 ['Toru']
# 1403 ['Douglas Netter', 'Stewart Copeland']
# 1404 ['TNT', 'Prime Time Entertainment Network']
# 1405 ['WPC Dynamo Moscow']
# 1406 ['Maniac Magee']
# 1407 ['one', 'Frank Rogers']
# 1408 ['Ted Hartley']
# 1409 ['Ron Grainer']
# 1410 ['Henry Hyde']
# 1411 ['Montecito Inn']
# 1412 []
# 1413 ['Canal and River Trust']
# 1414 ['Urbain Le']
# 1415 ['Papus']
# 1416 ['Megabalanus']
# 1417 ['Barbara Ann Crancer']
# 1418 ['Sony Music Entertainment']
# 1419 []
# 1420 ['Marlboro Township', 'New Jersey']
# 1421 ['Ford Falcon Cobra']
# 1422 ['Saores de costa']
# 1423 ['CKFM-FM']
# 1424 []
# 1425 ['Chestnut']
# 1426 ['Jim Sasser', 'Mike McCurry']
# 1427 ['Chickasaw', '1736']
# 1428 ["Jerry Bock's"]
# 1429 ['Joe Jonas', 'Kevin Jonas']
# 1430 ['Miguel Garca Granados']
# 1431 ['Titus']
# 1432 ['Kimberly Stewart']
# 1433 ['the Journal of Cerebral Blood Flow & Metabolism']
# 1434 ['Micheal Santos', 'Wendy Jaquet']
# 1435 ['one', 'Chinese']
# 1436 ['Parliament Security Services']
# 1437 ['Carl McCall']
# 1438 ['Tuba Dei']
# 1439 ['Lake County', 'Oregon']
# 1440 ['CE Webber', 'Companion']
# 1441 ['New Mexico']
# 1442 ['National Collegiate Athletic Association']
# 1443 ['X']
# 1444 ['States Colleges', 'Universities']
# 1445 ['Martin prochzka']
# 1446 ['Shannon']
# 1447 ['Fergus McMaster']
# 1448 ['Nicholas S. Zeppos']
# 1449 ['United States']
# 1450 []
# 1451 ['Al Bano', 'Romina Power']
# 1452 []
# 1453 ['John McGeever', 'Ben Dreith']
# 1454 ['Marionette', 'Edwin']
# 1455 []
# 1456 ['Rolando Gomez']
# 1457 ['Noko']
# 1458 ['IBC']
# 1459 ['Fred Hoiberg']
# 1460 ['OSes']
# 1461 ['Michael Jeffery']
# 1462 ['Vangelis']
# 1463 ['Walt Disney', 'Mickey', 'Mellerdrammer']
# 1464 ['1955']
# 1465 ['Aubie']
# 1466 ['Lennier', 'Londo Mollari']
# 1467 ['Walter Scharf']
# 1468 []
# 1469 []
# 1470 ['Morocco']
# 1471 ['Denton', 'texas']
# 1472 ['Christians']
# 1473 ['first', 'Yankees']
# 1474 ['Andrew Peacock', 'Alexander Downer']
# 1475 ['UK']
# 1476 ['Companion (Doctor', 'Sarah Jane']
# 1477 []
# 1478 ['Robert Schenkkan']
# 1479 ['Westminister']
# 1480 ['Robert Nutting']
# 1481 []
# 1482 ['Beverly Hills', 'California']
# 1483 ['Marie Curie', 'Henri Becquerel']
# 1484 []
# 1485 ['Onedrive']
# 1486 ['Kazan']
# 1487 ['John Tortorella']
# 1488 ['Donna Shalala']
# 1489 []
# 1490 ['King County', 'Washington']
# 1491 ['Germany']
# 1492 ['Arctic Ocean', 'Laptev Sea']
# 1493 ['Lucrezia Tornabuoni', "Lorenzo de' Medici"]
# 1494 ['Nick Jonas', 'Kevin Jonas']
# 1495 ['the Northwest Indian War', 'Linda Hogan']
# 1496 []
# 1497 ['first']
# 1498 ['the Northwestern Hawaiian Islands']
# 1499 ['Ottawa Citizen']
# 1500 ['Trevor Peacock', ' ', 'Christophe Beck']
# 1501 ['Stanley Kubrick']
# 1502 ['Christopher Franke']
# 1503 ['Canada']
# 1504 ['Modern Architectural']
# 1505 ['the United World College of Costa Rica', 'United World Colleges']
# 1506 ['Michael Deeley', 'Warner Bros']
# 1507 ['Dean Ambrose']
# 1508 ['PCL']
# 1509 ['Cam Plante', 'Doug Acomb']
# 1510 ['Vesak']
# 1511 ['Continental Army']
# 1512 ['VP', 'Emilio Nez']
# 1513 ['Kaulahea']
# 1514 ['National Museum of Racing and Hall of Fame']
# 1515 ['Fort Gadsen']
# 1516 ['Phillippe Cabot', 'Columbia']
# 1517 ['Brower', 'Spring']
# 1518 ['Edinburgh']
# 1519 ['Protestant']
# 1520 []
# 1521 ['The Tony Randall Show']
# 1522 ['C++']
# 1523 ['Dale Mitchell', 'Master Card']
# 1524 ['Linn Ullmann']
# 1525 ['Karl Ewald Hasse']
# 1526 ['Paris']
# 1527 ['City of Angels']
# 1528 ['Playboy', '1954']
# 1529 ['Al Arabiya', '99']
# 1530 []
# 1531 ['Chip Hale']
# 1532 []
# 1533 ['Balangir']
# 1534 ['the National Hockey League']
# 1535 ['Ivanpah Solar Power Facility']
# 1536 ['Arlington']
# 1537 ['Jerry Tagge']
# 1538 []
# 1539 ['El Salvador', 'Sierra del Merendn']
# 1540 ['Elliot Goldenthal', 'Akiva Goldsman']
# 1541 ['England']
# 1542 []
# 1543 []
# 1544 ['First Legislative Assembly', 'Pradesh']
# 1545 ['Mauritius']
# 1546 ['Toronto']
# 1547 ['Microsoft Azure', 'Microsoft Surface']
# 1548 ['Microsoft Office Picture Manager', 'Google Clud Connect']
# 1549 ['Stan Lee']
# 1550 ['Luke Scott']
# 1551 ['Whihc', 'the Mizoram Legislative Assembly']
# 1552 ['Toronto']
# 1553 ['a Norbert Wiener Award for Social and Professional Responsibility']
# 1554 ['Ford Transit']
# 1555 ['Ferrel Harris', 'Unthank']
# 1556 ['French']
# 1557 ['Serbia', 'Dobinsk']
# 1558 ['Shaun Thong', 'Kaannder']
# 1559 ['Jason Carter', 'TNT']
# 1560 ['731', 'Lexington Avenue']
# 1561 ['UFC', '152']
# 1562 ['Iran']
# 1563 ['timothy l. woodruff']
# 1564 ['first', 'European', '1993', 'first', '1985', 'Portuguese']
# 1565 ['Vijay Chavan', 'Eka Lagnachi', 'Teesri Goshta']
# 1566 ['Paul Demiville', 'Sylvain']
# 1567 ['Ernest Rutherford']
# 1568 ['Liliya Lobanova', 'the Snake Island']
# 1569 ['Steve Winwood']
# 1570 ['Aishath Saffa']
# 1571 ['Jonathan Haskell']
# 1572 ['Dowra']
# 1573 ['Kerguelen Islands']
# 1574 ['Jevan Snead']
# 1575 ['Coconut']
# 1576 ['Jennifer Lopez', 'Randy Jackson']
# 1577 ['Society Islands']
# 1578 ['Hirokazu Tanaka']
# 1579 ['the Stony Brook University Hospital']
# 1580 ['Ryan Seacrest']
# 1581 ['Queen Latifah']
# 1582 ['Russell Davies']
# 1583 ['Forks Air Force Base']
# 1584 ['the Metro Blue Line', 'minnesota']
# 1585 ['Jamestown', 'Virginia']
# 1586 ['BJP']
# 1587 ['CNN']
# 1588 []
# 1589 ['the Naval Air Facility', 'Adak', 'Oahu Railway', 'Land Company']
# 1590 ['PRS']
# 1591 ['the Funky Lab Rat', 'North America']
# 1592 ['Dornier Aerodyne']
# 1593 ['Somerset Berkeley Regional']
# 1594 ['Lodaiska', 'David']
# 1595 ['Mohamedia', 'Tunisia']
# 1596 ['HBO', 'Playtone']
# 1597 ['Willem-Alexander', 'Fredis Refunjol']
# 1598 []
# 1599 ['Gettv']
# 1600 ['Austin College']
# 1601 ['Leallah']
# 1602 ['Ike Clanton', 'Tom McLaury']
# 1603 ['the Los Angeles World Airports']
# 1604 ['French', 'Antarctic Lands', 'the Karafarin Bank']
# 1605 ['Palo Alto', 'California', 'Adrian A. Basora']
# 1606 ['Denzil Minnan Wong']
# 1607 ['George Washington', 'John Forbes', 'British Army']
# 1608 ['Tokaj']
# 1609 ['Arizona', 'Sun Devils']
# 1610 ['john waldo']
# 1611 ['Cline Buckens', 'Richard']
# 1612 ['the Jefferson North Assembly']
# 1613 ['Stockholm']
# 1614 ['Robbie Diack']
# 1615 ['Air', 'Ryan Seacrest']
# 1616 []
# 1617 []
# 1618 ['Atamurat-Kerkichi Bridge']
# 1619 ['EMI']
# 1620 ['Besiktas JK']
# 1621 ['Air 2000']
# 1622 ['the Project Runaway Canada']
# 1623 ['Blue Jacket']
# 1624 ['Stan Lee']
# 1625 []
# 1626 ['Le Hong Phong']
# 1627 ['Sukhumbhand Paribatra']
# 1628 ['Picasso']
# 1629 ['Pat Kirkwood']
# 1630 []
# 1631 ['Pulau Ubin']
# 1632 ['Athens']
# 1633 ['Elders', 'World College']
# 1634 ['Uganda']
# 1635 ['Simon Fuller', 'Jennifier Lopez']
# 1636 ['BBC one', 'BBC']
# 1637 ['Jay Lane']
# 1638 ['London']
# 1639 ['Jared Kushner']
# 1640 ['Buzz Williams', 'the Marquette Golden Eagles mens']
# 1641 ["the US Navy Department's"]
# 1642 ['US', 'John G Schmitz']
# 1643 ['Whcih', 'Theme Time Radio Hour', 'Moondoc Matinee']
# 1644 ['Duncan U. Fletcher', 'Vanderbilt', 'Commodores']
# 1645 ['MSX', 'Language Integrated']
# 1646 ['United States', 'Indiana']
# 1647 ['Ford', 'Y-']
# 1648 ['Ellen Lundstrom']
# 1649 ['Plymouth High School for Girls', 'Devon county']
# 1650 ['Club One Air']
# 1651 ['Mika Hakkinen']
# 1652 ['the Pixar Image Computer']
# 1653 ['Cleopatra V', 'Ptolemy XIV', 'Egypt']
# 1654 []
# 1655 ['John Paul', 'second']
# 1656 ['Saleen', 'Raptor']
# 1657 ['Buckethead']
# 1658 ['Balanidae']
# 1659 ['US']
# 1660 ['Cologny', 'Chne-Bougeries']
# 1661 ['Kurt Rambis']
# 1662 ['Pacific Ocean']
# 1663 ['Graham Richardson', 'Bon McMullan']
# 1664 ['Ernest de Saisset']
# 1665 ['Giannis Alafouzos']
# 1666 ['Duboce Triangle']
# 1667 ['Mark Latham', 'Tim Mathieson']
# 1668 ['Berlin']
# 1669 []
# 1670 ['the Denver Broncos', 'the William C. Cramer']
# 1671 []
# 1672 ['Hiroji Kiyotake', 'Virtual Console']
# 1673 ['the Maine School of Science and Mathematics', 'Charles A. Boutelle']
# 1674 ['Harris County', 'Tandem Computers']
# 1675 ['Lysistrata']
# 1676 ['Elmo Futrell Jr']
# 1677 ['Ptolemy XIV', 'Ptolemy XII']
# 1678 ['Houston Astros']
# 1679 ['FremantleMedia']
# 1680 ['Stan Kroenke']
# 1681 ['Texas']
# 1682 ['one', 'Mntries']
# 1683 ['Red Willow Creek']
# 1684 ['Manu']
# 1685 ['Fazlur Rahman Khan']
# 1686 []
# 1687 ['Barbara']
# 1688 ['Ontario']
# 1689 ['Mrunalini Kunte']
# 1690 ['James W. Hyatt']
# 1691 ['Diana Taylor']
# 1692 ['Brandenton']
# 1693 ['Methodist Central Hall Westminster']
# 1694 ['Stephen Law']
# 1695 ['Jean Louis Arcand', 'Geneva']
# 1696 ['Korean']
# 1697 ['Hyderabad']
# 1698 ['Pyusawhti']
# 1699 ['Esther Alder', 'Geneva']
# 1700 ['San Francisco Giants']
# 1701 ['Marine Corps Air Station Kaneohe Bay', 'New Sanno']
# 1702 ['the USS Camp', 'Sturtevant']
# 1703 ['the Jerusalem Institute of Justice']
# 1704 ['Bodhi Elfman']
# 1705 ['First Legislative Assembly', 'Pradesh']
# 1706 ['Menlo Park', 'California']
# 1707 ['Fox Sports']
# 1708 ['David Paton']
# 1709 []
# 1710 ['Metro', 'Manila']
# 1711 ['Kafue', 'Shire']
# 1712 ['US', 'Brian Deegan', 'Harold Lyold']
# 1713 ['Loretta Ucelli', 'Democratic']
# 1714 ['Charlemagne', '3']
# 1715 ['Carolina Panthers', 'Indianapolis', 'Colts']
# 1716 ['Akan', 'Ghana']
# 1717 ['Midland']
# 1718 ['Rickenbacker']
# 1719 ['Deion', 'Hinkey']
# 1720 ['Liang Chow', 'Shawn Johnson']
# 1721 ['University of Miami']
# 1722 ['Linda Hogan', 'Holmes Colbert']
# 1723 ['Eliza Schneider']
# 1724 ['Dubai World Cup']
# 1725 ["Lawrence Okoye's"]
# 1726 ['Michigan']
# 1727 ['Walter Evans Edge', 'Miller']
# 1728 ['Benelux']
# 1729 ['Glasgow']
# 1730 ['PATTS College of Aeronautics', 'University of the Philippines']
# 1731 ['Steve Romeo']
# 1732 ['Islamic', 'Azad Uni', 'tehran', 'Jon Speelman']
# 1733 ['Ancient Rome']
# 1734 ['The Skeleton Dance']
# 1735 ['Agatha', 'Sicily']
# 1736 ['Laurence Mark']
# 1737 ['Ganz UV', 'Balaton']
# 1738 ['Greenpeace Nordic']
# 1739 []
# 1740 ['the Novair International Airways', 'Chevrolet', 'Caprice']
# 1741 []
# 1742 ['Harry Harlow']
# 1743 ['Panthera']
# 1744 ['France']
# 1745 ['California']
# 1746 ['Moondog Matinee', 'The TImes']
# 1747 ['FC', 'Barcelona']
# 1748 ['Church', 'Wellesley']
# 1749 ['Erastus Wiman']
# 1750 ['Amazon River', 'Arequipa Region']
# 1751 ['Elliott Bay']
# 1752 ['Marritt Cabal', 'Lucifer Hammer']
# 1753 ['Eric Roth']
# 1754 ['Geoffrey Burgon', 'Cinema International Corporation']
# 1755 ['Sherlock Holmes']
# 1756 ['Shahid Khan']
# 1757 ['Nihoa', 'Bird Island']
# 1758 ['Stoke City F.C.']
# 1759 []
# 1760 []
# 1761 []
# 1762 ['Jann Wenner']
# 1763 ['Thomas Franois Burgers', 'Johannes Gerhardus Strijdom']
# 1764 []
# 1765 ['Mauritius Broadcasting Corporation']
# 1766 ['Alan Kusov']
# 1767 ['Joseph Stiglitz']
# 1768 ['Piotr']
# 1769 ['Australian', 'Alps', 'Goolwa', 'Siyuth Australia']
# 1770 ['Trish Stratus', 'Christina Crawford']
# 1771 ['the Cavalcade of America', 'The United States Steel Hour']
# 1772 ['Victor Gunasekara', 'Anuruddha Ratwatte']
# 1773 ['Kris Kristofferson']
# 1774 ['England']
# 1775 ['Michael Springer', 'Syracuse University']
# 1776 ['Tom']
# 1777 ['washington']
# 1778 ['Players Championship']
# 1779 ['the United States', '1790']
# 1780 ['Collin County', 'Texas']
# 1781 ['Terminal Station', 'Chattanooga', 'University']
# 1782 ['2011', '12', 'FC', 'Svetlana']
# 1783 ['Chris Knierim']
# 1784 ['BMW', 'M40']
# 1785 ['Renault', 'first']
# 1786 ['2006', 'Oakland Raiders']
# 1787 ['Lovelace', 'John Robert']
# 1788 ['2008']
# 1789 ['Bertrada', 'Laon']
# 1790 ['Ganga']
# 1791 ['JSM Hopoer', 'Robert Valentine']
# 1792 ['Rob Patterson']
# 1793 ['Julie Gardner']
# 1794 ['Ford Air Transport Service']
# 1795 ['Oakland Athletics']
# 1796 ['Hynief']
# 1797 ['1972', 'Winter Olympics']
# 1798 ['Mt St.', 'Peter Churt']
# 1799 ['Super Mario Adventures']
# 1800 []
# 1801 ['Georgetown']
# 1802 []
# 1803 ['Warner Bros']
# 1804 ['Elizabeth Ann Seton', 'Pope Paul VI']
# 1805 ['Sao Paulo', 'Brazil']
# 1806 ['Ford', 'Ford Kansas Assembly']
# 1807 []
# 1808 ['David Gilmour', 'Pink Floyd']
# 1809 ['lori Black', 'Harvard Westlake', 'one']
# 1810 ['Yashpal Kapur', 'National Herald']
# 1811 ['2015', 'Duta FC']
# 1812 ['Toll Global Express', 'Siberia']
# 1813 ['McLean']
# ...
# 4434 ['Bataan']
# 4435 ['Gemini', 'Apollo 11']
# 4436 ['Joe McKeehen']
# 4437 ['US']
# 4438 ['Lohan Ratwatte']
# 4439 ['Tillingdale']
# 4440 []
# 4441 ['Andrew W. Lewis']
# 4442 ['Stephen Ambrose', 'Erik Bork']
# 4443 ['Mark Steven']
# 4444 ['Chicago', 'Northwestern Transportation']
# 4445 []
# 4446 ['John Tory']
# 4447 ['Firmicutes', 'Bacteria']
# 4448 ['Dzogchen Ponolop Rinpoche']
# 4449 ['Deborah Crombie']
# 4450 ['Bob Suci', 'the New England Patriots']
# 4451 ['Neil Cross', 'Russel Davies']
# 4452 []
# 4453 ['Paramount Television', 'Massachusetts']
# 4454 ['Sierra Nevada', 'Inyo National Forest']
# 4455 ['Windows RT', 'OS']
# 4456 []
# 4457 ['Audi']
# 4458 ['Linda Lee Cadwell']
# 4459 ['Carmela Soprano']
# 4460 ['Eurovision']
# 4461 ['Stan Lee', 'Jean Grey']
# 4462 ['2014', '4th']
# 4463 ['Marine Corps Air Station', 'Kaneohe Bay']
# 4464 ['Sanjay Gandhi']
# 4465 ['FC', 'the Cobham Training Centre']
# 4466 ['Cape Canaveral Air Force Station Launch Complex 5']
# 4467 ['David King-Wood', 'John Steed']
# 4468 ['Ikelenge  District', 'Mozambique']
# 4469 [' ', 'Giuseppe Bertello']
# 4470 ['Amalgamated Clothing Workers of America']
# 4471 ['the New York Post']
# 4472 ['Sony']
# 4473 ['Gustavo Rojas Pinilla']
# 4474 ['C++', 'Microsoft', 'Windows']
# 4475 ['Mouse Morris']
# 4476 ['Canada']
# 4477 ['George Madison']
# 4478 ['Judy  Hart  Angelo', 'Glen', 'Les Charles']
# 4479 ['Heydar']
# 4480 ['American Pekin', 'Ludwig Von Drake']
# 4481 ['Mark Sandrich']
# 4482 ['the Bank of Thailand']
# 4483 ['U.S.']
# 4484 ['one', 'Sanskrit']
# 4485 ['KTXY']
# 4486 ['Maria Sharapova', '2012']
# 4487 []
# 4488 ['Zambia']
# 4489 ['the Subang Interchange']
# 4490 ['Massachusetts']
# 4491 ['Naples']
# 4492 ['Microsoft']
# 4493 ['Royal Society', 'Trinity House']
# 4494 ['Williamsburg', 'Kansas']
# 4495 ['Daund Junction', 'INS Viraat']
# 4496 []
# 4497 ['Saint Petersburg', 'Moscow Railway']
# 4498 ['Eric Jendresen', 'John Orloff']
# 4499 ['Sony Music']
# 4500 ['Hylebos Creek']
# 4501 ['Arthur Gegei']
# 4502 ['Goya Award Winners']
# 4503 ['Cahora Bassa', "Batoka Gorge Hydroelectric Power Station's"]
# 4504 ['clearwater', 'minnesota']
# 4505 ['the Massachusetts Department of Transportation']
# 4506 []
# 4507 ['Surface']
# 4508 ['Grameen Bank']
# 4509 ['Earl B. Ruth']
# 4510 ['the Tim Mathieson', 'the Mike Kelly', 'Australian']
# 4511 ['Katima Mulilo Bridge']
# 4512 ['Black Grape Global']
# 4513 ['Nintendo eShop']
# 4514 ['Phil-Ellena']
# 4515 ['Lucius Crus']
# 4516 ['David Animle Hanses']
# 4517 ['MasterCard Centre']
# 4518 ['one', 'Lesley-Anne']
# 4519 ['NTSC', 'Ron Grainer']
# 4520 ['Kelly Brook', 'Rosie Huntington-Whiteley']
# 4521 ['Gerard Marino']
# 4522 ['jimmy Wales', 'Latvian']
# 4523 ['Siberia']
# 4524 []
# 4525 ['the San Francisco 49ers']
# 4526 ['Comedy Central']
# 4527 ['Pahang']
# 4528 []
# 4529 []
# 4530 ['Richard Marx']
# 4531 ['Rostock', 'Kaliningrad']
# 4532 ['Jay Gogue']
# 4533 ['Arabic']
# 4534 ['Dolley Madison', 'Militia']
# 4535 ['Middlesbrough F.C.', 'England']
# 4536 ['John Mc Ewen', 'Park Chunghee']
# 4537 []
# 4538 ['Regional Transit Authority of Southeast Michigan']
# 4539 ['Charles Goodell']
# 4540 ['jerry Tagge']
# 4541 ['Daund Junction', 'Ujjain Junction']
# 4542 []
# 4543 ['Paphos']
# 4544 ['Edward Joseph Schwartz  ', 'John Tower']
# 4545 ['Ricardo Alfonso Cerna  ', 'Apostolic Vicariate', 'El Petn']
# 4546 ['the Korean Peninsula', 'Krusty']
# 4547 ['Novair International Airways']
# 4548 ['Broadway']
# 4549 ['Bjelasnica']
# 4550 ['Slapstick']
# 4551 ['Christchurch', 'South Island']
# 4552 ['Oslo']
# 4553 ['Defenceman']
# 4554 ['Metal Mayhem']
# 4555 ['Francisco de Robles', 'Miguel de Cervantes']
# 4556 ['Purnima Banerjee']
# 4557 ['1984', 'the Soviet Union']
# 4558 ['Tulane Green']
# 4559 ['England']
# 4560 ['Uniontown', 'Keller']
# 4561 ['British Columbia']
# 4562 ['American Basketball League', '1996-1998']
# 4563 ['Omar D. Conger', 'Robert Sarvis']
# 4564 ['Emil Dean Zoghby']
# 4565 ["Louis Briere de I'Isle"]
# 4566 []
# 4567 ['John Fanning']
# 4568 ['Fort Lauderdale Strikers', '2015', 'Fort Lauderdale Strikers season']
# 4569 ['Pullaiahgaripalli']
# 4570 ['one', 'Germanic']
# 4571 ['Elasticsearch', 'the Yellow Claw DJ']
# 4572 ['Chicago']
# 4573 ['England']
# 4574 ['Massachusetts']
# 4575 ['Charles Willing', 'John Scott']
# 4576 ['Warner Bros. Television']
# 4577 ['Egypt Nanotechnology Center']
# 4578 ['Akio Morita']
# 4579 []
# 4580 ['Rheinmetall MG 60']
# 4581 ['K Fordice', 'Fitzwallace']
# 4582 ['the National Archaeological Museum of Florence']
# 4583 ['Barcelona FC']
# 4584 ['Frasier']
# 4585 ['Just Another day', 'Queen Latifah']
# 4586 ['Ferran Soriano']
# 4587 []
# 4588 ['Kurt Vonnegut Memorial', 'Louis LeCocq']
# 4589 ['Sean Young']
# 4590 ['Palm City', 'Florida']
# 4591 ['Purvis Eureka']
# 4592 ['Egyptian', 'Arabic', 'the Central Semitic Languages']
# 4593 ['Google Web Toolkit', 'Google']
# 4594 ['Huey, Dewey', 'Louie']
# 4595 ['Robin']
# 4596 ['Ben Wilson', 'American']
# 4597 ['Fr.']
# 4598 ['the North-South Transport Corridor', 'Mumbai Vadodara Expressway']
# 4599 ['isabelle caro']
# 4600 ['Crusade', 'Stewart Copeland']
# 4601 ['Katharevousa']
# 4602 ['the San Francisco Art Institute']
# 4603 ['Orson Welles']
# 4604 ['Karl Ewald Hasse']
# 4605 ['Sierra Nevada']
# 4606 ['Animal Kingdom']
# 4607 ['one', 'Pau Broca']
# 4608 ['Chordate']
# 4609 ['Asus', 'Sony']
# 4610 []
# 4611 []
# 4612 ['Daniel Gibson']
# 4613 ['Homestead Grays']
# 4614 ['Harvard-Westlake School', 'Henry E. Catto', '  ']
# 4615 []
# 4616 ['Euboea']
# 4617 ['Tamera Mowry', 'Voices']
# 4618 ['Cinema International Corporation']
# 4619 ['John W. Weeks']
# 4620 ['Democratic Party']
# 4621 ['American', 'Indianapolis', 'Colts', 'Michigan']
# 4622 ['Zambia', 'Mozambique']
# 4623 ['the American Magazine']
# 4624 ['Toll Global Express']
# 4625 ['140']
# 4626 ['Canton', 'Fribourg']
# 4627 ['the Royal Thai Army']
# 4628 []
# 4629 ['James', 'Killing is Out']
# 4630 ['PIAS Recordings', 'Wichita']
# 4631 ['Siddharta Shankar Ray', 'Kamla Beniwal']
# 4632 ['Lucas Oil Stadium']
# 4633 ['Atlantic']
# 4634 []
# 4635 ['Irving Chernev', 'Karen Grigorian']
# 4636 ['Lake Victoria']
# 4637 ['Ivan Fomin']
# 4638 ['Tupac']
# 4639 ['Zuo Zongtang']
# 4640 ['Salsette Island', 'India']
# 4641 ['Moscow', '2011-12', 'FC', 'Moscow']
# 4642 ['Panionios G.S.S.']
# 4643 ['PM', 'William Deane']
# 4644 ['Garry Unger']
# 4645 ['John Thompson Mason', 'Martino Martini']
# 4646 ['France']
# 4647 ['Mona Lisa', 'Louvre']
# 4648 ['Dallas', 'Cowboys']
# 4649 ['one', 'Ludacris']
# 4650 ['Young Life']
# 4651 ['Christian', 'Turk']
# 4652 ['Persona']
# 4653 ['Mark Stevens']
# 4654 ['Josh Groban']
# 4655 ['Julian Gingell', 'Simon Fuller']
# 4656 ['WBCQ-FM']
# 4657 ['British Columbia']
# 4658 ['Latin', 'Sovereign Military Order of Malta']
# 4659 ['Lake Uniamsi']
# 4660 ['A Barrel of Laughs', 'Vale']
# 4661 ['Carlene Carter']
# 4662 ['Harlan Mathews', 'Richard Meriil Atkinson']
# 4663 ['Wisconsin']
# 4664 ['Jovan Vladimir']
# 4665 ['Viacom Productions']
# 4666 ['West Africa']
# 4667 ['Shimsa Plateau']
# 4668 ['British Gazette']
# 4669 ['spanish', 'Francisco de Robles']
# 4670 ['Chicago', 'Los Angeles Clippers']
# 4671 ['one', 'Russia']
# 4672 ['Bruce Lee']
# 4673 ['Desilu Productions']
# 4674 ['Cyril Hume']
# 4675 ['Central', '2013']
# 4676 []
# 4677 ['Robin Kovacs']
# 4678 ['George Robert Andrews']
# 4679 ['Karl Marx']
# 4680 ['Brain Graden', 'Primus']
# 4681 ['Diprotodontia']
# 4682 ['Rome']
# 4683 ['Edward Douglass White', 'Charles Phelps Taft II']
# 4684 []
# 4685 ['Perianne Jones']
# 4686 ['John Smith Griffin']
# 4687 ['Barefoot Trinitarians']
# 4688 ['the Vandenberg Air Force Air']
# 4689 ['Stephanie Rice', 'Australia', '2008']
# 4690 ['Spanish']
# 4691 ['Oprah Winfrey Network', 'U.S. TV']
# 4692 ['Venkatraman Ramakrishnan']
# 4693 ['Geography Club', 'Seattle Great Wheel']
# 4694 ['Massachusetts', 'Everybody Knows Your Name']
# 4695 ['George Arceneaux']
# 4696 ['Mikhail Pashnin']
# 4697 []
# 4698 ['Gough Whitlam']
# 4699 ['CBS']
# 4700 ['Guerrini', 'Massimo Liverani']
# 4701 ['California']
# 4702 ['one', 'World War II']
# 4703 ['Rev']
# 4704 ['Erich Bagge']
# 4705 ['Japan']
# 4706 ['Trn Vit Hng']
# 4707 ['Albert Kwesi Ocran']
# 4708 ['Sony Financial']
# 4709 ['William L. Dayton']
# 4710 ['Dick Lundy']
# 4711 ['Madagascar']
# 4712 []
# 4713 ['Microsft Azure', 'OneDrive']
# 4714 ['Vancouver Whitecaps FC']
# 4715 []
# 4716 ['The Producers (', '2005']
# 4717 ['Michael Deeley', 'Ridley Scott']
# 4718 ['Denver']
# 4719 ['American', 'English']
# 4720 ['Teriitaria II']
# 4721 ['Schally', 'WTUL']
# 4722 ['EXXV-TV']
# 4723 []
# 4724 []
# 4725 ['Trinity School', 'Brentwood', 'Buckhurst Hill County High School']
# 4726 ['Mid Wales']
# 4727 ['Fox Broadcasting Company']
# 4728 ['C++']
# 4729 ['Rickenbacker']
# 4730 ['Henry Howard', 'Northampton Earl']
# 4731 ['Diprotodontia', 'Chordate']
# 4732 ['U.S.', 'Texas', 'U.S.', '59']
# 4733 ['North-Western Province', 'Zambia', 'Ikelenge  District']
# 4734 ['Phoenix Suns']
# 4735 ['Nice']
# 4736 ['John Tyler', 'Sr']
# 4737 ['Ethiopia']
# 4738 ['Ulrich II', 'East Frisia']
# 4739 []
# 4740 []
# 4741 ['Liverpool']
# 4742 ['San Francisco Art Institute']
# 4743 ['New York', 'Tremount Avenue']
# 4744 ['2016', 'Fort Lauderdale Strikers']
# 4745 ['the Michael Marder', 'Tigran Petrosian']
# 4746 ['Bruce Lee']
# 4747 ['the Turkish Handball Super League']
# 4748 ['Berkshire']
# 4749 ['Dan Daoust', 'Don Ashby']
# 4750 ['the USS Tillamook', 'Seattle']
# 4751 ['Micheal Powell', 'Syracuse University Press']
# 4752 ['Chiva', 'Ford Falcon Cobra']
# 4753 ['Whihc', 'McDonnell Douglas', 'Delta 3']
# 4754 ['Barbara Bush']
# 4755 ['Rosie Huntington Whiteley']
# 4756 ['the Neungin High School', 'Sylvain Lvi']
# 4757 ['European', 'Oulu', 'one']
# 4758 ['Arkansas']
# 4759 ['Medininagar']
# 4760 ['Julian Leow Beng Kim']
# 4761 ['Chess', 'Monthly']
# 4762 ['Dick Redding']
# 4763 ['Robin Kovacs', 'Bob MacMillan']
# 4764 ['the National Collegiate Athletic Association']
# 4765 []
# 4766 []
# 4767 []
# 4768 ['Fluidinfo', 'PostgreSQL']
# 4769 ['one', 'Chicago', 'St Paul', 'Minneapolis', 'Omaha']
# 4770 ['the University of Oxford']
# 4771 ['Fort Heath', 'Joesph Story']
# 4772 ['German', 'Europe']
# 4773 []
# 4774 ['Serbian', 'Titieca', 'Werner Heisenberghttp://dbpedia.org/resource/Werner_Heisenberg']
# 4775 ['Randy Jackson', 'Simon Fuller']
# 4776 ['ARM']
# 4777 ['vineyards', 'Mt.']
# 4778 ['Time', 'PlayStation 2']
# 4779 ['Western']
# 4780 ['Henry Knox', 'Continental Artillery Regiment']
# 4781 ['Josh Friedman', 'Terminator Genisys']
# 4782 []
# 4783 ['Hirokazu Tanaka']
# 4784 ['Brian Moriarty']
# 4785 ['the Michael M. Sears', 'the Burro Flats Painted Cave']
# 4786 ['the Continental Army']
# 4787 ['Mongolian', '2004']
# 4788 ['Dalek']
# 4789 ['Citizen Kane', 'Gregg Toland']
# 4790 ['Bruce Beutler']
# 4791 ['Trump Entertainment Resorts', 'Maryanne Barry']
# 4792 ['Barasat']
# 4793 ['Alan Freeman Days']
# 4794 ['Janice Soprano', 'Soprano']
# 4795 ['John muir', 'one', 'first', 'Mt']
# 4796 ['England', '21', 'Aston Villa F.C season']
# 4797 ['Bruce Timm']
# 4798 ['AMC Gremlin', 'Volkswagen']
# 4799 ['Freescale Semiconductor', 'Marvell Technology Group']
# 4800 ['Magnolia Plantation']
# 4801 []
# 4802 ['Judy Garland']
# 4803 ['Perkins']
# 4804 ['1967', 'Mexican Grand Prix']
# 4805 ['Chaeng Watthana Govt Complex']
# 4806 ['Sacramento']
# 4807 ['Hellenic Naval Academy']
# 4808 ['BASIC and Language Integrated']
# 4809 ['London']
# 4810 ['The Palace of Auburn', 'Stan Van Gundy']
# 4811 ['Wallace', 'Gromit']
# 4812 []
# 4813 ['Alvin Bell', 'Charles Plosser']
# 4814 ['Michael Jackson']
# 4815 []
# 4816 ['The Motorcycle Diaries']
# 4817 ['Terminator', 'Terminator 2:', 'Judgment Day']
# 4818 ['Christen-Democratisch en Vlaams']
# 4819 ['Juno']
# 4820 ['PlayN']
# 4821 ['Steven Moffat']
# 4822 ['BBC Two']
# 4823 ['Tupelo', 'Mississippi']
# 4824 ['Walt Disney Records']
# 4825 ['cohoes', 'NY']
# 4826 ['the Columbia University', 'William Campbell']
# 4827 ['Maharashtran']
# 4828 ['Cinema International Corporation']
# 4829 ['Ashot Grashi']
# 4830 ['Ae Fond Kiss', 'Halloween']
# 4831 ['Steve Buyer']
# 4832 ['Steven Moffat']
# 4833 ['Michael Schumacher', 'Pole', '1994', 'Spanish']
# 4834 ['Shaheed Minar', 'Kolkata']
# 4835 ['Canada']
# 4836 ['Batman Live']
# 4837 ['San Salvador Island', 'Bahamas']
# 4838 ['Audi India Correct Question']
# 4839 ['NASA', 'Gemini']
# 4840 ['South Side', '400']
# 4841 ['Michelle D. Johnson', 'United States Air Force Academy']
# 4842 ['Pittsburgh']
# 4843 ['Stanlee', 'the Tales of Suspense']
# 4844 ['Middlesbrough FC']
# 4845 ['National Basketball Association']
# 4846 ['Cubic Hermite']
# 4847 ['Dallas']
# 4848 ['bloomington']
# 4849 ['Paradise']
# 4850 ['Copley Medal']
# 4851 ['South Korean', '1992']
# 4852 ['Stanford', 'Gerald Reaven']
# 4853 ['Mark davis', 'O.co Colliseum']
# 4854 ['BBC', 'Sarah Jane']
# 4855 ['first', 'Autodromo Enzo e Dino Ferrari']
# 4856 ['Canada']
# 4857 ['Novelas Ejemplares']
# 4858 ['P. Sathyanarayanan']
# 4859 ['Northeast']
# 4860 ['Leuven']
# 4861 ['New York']
# 4862 ['HBO', 'Erik Bork']
# 4863 ['Fr.', 'Jamiatu', 'Mindanao']
# 4864 ['Paul Dini']
# 4865 ['Atlantic']
# 4866 ['Rolv Erik Ryssdal']
# 4867 ['Middlesbrough F.C.']
# 4868 ['Marquette', '09', '10', '13', '14']
# 4869 ['EMMS']
# 4870 ['Moscow', 'Ilya Savelev']
# 4871 ['Taekwondo']
# 4872 ['Championship']
# 4873 ['Winnipeg River']
# 4874 ['Supachai Somcharoen']
# 4875 ['Bill Peters']
# 4876 ['Grand Bahama']
# 4877 ['Battle Chess']
# 4878 ['Virginia']
# 4879 []
# 4880 ['Kobalt Label Services']
# 4881 ['CFRB']
# 4882 ['one', 'Warner Bros. Animation']
# 4883 ['Namt', 'Paul Demiville']
# 4884 ['Kaliningrad', 'Gdask']
# 4885 ['Alexander Lippisch']
# 4886 ['Thorington', ' David Lewis']
# 4887 ['NASA']
# 4888 ['Gibson Les Paul']
# 4889 ['Castro District', 'Haight-Ashbury']
# 4890 ['UK']
# 4891 ['Moondog Matinee', 'Motorpsycho Nitemare']
# 4892 ['Schutzstaffels']
# 4893 ['Kron Ngoy']
# 4894 ['William W Brien']
# 4895 ['iOS']
# 4896 ['1982']
# 4897 ['one', 'Carl Sanders']
# 4898 ['William C P']
# 4899 ["St. Peter's Basilica"]
# 4900 ['Stephen E. Ambrose', 'DreamWorks Television']
# 4901 []
# 4902 ['FedExField']
# 4903 ['Edsel']
# 4904 ['the Sierra Madre de Chiapas']
# 4905 ['Cherokee']
# 4906 []
# 4907 ['Mazes', 'BBC']
# 4908 ['Doonesbury']
# 4909 []
# 4910 ['Charles Phelps', 'Taft II', 'Robert A. Taft']
# 4911 ['Giorgos Kaminis']
# 4912 ['Linda Jenness']
# 4913 ['the Plymouth Savoy', 'the NorthSouth Transport Corridor']
# 4914 []
# 4915 ['Primate']
# 4916 ['Willem-Alexander', 'Netherlands']
# 4917 ['Chelsea F.C.']
# 4918 ['Israelite', 'United Monarch']
# 4919 ['PWD']
# 4920 ['the King County', 'Washington', 'Phil Lumpkin']
# 4921 ['Old Lyme', 'Connecticut']
# 4922 ['OS', 'Microsoft', 'Windows', 'Mac OS']
# 4923 ['Ike Clanton']
# 4924 ['Indian', '2004', 'Andhra Pradesh']
# 4925 ['the Palang Dharma Party', 'Miao']
# 4926 ["the Brown's Corners", 'Krista Kelly']
# 4927 []
# 4928 []
# 4929 ['Brown']
# 4930 ['Solon', 'Spencer Beman']
# 4931 ['first', 'the 1967 Mexican Grand Prix', '1971', 'US']
# 4932 ['Sam Sen Railway Station']
# 4933 ['Newcastle']
# 4934 ['Tehran']
# 4935 []
# 4936 ['Mickey', 'Mellerdrammer', "Tommy Tucker's"]
# 4937 ['Quich Department', 'one']
# 4938 ['Apollo 11', 'Gemini']
# 4939 ['Seattle Great Wheel']
# 4940 ['Harvard-Westlake School', 'Alta Mesa Memorial Park']
# 4941 []
# 4942 ['Russian']
# 4943 ['Wizards']
# 4944 ['Arkansas']
# 4945 ['Ceratosoma']
# 4946 ['Riley Reid', 'Holmes Colbert']
# 4947 ['Girls']
# 4948 ['Indira Gandhi']
# 4949 ['the Manhattan Project']
# 4950 []
# 4951 ['Ohio']
# 4952 []
# 4953 ['American', 'Bobby Hoppe']
# 4954 ['Jimmy']
# 4955 ['Ted Williams', 'Leonard Memorial ridge']
# 4956 ['Michaelhouse']
# 4957 ['first', 'the Yosemite Park']
# 4958 ['Levant']
# 4959 ['Awakening and fifety', 'five days']
# 4960 ['Clan McDuck', 'Huey', 'Dewey', 'Louie']
# 4961 ['Ennejma Ezzahra', 'Boga']
# 4962 ['Charles Gordon']
# 4963 ['Le Cirque', 'Maryanne Trump']
# 4964 ['Toronto']
# 4965 ["Stanley Kubrick's", 'Laurie Johnson']
# 4966 ['Haight-Ashbury', 'USS Kittiwake']
# 4967 ['motorpsycho Nitemare']
# 4968 ['Erik Jendresen', 'HBO']
# 4969 ['Battle of the Bulge']
# 4970 ['Colin Powell']
# 4971 ['The Ultimate Fighter: Team Rousey', 'Team Tate']
# 4972 ['Alexa Scimeca']
# 4973 ['South African', '11e', 'RENFE', '333']
# 4974 ['Erich Bagge']
# 4975 ['NASA', 'Apollo 11']
# 4976 ['Ape', 'Primate']
# 4977 ['Goethe Prize']
# 4978 []
# 4979 ['William Henry Harrison Tomb State Memorial', 'John Scott Harrison']
# 4980 ['Muhammad Yunus']
# 4981 ['Saunders']
# 4982 ['Miao']
# 4983 []
# 4984 ['the BBC Multimedia', 'Visions']
# 4985 ['Donna Shalala']
# 4986 ['Kerguelen', 'French']
# 4987 ['Weber Thompson']
# 4988 ['Edith Vonnegut']
# 4989 ['Iyoas']
# 4990 ['WCW Mayhem']
# 4991 ['RCA']
# 4992 ['Brazilian', 'Nick Diaz']
# 4993 ['Amstelveen']
# 4994 ['Choctaw']
# 4995 ['Larry J. Franco']
# 4996 ['J. Michael Stroczynski', 'TNT']
# 4997 ['Varsity Stadium']
# 4998 ['NY Rangers', 'Robin Kovacs']
# 4999 ['Marquette Golden Eagles', '2008-09', 'Marquette Golden Eagles']

# %%
with open('results/NER_spacy.txt', 'rt', encoding='utf-8') as f:
    entities_spacy_sm = f.read().splitlines()
    
with open('results/NER_spacy_2.txt', 'rt', encoding='utf-8') as f:
    entities_spacy_md = f.read().splitlines()

# %%
n = 5000

ner_sm = [['']]*n
ner_md = [['']]*n

for entity in entities_spacy_sm:
    idx, ent = entity.split(',', 1)
    if ner_sm[int(idx)] == ['']:
        ner_sm[int(idx)] = [entity]
    else:
        ner_sm[int(idx)].append(entity)
        
for entity in entities_spacy_md:
    idx, ent = entity.split(',', 1)
    if ner_md[int(idx)] == ['']:
        ner_md[int(idx)] = [entity]
    else:
        ner_md[int(idx)].append(entity)

# %%
print(ner_sm[0:10])
print(ner_md[0:10])
# Out:
# [['0,Bill Finger'], ['1,Selwyn Lloyd'], [''], ['3,Mumbai'], ['4,Roberto Clemente Bridge'], ['5,XIII Theos Philopator', '5,Cleopatra V'], ['6,Li Si'], ['7,PAvel Moroz', '7,the Yakov Estrin'], ['8,Broadmeadows', '8,Victoria'], ['9,ASC Creative Services']]
# [['0,Bill Finger'], ['1,Selwyn Lloyd'], ['2,Gestapo'], ['3,Mumbai'], ['4,Roberto Clemente Bridge'], ['5,ptolemy XIII Theos Philopator', '5,Cleopatra V'], ['6,Li Si'], ['7,PAvel Moroz', '7,Yakov Estrin'], ['8,Broadmeadows, Victoria'], ['9,ASC Creative Services']]

# %%
ner_sm_md = ['']*n

for i in range(0, n):
    if len(ner_sm[i])==len(ner_md[i]):
        if all(elem in ner_md[i] for elem in ner_sm[i]) == True:
            ner_sm_md[i] = ner_sm[i]
        else:
            if ner_sm[i] == ['']:
                ner_sm_md[i] = ner_md[i]            
            else:
                ner_sm_md[i] = ner_sm[i]            
    elif len(ner_sm[i])<len(ner_md[i]):
        if all(elem in ner_md[i] for elem in ner_sm[i]) == True:
            ner_sm_md[i] = ner_md[i]           
        else:
            if ner_sm[i] == ['']:
                ner_sm_md[i] = ner_md[i]            
            else:
                inter = list(set(ner_sm[i]) & set(ner_md[i]))
                dif = list(set(ner_sm[i]) - set(ner_md[i]))
                ner_sm_md[i] = inter+dif
                
    elif len(ner_sm[i])>len(ner_md[i]):
        if all(elem in ner_sm[i] for elem in ner_md[i]) == True:
            ner_sm_md[i] = ner_md[i]
        else:
            if ner_md[i] == ['']:
                ner_sm_md[i] = ner_sm[i]
            else:
                inter = list(set(ner_sm[i]) & set(ner_md[i]))
                dif = list(set(ner_md[i]) - set(ner_sm[i]))
                ner_sm_md[i] = inter+dif
# Out:
# [['0,Bill Finger'], ['1,Selwyn Lloyd'], ['2,Gestapo'], ['3,Mumbai'], ['4,Roberto Clemente Bridge'], ['5,XIII Theos Philopator', '5,Cleopatra V'], ['6,Li Si'], ['7,PAvel Moroz', '7,the Yakov Estrin'], ['8,Broadmeadows, Victoria'], ['9,ASC Creative Services'], ['10,Ernest Rutherford', '10,Charles Drummond Ellis'], ['11,REP Parasol'], ["12,the Monroe Carell Jr. Children's Hospital", '12,Vanderbilt', '12,the Duncan U. Fletcher'], ['13,Nader Guirat', '13,Josef Johansson'], [''], ['15,HBO'], ['16,Nikolai Morozov', '16,Stanislav Morozov'], ['17,Abhijit Kunte', '17,Kasparov'], ['18,the MSX Basics'], ['19,seasons', '19,Ronaldo'], ['20,SamurAbsheron', '20,Anar Salmanov'], ['21,2nd Foreign Infantry Regiment'], ['22,3Sub'], ['23,Kevin Jonas', '23,Joe Jonas'], ['24,Timm Gunn', '24,Sunrise (HIMYM'], ['25,O.co Coliseum'], ['26,Rishkiesh'], ['27,one'], ['28,PhDs', '28,National Medal of Science'], ['29,Aston Villa 2000-02 season', '29,Middlesbrough F.C.', '29,2009-10'], ['30,William Harper'], ['31,PCL'], ['32,Kevin Jonas', '32,Jonas'], ['33,Sagan'], ['34,Rosemont', '34,Illinois'], ['35,Greenup County High School'], ['36,Bobby Hoppe'], ['37,The Second Coming'], ['38,Miguel de Cervantes'], [''], ['40,Berkshire'], ['41,Crystal Harris'], ['42,Essex'], ['43,Niederkirchnerstrae'], ['44,Steven Moffat'], ['45,Dagenham', '45,Ford'], ['46,San Francisco International Airport'], ['47,San Diego'], ['48,the Sarah Walker', '48,the Trinity School, Brentwood'], [''], ['50,Johann Gottfired', '50,Urbain'], ['51,Elmer Burkett'], ['52,Hensley Meulens', '52,Steve Ontiveros'], ['53,Lucy Sullivan'], ['54,Society Islands', '54,Faaa'], ['55,1997', '55,94'], ['56,Richard Winn'], ['57,Sherlock', '57,Arthur Levinson'], ['58,Master Card', '58,Sam Carrrick'], ['59,Fremantle Media'], ['60,South Loop Printing House District'], ['61,Visual Studio'], ['62,Croatia'], ['63,Newin Chidchob'], ['64,Dave Bing', '64,Ron Reed'], ['65,Galileo Galilei'], [''], ['67,Elizabeth'], ['68,OneDrive'], ['69,Washington, D.C.'], ['70,Jordan', '70,one'], ['71,Robert Witherspoon'], [''], ['73,Oj'], ['74,Allen Walker'], ['75,Publius Servilius Vatia Isauricus', '75,Marcus Calpurnius'], ['76,chowdhury'], ['77,Mount Hoffmann'], ['78,Indiana'], [''], ['80,the North Country', '80,the Moondog Matinee'], ['81, ', '81,April Stewart', '81,Mona Marshall'], ['82, ', '82,Trinity House'], ['83,Reza Amrollahi', '83,Iran'], ['84,Zaman Shah Durrani', '84,Salahuddin'], ['85,Roh Tae Woo', '85,Lee Leffingwell'], ['86,Rosemarie DeWitt'], ['87,Sapindales'], ['88,Lewis Hamilton'], ['89,Giorgos Kaminis'], ['90,Michael'], ['91,Berlin'], ['92,India'], ['93,The Simpsons Ride'], ['94, '], ['95,Mams'], ['96,Playboy Enterprises'], ['97,Gwo Ka', '97,Western Africa'], [''], ['99,Visual Studio'], ['100,Wyandot'], ['101,the Michigan Stadium'], ['102,David Johnston'], ['103,Francois Marie Le', '103,Marchand de Lignery'], ['104,Myntdu'], ['105,London'], ['106,Al Gore', '106,2000', '106,Ann Lewis'], ['107,Darius I'], ['108,Kim Sawchuk', '108,the Airtours International Airways'], ['109,Antonio Giannini'], ['110,David Scherman'], ['111,Outlook.com', '111,OneDrive'], ['112,Rouen Business School'], ['113,the Korean Minjoo Party'], ['114,one', '114,McDonnell Aircraft'], ['115,Gales Ferry', '115,Connecticut'], ['116,Detroit', '116,MI'], ['117,english', '117,under twenty'], ['118,Helsinki', '118,one', '118,Danish'], ['119,Timmy Time'], ['120,Fort Heath'], ['121,Harding', '121,Lyons'], ['122,Rosario', '122,Santa Fe'], [''], ['124,New Jersey', '124,Oahu Railway and Land Company', '124,Chris Myers'], [''], ['126,Brian Graden', '126,Isaac Hayes'], [''], ['128,Steve Sampson', '128,Santa Clara'], ['129,Schibsted'], ['130,WPC Dynamo Moscow', '130,Tigran Petrosian'], ['131,Joan Laporta'], ['132,four'], ['133,Pong Pha'], ['134,the Angela Trusty', '134,Charles Ayres'], ['135,Conglomerate'], ['136,Lagnacha'], ['137,English'], ['138,El Sobrante', '138,California'], ["139,the Nickname of Daniel O'Regan"], ['140,Solidus'], [''], [''], ['143,Tim Gunn', '143 ...

# %%
### compare only sm predictions

match, partial, less, more, none_match, none_less, none_more, predicted = compare_predictions(real, ner_sm)
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# TRUE:  ['0,bill finger']
# PRED:  ['0,bill finger']
# SAME:  ['0,bill finger']
# TRUE:  ['1,selwyn lloyd', '1,winston churchill']
# PRED:  ['1,selwyn lloyd']
# LESS:  ['1,selwyn lloyd']
# TRUE:  ['2,gestapo']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['2,gestapo']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['3,mumbai north']
# PRED:  ['3,mumbai']
# SAME:  []
# NONE_TRUE_EQUAL:  ['3,mumbai north']
# NONE_PRED_EQUAL:  ['3,mumbai']
# TRUE:  ['4,roberto clemente bridge']
# PRED:  ['4,roberto clemente bridge']
# SAME:  ['4,roberto clemente bridge']
# TRUE:  ['5,ptolemy xiii theos philopator', '5,cleopatra v']
# PRED:  ['5,xiii theos philopator', '5,cleopatra v']
# SAME:  ['5,cleopatra v']
# PARTIAL:  ['5,cleopatra v']
# TRUE:  ['6,li si']
# PRED:  ['6,li si']
# SAME:  ['6,li si']
# TRUE:  ['7,pavel moroz', '7,yakov estrin']
# PRED:  ['7,pavel moroz', '7,the yakov estrin']
# SAME:  ['7,pavel moroz']
# PARTIAL:  ['7,pavel moroz']
# TRUE:  ['8,broadmeadows, victoria']
# PRED:  ['8,broadmeadows', '8,victoria']
# NONE_TRUE_MORE:  ['8,broadmeadows, victoria']
# NONE_PRED_MORE:  ['8,broadmeadows', '8,victoria']
# TRUE:  ['9,asc creative services']
# PRED:  ['9,asc creative services']
# SAME:  ['9,asc creative services']
# TRUE:  ['10,ernest rutherford', '10,charles drummond ellis']
# PRED:  ['10,ernest rutherford', '10,charles drummond ellis']
# SAME:  ['10,ernest rutherford', '10,charles drummond ellis']
# TRUE:  ['11,rep parasol']
# PRED:  ['11,rep parasol']
# SAME:  ['11,rep parasol']
# TRUE:  ["12,monroe carell jr. children's hospital", '12,vanderbilt', '12,duncan u. fletcher']
# PRED:  ["12,the monroe carell jr. children's hospital", '12,vanderbilt', '12,the duncan u. fletcher']
# SAME:  ['12,vanderbilt']
# PARTIAL:  ['12,vanderbilt']
# TRUE:  ['13,josef johansson', '13,nader guirat']
# PRED:  ['13,nader guirat', '13,josef johansson']
# SAME:  ['13,nader guirat', '13,josef johansson']
# TRUE:  ['14,dr who confidential', '14,the sara jane adventure']
# PRED:  ['']
# NONE_TRUE_LESS:  ['14,dr who confidential', '14,the sara jane adventure']
# NONE_PRED_LESS:  ['']
# TRUE:  ['15,hbo']
# PRED:  ['15,hbo']
# SAME:  ['15,hbo']
# TRUE:  ['16,stanislav morozov', '16,nikolai morozov']
# PRED:  ['16,nikolai morozov', '16,stanislav morozov']
# SAME:  ['16,nikolai morozov', '16,stanislav morozov']
# TRUE:  ['17,abhijit kunte', '17,kasparov']
# PRED:  ['17,abhijit kunte', '17,kasparov']
# SAME:  ['17,abhijit kunte', '17,kasparov']
# TRUE:  ['18,outlook', '18,msx basics']
# PRED:  ['18,the msx basics']
# NONE_TRUE_LESS:  ['18,outlook', '18,msx basics']
# NONE_PRED_LESS:  ['18,the msx basics']
# TRUE:  ['19,ronaldo']
# PRED:  ['19,ronaldo']
# SAME:  ['19,ronaldo']
# TRUE:  ['20,samurabsheron channel', '20,anar salmanov']
# PRED:  ['20,samurabsheron', '20,anar salmanov']
# SAME:  ['20,anar salmanov']
# PARTIAL:  ['20,anar salmanov']
# TRUE:  ['21,2nd foreign infantry regiment']
# PRED:  ['21,2nd foreign infantry regiment']
# SAME:  ['21,2nd foreign infantry regiment']
# TRUE:  ['22,sr class 3sub']
# PRED:  ['22,sr', '22,3sub']
# NONE_TRUE_MORE:  ['22,sr class 3sub']
# NONE_PRED_MORE:  ['22,sr', '22,3sub']
# TRUE:  ['23,kevin jonas', '23,joe jonas']
# PRED:  ['23, ', '23,kevin jonas', '23,joe jonas']
# MORE:  ['23,kevin jonas', '23,joe jonas']
# TRUE:  ['24,sunrise (himym)', '24,timm gunn']
# PRED:  ['24,timm gunn', '24,sunrise (himym']
# SAME:  ['24,timm gunn']
# PARTIAL:  ['24,timm gunn']
# TRUE:  ['25,o.co coliseum']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['25,o.co coliseum']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['26,rishkiesh']
# PRED:  ['26,rishkiesh']
# SAME:  ['26,rishkiesh']
# TRUE:  ['27,north america', '27,airtours airways']
# PRED:  ['27,one']
# NONE_TRUE_LESS:  ['27,north america', '27,airtours airways']
# NONE_PRED_LESS:  ['27,one']
# TRUE:  ['28,national medal of science']
# PRED:  ['28,phds', '28,national medal of science']
# MORE:  ['28,national medal of science']
# TRUE:  ['29,aston villa 2000-02 season', '29,middlesbrough f.c. season 2009-10']
# PRED:  ['29,aston villa 2000-02 season', '29,middlesbrough f.c.', '29,2009-10']
# MORE:  ['29,aston villa 2000-02 season']
# TRUE:  ['30,william harper']
# PRED:  ['30,william harper']
# SAME:  ['30,william harper']
# TRUE:  ['31,pcl constructures']
# PRED:  ['31,pcl']
# SAME:  []
# NONE_TRUE_EQUAL:  ['31,pcl constructures']
# NONE_PRED_EQUAL:  ['31,pcl']
# TRUE:  ['32,jonas brothers', '32,kevin jonas']
# PRED:  ['32,kevin jonas', '32,jonas']
# SAME:  ['32,kevin jonas']
# PARTIAL:  ['32,kevin jonas']
# TRUE:  ['33,cosmos']
# PRED:  ['33,sagan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['33,cosmos']
# NONE_PRED_EQUAL:  ['33,sagan']
# TRUE:  ['34,rosemont, illinois']
# PRED:  ['34,rosemont', '34,illinois']
# NONE_TRUE_MORE:  ['34,rosemont, illinois']
# NONE_PRED_MORE:  ['34,rosemont', '34,illinois']
# TRUE:  ['35,greenup county high school']
# PRED:  ['35,greenup county high school']
# SAME:  ['35,greenup county high school']
# TRUE:  ['36,bobby hoppe']
# PRED:  ['36,bobby hoppe']
# SAME:  ['36,bobby hoppe']
# TRUE:  ['37,the second coming']
# PRED:  ['37,the second coming']
# SAME:  ['37,the second coming']
# TRUE:  ['38,miguel de cervantes']
# PRED:  ['38,miguel de cervantes']
# SAME:  ['38,miguel de cervantes']
# TRUE:  ['39,progressive rock']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['39,progressive rock']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['40,reading, berkshire']
# PRED:  ['40,reading', '40,berkshire']
# NONE_TRUE_MORE:  ['40,reading, berkshire']
# NONE_PRED_MORE:  ['40,reading', '40,berkshire']
# TRUE:  ['41,crystal harris']
# PRED:  ['41,crystal harris']
# SAME:  ['41,crystal harris']
# TRUE:  ['42,west thurrock', '42,essex']
# PRED:  ['42,essex']
# LESS:  ['42,essex']
# TRUE:  ['43,niederkirchnerstrae']
# PRED:  ['43,niederkirchnerstrae']
# SAME:  ['43,niederkirchnerstrae']
# TRUE:  ['44,steven moffat']
# PRED:  ['44,steven moffat']
# SAME:  ['44,steven moffat']
# TRUE:  ['45,ford falcon cobra', '45,dagenham wind turbines']
# PRED:  ['45,dagenham', '45,ford']
# SAME:  []
# NONE_TRUE_EQUAL:  ['45,ford falcon cobra', '45,dagenham wind turbines']
# NONE_PRED_EQUAL:  ['45,dagenham', '45,ford']
# TRUE:  ['46,san francisco international airport']
# PRED:  ['46,san francisco international airport']
# SAME:  ['46,san francisco international airport']
# TRUE:  ['47,maritime museum of san diego']
# PRED:  ['47,san diego']
# SAME:  []
# NONE_TRUE_EQUAL:  ['47,maritime museum of san diego']
# NONE_PRED_EQUAL:  ['47,san diego']
# TRUE:  ['48,sarah walker', '48,trinity school, brentwood']
# PRED:  ['48,the trinity school, brentwood', '48,the sarah walker']
# SAME:  []
# NONE_TRUE_EQUAL:  ['48,sarah walker', '48,trinity school, brentwood']
# NONE_PRED_EQUAL:  ['48,the trinity school, brentwood', '48,the sarah walker']
# TRUE:  ['49,21vianet']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['49,21vianet']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['50,urbain le verrier', '50,johann gottfried']
# PRED:  ['50,johann gottfired', '50,urbain']
# SAME:  []
# NONE_TRUE_EQUAL:  ['50,urbain le verrier', '50,johann gottfried']
# NONE_PRED_EQUAL:  ['50,johann gottfired', '50,urbain']
# TRUE:  ['51,elmer burkett']
# PRED:  ['51,elmer burkett']
# SAME:  ['51,elmer burkett']
# TRUE:  ['52,hensley meulens', '52,steve ontiveros']
# PRED:  ['52,hensley meulens', '52,steve ontiveros']
# SAME:  ['52,hensley meulens', '52,steve ontiveros']
# TRUE:  ['53,lucy sullivan is getting married']
# PRED:  ['53, ', '53,lucy sullivan']
# NONE_TRUE_MORE:  ['53,lucy sullivan is getting married']
# NONE_PRED_MORE:  ['53, ', '53,lucy sullivan']
# TRUE:  ['54,faaa', '54,society islands']
# PRED:  ['54,society islands', '54,faaa']
# SAME:  ['54,society islands', '54,faaa']
# TRUE:  ['55,1997 canadian grand prix', '55,94 spanish']
# PRED:  ['55,1997', '55,94']
# SAME:  []
# NONE_TRUE_EQUAL:  ['55,1997 canadian grand prix', '55,94 spanish']
# NONE_PRED_EQUAL:  ['55,1997', '55,94']
# TRUE:  ['56,richard winn']
# PRED:  ['56,richard winn']
# SAME:  ['56,richard winn']
# TRUE:  ['57,sherlock', '57,arthur levinson']
# PRED:  ['57,sherlock', '57,arthur levinson']
# SAME:  ['57,sherlock', '57,arthur levinson']
# TRUE:  ['58,master card center', '58,sam carrrick']
# PRED:  ['58,master card', '58,sam carrrick']
# SAME:  ['58,sam carrrick']
# PARTIAL:  ['58,sam carrrick']
# TRUE:  ['59,fremantle media']
# PRED:  ['59,fremantle media']
# SAME:  ['59,fremantle media']
# TRUE:  ['60,south loop printing house district']
# PRED:  ['60,south loop printing house district']
# SAME:  ['60,south loop printing house district']
# TRUE:  ['61,outlook', '61,visual studio']
# PRED:  ['61, outlook', '61, ', '61,visual studio']
# MORE:  ['61,visual studio']
# TRUE:  ['62,croatia', '62,ombla']
# PRED:  ['62,croatia']
# LESS:  ['62,croatia']
# TRUE:  ['63,newin chidchob']
# PRED:  ['63,newin chidchob']
# SAME:  ['63,newin chidchob']
# TRUE:  ['64,ron reed', '64,dave bing']
# PRED:  ['64,dave bing', '64,ron reed']
# SAME:  ['64,dave bing', '64,ron reed']
# TRUE:  ['65,galileo galilei', '65,ganymede']
# PRED:  ['65,ganymede', '65,galileo']
# SAME:  ['65,ganymede']
# PARTIAL:  ['65,ganymede']
# TRUE:  ['66,guitar']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['66,guitar']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['67,elizabeth: the golden age']
# PRED:  ['67,elizabeth', '67,the golden age']
# NONE_TRUE_MORE:  ['67,elizabeth: the golden age']
# NONE_PRED_MORE:  ['67,elizabeth', '67,the golden age']
# TRUE:  ['68,onedrive']
# PRED:  ['68,onedrive']
# SAME:  ['68,onedrive']
# TRUE:  ['69,washington, d.c.']
# PRED:  ['69,washington', '69,d.c.']
# NONE_TRUE_MORE:  ['69,washington, d.c.']
# NONE_PRED_MORE:  ['69,washington', '69,d.c.']
# TRUE:  ['70,queen noor of jordan']
# PRED:  ['70,jordan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['70,queen noor of jordan']
# NONE_PRED_EQUAL:  ['70,jordan']
# TRUE:  ['71,robert witherspoon']
# PRED:  ['71,robert witherspoon']
# SAME:  ['71,robert witherspoon']
# TRUE:  ["72,he's a liar"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["72,he's a liar"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['73,oj, svijetla majska zoro']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['73,oj, svijetla majska zoro']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['74,allen walker']
# PRED:  ['74,allen walker']
# SAME:  ['74,allen walker']
# TRUE:  ['75,marcus calpurnius bibulus', '75,publius servilius vatia isauricus']
# PRED:  ['75,publius servilius vatia isauricus', '75,marcus calpurnius']
# SAME:  ['75,publius servilius vatia isauricus']
# PARTIAL:  ['75,publius servilius vatia isauricus']
# TRUE:  ['76,edmund john', '76,saima chowdhury']
# PRED:  ['']
# NONE_TRUE_LESS:  ['76,edmund john', '76,saima chowdhury']
# NONE_PRED_LESS:  ['']
# TRUE:  ['77,mount hoffmann', '77,cathedral peak']
# PRED:  ['77,first', '77,the cathedral peak', '77,mount hoffmann']
# MORE:  ['77,mount hoffmann']
# TRUE:  ['78,indiana']
# PRED:  ['78,indiana']
# SAME:  ['78,indiana']
# TRUE:  ['79,swedish covenant hospital']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['79,swedish covenant hospital']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['80,moondog matinee', '80,girl from the north country']
# PRED:  ['80,girl', '80,the north country', '80,the moondog matinee']
# NONE_TRUE_MORE:  ['80,moondog matinee', '80,girl from the north country']
# NONE_PRED_MORE:  ['80,girl', '80,the north country', '80,the moondog matinee']
# TRUE:  ['81,april stewart', '81,mona marshall']
# PRED:  ['81, ', '81,april stewart', '81,mona marshall']
# MORE:  ['81,april stewart', '81,mona marshall']
# TRUE:  ['82,trinity house', '82,freedom']
# PRED:  ['82, ', '82,trinity house']
# SAME:  ['82,trinity house']
# PARTIAL:  ['82,trinity house']
# TRUE:  ['83,iran', '83,reza amrollahi']
# PRED:  ['83,iran']
# LESS:  ['83,iran']
# TRUE:  ['84,zaman shah durrani', '84,salahuddin']
# PRED:  ['84,zaman shah durrani', '84,salahuddin']
# SAME:  ['84,zaman shah durrani', '84,salahuddin']
# TRUE:  ['85,roh tae woo', '85,lee leffingwell']
# PRED:  ['85,roh tae woo', '85,lee leffingwell']
# SAME:  ['85,roh tae woo', '85,lee leffingwell']
# TRUE:  ['86,rosemarie dewitt']
# PRED:  ['86,rosemarie dewitt']
# SAME:  ['86,rosemarie dewitt']
# TRUE:  ['87,sapindales']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['87,sapindales']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['88,lewis hamilton']
# PRED:  ['88,lewis hamilton']
# SAME:  ['88,lewis hamilton']
# TRUE:  ['89,giorgos kaminis']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['89,giorgos kaminis']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['90,michael hahn']
# PRED:  ['90,michael']
# SAME:  []
# NONE_TRUE_EQUAL:  ['90,michael hahn']
# NONE_PRED_EQUAL:  ['90,michael']
# TRUE:  ['91,berlin']
# PRED:  ['91,berlin']
# SAME:  ['91,berlin']
# TRUE:  ['92,india']
# PRED:  ['92,india']
# SAME:  ['92,india']
# TRUE:  ['93,the simpsons ride']
# PRED:  ['93,the simpsons ride']
# SAME:  ['93,the simpsons ride']
# TRUE:  ['94,o.co coliseum']
# PRED:  ['94, ']
# SAME:  []
# NONE_TRUE_EQUAL:  ['94,o.co coliseum']
# NONE_PRED_EQUAL:  ['94, ']
# TRUE:  ['95,mams taylor', '95,the mating habits of the earthbound humans']
# PRED:  ['']
# NONE_TRUE_LESS:  ['95,mams taylor', '95,the mating habits of the earthbound humans']
# NONE_PRED_LESS:  ['']
# TRUE:  ['96,playboy enterprises']
# PRED:  ['96,playboy enterprises']
# SAME:  ['96,playboy enterprises']
# TRUE:  ['97,gwo ka', '97,western africa']
# PRED:  ['97,western africa']
# LESS:  ['97,western africa']
# TRUE:  ['98,send it on']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['98,send it on']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['99,onedrive', '99,visual studio']
# PRED:  ['99,visual studio', '99,one']
# SAME:  ['99,visual studio']
# PARTIAL:  ['99,visual studio']
# TRUE:  ['100,roundhead']
# PRED:  ['100,wyandot']
# SAME:  []
# NONE_TRUE_EQUAL:  ['100,roundhead']
# NONE_PRED_EQUAL:  ['100,wyandot']
# TRUE:  ['101,michigan stadium']
# PRED:  ['101,the michigan stadium']
# SAME:  []
# NONE_TRUE_EQUAL:  ['101,michigan stadium']
# NONE_PRED_EQUAL:  ['101,the michigan stadium']
# TRUE:  ['102,david johnston']
# PRED:  ['102,david johnston']
# SAME:  ['102,david johnston']
# TRUE:  ['103,francois marie le marchand de lignery']
# PRED:  ['103,francois marie le', '103,marchand de lignery']
# NONE_TRUE_MORE:  ['103,francois marie le marchand de lignery']
# NONE_PRED_MORE:  ['103,francois marie le', '103,marchand de lignery']
# TRUE:  ['104,myntdu river']
# PRED:  ['104,myntdu']
# SAME:  []
# NONE_TRUE_EQUAL:  ['104,myntdu river']
# NONE_PRED_EQUAL:  ['104,myntdu']
# TRUE:  ['105,london']
# PRED:  ['105,london']
# SAME:  ['105,london']
# TRUE:  ['106,ann lewis', '106,al gore presidential campaign, 2000']
# PRED:  ['106,al gore', '106,2000', '106,ann lewis']
# MORE:  ['106,ann lewis']
# TRUE:  ['107,darius i']
# PRED:  ['107,darius i']
# SAME:  ['107,darius i']
# TRUE:  ['108,airtours international airways', '108,kim sawchuk']
# PRED:  ['108,kim sawchuk', '108,the airtours international airways']
# SAME:  ['108,kim sawchuk']
# PARTIAL:  ['108,kim sawchuk']
# TRUE:  ['109,antonio giannini']
# PRED:  ['109,antonio giannini']
# SAME:  ['109,antonio giannini']
# TRUE:  ['110,david scherman']
# PRED:  ['110,david scherman']
# SAME:  ['110,david scherman']
# TRUE:  ['111,outlook.com', '111,onedrive']
# PRED:  ['111,outlook.com', '111,onedrive']
# SAME:  ['111,outlook.com', '111,onedrive']
# TRUE:  ['112,rouen business school']
# PRED:  ['112,rouen business school']
# SAME:  ['112,rouen business school']
# TRUE:  ['113,minjoo party']
# PRED:  ['113,the korean minjoo party']
# SAME:  []
# NONE_TRUE_EQUAL:  ['113,minjoo party']
# NONE_PRED_EQUAL:  ['113,the korean minjoo party']
# TRUE:  ['114,mcdonnell aircraft']
# PRED:  ['114,one', '114,mcdonnell aircraft']
# MORE:  ['114,mcdonnell aircraft']
# TRUE:  ['115,gales ferry, connecticut']
# PRED:  ['115,gales ferry', '115,connecticut']
# NONE_TRUE_MORE:  ['115,gales ferry, connecticut']
# NONE_PRED_MORE:  ['115,gales ferry', '115,connecticut']
# TRUE:  ['116,live in detroit, mi']
# PRED:  ['116,detroit', '116,mi']
# NONE_TRUE_MORE:  ['116,live in detroit, mi']
# NONE_PRED_MORE:  ['116,detroit', '116,mi']
# TRUE:  ['117,english under twenty one football team']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['117,english under twenty one football team']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['118,helsinki', '118,danish straits']
# PRED:  ['118,helsinki', '118,one', '118,danish']
# MORE:  ['118,helsinki']
# TRUE:  ['119,timmy time']
# PRED:  ['119,timmy time']
# SAME:  ['119,timmy time']
# TRUE:  ['120,fort heath radar station']
# PRED:  ['120,fort heath']
# SAME:  []
# NONE_TRUE_EQUAL:  ['120,fort heath radar station']
# NONE_PRED_EQUAL:  ['120,fort heath']
# TRUE:  ['121,lyons township high school', '121,harding academy']
# PRED:  ['']
# NONE_TRUE_LESS:  ['121,lyons township high school', '121,harding academy']
# NONE_PRED_LESS:  ['']
# TRUE:  ['122,rosario, santa fe']
# PRED:  ['122,rosario', '122,santa fe']
# NONE_TRUE_MORE:  ['122,rosario, santa fe']
# NONE_PRED_MORE:  ['122,rosario', '122,santa fe']
# TRUE:  ['123,animal']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['123,animal']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['124,oahu railway and land company', '124,chris myers']
# PRED:  ['124,the chris myers', '124,new jersey', '124,oahu railway', '124,land company']
# NONE_TRUE_MORE:  ['124,oahu railway and land company', '124,chris myers']
# NONE_PRED_MORE:  ['124,the chris myers', '124,new jersey', '124,oahu railway', '124,land company']
# TRUE:  ['125,ngos']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['125,ngos']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['126,brian graden', '126,isaac hayes']
# PRED:  ['126,brian graden', '126,isaac hayes']
# SAME:  ['126,brian graden', '126,isaac hayes']
# TRUE:  ['127,cars']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['127,cars']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['128,steve sampson', '128,santa clara university']
# PRED:  ['128,steve sampson', '128,santa clara']
# SAME:  ['128,steve sampson']
# PARTIAL:  ['128,steve sampson']
# TRUE:  ['129,schibsted']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['129,schibsted']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# PRED:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# SAME:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# TRUE:  ['131,joan laporta']
# PRED:  ['131,joan laporta']
# SAME:  ['131,joan laporta']
# TRUE:  ['132,four-wheel-drive layout']
# PRED:  ['132,one', '132,four']
# NONE_TRUE_MORE:  ['132,four-wheel-drive layout']
# NONE_PRED_MORE:  ['132,one', '132,four']
# TRUE:  ['133,pong pha']
# PRED:  ['133,pong pha']
# SAME:  ['133,pong pha']
# TRUE:  ['134,charles ayres', '134,angela trusty']
# PRED:  ['134,the angela trusty', '134,charles ayres']
# SAME:  ['134,charles ayres']
# PARTIAL:  ['134,charles ayres']
# TRUE:  ['135,the conglomerate', '135,before i let you go']
# PRED:  ['135,conglomerate']
# NONE_TRUE_LESS:  ['135,the conglomerate', '135,before i let you go']
# NONE_PRED_LESS:  ['135,conglomerate']
# TRUE:  ['136,lagnacha dhumdhadaka']
# PRED:  ['136,lagnacha']
# SAME:  []
# NONE_TRUE_EQUAL:  ['136,lagnacha dhumdhadaka']
# NONE_PRED_EQUAL:  ['136,lagnacha']
# TRUE:  ['137,english']
# PRED:  ['137,english']
# SAME:  ['137,english']
# TRUE:  ['138,el sobrante, california']
# PRED:  ['138,el sobrante', '138,california']
# NONE_TRUE_MORE:  ['138,el sobrante, california']
# NONE_PRED_MORE:  ['138,el sobrante', '138,california']
# TRUE:  ["139,daniel o'regan"]
# PRED:  ["139,the nickname of daniel o'regan"]
# SAME:  []
# NONE_TRUE_EQUAL:  ["139,daniel o'regan"]
# NONE_PRED_EQUAL:  ["139,the nickname of daniel o'regan"]
# TRUE:  ['140,aureus', '140,solidus']
# PRED:  ['']
# NONE_TRUE_LESS:  ['140,aureus', '140,solidus']
# NONE_PRED_LESS:  ['']
# TRUE:  ['141,cardiovascular disease']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['141,cardiovascular disease']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['142,mammal', '142,chestnut white bellied rat']
# PRED:  ['']
# NONE_TRUE_LESS:  ['142,mammal', '142,chestnut white bellied rat']
# NONE_PRED_LESS:  ['']
# TRUE:  ['143,the broken code', '143,tim gunn']
# PRED:  ['143,tim gunn', '143,the broken code']
# SAME:  ['143,tim gunn', '143,the broken code']
# TRUE:  ['144,shallot']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['144,shallot']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['145,oktoc, mississippi']
# PRED:  ['145,oktoc', '145,mississippi']
# NONE_TRUE_MORE:  ['145,oktoc, mississippi']
# NONE_PRED_MORE:  ['145,oktoc', '145,mississippi']
# TRUE:  ['146,nord', '146,the beauty inside']
# PRED:  ['146,nord']
# LESS:  ['146,nord']
# TRUE:  ['147,tirana', '147,albania']
# PRED:  ['147,albania']
# LESS:  ['147,albania']
# TRUE:  ['148,vishwajyot high school', '148,fr agnel multipurpose school']
# PRED:  ['148,fr agnel multipurpose school', '148,vishwajyot high school']
# SAME:  ['148,fr agnel multipurpose school', '148,vishwajyot high school']
# TRUE:  ['149,bob hawke']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['149,bob hawke']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['150,cbs corporation']
# PRED:  ['150,the cbs corporation']
# SAME:  []
# NONE_TRUE_EQUAL:  ['150,cbs corporation']
# NONE_PRED_EQUAL:  ['150,the cbs corporation']
# TRUE:  ['151,taguig']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['151,taguig']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['152,joe hahn']
# PRED:  ['152,joe hahn']
# SAME:  ['152,joe hahn']
# TRUE:  ['153,comedy central', '153,isaac hayes']
# PRED:  ['153,comedy', '153, ', '153,isaac']
# NONE_TRUE_MORE:  ['153,comedy central', '153,isaac hayes']
# NONE_PRED_MORE:  ['153,comedy', '153, ', '153,isaac']
# TRUE:  ['154,raymond johansen']
# PRED:  ['154,raymond johansen']
# SAME:  ['154,raymond johansen']
# TRUE:  ['155,ikaros smederna']
# PRED:  ['155,ikaros smederna']
# SAME:  ['155,ikaros smederna']
# TRUE:  ['156,windows']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['156,windows']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['157,hockey']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['157,hockey']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['158,washington dc']
# PRED:  ['158,washington dc']
# SAME:  ['158,washington dc']
# TRUE:  ['159,temenos group']
# PRED:  ['159,temenos group']
# SAME:  ['159,temenos group']
# TRUE:  ['160,to know him is to love him']
# PRED:  ['160,love']
# SAME:  []
# NONE_TRUE_EQUAL:  ['160,to know him is to love him']
# NONE_PRED_EQUAL:  ['160,love']
# TRUE:  ['161,spain...']
# PRED:  ['161,spain']
# SAME:  []
# NONE_TRUE_EQUAL:  ['161,spain...']
# NONE_PRED_EQUAL:  ['161,spain']
# TRUE:  ['162,chris marve', '162,neria douglass']
# PRED:  ['162,chris marve', '162,neria douglass']
# SAME:  ['162,chris marve', '162,neria douglass']
# TRUE:  ['163,monticello, maine']
# PRED:  ['163,monticello', '163,maine']
# NONE_TRUE_MORE:  ['163,monticello, maine']
# NONE_PRED_MORE:  ['163,monticello', '163,maine']
# TRUE:  ['164,josiah idowu-fearon', '164,john']
# PRED:  ['164,josiah idowu-fearon', '164,damasucs']
# SAME:  ['164,josiah idowu-fearon']
# PARTIAL:  ['164,josiah idowu-fearon']
# TRUE:  ['165,paramount television', '165,judy hart angelo']
# PRED:  ['165,judy hart angelo', '165,paramount']
# SAME:  ['165,judy hart angelo']
# PARTIAL:  ['165,judy hart angelo']
# TRUE:  ['166,caspian']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['166,caspian']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['167,united states department of defense', '167,arlington county, virginia']
# PRED:  ['167,arlington county', '167,virginia', '167,united states department of defense']
# MORE:  ['167,united states department of defense']
# TRUE:  ['168,thongsuk samdaengpan']
# PRED:  ['168,thongsuk samdaengpan']
# SAME:  ['168,thongsuk samdaengpan']
# TRUE:  ['169,asus']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['169,asus']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['170,ncaa']
# PRED:  ['170,ncaa']
# SAME:  ['170,ncaa']
# TRUE:  ['171,afrika baby bam', '171,queen latifah']
# PRED:  ['171,queen latifah', '171,afrika baby bam']
# SAME:  ['171,queen latifah', '171,afrika baby bam']
# TRUE:  ['172,kazuo hirai']
# PRED:  ['172,kazuo hirai']
# SAME:  ['172,kazuo hirai']
# TRUE:  ['173,patts college of aeronautics']
# PRED:  ['173,patts college of aeronautics']
# SAME:  ['173,patts college of aeronautics']
# TRUE:  ['174,dan shamash', '174,ever bank field']
# PRED:  ['174,dan shamash']
# LESS:  ['174,dan shamash']
# TRUE:  ['175,thanong bidaya']
# PRED:  ['175,thanong bidaya']
# SAME:  ['175,thanong bidaya']
# TRUE:  ['176,san marcos river']
# PRED:  ['176,san marcos river']
# SAME:  ['176,san marcos river']
# TRUE:  ['177,jazz fusion']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['177,jazz fusion']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['178,bogumilus']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['178,bogumilus']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['179,screen actors guild life achievement award', '179,henry e. catto, jr.']
# PRED:  ['179,henry e. catto', '179,jr.', '179,screen actors']
# NONE_TRUE_MORE:  ['179,screen actors guild life achievement award', '179,henry e. catto, jr.']
# NONE_PRED_MORE:  ['179,henry e. catto', '179,jr.', '179,screen actors']
# TRUE:  ['180,pope gregory i']
# PRED:  ['180,pope gregory']
# SAME:  []
# NONE_TRUE_EQUAL:  ['180,pope gregory i']
# NONE_PRED_EQUAL:  ['180,pope gregory']
# TRUE:  ['181,human rights party']
# PRED:  ['181,cambodian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['181,human rights party']
# NONE_PRED_EQUAL:  ['181,cambodian']
# TRUE:  ['182,czech extraliga']
# PRED:  ['182,the czech extraliga']
# SAME:  []
# NONE_TRUE_EQUAL:  ['182,czech extraliga']
# NONE_PRED_EQUAL:  ['182,the czech extraliga']
# TRUE:  ['183,croix de guerre']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['183,croix de guerre']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['184,azam f.c.']
# PRED:  ['184,azam f.c.']
# SAME:  ['184,azam f.c.']
# TRUE:  ['185,inkas', '185,t.i. ahmadiyya senior high school, kumasi']
# PRED:  ['185, inkas', '185, t.i. ahmadiyya senior high school', '185,kumasi']
# NONE_TRUE_MORE:  ['185,inkas', '185,t.i. ahmadiyya senior high school, kumasi']
# NONE_PRED_MORE:  ['185, inkas', '185, t.i. ahmadiyya senior high school', '185,kumasi']
# TRUE:  ['186,mausoleum of augustus', '186,rome']
# PRED:  ['186, rome', '186,mausoleum of augustus']
# SAME:  ['186,mausoleum of augustus']
# PARTIAL:  ['186,mausoleum of augustus']
# TRUE:  ['187,1st free french division']
# PRED:  ['187,1st free french division']
# SAME:  ['187,1st free french division']
# TRUE:  ['188,mediterranean sea']
# PRED:  ['188,the mediterranean sea']
# SAME:  []
# NONE_TRUE_EQUAL:  ['188,mediterranean sea']
# NONE_PRED_EQUAL:  ['188,the mediterranean sea']
# TRUE:  ['189,zambia', '189,ikelenge district']
# PRED:  ['189,zambia', '189,ikelenge']
# SAME:  ['189,zambia']
# PARTIAL:  ['189,zambia']
# TRUE:  ['190,royal society']
# PRED:  ['190,royal society']
# SAME:  ['190,royal society']
# TRUE:  ['191,acer nigrum']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['191,acer nigrum']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['192,filipinos']
# PRED:  ['192,filipinos']
# SAME:  ['192,filipinos']
# TRUE:  ['193,neil brown', '193,andrew peacock']
# PRED:  ['193,neil brown', '193,andrew peacock']
# SAME:  ['193,neil brown', '193,andrew peacock']
# TRUE:  ['194,wizards vs aliens', '194,into the dalek']
# PRED:  ['194,into the dalek', '194,wizards']
# SAME:  ['194,into the dalek']
# PARTIAL:  ['194,into the dalek']
# TRUE:  ['195,charles pinckney']
# PRED:  ['195,charles pinckney']
# SAME:  ['195,charles pinckney']
# TRUE:  ["196,us men's national soccer team"]
# PRED:  ['196,us']
# SAME:  []
# NONE_TRUE_EQUAL:  ["196,us men's national soccer team"]
# NONE_PRED_EQUAL:  ['196,us']
# TRUE:  ['197,tessa dahl']
# PRED:  ['197,tessa dahl']
# SAME:  ['197,tessa dahl']
# TRUE:  ['198,eu broadcasting union']
# PRED:  ['198,eu broadcasting union']
# SAME:  ['198,eu broadcasting union']
# TRUE:  ['199,jack ryan', '199,us senate']
# PRED:  ['199,jack ryan', '199,us senate']
# SAME:  ['199,jack ryan', '199,us senate']
# TRUE:  ['200,ananda college']
# PRED:  ['200,ananda college']
# SAME:  ['200,ananda college']
# TRUE:  ['201,mediterranean sea', '201,panionios g.s.s. season']
# PRED:  ['201,mediterranean sea', '201,panionios g.s.s.']
# SAME:  ['201,mediterranean sea']
# PARTIAL:  ['201,mediterranean sea']
# TRUE:  ['202,murray mouth', '202,cowombat flat']
# PRED:  ['202,cowombat', '202, flat', '202,murray mouth']
# MORE:  ['202,murray mouth']
# TRUE:  ['203,wbcq']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['203,wbcq']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['204,2015 argentine primera division']
# PRED:  ['204,2015', '204,argentine primera division']
# NONE_TRUE_MORE:  ['204,2015 argentine primera division']
# NONE_PRED_MORE:  ['204,2015', '204,argentine primera division']
# TRUE:  ['205,florida']
# PRED:  ['205,florida']
# SAME:  ['205,florida']
# TRUE:  ['206,god defend new zealand']
# PRED:  ['206,new zealand']
# SAME:  []
# NONE_TRUE_EQUAL:  ['206,god defend new zealand']
# NONE_PRED_EQUAL:  ['206,new zealand']
# TRUE:  ['207,vangelis', '207,jordan cronenweth']
# PRED:  ['207,jordan cronenweth', '207,vangelis']
# SAME:  ['207,jordan cronenweth', '207,vangelis']
# TRUE:  ['208,klang valley']
# PRED:  ['208,the klang valley']
# SAME:  []
# NONE_TRUE_EQUAL:  ['208,klang valley']
# NONE_PRED_EQUAL:  ['208,the klang valley']
# TRUE:  ['209,discovery communications']
# PRED:  ['209,discovery communications']
# SAME:  ['209,discovery communications']
# TRUE:  ['210,queer as folk']
# PRED:  ['210,queer']
# SAME:  []
# NONE_TRUE_EQUAL:  ['210,queer as folk']
# NONE_PRED_EQUAL:  ['210,queer']
# TRUE:  ['211,high desert']
# PRED:  ['211,oregon']
# SAME:  []
# NONE_TRUE_EQUAL:  ['211,high desert']
# NONE_PRED_EQUAL:  ['211,oregon']
# TRUE:  ['212,paramount domestic television']
# PRED:  ['212,paramount domestic television']
# SAME:  ['212,paramount domestic television']
# TRUE:  ['213,city of new orleans']
# PRED:  ['213,city of new orleans']
# SAME:  ['213,city of new orleans']
# TRUE:  ['214,get tv', '214,the galleria']
# PRED:  ['214,get tv', '214,galleria']
# SAME:  ['214,get tv']
# PARTIAL:  ['214,get tv']
# TRUE:  ['215,madagascar: operation penguin', "215,he's a pirate"]
# PRED:  ['215,madagascar: operation penguin', '215,pirate']
# SAME:  ['215,madagascar: operation penguin']
# PARTIAL:  ['215,madagascar: operation penguin']
# TRUE:  ['216,goran cengic']
# PRED:  ['216,goran cengic']
# SAME:  ['216,goran cengic']
# TRUE:  ['217,zhorstoke nebo']
# PRED:  ['217,zhorstoke']
# SAME:  []
# NONE_TRUE_EQUAL:  ['217,zhorstoke nebo']
# NONE_PRED_EQUAL:  ['217,zhorstoke']
# TRUE:  ['218,louis dunbar', '218,jeff munn']
# PRED:  ['218,louis dunbar', '218,jeff munn']
# SAME:  ['218,louis dunbar', '218,jeff munn']
# TRUE:  ['219,populous']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['219,populous']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['220,chumash people']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['220,chumash people']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['221,pavel moroz', '221,helena of moscow']
# PRED:  ['221,moroz', '221,helena', '221,moscow']
# NONE_TRUE_MORE:  ['221,pavel moroz', '221,helena of moscow']
# NONE_PRED_MORE:  ['221,moroz', '221,helena', '221,moscow']
# TRUE:  ['222,christopher franke', '222,j. michael straczynski']
# PRED:  ['222,j. michael stracznski', '222,christopher franke']
# SAME:  ['222,christopher franke']
# PARTIAL:  ['222,christopher franke']
# TRUE:  ['223,cy-fair high school']
# PRED:  ['223,a cy-fair high school']
# SAME:  []
# NONE_TRUE_EQUAL:  ['223,cy-fair high school']
# NONE_PRED_EQUAL:  ['223,a cy-fair high school']
# TRUE:  ['224,senser']
# PRED:  ['224,senser']
# SAME:  ['224,senser']
# TRUE:  ['225,teddy riley', '225,blayse']
# PRED:  ['225,blayse', '225,teddy riley']
# SAME:  ['225,blayse', '225,teddy riley']
# TRUE:  ['226,to where you are']
# PRED:  ['226,to you are']
# SAME:  []
# NONE_TRUE_EQUAL:  ['226,to where you are']
# NONE_PRED_EQUAL:  ['226,to you are']
# TRUE:  ['227,merlin express', '227,cibano international airport']
# PRED:  ['']
# NONE_TRUE_LESS:  ['227,merlin express', '227,cibano international airport']
# NONE_PRED_LESS:  ['']
# TRUE:  ['228,wilton, connecticut']
# PRED:  ['228,wilton', '228,connecticut']
# NONE_TRUE_MORE:  ['228,wilton, connecticut']
# NONE_PRED_MORE:  ['228,wilton', '228,connecticut']
# TRUE:  ['229,ontariana']
# PRED:  ['229,ontarians']
# SAME:  []
# NONE_TRUE_EQUAL:  ['229,ontariana']
# NONE_PRED_EQUAL:  ['229,ontarians']
# TRUE:  ['230,ryan seacrest', '230,fox']
# PRED:  ['230,fox', '230,ryan seacrest']
# SAME:  ['230,fox', '230,ryan seacrest']
# TRUE:  ['231,box girder bridges']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['231,box girder bridges']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ["232,the god who wasn't there"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["232,the god who wasn't there"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['233,public transport authority']
# PRED:  ['233,western australian public transport authority']
# SAME:  []
# NONE_TRUE_EQUAL:  ['233,public transport authority']
# NONE_PRED_EQUAL:  ['233,western australian public transport authority']
# TRUE:  ['234,thomas meehan']
# PRED:  ['234,thomas meehan']
# SAME:  ['234,thomas meehan']
# TRUE:  ['235,municipal council']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['235,municipal council']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['236,jacques-dsir laval']
# PRED:  ['236,jacques-dsir laval']
# SAME:  ['236,jacques-dsir laval']
# TRUE:  ['237,mecklenburg-vorpommern']
# PRED:  ['237,mecklenburg-vorpommern']
# SAME:  ['237,mecklenburg-vorpommern']
# TRUE:  ['238,herzogenaurach']
# PRED:  ['238,herzogenaurach']
# SAME:  ['238,herzogenaurach']
# TRUE:  ['239,lucy sullivan is getting married']
# PRED:  ['239,lucy sullivan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['239,lucy sullivan is getting married']
# NONE_PRED_EQUAL:  ['239,lucy sullivan']
# TRUE:  ['240,blizzard entertainment']
# PRED:  ['240,blizzard entertainment']
# SAME:  ['240,blizzard entertainment']
# TRUE:  ['241,alexander downer', '241,neil brown']
# PRED:  ['241,alexander downer', '241,neil brown']
# SAME:  ['241,alexander downer', '241,neil brown']
# TRUE:  ['242,costa rica national football team']
# PRED:  ['242,costa rica']
# SAME:  []
# NONE_TRUE_EQUAL:  ['242,costa rica national football team']
# NONE_PRED_EQUAL:  ['242,costa rica']
# TRUE:  ['243,amitava datta']
# PRED:  ['243,amitava']
# SAME:  []
# NONE_TRUE_EQUAL:  ['243,amitava datta']
# NONE_PRED_EQUAL:  ['243,amitava']
# TRUE:  ['244,londo mollari']
# PRED:  ['244,londo mollari']
# SAME:  ['244,londo mollari']
# TRUE:  ['245,scientologists']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['245,scientologists']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# PRED:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# SAME:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# TRUE:  ['247,qadir huseynov', '247,liudmila privivkova']
# PRED:  ['247,liudmila privivkova', '247,qadir huseynov']
# SAME:  ['247,liudmila privivkova', '247,qadir huseynov']
# TRUE:  ['248,cadillac fleetwood']
# PRED:  ['248,cadillac', '248,fleetwood']
# NONE_TRUE_MORE:  ['248,cadillac fleetwood']
# NONE_PRED_MORE:  ['248,cadillac', '248,fleetwood']
# TRUE:  ['249,commodore cdtv']
# PRED:  ['249,cdtv']
# SAME:  []
# NONE_TRUE_EQUAL:  ['249,commodore cdtv']
# NONE_PRED_EQUAL:  ['249,cdtv']
# TRUE:  ['250,mark johnson']
# PRED:  ['250,mark johnson']
# SAME:  ['250,mark johnson']
# TRUE:  ['251,canary islands']
# PRED:  ['251,canary islands']
# SAME:  ['251,canary islands']
# TRUE:  ['252,fusil gras mile 1874']
# PRED:  ['252, ', '252,fusil gras mile', '252,1874']
# NONE_TRUE_MORE:  ['252,fusil gras mile 1874']
# NONE_PRED_MORE:  ['252, ', '252,fusil gras mile', '252,1874']
# TRUE:  ['253,claiborne pell', '253,ralph flanders']
# PRED:  ['253,the ralph flanders', '253, claiborne pell']
# SAME:  []
# NONE_TRUE_EQUAL:  ['253,claiborne pell', '253,ralph flanders']
# NONE_PRED_EQUAL:  ['253,the ralph flanders', '253, claiborne pell']
# TRUE:  ['254,ontario']
# PRED:  ['254,ontario']
# SAME:  ['254,ontario']
# TRUE:  ['255,san antonio', '255,us route 281']
# PRED:  ['255,us', '255,281', '255,san antonio']
# MORE:  ['255,san antonio']
# TRUE:  ['256,cnn']
# PRED:  ['256,cnn']
# SAME:  ['256,cnn']
# TRUE:  ['257,norfolk southern railway']
# PRED:  ['257,norfolk southern railway']
# SAME:  ['257,norfolk southern railway']
# TRUE:  ['258,edwin catmull', '258,pixar image computer']
# PRED:  ['258,one', '258,pixar image computer', '258,one', '258,edwin catmull']
# MORE:  ['258,pixar image computer', '258,edwin catmull']
# TRUE:  ['259,beverly hills', '259,colts neck township']
# PRED:  ['259,beverly hills', '259,colts neck township']
# SAME:  ['259,beverly hills', '259,colts neck township']
# TRUE:  ['260,rome']
# PRED:  ['260,rome']
# SAME:  ['260,rome']
# TRUE:  ['261,rhode island route 15']
# PRED:  ['261,rhode island route', '261,15']
# NONE_TRUE_MORE:  ['261,rhode island route 15']
# NONE_PRED_MORE:  ['261,rhode island route', '261,15']
# TRUE:  ['262,trump productions', '262,the ultimate merger']
# PRED:  ['262,trump productions']
# LESS:  ['262,trump productions']
# TRUE:  ['263,komc-fm', '263,komc']
# PRED:  ['263,komc-fm', '263,komc (am']
# SAME:  ['263,komc-fm']
# PARTIAL:  ['263,komc-fm']
# TRUE:  ['264,asiana airlines', '264,jeju airport']
# PRED:  ['']
# NONE_TRUE_LESS:  ['264,asiana airlines', '264,jeju airport']
# NONE_PRED_LESS:  ['']
# TRUE:  ['265,swedish academy']
# PRED:  ['265,swedish academy']
# SAME:  ['265,swedish academy']
# TRUE:  ['266,tennessee state museum']
# PRED:  ['266,tennessee state museum']
# SAME:  ['266,tennessee state museum']
# TRUE:  ['267,ishir honda']
# PRED:  ['267,ishir honda']
# SAME:  ['267,ishir honda']
# TRUE:  ["268,alpine skiing at the 1964 winter olympics men's slalom"]
# PRED:  ['268,alpine', '268,1964', '268,winter olympics', '268,men']
# NONE_TRUE_MORE:  ["268,alpine skiing at the 1964 winter olympics men's slalom"]
# NONE_PRED_MORE:  ['268,alpine', '268,1964', '268,winter olympics', '268,men']
# TRUE:  ['269,virgin radio']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['269,virgin radio']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['270,tani university']
# PRED:  ['270,university']
# SAME:  []
# NONE_TRUE_EQUAL:  ['270,tani university']
# NONE_PRED_EQUAL:  ['270,university']
# TRUE:  ['271,dowra']
# PRED:  ['271,dowra']
# SAME:  ['271,dowra']
# TRUE:  ['272,pittsburgh pirates']
# PRED:  ['272,the pittsburgh pirates']
# SAME:  []
# NONE_TRUE_EQUAL:  ['272,pittsburgh pirates']
# NONE_PRED_EQUAL:  ['272,the pittsburgh pirates']
# TRUE:  ['273,simon fuller']
# PRED:  ['273,simon fuller']
# SAME:  ['273,simon fuller']
# TRUE:  ['274,the producers', '274,next thing']
# PRED:  ['274,the the producers (', '274,2005']
# SAME:  []
# NONE_TRUE_EQUAL:  ['274,the producers', '274,next thing']
# NONE_PRED_EQUAL:  ['274,the the producers (', '274,2005']
# TRUE:  ['275,henry ford', '275,ford model c']
# PRED:  ['275,henry ford']
# LESS:  ['275,henry ford']
# TRUE:  ["276,dragons' den"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["276,dragons' den"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['277,joseph case high school', '277,providence chapel, charlwood']
# PRED:  ['277,the providence chapel', '277,charlwood', '277,joseph case high school']
# MORE:  ['277,joseph case high school']
# TRUE:  ['278,norbert wiener award for social and professional responsibility', '278,john robert woodyard']
# PRED:  ['278,john robert woodyard', '278,norbert wiener award']
# SAME:  ['278,john robert woodyard']
# PARTIAL:  ['278,john robert woodyard']
# TRUE:  ['279,leroy collins', '279,george siebels jr']
# PRED:  ['279,american', '279,george siebels', '279,leroy collins']
# MORE:  ['279,leroy collins']
# TRUE:  ['280,germany']
# PRED:  ['280,germany']
# SAME:  ['280,germany']
# TRUE:  ['281,downtown athletic club', '281,yale club']
# PRED:  ['281,downtown athletic club', '281,yale club nycity']
# SAME:  ['281,downtown athletic club']
# PARTIAL:  ['281,downtown athletic club']
# TRUE:  ['282,victor hope, 2nd marquess of linlithgow']
# PRED:  ['282,victor hope', '282,2nd marquess of linlithgow']
# NONE_TRUE_MORE:  ['282,victor hope, 2nd marquess of linlithgow']
# NONE_PRED_MORE:  ['282,victor hope', '282,2nd marquess of linlithgow']
# TRUE:  ['283,ashton historic district']
# PRED:  ['283,ashton historic']
# SAME:  []
# NONE_TRUE_EQUAL:  ['283,ashton historic district']
# NONE_PRED_EQUAL:  ['283,ashton historic']
# TRUE:  ['284,greater napanee']
# PRED:  ['284,greater napanee']
# SAME:  ['284,greater napanee']
# TRUE:  ['285,channel district']
# PRED:  ['285,channel']
# SAME:  []
# NONE_TRUE_EQUAL:  ['285,channel district']
# NONE_PRED_EQUAL:  ['285,channel']
# TRUE:  ['286,vagif aliyev']
# PRED:  ['286,vagif aliyev']
# SAME:  ['286,vagif aliyev']
# TRUE:  ['287,onedrive', '287,us']
# PRED:  ['287,us', '287,onedrive']
# SAME:  ['287,us', '287,onedrive']
# TRUE:  ['288,james l. mcconaughy']
# PRED:  ['288,james l. mcconaughy']
# SAME:  ['288,james l. mcconaughy']
# TRUE:  ['289,catwoman']
# PRED:  ['289,one']
# SAME:  []
# NONE_TRUE_EQUAL:  ['289,catwoman']
# NONE_PRED_EQUAL:  ['289,one']
# TRUE:  ['290,mediterranean sea']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['290,mediterranean sea']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['291,bacillus', '291,bacteria']
# PRED:  ['291,bacteria']
# LESS:  ['291,bacteria']
# TRUE:  ['292,french']
# PRED:  ['292,french']
# SAME:  ['292,french']
# TRUE:  ['293,baraily', '293,jowai']
# PRED:  ['293,baraily', '293,jowai']
# SAME:  ['293,baraily', '293,jowai']
# TRUE:  ['294,siege of fort recovery']
# PRED:  ['294,siege of fort recovery']
# SAME:  ['294,siege of fort recovery']
# TRUE:  ['295,germanic']
# PRED:  ['295,germanic']
# SAME:  ['295,germanic']
# TRUE:  ['296,duane allman', '296,les paul']
# PRED:  ['296,duanne allman', '296,the les paul']
# SAME:  []
# NONE_TRUE_EQUAL:  ['296,duane allman', '296,les paul']
# NONE_PRED_EQUAL:  ['296,duanne allman', '296,the les paul']
# TRUE:  ['297,tanzanian national football team']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['297,tanzanian national football team']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['298,bloomberg markets']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['298,bloomberg markets']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['299,motor vehicles']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['299,motor vehicles']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['300,holmes colbert', '300,linda hogan']
# PRED:  ['300,linda hogan', '300,the holmes colbert']
# SAME:  ['300,linda hogan']
# PARTIAL:  ['300,linda hogan']
# TRUE:  ['301,jon speelman']
# PRED:  ['301,jon speelman']
# SAME:  ['301,jon speelman']
# TRUE:  ['302,ella loves cole']
# PRED:  ['302,ella', '302,cole']
# NONE_TRUE_MORE:  ['302,ella loves cole']
# NONE_PRED_MORE:  ['302,ella', '302,cole']
# TRUE:  ['303,prime time entertainment network']
# PRED:  ['303,prime time entertainment network']
# SAME:  ['303,prime time entertainment network']
# TRUE:  ['304,auto shankar']
# PRED:  ['304,auto shankar']
# SAME:  ['304,auto shankar']
# TRUE:  ['305,burr truss']
# PRED:  ['305,burr truss']
# SAME:  ['305,burr truss']
# TRUE:  ['306,tonle sap']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['306,tonle sap']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['307,cheryl teigs']
# PRED:  ['307,cheryl teigs']
# SAME:  ['307,cheryl teigs']
# TRUE:  ['308,ndonga mianga']
# PRED:  ['308,ndonga mianga']
# SAME:  ['308,ndonga mianga']
# TRUE:  ['309,papeete']
# PRED:  ['309,papeete']
# SAME:  ['309,papeete']
# TRUE:  ['310,lake victoria']
# PRED:  ['310, lake victoria']
# SAME:  []
# NONE_TRUE_EQUAL:  ['310,lake victoria']
# NONE_PRED_EQUAL:  ['310, lake victoria']
# TRUE:  ['311,domenico modugno']
# PRED:  ['311,domenico modugno']
# SAME:  ['311,domenico modugno']
# TRUE:  ['312,grameen bank']
# PRED:  ['312,grameen bank']
# SAME:  ['312,grameen bank']
# TRUE:  ['313,benjamin franklin terry', '313,us route 59']
# PRED:  ['313,benjamin franklin terry', '313,us route 59']
# SAME:  ['313,benjamin franklin terry', '313,us route 59']
# TRUE:  ['314,james langer']
# PRED:  ['314,james langer']
# SAME:  ['314,james langer']
# TRUE:  ['315,john trumbull', '315,a foreign policy']
# PRED:  ['315,john trumbull']
# LESS:  ['315,john trumbull']
# TRUE:  ['316,peter-john vettese']
# PRED:  ['316,peter-john vettese']
# SAME:  ['316,peter-john vettese']
# TRUE:  ['317,edwin catmull']
# PRED:  ['317,edwin catmull']
# SAME:  ['317,edwin catmull']
# TRUE:  ['318,eric roth']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['318,eric roth']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['319,coneygree', '319,martin molony']
# PRED:  ['319,the martin molony', '319,coneygree']
# SAME:  ['319,coneygree']
# PARTIAL:  ['319,coneygree']
# TRUE:  ['320,dallas']
# PRED:  ['320,dallas']
# SAME:  ['320,dallas']
# TRUE:  ['321,royal society']
# PRED:  ['321,the royal society']
# SAME:  []
# NONE_TRUE_EQUAL:  ['321,royal society']
# NONE_PRED_EQUAL:  ['321,the royal society']
# TRUE:  ['322,philosophy', '322,stephen law']
# PRED:  ['322,stephen law']
# LESS:  ['322,stephen law']
# TRUE:  ['323,gervase helwys']
# PRED:  ['323,gervase helwys']
# SAME:  ['323,gervase helwys']
# TRUE:  ['324,raamlaxman']
# PRED:  ['324,raamlaxman']
# SAME:  ['324,raamlaxman']
# TRUE:  ['325,jose cha cha jimenez']
# PRED:  ['325,jose cha cha jimenez']
# SAME:  ['325,jose cha cha jimenez']
# TRUE:  ['326,bernard herrmann', '326,rko pictures']
# PRED:  ['326,rko pictures', '326,bernard herrmann']
# SAME:  ['326,rko pictures', '326,bernard herrmann']
# TRUE:  ['327,red ahead']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['327,red ahead']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['328,kore presbyterian theological seminar', '328,celal bayar university']
# PRED:  ['328,celal bayer', '328,presbyterian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['328,kore presbyterian theological seminar', '328,celal bayar university']
# NONE_PRED_EQUAL:  ['328,celal bayer', '328,presbyterian']
# TRUE:  ['329,hamline avenue']
# PRED:  ['329,hamline avenue']
# SAME:  ['329,hamline avenue']
# TRUE:  ['330,yasmin paige']
# PRED:  ['330,yasmin paige']
# SAME:  ['330,yasmin paige']
# TRUE:  ['331,heinz kokott']
# PRED:  ['331,heinz kokott', '331,nazi army']
# MORE:  ['331,heinz kokott']
# TRUE:  ['332,jann wenner', '332,ralph j. gleason']
# PRED:  ['332,jann wenner', '332,ralph j. gleason']
# SAME:  ['332,jann wenner', '332,ralph j. gleason']
# TRUE:  ['333,nevado de toluca', '333,sierra nevada']
# PRED:  ['333,sierra nevada', '333,u.s.', '333,nevado de toluca']
# MORE:  ['333,sierra nevada', '333,nevado de toluca']
# TRUE:  ['334,bbc hd', '334,doctor who confidential']
# PRED:  ['334, ', '334,bbc hd']
# SAME:  ['334,bbc hd']
# PARTIAL:  ['334,bbc hd']
# TRUE:  ['335,milk cow blues', '335,sings kristofferson']
# PRED:  ['335,sings kristofferson', '335,milk cow blues']
# SAME:  ['335,sings kristofferson', '335,milk cow blues']
# TRUE:  ['336,thesaban']
# PRED:  ['336,thesaban']
# SAME:  ['336,thesaban']
# TRUE:  ['337,micronesia']
# PRED:  ['337,micronesia']
# SAME:  ['337,micronesia']
# TRUE:  ['338,stephen e. ambrose']
# PRED:  ['338,stephen e. ambrose']
# SAME:  ['338,stephen e. ambrose']
# TRUE:  ['339,central european summer time']
# PRED:  ['339,central european']
# SAME:  []
# NONE_TRUE_EQUAL:  ['339,central european summer time']
# NONE_PRED_EQUAL:  ['339,central european']
# TRUE:  ['340,steven peterman', '340,the best of both worlds']
# PRED:  ['340, ', '340,the best of both worlds', '340,steven peterman']
# MORE:  ['340,the best of both worlds', '340,steven peterman']
# TRUE:  ['341,ralph j. gleason']
# PRED:  ['341,ralph j. gleason']
# SAME:  ['341,ralph j. gleason']
# TRUE:  ['342,paul morphy']
# PRED:  ['342,paul morphy']
# SAME:  ['342,paul morphy']
# TRUE:  ['343,thames estuary', '343,north sea']
# PRED:  ['343, thames estuary', '343,north sea']
# SAME:  ['343,north sea']
# PARTIAL:  ['343,north sea']
# TRUE:  ['344,ganefo']
# PRED:  ['344,ganefo']
# SAME:  ['344,ganefo']
# TRUE:  ['345,matt williams']
# PRED:  ['345,matt williams']
# SAME:  ['345,matt williams']
# TRUE:  ['346,massachusetts house of representatives', '346,samuel w. mccall']
# PRED:  ['346,samuel w. mccall', '346,massachusetts house of representatives']
# SAME:  ['346,samuel w. mccall', '346,massachusetts house of representatives']
# TRUE:  ['347,golden globe']
# PRED:  ['347,the golden globe']
# SAME:  []
# NONE_TRUE_EQUAL:  ['347,golden globe']
# NONE_PRED_EQUAL:  ['347,the golden globe']
# TRUE:  ['348,pizza', "348,mr. jim's pizza"]
# PRED:  ['348,jim']
# NONE_TRUE_LESS:  ['348,pizza', "348,mr. jim's pizza"]
# NONE_PRED_LESS:  ['348,jim']
# TRUE:  ['349,even-toed ungulate']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['349,even-toed ungulate']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['350,mathematics']
# PRED:  ['350,one']
# SAME:  []
# NONE_TRUE_EQUAL:  ['350,mathematics']
# NONE_PRED_EQUAL:  ['350,one']
# TRUE:  ['351,winston bryant', '351,joe purcell']
# PRED:  ['351,joe purcell', '351,winston bryant']
# SAME:  ['351,joe purcell', '351,winston bryant']
# TRUE:  ['352,jim harris']
# PRED:  ['352,jim harris']
# SAME:  ['352,jim harris']
# TRUE:  ['353,corringham railway station']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['353,corringham railway station']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['354,stan lee', '354,the incredible hulk']
# PRED:  ['']
# NONE_TRUE_LESS:  ['354,stan lee', '354,the incredible hulk']
# NONE_PRED_LESS:  ['']
# TRUE:  ['355,emanuel de guzman']
# PRED:  ['355,emanuel de guzman']
# SAME:  ['355,emanuel de guzman']
# TRUE:  ['356,al khaleejiya 100.9']
# PRED:  ['356,al khaleejiya 100.9']
# SAME:  ['356,al khaleejiya 100.9']
# TRUE:  ['357,harvest christian center']
# PRED:  ['357,the harvest christian center']
# SAME:  []
# NONE_TRUE_EQUAL:  ['357,harvest christian center']
# NONE_PRED_EQUAL:  ['357,the harvest christian center']
# TRUE:  ["358,master's sun"]
# PRED:  ["358,master's sun"]
# SAME:  ["358,master's sun"]
# TRUE:  ['359,virtual kasparov', '359,fr agnel school and jr college']
# PRED:  ['359,fr agnel school', '359,jr']
# SAME:  []
# NONE_TRUE_EQUAL:  ['359,virtual kasparov', '359,fr agnel school and jr college']
# NONE_PRED_EQUAL:  ['359,fr agnel school', '359,jr']
# TRUE:  ['360,colts neck township', '360,beverly hills']
# PRED:  ['360,colts neck township', '360,beverly hills']
# SAME:  ['360,colts neck township', '360,beverly hills']
# TRUE:  ['361,blizzard']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['361,blizzard']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['362,shannon pot', '362,limerick']
# PRED:  ['362,shannon pot', '362,limerick']
# SAME:  ['362,shannon pot', '362,limerick']
# TRUE:  ['363,gloucestershire', '363,reading']
# PRED:  ['363,reading', '363,gloucestershire']
# ...
# PRED:  ['4882,one', '4882,warner bros. animation']
# MORE:  ['4882,warner bros. animation']
# TRUE:  ['4883,paul demiville']
# PRED:  ['4883,paul demiville']
# SAME:  ['4883,paul demiville']
# TRUE:  ['4884,gdask', '4884,kaliningrad']
# PRED:  ['4884,kaliningrad']
# LESS:  ['4884,kaliningrad']
# TRUE:  ['4885,alexander lippisch']
# PRED:  ['4885,alexander lippisch']
# SAME:  ['4885,alexander lippisch']
# TRUE:  ['4886,david lewis', '4886,thorington railway station']
# PRED:  ['4886,thorington', '4886, ', '4886,david lewis']
# MORE:  ['4886,david lewis']
# TRUE:  ['4887,nasa']
# PRED:  ['4887,nasa']
# SAME:  ['4887,nasa']
# TRUE:  ['4888,gibson les paul']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4888,gibson les paul']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4889,haight-ashbury', '4889,castro district']
# PRED:  ['4889,castro district', '4889,haight-ashbury']
# SAME:  ['4889,castro district', '4889,haight-ashbury']
# TRUE:  ['4890,uk']
# PRED:  ['4890,uk']
# SAME:  ['4890,uk']
# TRUE:  ['4891,motorpsycho nitemare', '4891,moondog matinee']
# PRED:  ['4891,moondog matinee', '4891,motorpsycho nitemare']
# SAME:  ['4891,moondog matinee', '4891,motorpsycho nitemare']
# TRUE:  ['4892,schutzstaffels']
# PRED:  ['4892,schutzstaffels']
# SAME:  ['4892,schutzstaffels']
# TRUE:  ['4893,kron ngoy', '4893,hang chuon naron']
# PRED:  ['4893,kron ngoy']
# LESS:  ['4893,kron ngoy']
# TRUE:  ['4894,william w brien']
# PRED:  ['4894,william w brien']
# SAME:  ['4894,william w brien']
# TRUE:  ['4895,ios']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4895,ios']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4896,the incredible hulk']
# PRED:  ['4896,1982']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4896,the incredible hulk']
# NONE_PRED_EQUAL:  ['4896,1982']
# TRUE:  ['4897,carl sanders']
# PRED:  ['4897,one', '4897,carl sanders']
# MORE:  ['4897,carl sanders']
# TRUE:  ['4898,william c p breckinridge']
# PRED:  ['4898,william c p']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4898,william c p breckinridge']
# NONE_PRED_EQUAL:  ['4898,william c p']
# TRUE:  ["4899,st. peter's basilica"]
# PRED:  ["4899,st. peter's basilica"]
# SAME:  ["4899,st. peter's basilica"]
# TRUE:  ['4900,dreamworks television', '4900,stephen e. ambrose']
# PRED:  ['4900,stephen e. ambrose', '4900,dreamworks television']
# SAME:  ['4900,stephen e. ambrose', '4900,dreamworks television']
# TRUE:  ['4901,lake washington']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4901,lake washington']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4902,fedexfield']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4902,fedexfield']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4903,edsel villager']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4903,edsel villager']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4904,sierra madre de chiapas']
# PRED:  ['4904,the sierra madre de chiapas']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4904,sierra madre de chiapas']
# NONE_PRED_EQUAL:  ['4904,the sierra madre de chiapas']
# TRUE:  ['4905,cherokee']
# PRED:  ['4905,cherokee']
# SAME:  ['4905,cherokee']
# TRUE:  ["4906,he's a liar"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["4906,he's a liar"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4907,bbc multimedia', '4907,mazes of time']
# PRED:  ['4907,mazes', '4907,bbc']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4907,bbc multimedia', '4907,mazes of time']
# NONE_PRED_EQUAL:  ['4907,mazes', '4907,bbc']
# TRUE:  ['4908,doonesbury']
# PRED:  ['4908,doonesbury']
# SAME:  ['4908,doonesbury']
# TRUE:  ['4909,aachen cathedral']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4909,aachen cathedral']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4910,robert a. taft', '4910,charles phelps taft ii']
# PRED:  ['4910,charles phelps taft ii', '4910,robert a. taft']
# SAME:  ['4910,charles phelps taft ii', '4910,robert a. taft']
# TRUE:  ['4911,giorgos kaminis']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4911,giorgos kaminis']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4912,linda jenness']
# PRED:  ['4912,linda jenness']
# SAME:  ['4912,linda jenness']
# TRUE:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# PRED:  ['4913,the northsouth transport corridor']
# NONE_TRUE_LESS:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# NONE_PRED_LESS:  ['4913,the northsouth transport corridor']
# TRUE:  ['4914,fender stratocaster']
# PRED:  ['4914,one', '4914,the fender stratocaster']
# NONE_TRUE_MORE:  ['4914,fender stratocaster']
# NONE_PRED_MORE:  ['4914,one', '4914,the fender stratocaster']
# TRUE:  ['4915,primate']
# PRED:  ['4915,primate']
# SAME:  ['4915,primate']
# TRUE:  ['4916,willem-alexander']
# PRED:  ['4916,willem-alexander', '4916,netherlands']
# MORE:  ['4916,willem-alexander']
# TRUE:  ['4917,chelsea f.c.']
# PRED:  ['4917,chelsea f.c.']
# SAME:  ['4917,chelsea f.c.']
# TRUE:  ['4918,kingdom']
# PRED:  ['4918,united monarch']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4918,kingdom']
# NONE_PRED_EQUAL:  ['4918,united monarch']
# TRUE:  ['4919,malaysian pwd']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4919,malaysian pwd']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4920,king county, washington', '4920,phil lumpkin']
# PRED:  ['4920,the king county', '4920,washington', '4920,phil lumpkin']
# MORE:  ['4920,phil lumpkin']
# TRUE:  ['4921,old lyme, connecticut']
# PRED:  ['4921,old lyme', '4921,connecticut']
# NONE_TRUE_MORE:  ['4921,old lyme, connecticut']
# NONE_PRED_MORE:  ['4921,old lyme', '4921,connecticut']
# TRUE:  ['4922,mac os', '4922,microsoft windows']
# PRED:  ['4922,os', '4922,microsoft', '4922,windows', '4922,mac os']
# MORE:  ['4922,mac os']
# TRUE:  ['4923,ike clanton']
# PRED:  ['4923,ike clanton']
# SAME:  ['4923,ike clanton']
# TRUE:  ['4924,indian general election, 2004']
# PRED:  ['4924,indian', '4924,2004', '4924,andhra pradesh']
# NONE_TRUE_MORE:  ['4924,indian general election, 2004']
# NONE_PRED_MORE:  ['4924,indian', '4924,2004', '4924,andhra pradesh']
# TRUE:  ['4925,miao people', '4925,palang dharma party']
# PRED:  ['4925,the palang dharma party', '4925, ']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4925,miao people', '4925,palang dharma party']
# NONE_PRED_EQUAL:  ['4925,the palang dharma party', '4925, ']
# TRUE:  ["4926,brown's corners, toronto", '4926,krista kelly']
# PRED:  ['4926,krista kelly']
# LESS:  ['4926,krista kelly']
# TRUE:  ['4927,judge advocate general corps']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4927,judge advocate general corps']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4928,pope pius xi']
# PRED:  ['4928,pope']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4928,pope pius xi']
# NONE_PRED_EQUAL:  ['4928,pope']
# TRUE:  ['4929,brown']
# PRED:  ['4929,brown']
# SAME:  ['4929,brown']
# TRUE:  ['4930,solon spencer beman']
# PRED:  ['4930,solon spencer beman']
# SAME:  ['4930,solon spencer beman']
# TRUE:  ['4931,1967 mexican grand prix', '4931,1971 us']
# PRED:  ['4931,the 1967 mexican grand prix', '4931,1971', '4931,us']
# NONE_TRUE_MORE:  ['4931,1967 mexican grand prix', '4931,1971 us']
# NONE_PRED_MORE:  ['4931,the 1967 mexican grand prix', '4931,1971', '4931,us']
# TRUE:  ['4932,sam sen railway station']
# PRED:  ['4932,sam sen railway station']
# SAME:  ['4932,sam sen railway station']
# TRUE:  ['4933,newcastle']
# PRED:  ['4933,newcastle']
# SAME:  ['4933,newcastle']
# TRUE:  ['4934,tehran']
# PRED:  ['4934,tehran']
# SAME:  ['4934,tehran']
# TRUE:  ['4935,wxme']
# PRED:  ['4935,wxme']
# SAME:  ['4935,wxme']
# TRUE:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# PRED:  ['4936,mickey', "4936,tommy tucker's"]
# SAME:  []
# NONE_TRUE_EQUAL:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# NONE_PRED_EQUAL:  ['4936,mickey', "4936,tommy tucker's"]
# TRUE:  ['4937,quich department']
# PRED:  ['4937,quich department']
# SAME:  ['4937,quich department']
# TRUE:  ['4938,apollo 11', '4938,gemini 8']
# PRED:  ['4938,apollo 11', '4938,gemini']
# SAME:  ['4938,apollo 11']
# PARTIAL:  ['4938,apollo 11']
# TRUE:  ['4939,seattle great wheel']
# PRED:  ['4939,seattle great wheel']
# SAME:  ['4939,seattle great wheel']
# TRUE:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# PRED:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# SAME:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# TRUE:  ['4941,the bleeding heart band']
# PRED:  ['4941,the bleeding heart band']
# SAME:  ['4941,the bleeding heart band']
# TRUE:  ['4942,russian railways']
# PRED:  ['4942,russian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4942,russian railways']
# NONE_PRED_EQUAL:  ['4942,russian']
# TRUE:  ['4943,russell t davies', '4943,wizards and the aliens']
# PRED:  ['4943,wizards']
# NONE_TRUE_LESS:  ['4943,russell t davies', '4943,wizards and the aliens']
# NONE_PRED_LESS:  ['4943,wizards']
# TRUE:  ['4944,arkansas']
# PRED:  ['4944,arkansas']
# SAME:  ['4944,arkansas']
# TRUE:  ['4945,ceratosoma tenue']
# PRED:  ['4945,ceratosoma']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4945,ceratosoma tenue']
# NONE_PRED_EQUAL:  ['4945,ceratosoma']
# TRUE:  ['4946,riley reid', '4946,holmes colbert']
# PRED:  ['4946, riley reid', '4946,holmes colbert']
# SAME:  ['4946,holmes colbert']
# PARTIAL:  ['4946,holmes colbert']
# TRUE:  ['4947,girls']
# PRED:  ['4947,prodigy']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4947,girls']
# NONE_PRED_EQUAL:  ['4947,prodigy']
# TRUE:  ['4948,indira gandhi']
# PRED:  ['4948,indira gandhi']
# SAME:  ['4948,indira gandhi']
# TRUE:  ['4949,manhattan project']
# PRED:  ['4949,the manhattan project']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4949,manhattan project']
# NONE_PRED_EQUAL:  ['4949,the manhattan project']
# TRUE:  ['4950,secrets and lies']
# PRED:  ['4950,lies']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4950,secrets and lies']
# NONE_PRED_EQUAL:  ['4950,lies']
# TRUE:  ['4951,ohio']
# PRED:  ['4951,ohio']
# SAME:  ['4951,ohio']
# TRUE:  ['4952,john o conner']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4952,john o conner']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4953,charlie justice', '4953,bobby hoppe']
# PRED:  ['4953,the charlie justice', '4953,american', '4953,bobby hoppe']
# MORE:  ['4953,bobby hoppe']
# TRUE:  ['4954,jimmy wales']
# PRED:  ['4954,jimmy']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4954,jimmy wales']
# NONE_PRED_EQUAL:  ['4954,jimmy']
# TRUE:  ['4955,ted williams tunnel', '4955,leonard memorial']
# PRED:  ['4955,ted williams', '4955,leonard memorial']
# SAME:  ['4955,leonard memorial']
# PARTIAL:  ['4955,leonard memorial']
# TRUE:  ['4956,michaelhouse']
# PRED:  ['4956,michaelhouse']
# SAME:  ['4956,michaelhouse']
# TRUE:  ['4957,yosemite park']
# PRED:  ['4957,first', '4957,yosemite park']
# MORE:  ['4957,yosemite park']
# TRUE:  ['4958,levant']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4958,levant']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4959,fifety five days at peking', '4959,awakening']
# PRED:  ['4959,awakening', '4959,five days']
# SAME:  ['4959,awakening']
# PARTIAL:  ['4959,awakening']
# TRUE:  ['4960,huey, dewey, and louie', '4960,clan mcduck']
# PRED:  ['4960,clan mcduck', '4960,huey', '4960,dewey', '4960,louie']
# MORE:  ['4960,clan mcduck']
# TRUE:  ['4961,ennejma ezzahra', '4961,boga']
# PRED:  ['4961,ennejma ezzahra', '4961,boga']
# SAME:  ['4961,ennejma ezzahra', '4961,boga']
# TRUE:  ['4962,charles gordon']
# PRED:  ['4962,charles gordon']
# SAME:  ['4962,charles gordon']
# TRUE:  ['4963,maryanne trump barry', '4963,le cirque']
# PRED:  ['4963,le cirque', '4963,maryanne trump']
# SAME:  ['4963,le cirque']
# PARTIAL:  ['4963,le cirque']
# TRUE:  ['4964,toronto']
# PRED:  ['4964,toronto']
# SAME:  ['4964,toronto']
# TRUE:  ['4965,laurie johnson', '4965,stanley kubrick']
# PRED:  ["4965,the stanley kubrick's", '4965,laurie johnson']
# SAME:  ['4965,laurie johnson']
# PARTIAL:  ['4965,laurie johnson']
# TRUE:  ['4966,uss kittiwake', '4966,haight-ashbury']
# PRED:  ['4966,haight-ashbury', '4966,uss kittiwake']
# SAME:  ['4966,haight-ashbury', '4966,uss kittiwake']
# TRUE:  ['4967,motorpsycho nitemare']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4967,motorpsycho nitemare']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4968,hbo', '4968,erik jendresen']
# PRED:  ['4968,erik jendresen', '4968,hbo']
# SAME:  ['4968,erik jendresen', '4968,hbo']
# TRUE:  ['4969,battle']
# PRED:  ['4969,battle of the bulge']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4969,battle']
# NONE_PRED_EQUAL:  ['4969,battle of the bulge']
# TRUE:  ['4970,israel', '4970,colin powell']
# PRED:  ['4970,colin powell']
# LESS:  ['4970,colin powell']
# TRUE:  ['4971,the ultimate fighter: team rousey vs. team tate']
# PRED:  ['4971,the ultimate fighter', '4971,team tate']
# NONE_TRUE_MORE:  ['4971,the ultimate fighter: team rousey vs. team tate']
# NONE_PRED_MORE:  ['4971,the ultimate fighter', '4971,team tate']
# TRUE:  ['4972,alexa scimeca']
# PRED:  ['4972,alexa']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4972,alexa scimeca']
# NONE_PRED_EQUAL:  ['4972,alexa']
# TRUE:  ['4973,south african class 11e', '4973,renfe class 333']
# PRED:  ['4973,south african', '4973,11e', '4973,renfe', '4973,333']
# NONE_TRUE_MORE:  ['4973,south african class 11e', '4973,renfe class 333']
# NONE_PRED_MORE:  ['4973,south african', '4973,11e', '4973,renfe', '4973,333']
# TRUE:  ['4974,erich bagge', '4974,erban ieica']
# PRED:  ['4974,erich bagge']
# LESS:  ['4974,erich bagge']
# TRUE:  ['4975,apollo 11', '4975,nasa']
# PRED:  ['4975,nasa', '4975,apollo 11']
# SAME:  ['4975,nasa', '4975,apollo 11']
# TRUE:  ['4976,ape', '4976,primate']
# PRED:  ['4976,ape']
# LESS:  ['4976,ape']
# TRUE:  ['4977,goethe prize']
# PRED:  ['4977,goethe prize']
# SAME:  ['4977,goethe prize']
# TRUE:  ['4978,amiga']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4978,amiga']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4979,william henry harrison tomb state memorial', '4979,john scott harrison']
# PRED:  ['4979,william henry harrison', '4979,john scott harrison']
# SAME:  ['4979,john scott harrison']
# PARTIAL:  ['4979,john scott harrison']
# TRUE:  ['4980,muhammad yunus']
# PRED:  ['4980,muhammad yunus']
# SAME:  ['4980,muhammad yunus']
# TRUE:  ['4981,saunders county']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4981,saunders county']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4982,miao rebellion']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4982,miao rebellion']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4983,italic']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4983,italic']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4984,bbc multimedia', '4984,visions']
# PRED:  ['4984,bbc']
# NONE_TRUE_LESS:  ['4984,bbc multimedia', '4984,visions']
# NONE_PRED_LESS:  ['4984,bbc']
# TRUE:  ['4985,donna shalala']
# PRED:  ['4985,donna shalala']
# SAME:  ['4985,donna shalala']
# TRUE:  ['4986,french southern and antarctic lands', '4986,kerguelen islands']
# PRED:  ['4986,kerguelen', '4986,french']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4986,french southern and antarctic lands', '4986,kerguelen islands']
# NONE_PRED_EQUAL:  ['4986,kerguelen', '4986,french']
# TRUE:  ['4987,weber thompson']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4987,weber thompson']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4988,edith vonnegut']
# PRED:  ['4988,edith vonnegut']
# SAME:  ['4988,edith vonnegut']
# TRUE:  ['4989,iyoas i']
# PRED:  ['4989,iyoas']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4989,iyoas i']
# NONE_PRED_EQUAL:  ['4989,iyoas']
# TRUE:  ['4990,wcw mayhem']
# PRED:  ['4990,wcw mayhem']
# SAME:  ['4990,wcw mayhem']
# TRUE:  ['4991,rca records']
# PRED:  ['4991,rca']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4991,rca records']
# NONE_PRED_EQUAL:  ['4991,rca']
# TRUE:  ['4992,nick diaz', '4992,brazilian jiu-jitsu']
# PRED:  ['4992,brazilian', '4992,nick diaz']
# SAME:  ['4992,nick diaz']
# PARTIAL:  ['4992,nick diaz']
# TRUE:  ['4993,amstelveen']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4993,amstelveen']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4994,choctaw']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4994,choctaw']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4995,larry j. franco']
# PRED:  ['4995,larry j. franco']
# SAME:  ['4995,larry j. franco']
# TRUE:  ['4996,tnt', '4996,j. michael stroczynski']
# PRED:  ['4996,j. michael stroczynski', '4996,tnt']
# SAME:  ['4996,j. michael stroczynski', '4996,tnt']
# TRUE:  ['4997,varsity stadium']
# PRED:  ['4997,varsity stadium']
# SAME:  ['4997,varsity stadium']
# TRUE:  ['4998,robin kovacs', '4998,nyrangers']
# PRED:  ['4998,ny rangers', '4998,robin kovacs']
# SAME:  ['4998,robin kovacs']
# PARTIAL:  ['4998,robin kovacs']
# TRUE:  ["4999,marquette golden eagles men's basketball team, 2008-09", "4999,marquette golden eagles men's basketball team"]
# PRED:  ['4999,marquette golden eagles', '4999,2008-09', '4999,marquette golden eagles']
# NONE_TRUE_MORE:  ["4999,marquette golden eagles men's basketball team, 2008-09", "4999,marquette golden eagles men's basketball team"]
# NONE_PRED_MORE:  ['4999,marquette golden eagles', '4999,2008-09', '4999,marquette golden eagles']
# 2238
# 299
# 210
# 320
# 1322
# 198
# 413
# 4102

# %%
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# 2238
# 299
# 210
# 320
# 1322
# 198
# 413
# 4102
# 0.6175850647395363

# %%
### compare only md predictions

match, partial, less, more, none_match, none_less, none_more, predicted = compare_predictions(real, ner_md)
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# TRUE:  ['0,bill finger']
# PRED:  ['0,bill finger']
# SAME:  ['0,bill finger']
# TRUE:  ['1,selwyn lloyd', '1,winston churchill']
# PRED:  ['1,selwyn lloyd']
# LESS:  ['1,selwyn lloyd']
# TRUE:  ['2,gestapo']
# PRED:  ['2,gestapo']
# SAME:  ['2,gestapo']
# TRUE:  ['3,mumbai north']
# PRED:  ['3,mumbai']
# SAME:  []
# NONE_TRUE_EQUAL:  ['3,mumbai north']
# NONE_PRED_EQUAL:  ['3,mumbai']
# TRUE:  ['4,roberto clemente bridge']
# PRED:  ['4,roberto clemente bridge']
# SAME:  ['4,roberto clemente bridge']
# TRUE:  ['5,ptolemy xiii theos philopator', '5,cleopatra v']
# PRED:  ['5,ptolemy xiii theos philopator', '5,cleopatra v']
# SAME:  ['5,ptolemy xiii theos philopator', '5,cleopatra v']
# TRUE:  ['6,li si']
# PRED:  ['6,li si']
# SAME:  ['6,li si']
# TRUE:  ['7,pavel moroz', '7,yakov estrin']
# PRED:  ['7,pavel moroz', '7,yakov estrin']
# SAME:  ['7,pavel moroz', '7,yakov estrin']
# TRUE:  ['8,broadmeadows, victoria']
# PRED:  ['8,broadmeadows, victoria']
# SAME:  ['8,broadmeadows, victoria']
# TRUE:  ['9,asc creative services']
# PRED:  ['9,asc creative services']
# SAME:  ['9,asc creative services']
# TRUE:  ['10,ernest rutherford', '10,charles drummond ellis']
# PRED:  ['10,ernest rutherford', '10,charles drummond ellis']
# SAME:  ['10,ernest rutherford', '10,charles drummond ellis']
# TRUE:  ['11,rep parasol']
# PRED:  ['11,rep']
# SAME:  []
# NONE_TRUE_EQUAL:  ['11,rep parasol']
# NONE_PRED_EQUAL:  ['11,rep']
# TRUE:  ["12,monroe carell jr. children's hospital", '12,vanderbilt', '12,duncan u. fletcher']
# PRED:  ["12,the monroe carell jr. children's hospital", '12,vanderbilt', '12,the duncan u. fletcher']
# SAME:  ['12,vanderbilt']
# PARTIAL:  ['12,vanderbilt']
# TRUE:  ['13,josef johansson', '13,nader guirat']
# PRED:  ['13,nader guirat', '13,josef johansson']
# SAME:  ['13,nader guirat', '13,josef johansson']
# TRUE:  ['14,dr who confidential', '14,the sara jane adventure']
# PRED:  ['']
# NONE_TRUE_LESS:  ['14,dr who confidential', '14,the sara jane adventure']
# NONE_PRED_LESS:  ['']
# TRUE:  ['15,hbo']
# PRED:  ['15,hbo']
# SAME:  ['15,hbo']
# TRUE:  ['16,stanislav morozov', '16,nikolai morozov']
# PRED:  ['16,nikolai morozov', '16,stanislav morozov']
# SAME:  ['16,nikolai morozov', '16,stanislav morozov']
# TRUE:  ['17,abhijit kunte', '17,kasparov']
# PRED:  ['17,abhijit kunte', '17,kasparov']
# SAME:  ['17,abhijit kunte', '17,kasparov']
# TRUE:  ['18,outlook', '18,msx basics']
# PRED:  ['']
# NONE_TRUE_LESS:  ['18,outlook', '18,msx basics']
# NONE_PRED_LESS:  ['']
# TRUE:  ['19,ronaldo']
# PRED:  ['19,seasons', '19,ronaldo']
# MORE:  ['19,ronaldo']
# TRUE:  ['20,samurabsheron channel', '20,anar salmanov']
# PRED:  ['20,samurabsheron', '20,anar salmanov']
# SAME:  ['20,anar salmanov']
# PARTIAL:  ['20,anar salmanov']
# TRUE:  ['21,2nd foreign infantry regiment']
# PRED:  ['21,2nd foreign infantry regiment']
# SAME:  ['21,2nd foreign infantry regiment']
# TRUE:  ['22,sr class 3sub']
# PRED:  ['22,3sub']
# SAME:  []
# NONE_TRUE_EQUAL:  ['22,sr class 3sub']
# NONE_PRED_EQUAL:  ['22,3sub']
# TRUE:  ['23,kevin jonas', '23,joe jonas']
# PRED:  ['23,kevin jonas', '23,joe jonas']
# SAME:  ['23,kevin jonas', '23,joe jonas']
# TRUE:  ['24,sunrise (himym)', '24,timm gunn']
# PRED:  ['24,timm gunn', '24,sunrise', '24,himym']
# MORE:  ['24,timm gunn']
# TRUE:  ['25,o.co coliseum']
# PRED:  ['25,o.co coliseum']
# SAME:  ['25,o.co coliseum']
# TRUE:  ['26,rishkiesh']
# PRED:  ['26,rishkiesh']
# SAME:  ['26,rishkiesh']
# TRUE:  ['27,north america', '27,airtours airways']
# PRED:  ['']
# NONE_TRUE_LESS:  ['27,north america', '27,airtours airways']
# NONE_PRED_LESS:  ['']
# TRUE:  ['28,national medal of science']
# PRED:  ['28,phds', '28,national medal of science']
# MORE:  ['28,national medal of science']
# TRUE:  ['29,aston villa 2000-02 season', '29,middlesbrough f.c. season 2009-10']
# PRED:  ['29,aston villa 2000-02 season', '29,middlesbrough f.c.', '29,2009']
# MORE:  ['29,aston villa 2000-02 season']
# TRUE:  ['30,william harper']
# PRED:  ['30,william harper']
# SAME:  ['30,william harper']
# TRUE:  ['31,pcl constructures']
# PRED:  ['31,pcl']
# SAME:  []
# NONE_TRUE_EQUAL:  ['31,pcl constructures']
# NONE_PRED_EQUAL:  ['31,pcl']
# TRUE:  ['32,jonas brothers', '32,kevin jonas']
# PRED:  ['32,kevin jonas', '32,jonas']
# SAME:  ['32,kevin jonas']
# PARTIAL:  ['32,kevin jonas']
# TRUE:  ['33,cosmos']
# PRED:  ['33,sagan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['33,cosmos']
# NONE_PRED_EQUAL:  ['33,sagan']
# TRUE:  ['34,rosemont, illinois']
# PRED:  ['34,rosemont', '34,illinois']
# NONE_TRUE_MORE:  ['34,rosemont, illinois']
# NONE_PRED_MORE:  ['34,rosemont', '34,illinois']
# TRUE:  ['35,greenup county high school']
# PRED:  ['35,greenup county high school']
# SAME:  ['35,greenup county high school']
# TRUE:  ['36,bobby hoppe']
# PRED:  ['36,bobby hoppe']
# SAME:  ['36,bobby hoppe']
# TRUE:  ['37,the second coming']
# PRED:  ['37,second']
# SAME:  []
# NONE_TRUE_EQUAL:  ['37,the second coming']
# NONE_PRED_EQUAL:  ['37,second']
# TRUE:  ['38,miguel de cervantes']
# PRED:  ['38,miguel de cervantes']
# SAME:  ['38,miguel de cervantes']
# TRUE:  ['39,progressive rock']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['39,progressive rock']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['40,reading, berkshire']
# PRED:  ['40,berkshire']
# SAME:  []
# NONE_TRUE_EQUAL:  ['40,reading, berkshire']
# NONE_PRED_EQUAL:  ['40,berkshire']
# TRUE:  ['41,crystal harris']
# PRED:  ['41,crystal harris']
# SAME:  ['41,crystal harris']
# TRUE:  ['42,west thurrock', '42,essex']
# PRED:  ['42,essex county']
# NONE_TRUE_LESS:  ['42,west thurrock', '42,essex']
# NONE_PRED_LESS:  ['42,essex county']
# TRUE:  ['43,niederkirchnerstrae']
# PRED:  ['43,niederkirchnerstrae']
# SAME:  ['43,niederkirchnerstrae']
# TRUE:  ['44,steven moffat']
# PRED:  ['44,steven moffat']
# SAME:  ['44,steven moffat']
# TRUE:  ['45,ford falcon cobra', '45,dagenham wind turbines']
# PRED:  ['45,dagenham', '45,ford falcon cobra']
# SAME:  ['45,ford falcon cobra']
# PARTIAL:  ['45,ford falcon cobra']
# TRUE:  ['46,san francisco international airport']
# PRED:  ['46,san francisco international airport']
# SAME:  ['46,san francisco international airport']
# TRUE:  ['47,maritime museum of san diego']
# PRED:  ['47,san diego']
# SAME:  []
# NONE_TRUE_EQUAL:  ['47,maritime museum of san diego']
# NONE_PRED_EQUAL:  ['47,san diego']
# TRUE:  ['48,sarah walker', '48,trinity school, brentwood']
# PRED:  ['48,the trinity school', '48,brentwood', '48,sarah walker']
# MORE:  ['48,sarah walker']
# TRUE:  ['49,21vianet']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['49,21vianet']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['50,urbain le verrier', '50,johann gottfried']
# PRED:  ['50,johann gottfired', '50,urbain le']
# SAME:  []
# NONE_TRUE_EQUAL:  ['50,urbain le verrier', '50,johann gottfried']
# NONE_PRED_EQUAL:  ['50,johann gottfired', '50,urbain le']
# TRUE:  ['51,elmer burkett']
# PRED:  ['51,elmer burkett']
# SAME:  ['51,elmer burkett']
# TRUE:  ['52,hensley meulens', '52,steve ontiveros']
# PRED:  ['52,hensley meulens', '52,steve ontiveros']
# SAME:  ['52,hensley meulens', '52,steve ontiveros']
# TRUE:  ['53,lucy sullivan is getting married']
# PRED:  ['53,lucy sullivan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['53,lucy sullivan is getting married']
# NONE_PRED_EQUAL:  ['53,lucy sullivan']
# TRUE:  ['54,faaa', '54,society islands']
# PRED:  ['54,society islands', '54,faaa']
# SAME:  ['54,society islands', '54,faaa']
# TRUE:  ['55,1997 canadian grand prix', '55,94 spanish']
# PRED:  ['55,1997', '55,94']
# SAME:  []
# NONE_TRUE_EQUAL:  ['55,1997 canadian grand prix', '55,94 spanish']
# NONE_PRED_EQUAL:  ['55,1997', '55,94']
# TRUE:  ['56,richard winn']
# PRED:  ['56,richard winn']
# SAME:  ['56,richard winn']
# TRUE:  ['57,sherlock', '57,arthur levinson']
# PRED:  ['57,sherlock', '57,arthur levinson']
# SAME:  ['57,sherlock', '57,arthur levinson']
# TRUE:  ['58,master card center', '58,sam carrrick']
# PRED:  ['58,the master card', '58,sam carrrick']
# SAME:  ['58,sam carrrick']
# PARTIAL:  ['58,sam carrrick']
# TRUE:  ['59,fremantle media']
# PRED:  ['59,fremantle media']
# SAME:  ['59,fremantle media']
# TRUE:  ['60,south loop printing house district']
# PRED:  ['60,south loop printing', '60,house district']
# NONE_TRUE_MORE:  ['60,south loop printing house district']
# NONE_PRED_MORE:  ['60,south loop printing', '60,house district']
# TRUE:  ['61,outlook', '61,visual studio']
# PRED:  ['61,visual studio']
# LESS:  ['61,visual studio']
# TRUE:  ['62,croatia', '62,ombla']
# PRED:  ['62,croatia']
# LESS:  ['62,croatia']
# TRUE:  ['63,newin chidchob']
# PRED:  ['63,newin chidchob']
# SAME:  ['63,newin chidchob']
# TRUE:  ['64,ron reed', '64,dave bing']
# PRED:  ['64,dave bing', '64,ron reed']
# SAME:  ['64,dave bing', '64,ron reed']
# TRUE:  ['65,galileo galilei', '65,ganymede']
# PRED:  ['65,galileo galilei']
# LESS:  ['65,galileo galilei']
# TRUE:  ['66,guitar']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['66,guitar']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['67,elizabeth: the golden age']
# PRED:  ['67,elizabeth']
# SAME:  []
# NONE_TRUE_EQUAL:  ['67,elizabeth: the golden age']
# NONE_PRED_EQUAL:  ['67,elizabeth']
# TRUE:  ['68,onedrive']
# PRED:  ['68,onedrive']
# SAME:  ['68,onedrive']
# TRUE:  ['69,washington, d.c.']
# PRED:  ['69,washington, d.c.']
# SAME:  ['69,washington, d.c.']
# TRUE:  ['70,queen noor of jordan']
# PRED:  ['70,jordan', '70,one']
# NONE_TRUE_MORE:  ['70,queen noor of jordan']
# NONE_PRED_MORE:  ['70,jordan', '70,one']
# TRUE:  ['71,robert witherspoon']
# PRED:  ['71,robert witherspoon']
# SAME:  ['71,robert witherspoon']
# TRUE:  ["72,he's a liar"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["72,he's a liar"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['73,oj, svijetla majska zoro']
# PRED:  ['73,oj']
# SAME:  []
# NONE_TRUE_EQUAL:  ['73,oj, svijetla majska zoro']
# NONE_PRED_EQUAL:  ['73,oj']
# TRUE:  ['74,allen walker']
# PRED:  ['74,allen walker']
# SAME:  ['74,allen walker']
# TRUE:  ['75,marcus calpurnius bibulus', '75,publius servilius vatia isauricus']
# PRED:  ['75,publius servilius vatia isauricus', '75,marcus calpurnius bibulus']
# SAME:  ['75,publius servilius vatia isauricus', '75,marcus calpurnius bibulus']
# TRUE:  ['76,edmund john', '76,saima chowdhury']
# PRED:  ['76,chowdhury']
# NONE_TRUE_LESS:  ['76,edmund john', '76,saima chowdhury']
# NONE_PRED_LESS:  ['76,chowdhury']
# TRUE:  ['77,mount hoffmann', '77,cathedral peak']
# PRED:  ['77,mount hoffmann']
# LESS:  ['77,mount hoffmann']
# TRUE:  ['78,indiana']
# PRED:  ['78,indiana']
# SAME:  ['78,indiana']
# TRUE:  ['79,swedish covenant hospital']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['79,swedish covenant hospital']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['80,moondog matinee', '80,girl from the north country']
# PRED:  ['80,the north country', '80,the moondog matinee']
# SAME:  []
# NONE_TRUE_EQUAL:  ['80,moondog matinee', '80,girl from the north country']
# NONE_PRED_EQUAL:  ['80,the north country', '80,the moondog matinee']
# TRUE:  ['81,april stewart', '81,mona marshall']
# PRED:  ['81,april', '81,stewart', '81,mona marshall']
# MORE:  ['81,mona marshall']
# TRUE:  ['82,trinity house', '82,freedom']
# PRED:  ['82,freedom of the city', '82,trinity house']
# SAME:  ['82,trinity house']
# PARTIAL:  ['82,trinity house']
# TRUE:  ['83,iran', '83,reza amrollahi']
# PRED:  ['83,reza amrollahi', '83,iran']
# SAME:  ['83,reza amrollahi', '83,iran']
# TRUE:  ['84,zaman shah durrani', '84,salahuddin']
# PRED:  ['84,zaman shah durrani', '84,salahuddin']
# SAME:  ['84,zaman shah durrani', '84,salahuddin']
# TRUE:  ['85,roh tae woo', '85,lee leffingwell']
# PRED:  ['85,roh tae woo', '85,lee leffingwell']
# SAME:  ['85,roh tae woo', '85,lee leffingwell']
# TRUE:  ['86,rosemarie dewitt']
# PRED:  ['86,rosemarie dewitt']
# SAME:  ['86,rosemarie dewitt']
# TRUE:  ['87,sapindales']
# PRED:  ['87,sapindales']
# SAME:  ['87,sapindales']
# TRUE:  ['88,lewis hamilton']
# PRED:  ['88,lewis hamilton']
# SAME:  ['88,lewis hamilton']
# TRUE:  ['89,giorgos kaminis']
# PRED:  ['89,giorgos kaminis']
# SAME:  ['89,giorgos kaminis']
# TRUE:  ['90,michael hahn']
# PRED:  ['90,michael hahn']
# SAME:  ['90,michael hahn']
# TRUE:  ['91,berlin']
# PRED:  ['91,berlin']
# SAME:  ['91,berlin']
# TRUE:  ['92,india']
# PRED:  ['92,india']
# SAME:  ['92,india']
# TRUE:  ['93,the simpsons ride']
# PRED:  ['93,the simpsons ride']
# SAME:  ['93,the simpsons ride']
# TRUE:  ['94,o.co coliseum']
# PRED:  ['94,o.co coliseum']
# SAME:  ['94,o.co coliseum']
# TRUE:  ['95,mams taylor', '95,the mating habits of the earthbound humans']
# PRED:  ['95,mams']
# NONE_TRUE_LESS:  ['95,mams taylor', '95,the mating habits of the earthbound humans']
# NONE_PRED_LESS:  ['95,mams']
# TRUE:  ['96,playboy enterprises']
# PRED:  ['96,playboy enterprises']
# SAME:  ['96,playboy enterprises']
# TRUE:  ['97,gwo ka', '97,western africa']
# PRED:  ['97,gwo ka', '97,western africa']
# SAME:  ['97,gwo ka', '97,western africa']
# TRUE:  ['98,send it on']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['98,send it on']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['99,onedrive', '99,visual studio']
# PRED:  ['99,visual studio']
# LESS:  ['99,visual studio']
# TRUE:  ['100,roundhead']
# PRED:  ['100,roundhead (wyandot']
# SAME:  []
# NONE_TRUE_EQUAL:  ['100,roundhead']
# NONE_PRED_EQUAL:  ['100,roundhead (wyandot']
# TRUE:  ['101,michigan stadium']
# PRED:  ['101,the michigan stadium']
# SAME:  []
# NONE_TRUE_EQUAL:  ['101,michigan stadium']
# NONE_PRED_EQUAL:  ['101,the michigan stadium']
# TRUE:  ['102,david johnston']
# PRED:  ['102,david johnston']
# SAME:  ['102,david johnston']
# TRUE:  ['103,francois marie le marchand de lignery']
# PRED:  ['103,francois marie', '103,le marchand de lignery']
# NONE_TRUE_MORE:  ['103,francois marie le marchand de lignery']
# NONE_PRED_MORE:  ['103,francois marie', '103,le marchand de lignery']
# TRUE:  ['104,myntdu river']
# PRED:  ['104,myntdu']
# SAME:  []
# NONE_TRUE_EQUAL:  ['104,myntdu river']
# NONE_PRED_EQUAL:  ['104,myntdu']
# TRUE:  ['105,london']
# PRED:  ['105,london']
# SAME:  ['105,london']
# TRUE:  ['106,ann lewis', '106,al gore presidential campaign, 2000']
# PRED:  ['106,al gore', '106,2000', '106,ann lewis']
# MORE:  ['106,ann lewis']
# TRUE:  ['107,darius i']
# PRED:  ['107,darius']
# SAME:  []
# NONE_TRUE_EQUAL:  ['107,darius i']
# NONE_PRED_EQUAL:  ['107,darius']
# TRUE:  ['108,airtours international airways', '108,kim sawchuk']
# PRED:  ['108,kim sawchuk', '108,the airtours international airways']
# SAME:  ['108,kim sawchuk']
# PARTIAL:  ['108,kim sawchuk']
# TRUE:  ['109,antonio giannini']
# PRED:  ['109,antonio giannini']
# SAME:  ['109,antonio giannini']
# TRUE:  ['110,david scherman']
# PRED:  ['110,david scherman']
# SAME:  ['110,david scherman']
# TRUE:  ['111,outlook.com', '111,onedrive']
# PRED:  ['111,outlook.com', '111,onedrive']
# SAME:  ['111,outlook.com', '111,onedrive']
# TRUE:  ['112,rouen business school']
# PRED:  ['112,rouen business school']
# SAME:  ['112,rouen business school']
# TRUE:  ['113,minjoo party']
# PRED:  ['113,the korean minjoo party']
# SAME:  []
# NONE_TRUE_EQUAL:  ['113,minjoo party']
# NONE_PRED_EQUAL:  ['113,the korean minjoo party']
# TRUE:  ['114,mcdonnell aircraft']
# PRED:  ['114,one', '114,mcdonnell aircraft']
# MORE:  ['114,mcdonnell aircraft']
# TRUE:  ['115,gales ferry, connecticut']
# PRED:  ['115,gales ferry', '115,connecticut']
# NONE_TRUE_MORE:  ['115,gales ferry, connecticut']
# NONE_PRED_MORE:  ['115,gales ferry', '115,connecticut']
# TRUE:  ['116,live in detroit, mi']
# PRED:  ['116,detroit', '116,mi']
# NONE_TRUE_MORE:  ['116,live in detroit, mi']
# NONE_PRED_MORE:  ['116,detroit', '116,mi']
# TRUE:  ['117,english under twenty one football team']
# PRED:  ['117,english', '117,under twenty']
# NONE_TRUE_MORE:  ['117,english under twenty one football team']
# NONE_PRED_MORE:  ['117,english', '117,under twenty']
# TRUE:  ['118,helsinki', '118,danish straits']
# PRED:  ['118,helsinki', '118,one', '118,danish']
# MORE:  ['118,helsinki']
# TRUE:  ['119,timmy time']
# PRED:  ['119,timmy time']
# SAME:  ['119,timmy time']
# TRUE:  ['120,fort heath radar station']
# PRED:  ['120,fort heath']
# SAME:  []
# NONE_TRUE_EQUAL:  ['120,fort heath radar station']
# NONE_PRED_EQUAL:  ['120,fort heath']
# TRUE:  ['121,lyons township high school', '121,harding academy']
# PRED:  ['121,harding', '121,lyons']
# SAME:  []
# NONE_TRUE_EQUAL:  ['121,lyons township high school', '121,harding academy']
# NONE_PRED_EQUAL:  ['121,harding', '121,lyons']
# TRUE:  ['122,rosario, santa fe']
# PRED:  ['122,rosario', '122,santa fe']
# NONE_TRUE_MORE:  ['122,rosario, santa fe']
# NONE_PRED_MORE:  ['122,rosario', '122,santa fe']
# TRUE:  ['123,animal']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['123,animal']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['124,oahu railway and land company', '124,chris myers']
# PRED:  ['124,chris myers', '124,new jersey', '124,oahu railway and land company']
# MORE:  ['124,chris myers', '124,oahu railway and land company']
# TRUE:  ['125,ngos']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['125,ngos']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['126,brian graden', '126,isaac hayes']
# PRED:  ['126,brian graden', '126,isaac hayes']
# SAME:  ['126,brian graden', '126,isaac hayes']
# TRUE:  ['127,cars']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['127,cars']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['128,steve sampson', '128,santa clara university']
# PRED:  ['128,steve sampson', '128,santa clara']
# SAME:  ['128,steve sampson']
# PARTIAL:  ['128,steve sampson']
# TRUE:  ['129,schibsted']
# PRED:  ['129,schibsted']
# SAME:  ['129,schibsted']
# TRUE:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# PRED:  ['130,wpc dynamo moscow', '130,tigran petrosian >']
# SAME:  ['130,wpc dynamo moscow']
# PARTIAL:  ['130,wpc dynamo moscow']
# TRUE:  ['131,joan laporta']
# PRED:  ['131,joan laporta']
# SAME:  ['131,joan laporta']
# TRUE:  ['132,four-wheel-drive layout']
# PRED:  ['132,four']
# SAME:  []
# NONE_TRUE_EQUAL:  ['132,four-wheel-drive layout']
# NONE_PRED_EQUAL:  ['132,four']
# TRUE:  ['133,pong pha']
# PRED:  ['133,pong pha']
# SAME:  ['133,pong pha']
# TRUE:  ['134,charles ayres', '134,angela trusty']
# PRED:  ['134,the angela trusty', '134,charles ayres']
# SAME:  ['134,charles ayres']
# PARTIAL:  ['134,charles ayres']
# TRUE:  ['135,the conglomerate', '135,before i let you go']
# PRED:  ['135,conglomerate']
# NONE_TRUE_LESS:  ['135,the conglomerate', '135,before i let you go']
# NONE_PRED_LESS:  ['135,conglomerate']
# TRUE:  ['136,lagnacha dhumdhadaka']
# PRED:  ['136,lagnacha dhumdhadaka']
# SAME:  ['136,lagnacha dhumdhadaka']
# TRUE:  ['137,english']
# PRED:  ['137,english']
# SAME:  ['137,english']
# TRUE:  ['138,el sobrante, california']
# PRED:  ['138,el sobrante', '138,california']
# NONE_TRUE_MORE:  ['138,el sobrante, california']
# NONE_PRED_MORE:  ['138,el sobrante', '138,california']
# TRUE:  ["139,daniel o'regan"]
# PRED:  ['139, ', "139,daniel o'regan"]
# MORE:  ["139,daniel o'regan"]
# TRUE:  ['140,aureus', '140,solidus']
# PRED:  ['140,solidus']
# LESS:  ['140,solidus']
# TRUE:  ['141,cardiovascular disease']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['141,cardiovascular disease']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['142,mammal', '142,chestnut white bellied rat']
# PRED:  ['']
# NONE_TRUE_LESS:  ['142,mammal', '142,chestnut white bellied rat']
# NONE_PRED_LESS:  ['']
# TRUE:  ['143,the broken code', '143,tim gunn']
# PRED:  ['143,tim gunn', '143,the broken code']
# SAME:  ['143,tim gunn', '143,the broken code']
# TRUE:  ['144,shallot']
# PRED:  ['144,shallot']
# SAME:  ['144,shallot']
# TRUE:  ['145,oktoc, mississippi']
# PRED:  ['145,oktoc', '145,mississippi']
# NONE_TRUE_MORE:  ['145,oktoc, mississippi']
# NONE_PRED_MORE:  ['145,oktoc', '145,mississippi']
# TRUE:  ['146,nord', '146,the beauty inside']
# PRED:  ['146,nord']
# LESS:  ['146,nord']
# TRUE:  ['147,tirana', '147,albania']
# PRED:  ['147,tirana', '147,albania']
# SAME:  ['147,tirana', '147,albania']
# TRUE:  ['148,vishwajyot high school', '148,fr agnel multipurpose school']
# PRED:  ['148,fr agnel', '148,multipurpose school', '148,vishwajyot high school']
# MORE:  ['148,vishwajyot high school']
# TRUE:  ['149,bob hawke']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['149,bob hawke']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['150,cbs corporation']
# PRED:  ['150,the cbs corporation']
# SAME:  []
# NONE_TRUE_EQUAL:  ['150,cbs corporation']
# NONE_PRED_EQUAL:  ['150,the cbs corporation']
# TRUE:  ['151,taguig']
# PRED:  ['151,taguig']
# SAME:  ['151,taguig']
# TRUE:  ['152,joe hahn']
# PRED:  ['152,joe hahn']
# SAME:  ['152,joe hahn']
# TRUE:  ['153,comedy central', '153,isaac hayes']
# PRED:  ['153,isaac hayes']
# LESS:  ['153,isaac hayes']
# TRUE:  ['154,raymond johansen']
# PRED:  ['154,raymond johansen']
# SAME:  ['154,raymond johansen']
# TRUE:  ['155,ikaros smederna']
# PRED:  ['155,ikaros smederna']
# SAME:  ['155,ikaros smederna']
# TRUE:  ['156,windows']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['156,windows']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['157,hockey']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['157,hockey']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['158,washington dc']
# PRED:  ['158,washington dc']
# SAME:  ['158,washington dc']
# TRUE:  ['159,temenos group']
# PRED:  ['159,temenos group']
# SAME:  ['159,temenos group']
# TRUE:  ['160,to know him is to love him']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['160,to know him is to love him']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['161,spain...']
# PRED:  ['161,spain']
# SAME:  []
# NONE_TRUE_EQUAL:  ['161,spain...']
# NONE_PRED_EQUAL:  ['161,spain']
# TRUE:  ['162,chris marve', '162,neria douglass']
# PRED:  ['162,chris marve', '162,neria douglass']
# SAME:  ['162,chris marve', '162,neria douglass']
# TRUE:  ['163,monticello, maine']
# PRED:  ['163,monticello', '163,maine']
# NONE_TRUE_MORE:  ['163,monticello, maine']
# NONE_PRED_MORE:  ['163,monticello', '163,maine']
# TRUE:  ['164,josiah idowu-fearon', '164,john']
# PRED:  ['164,josiah idowu-fearon', '164,damasucs']
# SAME:  ['164,josiah idowu-fearon']
# PARTIAL:  ['164,josiah idowu-fearon']
# TRUE:  ['165,paramount television', '165,judy hart angelo']
# PRED:  ['165,judy hart angelo', '165,paramount television']
# SAME:  ['165,judy hart angelo', '165,paramount television']
# TRUE:  ['166,caspian']
# PRED:  ['166,caspian']
# SAME:  ['166,caspian']
# TRUE:  ['167,united states department of defense', '167,arlington county, virginia']
# PRED:  ['167,arlington county', '167,virginia', '167,united states department of defense']
# MORE:  ['167,united states department of defense']
# TRUE:  ['168,thongsuk samdaengpan']
# PRED:  ['168,thongsuk samdaengpan']
# SAME:  ['168,thongsuk samdaengpan']
# TRUE:  ['169,asus']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['169,asus']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['170,ncaa']
# PRED:  ['170,ncaa']
# SAME:  ['170,ncaa']
# TRUE:  ['171,afrika baby bam', '171,queen latifah']
# PRED:  ['171,queen latifah', '171,afrika', '171,baby bam']
# MORE:  ['171,queen latifah']
# TRUE:  ['172,kazuo hirai']
# PRED:  ['172,kazuo hirai']
# SAME:  ['172,kazuo hirai']
# TRUE:  ['173,patts college of aeronautics']
# PRED:  ['173,patts college of aeronautics']
# SAME:  ['173,patts college of aeronautics']
# TRUE:  ['174,dan shamash', '174,ever bank field']
# PRED:  ['174,dan shamash']
# LESS:  ['174,dan shamash']
# TRUE:  ['175,thanong bidaya']
# PRED:  ['175,thanong bidaya']
# SAME:  ['175,thanong bidaya']
# TRUE:  ['176,san marcos river']
# PRED:  ['176,the san marcos river']
# SAME:  []
# NONE_TRUE_EQUAL:  ['176,san marcos river']
# NONE_PRED_EQUAL:  ['176,the san marcos river']
# TRUE:  ['177,jazz fusion']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['177,jazz fusion']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['178,bogumilus']
# PRED:  ['178,bogumilus']
# SAME:  ['178,bogumilus']
# TRUE:  ['179,screen actors guild life achievement award', '179,henry e. catto, jr.']
# PRED:  ['179,henry e. catto']
# NONE_TRUE_LESS:  ['179,screen actors guild life achievement award', '179,henry e. catto, jr.']
# NONE_PRED_LESS:  ['179,henry e. catto']
# TRUE:  ['180,pope gregory i']
# PRED:  ['180,pope gregory']
# SAME:  []
# NONE_TRUE_EQUAL:  ['180,pope gregory i']
# NONE_PRED_EQUAL:  ['180,pope gregory']
# TRUE:  ['181,human rights party']
# PRED:  ['181,cambodian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['181,human rights party']
# NONE_PRED_EQUAL:  ['181,cambodian']
# TRUE:  ['182,czech extraliga']
# PRED:  ['182,czech', '182,extraliga']
# NONE_TRUE_MORE:  ['182,czech extraliga']
# NONE_PRED_MORE:  ['182,czech', '182,extraliga']
# TRUE:  ['183,croix de guerre']
# PRED:  ['183,the croix de guerre']
# SAME:  []
# NONE_TRUE_EQUAL:  ['183,croix de guerre']
# NONE_PRED_EQUAL:  ['183,the croix de guerre']
# TRUE:  ['184,azam f.c.']
# PRED:  ['184,azam f.c.']
# SAME:  ['184,azam f.c.']
# TRUE:  ['185,inkas', '185,t.i. ahmadiyya senior high school, kumasi']
# PRED:  ['185,inkas', '185,t.i.', '185,kumasi']
# MORE:  ['185,inkas']
# TRUE:  ['186,mausoleum of augustus', '186,rome']
# PRED:  ['186,rome', '186,mausoleum']
# SAME:  ['186,rome']
# PARTIAL:  ['186,rome']
# TRUE:  ['187,1st free french division']
# PRED:  ['187,1st free french division']
# SAME:  ['187,1st free french division']
# TRUE:  ['188,mediterranean sea']
# PRED:  ['188,the mediterranean sea']
# SAME:  []
# NONE_TRUE_EQUAL:  ['188,mediterranean sea']
# NONE_PRED_EQUAL:  ['188,the mediterranean sea']
# TRUE:  ['189,zambia', '189,ikelenge district']
# PRED:  ['189,zambia', '189,ikelenge  district']
# SAME:  ['189,zambia']
# PARTIAL:  ['189,zambia']
# TRUE:  ['190,royal society']
# PRED:  ['190,royal society']
# SAME:  ['190,royal society']
# TRUE:  ['191,acer nigrum']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['191,acer nigrum']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['192,filipinos']
# PRED:  ['192,filipinos']
# SAME:  ['192,filipinos']
# TRUE:  ['193,neil brown', '193,andrew peacock']
# PRED:  ['193,neil brown', '193,andrew peacock']
# SAME:  ['193,neil brown', '193,andrew peacock']
# TRUE:  ['194,wizards vs aliens', '194,into the dalek']
# PRED:  ['194,into the dalek', '194,wizards']
# SAME:  ['194,into the dalek']
# PARTIAL:  ['194,into the dalek']
# TRUE:  ['195,charles pinckney']
# PRED:  ['195,charles pinckney']
# SAME:  ['195,charles pinckney']
# TRUE:  ["196,us men's national soccer team"]
# PRED:  ['196,us']
# SAME:  []
# NONE_TRUE_EQUAL:  ["196,us men's national soccer team"]
# NONE_PRED_EQUAL:  ['196,us']
# TRUE:  ['197,tessa dahl']
# PRED:  ['197,tessa dahl']
# SAME:  ['197,tessa dahl']
# TRUE:  ['198,eu broadcasting union']
# PRED:  ['198,eu broadcasting union']
# SAME:  ['198,eu broadcasting union']
# TRUE:  ['199,jack ryan', '199,us senate']
# PRED:  ['199,jack ryan', '199,us senate']
# SAME:  ['199,jack ryan', '199,us senate']
# TRUE:  ['200,ananda college']
# PRED:  ['200,ananda college']
# SAME:  ['200,ananda college']
# TRUE:  ['201,mediterranean sea', '201,panionios g.s.s. season']
# PRED:  ['201,mediterranean sea', '201,panionios g.s.s.']
# SAME:  ['201,mediterranean sea']
# PARTIAL:  ['201,mediterranean sea']
# TRUE:  ['202,murray mouth', '202,cowombat flat']
# PRED:  ['202,cowombat  flat', '202,murray mouth']
# SAME:  ['202,murray mouth']
# PARTIAL:  ['202,murray mouth']
# TRUE:  ['203,wbcq']
# PRED:  ['203,wbcq', '203,sw']
# MORE:  ['203,wbcq']
# TRUE:  ['204,2015 argentine primera division']
# PRED:  ['204,2015', '204,argentine primera division']
# NONE_TRUE_MORE:  ['204,2015 argentine primera division']
# NONE_PRED_MORE:  ['204,2015', '204,argentine primera division']
# TRUE:  ['205,florida']
# PRED:  ['205,florida']
# SAME:  ['205,florida']
# TRUE:  ['206,god defend new zealand']
# PRED:  ['206,new zealand']
# SAME:  []
# NONE_TRUE_EQUAL:  ['206,god defend new zealand']
# NONE_PRED_EQUAL:  ['206,new zealand']
# TRUE:  ['207,vangelis', '207,jordan cronenweth']
# PRED:  ['207,jordan cronenweth', '207,vangelis']
# SAME:  ['207,jordan cronenweth', '207,vangelis']
# TRUE:  ['208,klang valley']
# PRED:  ['208,the klang valley']
# SAME:  []
# NONE_TRUE_EQUAL:  ['208,klang valley']
# NONE_PRED_EQUAL:  ['208,the klang valley']
# TRUE:  ['209,discovery communications']
# PRED:  ['209,discovery communications']
# SAME:  ['209,discovery communications']
# TRUE:  ['210,queer as folk']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['210,queer as folk']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['211,high desert']
# PRED:  ['211,oregon']
# SAME:  []
# NONE_TRUE_EQUAL:  ['211,high desert']
# NONE_PRED_EQUAL:  ['211,oregon']
# TRUE:  ['212,paramount domestic television']
# PRED:  ['212,paramount domestic television']
# SAME:  ['212,paramount domestic television']
# TRUE:  ['213,city of new orleans']
# PRED:  ['213,city of new orleans']
# SAME:  ['213,city of new orleans']
# TRUE:  ['214,get tv', '214,the galleria']
# PRED:  ['214,get tv', '214,galleria']
# SAME:  ['214,get tv']
# PARTIAL:  ['214,get tv']
# TRUE:  ['215,madagascar: operation penguin', "215,he's a pirate"]
# PRED:  ['215,madagascar', '215,penguin', '215,pirate']
# NONE_TRUE_MORE:  ['215,madagascar: operation penguin', "215,he's a pirate"]
# NONE_PRED_MORE:  ['215,madagascar', '215,penguin', '215,pirate']
# TRUE:  ['216,goran cengic']
# PRED:  ['216,goran cengic']
# SAME:  ['216,goran cengic']
# TRUE:  ['217,zhorstoke nebo']
# PRED:  ['217,zhorstoke nebo']
# SAME:  ['217,zhorstoke nebo']
# TRUE:  ['218,louis dunbar', '218,jeff munn']
# PRED:  ['218,louis dunbar', '218,jeff munn']
# SAME:  ['218,louis dunbar', '218,jeff munn']
# TRUE:  ['219,populous']
# PRED:  ['219,populous']
# SAME:  ['219,populous']
# TRUE:  ['220,chumash people']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['220,chumash people']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['221,pavel moroz', '221,helena of moscow']
# PRED:  ['221,pavel moroz', '221,helena', '221,moscow']
# MORE:  ['221,pavel moroz']
# TRUE:  ['222,christopher franke', '222,j. michael straczynski']
# PRED:  ['222,j. michael stracznski', '222,christopher franke']
# SAME:  ['222,christopher franke']
# PARTIAL:  ['222,christopher franke']
# TRUE:  ['223,cy-fair high school']
# PRED:  ['223,a cy-fair high school']
# SAME:  []
# NONE_TRUE_EQUAL:  ['223,cy-fair high school']
# NONE_PRED_EQUAL:  ['223,a cy-fair high school']
# TRUE:  ['224,senser']
# PRED:  ['224,senser']
# SAME:  ['224,senser']
# TRUE:  ['225,teddy riley', '225,blayse']
# PRED:  ['225,blayse', '225,teddy riley']
# SAME:  ['225,blayse', '225,teddy riley']
# TRUE:  ['226,to where you are']
# PRED:  ['226,to you are']
# SAME:  []
# NONE_TRUE_EQUAL:  ['226,to where you are']
# NONE_PRED_EQUAL:  ['226,to you are']
# TRUE:  ['227,merlin express', '227,cibano international airport']
# PRED:  ['']
# NONE_TRUE_LESS:  ['227,merlin express', '227,cibano international airport']
# NONE_PRED_LESS:  ['']
# TRUE:  ['228,wilton, connecticut']
# PRED:  ['228,wilton', '228,connecticut']
# NONE_TRUE_MORE:  ['228,wilton, connecticut']
# NONE_PRED_MORE:  ['228,wilton', '228,connecticut']
# TRUE:  ['229,ontariana']
# PRED:  ['229,ontarians']
# SAME:  []
# NONE_TRUE_EQUAL:  ['229,ontariana']
# NONE_PRED_EQUAL:  ['229,ontarians']
# TRUE:  ['230,ryan seacrest', '230,fox']
# PRED:  ['230,fox  ', '230,ryan seacrest']
# SAME:  ['230,ryan seacrest']
# PARTIAL:  ['230,ryan seacrest']
# TRUE:  ['231,box girder bridges']
# PRED:  ['231,box girder']
# SAME:  []
# NONE_TRUE_EQUAL:  ['231,box girder bridges']
# NONE_PRED_EQUAL:  ['231,box girder']
# TRUE:  ["232,the god who wasn't there"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["232,the god who wasn't there"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['233,public transport authority']
# PRED:  ['233,western australian public transport authority']
# SAME:  []
# NONE_TRUE_EQUAL:  ['233,public transport authority']
# NONE_PRED_EQUAL:  ['233,western australian public transport authority']
# TRUE:  ['234,thomas meehan']
# PRED:  ['234,thomas meehan']
# SAME:  ['234,thomas meehan']
# TRUE:  ['235,municipal council']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['235,municipal council']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['236,jacques-dsir laval']
# PRED:  ['236,jacques-dsir', '236,laval']
# NONE_TRUE_MORE:  ['236,jacques-dsir laval']
# NONE_PRED_MORE:  ['236,jacques-dsir', '236,laval']
# TRUE:  ['237,mecklenburg-vorpommern']
# PRED:  ['237,mecklenburg-vorpommern']
# SAME:  ['237,mecklenburg-vorpommern']
# TRUE:  ['238,herzogenaurach']
# PRED:  ['238,herzogenaurach']
# SAME:  ['238,herzogenaurach']
# TRUE:  ['239,lucy sullivan is getting married']
# PRED:  ['239,lucy sullivan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['239,lucy sullivan is getting married']
# NONE_PRED_EQUAL:  ['239,lucy sullivan']
# TRUE:  ['240,blizzard entertainment']
# PRED:  ['240,blizzard entertainment']
# SAME:  ['240,blizzard entertainment']
# TRUE:  ['241,alexander downer', '241,neil brown']
# PRED:  ['241,alexander downer', '241,neil brown']
# SAME:  ['241,alexander downer', '241,neil brown']
# TRUE:  ['242,costa rica national football team']
# PRED:  ['242,costa rica']
# SAME:  []
# NONE_TRUE_EQUAL:  ['242,costa rica national football team']
# NONE_PRED_EQUAL:  ['242,costa rica']
# TRUE:  ['243,amitava datta']
# PRED:  ['243,amitava datta']
# SAME:  ['243,amitava datta']
# TRUE:  ['244,londo mollari']
# PRED:  ['244,londo mollari']
# SAME:  ['244,londo mollari']
# TRUE:  ['245,scientologists']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['245,scientologists']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# PRED:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# SAME:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# TRUE:  ['247,qadir huseynov', '247,liudmila privivkova']
# PRED:  ['247,liudmila privivkova', '247,qadir huseynov']
# SAME:  ['247,liudmila privivkova', '247,qadir huseynov']
# TRUE:  ['248,cadillac fleetwood']
# PRED:  ['248,cadillac', '248,fleetwood']
# NONE_TRUE_MORE:  ['248,cadillac fleetwood']
# NONE_PRED_MORE:  ['248,cadillac', '248,fleetwood']
# TRUE:  ['249,commodore cdtv']
# PRED:  ['249,cdtv']
# SAME:  []
# NONE_TRUE_EQUAL:  ['249,commodore cdtv']
# NONE_PRED_EQUAL:  ['249,cdtv']
# TRUE:  ['250,mark johnson']
# PRED:  ['250,mark johnson']
# SAME:  ['250,mark johnson']
# TRUE:  ['251,canary islands']
# PRED:  ['251,canary islands']
# SAME:  ['251,canary islands']
# TRUE:  ['252,fusil gras mile 1874']
# PRED:  ['252,fusil gras mile', '252,1874']
# NONE_TRUE_MORE:  ['252,fusil gras mile 1874']
# NONE_PRED_MORE:  ['252,fusil gras mile', '252,1874']
# TRUE:  ['253,claiborne pell', '253,ralph flanders']
# PRED:  ['253,ralph flanders', '253,claiborne pell']
# SAME:  ['253,ralph flanders', '253,claiborne pell']
# TRUE:  ['254,ontario']
# PRED:  ['254,ontario']
# SAME:  ['254,ontario']
# TRUE:  ['255,san antonio', '255,us route 281']
# PRED:  ['255,us', '255,281', '255,san antonio']
# MORE:  ['255,san antonio']
# TRUE:  ['256,cnn']
# PRED:  ['256,cnn']
# SAME:  ['256,cnn']
# TRUE:  ['257,norfolk southern railway']
# PRED:  ['257,norfolk southern railway']
# SAME:  ['257,norfolk southern railway']
# TRUE:  ['258,edwin catmull', '258,pixar image computer']
# PRED:  ['258,one', '258,pixar image computer', '258,one', '258,edwin catmull']
# MORE:  ['258,pixar image computer', '258,edwin catmull']
# TRUE:  ['259,beverly hills', '259,colts neck township']
# PRED:  ['259,beverly hills', '259,colts neck township']
# SAME:  ['259,beverly hills', '259,colts neck township']
# TRUE:  ['260,rome']
# PRED:  ['260,rome']
# SAME:  ['260,rome']
# TRUE:  ['261,rhode island route 15']
# PRED:  ['261,rhode island route 15']
# SAME:  ['261,rhode island route 15']
# TRUE:  ['262,trump productions', '262,the ultimate merger']
# PRED:  ['262,trump productions']
# LESS:  ['262,trump productions']
# TRUE:  ['263,komc-fm', '263,komc']
# PRED:  ['263,komc-fm', '263,komc (am']
# SAME:  ['263,komc-fm']
# PARTIAL:  ['263,komc-fm']
# TRUE:  ['264,asiana airlines', '264,jeju airport']
# PRED:  ['264,jeju']
# NONE_TRUE_LESS:  ['264,asiana airlines', '264,jeju airport']
# NONE_PRED_LESS:  ['264,jeju']
# TRUE:  ['265,swedish academy']
# PRED:  ['265,swedish academy']
# SAME:  ['265,swedish academy']
# TRUE:  ['266,tennessee state museum']
# PRED:  ['266,tennessee state museum']
# SAME:  ['266,tennessee state museum']
# TRUE:  ['267,ishir honda']
# PRED:  ['267,ishir honda']
# SAME:  ['267,ishir honda']
# TRUE:  ["268,alpine skiing at the 1964 winter olympics men's slalom"]
# PRED:  ['268,1964', '268,winter olympics']
# NONE_TRUE_MORE:  ["268,alpine skiing at the 1964 winter olympics men's slalom"]
# NONE_PRED_MORE:  ['268,1964', '268,winter olympics']
# TRUE:  ['269,virgin radio']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['269,virgin radio']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['270,tani university']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['270,tani university']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['271,dowra']
# PRED:  ['271,dowra']
# SAME:  ['271,dowra']
# TRUE:  ['272,pittsburgh pirates']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['272,pittsburgh pirates']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['273,simon fuller']
# PRED:  ['273,simon fuller']
# SAME:  ['273,simon fuller']
# TRUE:  ['274,the producers', '274,next thing']
# PRED:  ['274,the the producers (', '274,2005']
# SAME:  []
# NONE_TRUE_EQUAL:  ['274,the producers', '274,next thing']
# NONE_PRED_EQUAL:  ['274,the the producers (', '274,2005']
# TRUE:  ['275,henry ford', '275,ford model c']
# PRED:  ['275,henry ford']
# LESS:  ['275,henry ford']
# TRUE:  ["276,dragons' den"]
# PRED:  ['276,dragons']
# SAME:  []
# NONE_TRUE_EQUAL:  ["276,dragons' den"]
# NONE_PRED_EQUAL:  ['276,dragons']
# TRUE:  ['277,joseph case high school', '277,providence chapel, charlwood']
# PRED:  ['277,providence', '277,charlwood', '277,the joseph case high school']
# NONE_TRUE_MORE:  ['277,joseph case high school', '277,providence chapel, charlwood']
# NONE_PRED_MORE:  ['277,providence', '277,charlwood', '277,the joseph case high school']
# TRUE:  ['278,norbert wiener award for social and professional responsibility', '278,john robert woodyard']
# PRED:  ['278,john robert woodyard', '278,norbert wiener', '278,social and professional responsibility']
# MORE:  ['278,john robert woodyard']
# TRUE:  ['279,leroy collins', '279,george siebels jr']
# PRED:  ['279,george siebels jr', '279,leroy collins']
# SAME:  ['279,george siebels jr', '279,leroy collins']
# TRUE:  ['280,germany']
# PRED:  ['280,germany']
# SAME:  ['280,germany']
# TRUE:  ['281,downtown athletic club', '281,yale club']
# PRED:  ['281,downtown athletic club', '281,yale club nycity']
# SAME:  ['281,downtown athletic club']
# PARTIAL:  ['281,downtown athletic club']
# TRUE:  ['282,victor hope, 2nd marquess of linlithgow']
# PRED:  ['282,victor hope', '282,2nd', '282,marquess', '282,linlithgow']
# NONE_TRUE_MORE:  ['282,victor hope, 2nd marquess of linlithgow']
# NONE_PRED_MORE:  ['282,victor hope', '282,2nd', '282,marquess', '282,linlithgow']
# TRUE:  ['283,ashton historic district']
# PRED:  ['283,ashton historic']
# SAME:  []
# NONE_TRUE_EQUAL:  ['283,ashton historic district']
# NONE_PRED_EQUAL:  ['283,ashton historic']
# TRUE:  ['284,greater napanee']
# PRED:  ['284,napanee']
# SAME:  []
# NONE_TRUE_EQUAL:  ['284,greater napanee']
# NONE_PRED_EQUAL:  ['284,napanee']
# TRUE:  ['285,channel district']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['285,channel district']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['286,vagif aliyev']
# PRED:  ['286,vagif aliyev']
# SAME:  ['286,vagif aliyev']
# TRUE:  ['287,onedrive', '287,us']
# PRED:  ['287,us', '287,onedrive']
# SAME:  ['287,us', '287,onedrive']
# TRUE:  ['288,james l. mcconaughy']
# PRED:  ['288,james l. mcconaughy']
# SAME:  ['288,james l. mcconaughy']
# TRUE:  ['289,catwoman']
# PRED:  ['289,one', '289,catwoman']
# MORE:  ['289,catwoman']
# TRUE:  ['290,mediterranean sea']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['290,mediterranean sea']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['291,bacillus', '291,bacteria']
# PRED:  ['291,bacteria']
# LESS:  ['291,bacteria']
# TRUE:  ['292,french']
# PRED:  ['292,french']
# SAME:  ['292,french']
# TRUE:  ['293,baraily', '293,jowai']
# PRED:  ['293,baraily', '293,jowai']
# SAME:  ['293,baraily', '293,jowai']
# TRUE:  ['294,siege of fort recovery']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['294,siege of fort recovery']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['295,germanic']
# PRED:  ['295,germanic']
# SAME:  ['295,germanic']
# TRUE:  ['296,duane allman', '296,les paul']
# PRED:  ['296,duanne allman', '296,the les paul']
# SAME:  []
# NONE_TRUE_EQUAL:  ['296,duane allman', '296,les paul']
# NONE_PRED_EQUAL:  ['296,duanne allman', '296,the les paul']
# TRUE:  ['297,tanzanian national football team']
# PRED:  ['297,tanzanian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['297,tanzanian national football team']
# NONE_PRED_EQUAL:  ['297,tanzanian']
# TRUE:  ['298,bloomberg markets']
# PRED:  ['298,bloomberg markets']
# SAME:  ['298,bloomberg markets']
# TRUE:  ['299,motor vehicles']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['299,motor vehicles']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['300,holmes colbert', '300,linda hogan']
# PRED:  ['300,linda hogan', '300,holmes colbert']
# SAME:  ['300,linda hogan', '300,holmes colbert']
# TRUE:  ['301,jon speelman']
# PRED:  ['301,jon speelman']
# SAME:  ['301,jon speelman']
# TRUE:  ['302,ella loves cole']
# PRED:  ['302,ella loves cole']
# SAME:  ['302,ella loves cole']
# TRUE:  ['303,prime time entertainment network']
# PRED:  ['303,prime time entertainment network']
# SAME:  ['303,prime time entertainment network']
# TRUE:  ['304,auto shankar']
# PRED:  ['304,auto shankar']
# SAME:  ['304,auto shankar']
# TRUE:  ['305,burr truss']
# PRED:  ['305,burr truss']
# SAME:  ['305,burr truss']
# TRUE:  ['306,tonle sap']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['306,tonle sap']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['307,cheryl teigs']
# PRED:  ['307,cheryl teigs']
# SAME:  ['307,cheryl teigs']
# TRUE:  ['308,ndonga mianga']
# PRED:  ['308,ndonga mianga']
# SAME:  ['308,ndonga mianga']
# TRUE:  ['309,papeete']
# PRED:  ['309,papeete']
# SAME:  ['309,papeete']
# TRUE:  ['310,lake victoria']
# PRED:  ['310,lake victoria']
# SAME:  ['310,lake victoria']
# TRUE:  ['311,domenico modugno']
# PRED:  ['311,domenico modugno']
# SAME:  ['311,domenico modugno']
# TRUE:  ['312,grameen bank']
# PRED:  ['312,grameen bank']
# SAME:  ['312,grameen bank']
# TRUE:  ['313,benjamin franklin terry', '313,us route 59']
# PRED:  ['313,benjamin franklin terry', '313,us route 59']
# SAME:  ['313,benjamin franklin terry', '313,us route 59']
# TRUE:  ['314,james langer']
# PRED:  ['314,james langer']
# SAME:  ['314,james langer']
# TRUE:  ['315,john trumbull', '315,a foreign policy']
# PRED:  ['315,john trumbull']
# LESS:  ['315,john trumbull']
# TRUE:  ['316,peter-john vettese']
# PRED:  ['316,peter-john vettese']
# SAME:  ['316,peter-john vettese']
# TRUE:  ['317,edwin catmull']
# PRED:  ['317,edwin catmull']
# SAME:  ['317,edwin catmull']
# TRUE:  ['318,eric roth']
# PRED:  ['318,eric roth']
# SAME:  ['318,eric roth']
# TRUE:  ['319,coneygree', '319,martin molony']
# PRED:  ['319,martin molony', '319,coneygree']
# SAME:  ['319,martin molony', '319,coneygree']
# TRUE:  ['320,dallas']
# PRED:  ['320,dallas']
# SAME:  ['320,dallas']
# TRUE:  ['321,royal society']
# PRED:  ['321,the royal society']
# SAME:  []
# NONE_TRUE_EQUAL:  ['321,royal society']
# NONE_PRED_EQUAL:  ['321,the royal society']
# TRUE:  ['322,philosophy', '322,stephen law']
# PRED:  ['322,stephen law']
# LESS:  ['322,stephen law']
# TRUE:  ['323,gervase helwys']
# PRED:  ['323,gervase helwys']
# SAME:  ['323,gervase helwys']
# TRUE:  ['324,raamlaxman']
# PRED:  ['324,raamlaxman']
# SAME:  ['324,raamlaxman']
# TRUE:  ['325,jose cha cha jimenez']
# PRED:  ['325,jose cha cha jimenez']
# SAME:  ['325,jose cha cha jimenez']
# TRUE:  ['326,bernard herrmann', '326,rko pictures']
# PRED:  ['326,rko pictures', '326,bernard herrmann']
# SAME:  ['326,rko pictures', '326,bernard herrmann']
# TRUE:  ['327,red ahead']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['327,red ahead']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['328,kore presbyterian theological seminar', '328,celal bayar university']
# PRED:  ['328,celal bayer', '328,presbyterian theological seminar']
# SAME:  []
# NONE_TRUE_EQUAL:  ['328,kore presbyterian theological seminar', '328,celal bayar university']
# NONE_PRED_EQUAL:  ['328,celal bayer', '328,presbyterian theological seminar']
# TRUE:  ['329,hamline avenue']
# PRED:  ['329,quarters', '329,hamline avenue']
# MORE:  ['329,hamline avenue']
# TRUE:  ['330,yasmin paige']
# PRED:  ['330,yasmin paige']
# SAME:  ['330,yasmin paige']
# TRUE:  ['331,heinz kokott']
# PRED:  ['331,heinz kokott', '331,nazi army']
# MORE:  ['331,heinz kokott']
# TRUE:  ['332,jann wenner', '332,ralph j. gleason']
# PRED:  ['332,jann wenner', '332,ralph j. gleason']
# SAME:  ['332,jann wenner', '332,ralph j. gleason']
# TRUE:  ['333,nevado de toluca', '333,sierra nevada']
# PRED:  ['333,sierra nevada', '333,u.s.', '333,nevado de toluca']
# MORE:  ['333,sierra nevada', '333,nevado de toluca']
# TRUE:  ['334,bbc hd', '334,doctor who confidential']
# PRED:  ['334,bbc hd']
# LESS:  ['334,bbc hd']
# TRUE:  ['335,milk cow blues', '335,sings kristofferson']
# PRED:  ['335,sings kristofferson', '335,milk cow blues']
# SAME:  ['335,sings kristofferson', '335,milk cow blues']
# TRUE:  ['336,thesaban']
# PRED:  ['336,thesaban']
# SAME:  ['336,thesaban']
# TRUE:  ['337,micronesia']
# PRED:  ['337,micronesia']
# SAME:  ['337,micronesia']
# TRUE:  ['338,stephen e. ambrose']
# PRED:  ['338,stephen e. ambrose']
# SAME:  ['338,stephen e. ambrose']
# TRUE:  ['339,central european summer time']
# PRED:  ['339,central european', '339,summer time']
# NONE_TRUE_MORE:  ['339,central european summer time']
# NONE_PRED_MORE:  ['339,central european', '339,summer time']
# TRUE:  ['340,steven peterman', '340,the best of both worlds']
# PRED:  ['340,the best of both worlds', '340,steven peterman']
# SAME:  ['340,the best of both worlds', '340,steven peterman']
# TRUE:  ['341,ralph j. gleason']
# PRED:  ['341,ralph j. gleason']
# SAME:  ['341,ralph j. gleason']
# TRUE:  ['342,paul morphy']
# PRED:  ['342,paul morphy']
# SAME:  ['342,paul morphy']
# TRUE:  ['343,thames estuary', '343,north sea']
# PRED:  ['343,thames estuary', '343,north sea']
# SAME:  ['343,thames estuary', '343,north sea']
# TRUE:  ['344,ganefo']
# PRED:  ['344,ganefo']
# SAME:  ['344,ganefo']
# TRUE:  ['345,matt williams']
# PRED:  ['345,matt williams']
# SAME:  ['345,matt williams']
# TRUE:  ['346,massachusetts house of representatives', '346,samuel w. mccall']
# PRED:  ['346,samuel w. mccall', '346,massachusetts house of representatives']
# SAME:  ['346,samuel w. mccall', '346,massachusetts house of representatives']
# TRUE:  ['347,golden globe']
# PRED:  ['347,the golden globe']
# SAME:  []
# NONE_TRUE_EQUAL:  ['347,golden globe']
# NONE_PRED_EQUAL:  ['347,the golden globe']
# TRUE:  ['348,pizza', "348,mr. jim's pizza"]
# PRED:  ['348,jim']
# NONE_TRUE_LESS:  ['348,pizza', "348,mr. jim's pizza"]
# NONE_PRED_LESS:  ['348,jim']
# TRUE:  ['349,even-toed ungulate']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['349,even-toed ungulate']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['350,mathematics']
# PRED:  ['350,one']
# SAME:  []
# NONE_TRUE_EQUAL:  ['350,mathematics']
# NONE_PRED_EQUAL:  ['350,one']
# TRUE:  ['351,winston bryant', '351,joe purcell']
# PRED:  ['351,joe purcell', '351,winston bryant']
# SAME:  ['351,joe purcell', '351,winston bryant']
# TRUE:  ['352,jim harris']
# PRED:  ['352,jim harris']
# SAME:  ['352,jim harris']
# TRUE:  ['353,corringham railway station']
# PRED:  ['353,corringham']
# SAME:  []
# NONE_TRUE_EQUAL:  ['353,corringham railway station']
# NONE_PRED_EQUAL:  ['353,corringham']
# TRUE:  ['354,stan lee', '354,the incredible hulk']
# PRED:  ['']
# NONE_TRUE_LESS:  ['354,stan lee', '354,the incredible hulk']
# NONE_PRED_LESS:  ['']
# TRUE:  ['355,emanuel de guzman']
# PRED:  ['355,emanuel de guzman']
# SAME:  ['355,emanuel de guzman']
# TRUE:  ['356,al khaleejiya 100.9']
# PRED:  ['356,al khaleejiya', '356,100.9 play']
# NONE_TRUE_MORE:  ['356,al khaleejiya 100.9']
# NONE_PRED_MORE:  ['356,al khaleejiya', '356,100.9 play']
# TRUE:  ['357,harvest christian center']
# PRED:  ['357,the harvest christian center']
# SAME:  []
# NONE_TRUE_EQUAL:  ['357,harvest christian center']
# NONE_PRED_EQUAL:  ['357,the harvest christian center']
# TRUE:  ["358,master's sun"]
# PRED:  ["358,master's sun>"]
# SAME:  []
# NONE_TRUE_EQUAL:  ["358,master's sun"]
# NONE_PRED_EQUAL:  ["358,master's sun>"]
# TRUE:  ['359,virtual kasparov', '359,fr agnel school and jr college']
# PRED:  ['359,fr agnel school', '359,jr', '359,virtual kasparov']
# MORE:  ['359,virtual kasparov']
# TRUE:  ['360,colts neck township', '360,beverly hills']
# PRED:  ['360,colts neck township', '360,beverly hills']
# SAME:  ['360,colts neck township', '360,beverly hills']
# TRUE:  ['361,blizzard']
# PRED:  ['361,blizzard']
# SAME:  ['361,blizzard']
# TRUE:  ['362,shannon pot', '362,limerick']
# PRED:  ['362,shannon pot', '362,limerick']
# SAME:  ['362,shannon pot', '362,limerick']
# TRUE:  ['363,gloucestershire', '363,reading']
# PRED:  ['363,gloucestershire']
# LESS:  ['363,gloucestershire']
# TRUE:  ['364,gelnhausen', '364,pepperdine university']
# PRED:  ['364,gelnhausen', '364,pepperdine university']
# SAME:  ['364,gelnhausen', '364,pepperdine university']
# TRUE:  ['365,frontaccounting', '365,nubuntu']
# PRED:  ['365,frontaccounting', '365,nubuntu']
# SAME:  ['365,frontaccounting', '365,nubuntu']
# TRUE:  ['366,brian graden', '366,broadcast syndication']
# PRED:  ['366,brian graden']
# LESS:  ['366,brian graden']
# TRUE:  ['367,fort barrancas', '367,gadsden']
# PRED:  ['367,fort barrancas', '367,gadsden']
# SAME:  ['367,fort barrancas', '367,gadsden']
# TRUE:  ['368,richard h immerman', '368,franklin w olin']
# PRED:  ['368,richard h immerman', '368,franklin w olin']
# SAME:  ['368,richard h immerman', '368,franklin w olin']
# TRUE:  ['369,occupation of japan']
# PRED:  ['369,japan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['369,occupation of japan']
# NONE_PRED_EQUAL:  ['369,japan']
# TRUE:  ['370,vanderbilt university medical center', '370,monroe carell jr children hospital']
# PRED:  ['370,monrow', '370,carell jr children hospital', '370,vanderbilt university medical center']
# MORE:  ['370,vanderbilt university medical center']
# TRUE:  ['371,gm b']
# PRED:  ['371,gm']
# SAME:  []
# NONE_TRUE_EQUAL:  ['371,gm b']
# NONE_PRED_EQUAL:  ['371,gm']
# ...
# TRUE:  ['4886,david lewis', '4886,thorington railway station']
# PRED:  ['4886,thorington', '4886, david lewis']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4886,david lewis', '4886,thorington railway station']
# NONE_PRED_EQUAL:  ['4886,thorington', '4886, david lewis']
# TRUE:  ['4887,nasa']
# PRED:  ['4887,nasa']
# SAME:  ['4887,nasa']
# TRUE:  ['4888,gibson les paul']
# PRED:  ['4888,gibson les paul']
# SAME:  ['4888,gibson les paul']
# TRUE:  ['4889,haight-ashbury', '4889,castro district']
# PRED:  ['4889,castro district', '4889,haight-ashbury']
# SAME:  ['4889,castro district', '4889,haight-ashbury']
# TRUE:  ['4890,uk']
# PRED:  ['4890,uk']
# SAME:  ['4890,uk']
# TRUE:  ['4891,motorpsycho nitemare', '4891,moondog matinee']
# PRED:  ['4891,moondog matinee', '4891,motorpsycho nitemare']
# SAME:  ['4891,moondog matinee', '4891,motorpsycho nitemare']
# TRUE:  ['4892,schutzstaffels']
# PRED:  ['4892,schutzstaffels']
# SAME:  ['4892,schutzstaffels']
# TRUE:  ['4893,kron ngoy', '4893,hang chuon naron']
# PRED:  ['4893,kron ngoy']
# LESS:  ['4893,kron ngoy']
# TRUE:  ['4894,william w brien']
# PRED:  ['4894,william w brien']
# SAME:  ['4894,william w brien']
# TRUE:  ['4895,ios']
# PRED:  ['4895,ios']
# SAME:  ['4895,ios']
# TRUE:  ['4896,the incredible hulk']
# PRED:  ['4896,1982']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4896,the incredible hulk']
# NONE_PRED_EQUAL:  ['4896,1982']
# TRUE:  ['4897,carl sanders']
# PRED:  ['4897,one', '4897,carl sanders']
# MORE:  ['4897,carl sanders']
# TRUE:  ['4898,william c p breckinridge']
# PRED:  ['4898,william c p']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4898,william c p breckinridge']
# NONE_PRED_EQUAL:  ['4898,william c p']
# TRUE:  ["4899,st. peter's basilica"]
# PRED:  ["4899,st. peter's basilica"]
# SAME:  ["4899,st. peter's basilica"]
# TRUE:  ['4900,dreamworks television', '4900,stephen e. ambrose']
# PRED:  ['4900,stephen e. ambrose', '4900,dreamworks television']
# SAME:  ['4900,stephen e. ambrose', '4900,dreamworks television']
# TRUE:  ['4901,lake washington']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4901,lake washington']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4902,fedexfield']
# PRED:  ['4902,fedexfield']
# SAME:  ['4902,fedexfield']
# TRUE:  ['4903,edsel villager']
# PRED:  ['4903,edsel']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4903,edsel villager']
# NONE_PRED_EQUAL:  ['4903,edsel']
# TRUE:  ['4904,sierra madre de chiapas']
# PRED:  ['4904,the sierra madre de chiapas']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4904,sierra madre de chiapas']
# NONE_PRED_EQUAL:  ['4904,the sierra madre de chiapas']
# TRUE:  ['4905,cherokee']
# PRED:  ['4905,cherokee']
# SAME:  ['4905,cherokee']
# TRUE:  ["4906,he's a liar"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["4906,he's a liar"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4907,bbc multimedia', '4907,mazes of time']
# PRED:  ['4907,mazes', '4907,bbc']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4907,bbc multimedia', '4907,mazes of time']
# NONE_PRED_EQUAL:  ['4907,mazes', '4907,bbc']
# TRUE:  ['4908,doonesbury']
# PRED:  ['4908,doonesbury']
# SAME:  ['4908,doonesbury']
# TRUE:  ['4909,aachen cathedral']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4909,aachen cathedral']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4910,robert a. taft', '4910,charles phelps taft ii']
# PRED:  ['4910,charles phelps', '4910,taft ii', '4910,robert a. taft']
# MORE:  ['4910,robert a. taft']
# TRUE:  ['4911,giorgos kaminis']
# PRED:  ['4911,giorgos kaminis']
# SAME:  ['4911,giorgos kaminis']
# TRUE:  ['4912,linda jenness']
# PRED:  ['4912,linda jenness']
# SAME:  ['4912,linda jenness']
# TRUE:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# PRED:  ['4913,the plymouth savoy', '4913,the northsouth transport corridor']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# NONE_PRED_EQUAL:  ['4913,the plymouth savoy', '4913,the northsouth transport corridor']
# TRUE:  ['4914,fender stratocaster']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4914,fender stratocaster']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4915,primate']
# PRED:  ['4915,primate']
# SAME:  ['4915,primate']
# TRUE:  ['4916,willem-alexander']
# PRED:  ['4916,willem-alexander', '4916,netherlands']
# MORE:  ['4916,willem-alexander']
# TRUE:  ['4917,chelsea f.c.']
# PRED:  ['4917,chelsea f.c.']
# SAME:  ['4917,chelsea f.c.']
# TRUE:  ['4918,kingdom']
# PRED:  ['4918,israelite', '4918,united monarch']
# NONE_TRUE_MORE:  ['4918,kingdom']
# NONE_PRED_MORE:  ['4918,israelite', '4918,united monarch']
# TRUE:  ['4919,malaysian pwd']
# PRED:  ['4919,pwd']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4919,malaysian pwd']
# NONE_PRED_EQUAL:  ['4919,pwd']
# TRUE:  ['4920,king county, washington', '4920,phil lumpkin']
# PRED:  ['4920,the king county', '4920,washington', '4920,phil lumpkin']
# MORE:  ['4920,phil lumpkin']
# TRUE:  ['4921,old lyme, connecticut']
# PRED:  ['4921,old lyme', '4921,connecticut']
# NONE_TRUE_MORE:  ['4921,old lyme, connecticut']
# NONE_PRED_MORE:  ['4921,old lyme', '4921,connecticut']
# TRUE:  ['4922,mac os', '4922,microsoft windows']
# PRED:  ['4922,os', '4922,microsoft', '4922,windows', '4922,mac os']
# MORE:  ['4922,mac os']
# TRUE:  ['4923,ike clanton']
# PRED:  ['4923,ike clanton']
# SAME:  ['4923,ike clanton']
# TRUE:  ['4924,indian general election, 2004']
# PRED:  ['4924,indian', '4924,2004', '4924,andhra pradesh']
# NONE_TRUE_MORE:  ['4924,indian general election, 2004']
# NONE_PRED_MORE:  ['4924,indian', '4924,2004', '4924,andhra pradesh']
# TRUE:  ['4925,miao people', '4925,palang dharma party']
# PRED:  ['4925,the palang dharma party', '4925,miao']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4925,miao people', '4925,palang dharma party']
# NONE_PRED_EQUAL:  ['4925,the palang dharma party', '4925,miao']
# TRUE:  ["4926,brown's corners, toronto", '4926,krista kelly']
# PRED:  ["4926,the brown's corners", '4926,krista kelly']
# SAME:  ['4926,krista kelly']
# PARTIAL:  ['4926,krista kelly']
# TRUE:  ['4927,judge advocate general corps']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4927,judge advocate general corps']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4928,pope pius xi']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4928,pope pius xi']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4929,brown']
# PRED:  ['4929,brown']
# SAME:  ['4929,brown']
# TRUE:  ['4930,solon spencer beman']
# PRED:  ['4930,solon', '4930,spencer beman']
# NONE_TRUE_MORE:  ['4930,solon spencer beman']
# NONE_PRED_MORE:  ['4930,solon', '4930,spencer beman']
# TRUE:  ['4931,1967 mexican grand prix', '4931,1971 us']
# PRED:  ['4931,first', '4931,the 1967 mexican grand prix', '4931,1971', '4931,us']
# NONE_TRUE_MORE:  ['4931,1967 mexican grand prix', '4931,1971 us']
# NONE_PRED_MORE:  ['4931,first', '4931,the 1967 mexican grand prix', '4931,1971', '4931,us']
# TRUE:  ['4932,sam sen railway station']
# PRED:  ['4932,sam sen railway station']
# SAME:  ['4932,sam sen railway station']
# TRUE:  ['4933,newcastle']
# PRED:  ['4933,newcastle']
# SAME:  ['4933,newcastle']
# TRUE:  ['4934,tehran']
# PRED:  ['4934,tehran']
# SAME:  ['4934,tehran']
# TRUE:  ['4935,wxme']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4935,wxme']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# PRED:  ['4936,mickey', '4936,mellerdrammer', "4936,tommy tucker's"]
# NONE_TRUE_MORE:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# NONE_PRED_MORE:  ['4936,mickey', '4936,mellerdrammer', "4936,tommy tucker's"]
# TRUE:  ['4937,quich department']
# PRED:  ['4937,quich department', '4937,one']
# MORE:  ['4937,quich department']
# TRUE:  ['4938,apollo 11', '4938,gemini 8']
# PRED:  ['4938,apollo 11', '4938,gemini']
# SAME:  ['4938,apollo 11']
# PARTIAL:  ['4938,apollo 11']
# TRUE:  ['4939,seattle great wheel']
# PRED:  ['4939,seattle great wheel']
# SAME:  ['4939,seattle great wheel']
# TRUE:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# PRED:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# SAME:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# TRUE:  ['4941,the bleeding heart band']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4941,the bleeding heart band']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4942,russian railways']
# PRED:  ['4942,russian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4942,russian railways']
# NONE_PRED_EQUAL:  ['4942,russian']
# TRUE:  ['4943,russell t davies', '4943,wizards and the aliens']
# PRED:  ['4943,wizards']
# NONE_TRUE_LESS:  ['4943,russell t davies', '4943,wizards and the aliens']
# NONE_PRED_LESS:  ['4943,wizards']
# TRUE:  ['4944,arkansas']
# PRED:  ['4944,arkansas']
# SAME:  ['4944,arkansas']
# TRUE:  ['4945,ceratosoma tenue']
# PRED:  ['4945,ceratosoma']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4945,ceratosoma tenue']
# NONE_PRED_EQUAL:  ['4945,ceratosoma']
# TRUE:  ['4946,riley reid', '4946,holmes colbert']
# PRED:  ['4946,riley reid', '4946,holmes colbert']
# SAME:  ['4946,riley reid', '4946,holmes colbert']
# TRUE:  ['4947,girls']
# PRED:  ['4947,girls']
# SAME:  ['4947,girls']
# TRUE:  ['4948,indira gandhi']
# PRED:  ['4948,indira gandhi']
# SAME:  ['4948,indira gandhi']
# TRUE:  ['4949,manhattan project']
# PRED:  ['4949,the manhattan project']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4949,manhattan project']
# NONE_PRED_EQUAL:  ['4949,the manhattan project']
# TRUE:  ['4950,secrets and lies']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4950,secrets and lies']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4951,ohio']
# PRED:  ['4951,ohio']
# SAME:  ['4951,ohio']
# TRUE:  ['4952,john o conner']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4952,john o conner']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4953,charlie justice', '4953,bobby hoppe']
# PRED:  ['4953,american', '4953,bobby hoppe']
# SAME:  ['4953,bobby hoppe']
# PARTIAL:  ['4953,bobby hoppe']
# TRUE:  ['4954,jimmy wales']
# PRED:  ['4954,jimmy']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4954,jimmy wales']
# NONE_PRED_EQUAL:  ['4954,jimmy']
# TRUE:  ['4955,ted williams tunnel', '4955,leonard memorial']
# PRED:  ['4955,ted williams', '4955,leonard memorial ridge']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4955,ted williams tunnel', '4955,leonard memorial']
# NONE_PRED_EQUAL:  ['4955,ted williams', '4955,leonard memorial ridge']
# TRUE:  ['4956,michaelhouse']
# PRED:  ['4956,michaelhouse']
# SAME:  ['4956,michaelhouse']
# TRUE:  ['4957,yosemite park']
# PRED:  ['4957,first', '4957,the yosemite park']
# NONE_TRUE_MORE:  ['4957,yosemite park']
# NONE_PRED_MORE:  ['4957,first', '4957,the yosemite park']
# TRUE:  ['4958,levant']
# PRED:  ['4958,levant']
# SAME:  ['4958,levant']
# TRUE:  ['4959,fifety five days at peking', '4959,awakening']
# PRED:  ['4959,awakening and fifety', '4959,five days']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4959,fifety five days at peking', '4959,awakening']
# NONE_PRED_EQUAL:  ['4959,awakening and fifety', '4959,five days']
# TRUE:  ['4960,huey, dewey, and louie', '4960,clan mcduck']
# PRED:  ['4960,clan mcduck', '4960,huey', '4960,dewey', '4960,louie']
# MORE:  ['4960,clan mcduck']
# TRUE:  ['4961,ennejma ezzahra', '4961,boga']
# PRED:  ['4961,ennejma ezzahra', '4961,boga']
# SAME:  ['4961,ennejma ezzahra', '4961,boga']
# TRUE:  ['4962,charles gordon']
# PRED:  ['4962,charles gordon']
# SAME:  ['4962,charles gordon']
# TRUE:  ['4963,maryanne trump barry', '4963,le cirque']
# PRED:  ['4963,le cirque', '4963,maryanne trump']
# SAME:  ['4963,le cirque']
# PARTIAL:  ['4963,le cirque']
# TRUE:  ['4964,toronto']
# PRED:  ['4964,toronto']
# SAME:  ['4964,toronto']
# TRUE:  ['4965,laurie johnson', '4965,stanley kubrick']
# PRED:  ["4965,stanley kubrick's", '4965,laurie johnson']
# SAME:  ['4965,laurie johnson']
# PARTIAL:  ['4965,laurie johnson']
# TRUE:  ['4966,uss kittiwake', '4966,haight-ashbury']
# PRED:  ['4966,haight-ashbury', '4966,uss kittiwake']
# SAME:  ['4966,haight-ashbury', '4966,uss kittiwake']
# TRUE:  ['4967,motorpsycho nitemare']
# PRED:  ['4967,motorpsycho nitemare']
# SAME:  ['4967,motorpsycho nitemare']
# TRUE:  ['4968,hbo', '4968,erik jendresen']
# PRED:  ['4968,erik jendresen', '4968,hbo']
# SAME:  ['4968,erik jendresen', '4968,hbo']
# TRUE:  ['4969,battle']
# PRED:  ['4969,battle of the bulge']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4969,battle']
# NONE_PRED_EQUAL:  ['4969,battle of the bulge']
# TRUE:  ['4970,israel', '4970,colin powell']
# PRED:  ['4970,colin powell']
# LESS:  ['4970,colin powell']
# TRUE:  ['4971,the ultimate fighter: team rousey vs. team tate']
# PRED:  ['4971,the ultimate fighter: team rousey', '4971,team tate']
# NONE_TRUE_MORE:  ['4971,the ultimate fighter: team rousey vs. team tate']
# NONE_PRED_MORE:  ['4971,the ultimate fighter: team rousey', '4971,team tate']
# TRUE:  ['4972,alexa scimeca']
# PRED:  ['4972,alexa scimeca']
# SAME:  ['4972,alexa scimeca']
# TRUE:  ['4973,south african class 11e', '4973,renfe class 333']
# PRED:  ['4973,south african', '4973,11e', '4973,renfe', '4973,333']
# NONE_TRUE_MORE:  ['4973,south african class 11e', '4973,renfe class 333']
# NONE_PRED_MORE:  ['4973,south african', '4973,11e', '4973,renfe', '4973,333']
# TRUE:  ['4974,erich bagge', '4974,erban ieica']
# PRED:  ['4974,erich bagge']
# LESS:  ['4974,erich bagge']
# TRUE:  ['4975,apollo 11', '4975,nasa']
# PRED:  ['4975,nasa', '4975,apollo 11']
# SAME:  ['4975,nasa', '4975,apollo 11']
# TRUE:  ['4976,ape', '4976,primate']
# PRED:  ['4976,ape', '4976,primate']
# SAME:  ['4976,ape', '4976,primate']
# TRUE:  ['4977,goethe prize']
# PRED:  ['4977,goethe prize']
# SAME:  ['4977,goethe prize']
# TRUE:  ['4978,amiga']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4978,amiga']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4979,william henry harrison tomb state memorial', '4979,john scott harrison']
# PRED:  ['4979,william henry harrison tomb state memorial', '4979,john scott harrison']
# SAME:  ['4979,william henry harrison tomb state memorial', '4979,john scott harrison']
# TRUE:  ['4980,muhammad yunus']
# PRED:  ['4980,muhammad yunus']
# SAME:  ['4980,muhammad yunus']
# TRUE:  ['4981,saunders county']
# PRED:  ['4981,saunders']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4981,saunders county']
# NONE_PRED_EQUAL:  ['4981,saunders']
# TRUE:  ['4982,miao rebellion']
# PRED:  ['4982,miao']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4982,miao rebellion']
# NONE_PRED_EQUAL:  ['4982,miao']
# TRUE:  ['4983,italic']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4983,italic']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4984,bbc multimedia', '4984,visions']
# PRED:  ['4984,the bbc multimedia', '4984,visions']
# SAME:  ['4984,visions']
# PARTIAL:  ['4984,visions']
# TRUE:  ['4985,donna shalala']
# PRED:  ['4985,donna shalala']
# SAME:  ['4985,donna shalala']
# TRUE:  ['4986,french southern and antarctic lands', '4986,kerguelen islands']
# PRED:  ['4986,kerguelen', '4986,french']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4986,french southern and antarctic lands', '4986,kerguelen islands']
# NONE_PRED_EQUAL:  ['4986,kerguelen', '4986,french']
# TRUE:  ['4987,weber thompson']
# PRED:  ['4987,weber thompson']
# SAME:  ['4987,weber thompson']
# TRUE:  ['4988,edith vonnegut']
# PRED:  ['4988,edith vonnegut']
# SAME:  ['4988,edith vonnegut']
# TRUE:  ['4989,iyoas i']
# PRED:  ['4989,iyoas']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4989,iyoas i']
# NONE_PRED_EQUAL:  ['4989,iyoas']
# TRUE:  ['4990,wcw mayhem']
# PRED:  ['4990,wcw mayhem']
# SAME:  ['4990,wcw mayhem']
# TRUE:  ['4991,rca records']
# PRED:  ['4991,rca']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4991,rca records']
# NONE_PRED_EQUAL:  ['4991,rca']
# TRUE:  ['4992,nick diaz', '4992,brazilian jiu-jitsu']
# PRED:  ['4992,brazilian', '4992,nick diaz']
# SAME:  ['4992,nick diaz']
# PARTIAL:  ['4992,nick diaz']
# TRUE:  ['4993,amstelveen']
# PRED:  ['4993,amstelveen']
# SAME:  ['4993,amstelveen']
# TRUE:  ['4994,choctaw']
# PRED:  ['4994,choctaw']
# SAME:  ['4994,choctaw']
# TRUE:  ['4995,larry j. franco']
# PRED:  ['4995,larry j. franco']
# SAME:  ['4995,larry j. franco']
# TRUE:  ['4996,tnt', '4996,j. michael stroczynski']
# PRED:  ['4996,j. michael stroczynski', '4996,tnt']
# SAME:  ['4996,j. michael stroczynski', '4996,tnt']
# TRUE:  ['4997,varsity stadium']
# PRED:  ['4997,varsity stadium']
# SAME:  ['4997,varsity stadium']
# TRUE:  ['4998,robin kovacs', '4998,nyrangers']
# PRED:  ['4998,ny rangers', '4998,robin kovacs']
# SAME:  ['4998,robin kovacs']
# PARTIAL:  ['4998,robin kovacs']
# TRUE:  ["4999,marquette golden eagles men's basketball team, 2008-09", "4999,marquette golden eagles men's basketball team"]
# PRED:  ['4999,marquette golden eagles', '4999,2008-09', '4999,marquette golden eagles']
# NONE_TRUE_MORE:  ["4999,marquette golden eagles men's basketball team, 2008-09", "4999,marquette golden eagles men's basketball team"]
# NONE_PRED_MORE:  ['4999,marquette golden eagles', '4999,2008-09', '4999,marquette golden eagles']
# 2528
# 328
# 181
# 298
# 1144
# 137
# 384
# 4501

# %%
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# 2528
# 328
# 181
# 298
# 1144
# 137
# 384
# 4501
# 0.6776573321288768

# %%
### compare sm+md predictions

match, partial, less, more, none_match, none_less, none_more, predicted = compare_predictions(real, ner_sm_md)
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# TRUE:  ['0,bill finger']
# PRED:  ['0,bill finger']
# SAME:  ['0,bill finger']
# TRUE:  ['1,selwyn lloyd', '1,winston churchill']
# PRED:  ['1,selwyn lloyd']
# LESS:  ['1,selwyn lloyd']
# TRUE:  ['2,gestapo']
# PRED:  ['2,gestapo']
# SAME:  ['2,gestapo']
# TRUE:  ['3,mumbai north']
# PRED:  ['3,mumbai']
# SAME:  []
# NONE_TRUE_EQUAL:  ['3,mumbai north']
# NONE_PRED_EQUAL:  ['3,mumbai']
# TRUE:  ['4,roberto clemente bridge']
# PRED:  ['4,roberto clemente bridge']
# SAME:  ['4,roberto clemente bridge']
# TRUE:  ['5,ptolemy xiii theos philopator', '5,cleopatra v']
# PRED:  ['5,xiii theos philopator', '5,cleopatra v']
# SAME:  ['5,cleopatra v']
# PARTIAL:  ['5,cleopatra v']
# TRUE:  ['6,li si']
# PRED:  ['6,li si']
# SAME:  ['6,li si']
# TRUE:  ['7,pavel moroz', '7,yakov estrin']
# PRED:  ['7,pavel moroz', '7,the yakov estrin']
# SAME:  ['7,pavel moroz']
# PARTIAL:  ['7,pavel moroz']
# TRUE:  ['8,broadmeadows, victoria']
# PRED:  ['8,broadmeadows, victoria']
# SAME:  ['8,broadmeadows, victoria']
# TRUE:  ['9,asc creative services']
# PRED:  ['9,asc creative services']
# SAME:  ['9,asc creative services']
# TRUE:  ['10,ernest rutherford', '10,charles drummond ellis']
# PRED:  ['10,ernest rutherford', '10,charles drummond ellis']
# SAME:  ['10,ernest rutherford', '10,charles drummond ellis']
# TRUE:  ['11,rep parasol']
# PRED:  ['11,rep parasol']
# SAME:  ['11,rep parasol']
# TRUE:  ["12,monroe carell jr. children's hospital", '12,vanderbilt', '12,duncan u. fletcher']
# PRED:  ["12,the monroe carell jr. children's hospital", '12,vanderbilt', '12,the duncan u. fletcher']
# SAME:  ['12,vanderbilt']
# PARTIAL:  ['12,vanderbilt']
# TRUE:  ['13,josef johansson', '13,nader guirat']
# PRED:  ['13,nader guirat', '13,josef johansson']
# SAME:  ['13,nader guirat', '13,josef johansson']
# TRUE:  ['14,dr who confidential', '14,the sara jane adventure']
# PRED:  ['']
# NONE_TRUE_LESS:  ['14,dr who confidential', '14,the sara jane adventure']
# NONE_PRED_LESS:  ['']
# TRUE:  ['15,hbo']
# PRED:  ['15,hbo']
# SAME:  ['15,hbo']
# TRUE:  ['16,stanislav morozov', '16,nikolai morozov']
# PRED:  ['16,nikolai morozov', '16,stanislav morozov']
# SAME:  ['16,nikolai morozov', '16,stanislav morozov']
# TRUE:  ['17,abhijit kunte', '17,kasparov']
# PRED:  ['17,abhijit kunte', '17,kasparov']
# SAME:  ['17,abhijit kunte', '17,kasparov']
# TRUE:  ['18,outlook', '18,msx basics']
# PRED:  ['18,the msx basics']
# NONE_TRUE_LESS:  ['18,outlook', '18,msx basics']
# NONE_PRED_LESS:  ['18,the msx basics']
# TRUE:  ['19,ronaldo']
# PRED:  ['19,seasons', '19,ronaldo']
# MORE:  ['19,ronaldo']
# TRUE:  ['20,samurabsheron channel', '20,anar salmanov']
# PRED:  ['20,samurabsheron', '20,anar salmanov']
# SAME:  ['20,anar salmanov']
# PARTIAL:  ['20,anar salmanov']
# TRUE:  ['21,2nd foreign infantry regiment']
# PRED:  ['21,2nd foreign infantry regiment']
# SAME:  ['21,2nd foreign infantry regiment']
# TRUE:  ['22,sr class 3sub']
# PRED:  ['22,3sub']
# SAME:  []
# NONE_TRUE_EQUAL:  ['22,sr class 3sub']
# NONE_PRED_EQUAL:  ['22,3sub']
# TRUE:  ['23,kevin jonas', '23,joe jonas']
# PRED:  ['23,kevin jonas', '23,joe jonas']
# SAME:  ['23,kevin jonas', '23,joe jonas']
# TRUE:  ['24,sunrise (himym)', '24,timm gunn']
# PRED:  ['24,timm gunn', '24,sunrise (himym']
# SAME:  ['24,timm gunn']
# PARTIAL:  ['24,timm gunn']
# TRUE:  ['25,o.co coliseum']
# PRED:  ['25,o.co coliseum']
# SAME:  ['25,o.co coliseum']
# TRUE:  ['26,rishkiesh']
# PRED:  ['26,rishkiesh']
# SAME:  ['26,rishkiesh']
# TRUE:  ['27,north america', '27,airtours airways']
# PRED:  ['27,one']
# NONE_TRUE_LESS:  ['27,north america', '27,airtours airways']
# NONE_PRED_LESS:  ['27,one']
# TRUE:  ['28,national medal of science']
# PRED:  ['28,phds', '28,national medal of science']
# MORE:  ['28,national medal of science']
# TRUE:  ['29,aston villa 2000-02 season', '29,middlesbrough f.c. season 2009-10']
# PRED:  ['29,aston villa 2000-02 season', '29,middlesbrough f.c.', '29,2009-10']
# MORE:  ['29,aston villa 2000-02 season']
# TRUE:  ['30,william harper']
# PRED:  ['30,william harper']
# SAME:  ['30,william harper']
# TRUE:  ['31,pcl constructures']
# PRED:  ['31,pcl']
# SAME:  []
# NONE_TRUE_EQUAL:  ['31,pcl constructures']
# NONE_PRED_EQUAL:  ['31,pcl']
# TRUE:  ['32,jonas brothers', '32,kevin jonas']
# PRED:  ['32,kevin jonas', '32,jonas']
# SAME:  ['32,kevin jonas']
# PARTIAL:  ['32,kevin jonas']
# TRUE:  ['33,cosmos']
# PRED:  ['33,sagan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['33,cosmos']
# NONE_PRED_EQUAL:  ['33,sagan']
# TRUE:  ['34,rosemont, illinois']
# PRED:  ['34,rosemont', '34,illinois']
# NONE_TRUE_MORE:  ['34,rosemont, illinois']
# NONE_PRED_MORE:  ['34,rosemont', '34,illinois']
# TRUE:  ['35,greenup county high school']
# PRED:  ['35,greenup county high school']
# SAME:  ['35,greenup county high school']
# TRUE:  ['36,bobby hoppe']
# PRED:  ['36,bobby hoppe']
# SAME:  ['36,bobby hoppe']
# TRUE:  ['37,the second coming']
# PRED:  ['37,the second coming']
# SAME:  ['37,the second coming']
# TRUE:  ['38,miguel de cervantes']
# PRED:  ['38,miguel de cervantes']
# SAME:  ['38,miguel de cervantes']
# TRUE:  ['39,progressive rock']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['39,progressive rock']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['40,reading, berkshire']
# PRED:  ['40,berkshire']
# SAME:  []
# NONE_TRUE_EQUAL:  ['40,reading, berkshire']
# NONE_PRED_EQUAL:  ['40,berkshire']
# TRUE:  ['41,crystal harris']
# PRED:  ['41,crystal harris']
# SAME:  ['41,crystal harris']
# TRUE:  ['42,west thurrock', '42,essex']
# PRED:  ['42,essex']
# LESS:  ['42,essex']
# TRUE:  ['43,niederkirchnerstrae']
# PRED:  ['43,niederkirchnerstrae']
# SAME:  ['43,niederkirchnerstrae']
# TRUE:  ['44,steven moffat']
# PRED:  ['44,steven moffat']
# SAME:  ['44,steven moffat']
# TRUE:  ['45,ford falcon cobra', '45,dagenham wind turbines']
# PRED:  ['45,dagenham', '45,ford']
# SAME:  []
# NONE_TRUE_EQUAL:  ['45,ford falcon cobra', '45,dagenham wind turbines']
# NONE_PRED_EQUAL:  ['45,dagenham', '45,ford']
# TRUE:  ['46,san francisco international airport']
# PRED:  ['46,san francisco international airport']
# SAME:  ['46,san francisco international airport']
# TRUE:  ['47,maritime museum of san diego']
# PRED:  ['47,san diego']
# SAME:  []
# NONE_TRUE_EQUAL:  ['47,maritime museum of san diego']
# NONE_PRED_EQUAL:  ['47,san diego']
# TRUE:  ['48,sarah walker', '48,trinity school, brentwood']
# PRED:  ['48,the sarah walker', '48,the trinity school, brentwood']
# SAME:  []
# NONE_TRUE_EQUAL:  ['48,sarah walker', '48,trinity school, brentwood']
# NONE_PRED_EQUAL:  ['48,the sarah walker', '48,the trinity school, brentwood']
# TRUE:  ['49,21vianet']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['49,21vianet']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['50,urbain le verrier', '50,johann gottfried']
# PRED:  ['50,johann gottfired', '50,urbain']
# SAME:  []
# NONE_TRUE_EQUAL:  ['50,urbain le verrier', '50,johann gottfried']
# NONE_PRED_EQUAL:  ['50,johann gottfired', '50,urbain']
# TRUE:  ['51,elmer burkett']
# PRED:  ['51,elmer burkett']
# SAME:  ['51,elmer burkett']
# TRUE:  ['52,hensley meulens', '52,steve ontiveros']
# PRED:  ['52,hensley meulens', '52,steve ontiveros']
# SAME:  ['52,hensley meulens', '52,steve ontiveros']
# TRUE:  ['53,lucy sullivan is getting married']
# PRED:  ['53,lucy sullivan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['53,lucy sullivan is getting married']
# NONE_PRED_EQUAL:  ['53,lucy sullivan']
# TRUE:  ['54,faaa', '54,society islands']
# PRED:  ['54,society islands', '54,faaa']
# SAME:  ['54,society islands', '54,faaa']
# TRUE:  ['55,1997 canadian grand prix', '55,94 spanish']
# PRED:  ['55,1997', '55,94']
# SAME:  []
# NONE_TRUE_EQUAL:  ['55,1997 canadian grand prix', '55,94 spanish']
# NONE_PRED_EQUAL:  ['55,1997', '55,94']
# TRUE:  ['56,richard winn']
# PRED:  ['56,richard winn']
# SAME:  ['56,richard winn']
# TRUE:  ['57,sherlock', '57,arthur levinson']
# PRED:  ['57,sherlock', '57,arthur levinson']
# SAME:  ['57,sherlock', '57,arthur levinson']
# TRUE:  ['58,master card center', '58,sam carrrick']
# PRED:  ['58,master card', '58,sam carrrick']
# SAME:  ['58,sam carrrick']
# PARTIAL:  ['58,sam carrrick']
# TRUE:  ['59,fremantle media']
# PRED:  ['59,fremantle media']
# SAME:  ['59,fremantle media']
# TRUE:  ['60,south loop printing house district']
# PRED:  ['60,south loop printing house district']
# SAME:  ['60,south loop printing house district']
# TRUE:  ['61,outlook', '61,visual studio']
# PRED:  ['61,visual studio']
# LESS:  ['61,visual studio']
# TRUE:  ['62,croatia', '62,ombla']
# PRED:  ['62,croatia']
# LESS:  ['62,croatia']
# TRUE:  ['63,newin chidchob']
# PRED:  ['63,newin chidchob']
# SAME:  ['63,newin chidchob']
# TRUE:  ['64,ron reed', '64,dave bing']
# PRED:  ['64,dave bing', '64,ron reed']
# SAME:  ['64,dave bing', '64,ron reed']
# TRUE:  ['65,galileo galilei', '65,ganymede']
# PRED:  ['65,galileo galilei']
# LESS:  ['65,galileo galilei']
# TRUE:  ['66,guitar']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['66,guitar']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['67,elizabeth: the golden age']
# PRED:  ['67,elizabeth']
# SAME:  []
# NONE_TRUE_EQUAL:  ['67,elizabeth: the golden age']
# NONE_PRED_EQUAL:  ['67,elizabeth']
# TRUE:  ['68,onedrive']
# PRED:  ['68,onedrive']
# SAME:  ['68,onedrive']
# TRUE:  ['69,washington, d.c.']
# PRED:  ['69,washington, d.c.']
# SAME:  ['69,washington, d.c.']
# TRUE:  ['70,queen noor of jordan']
# PRED:  ['70,jordan', '70,one']
# NONE_TRUE_MORE:  ['70,queen noor of jordan']
# NONE_PRED_MORE:  ['70,jordan', '70,one']
# TRUE:  ['71,robert witherspoon']
# PRED:  ['71,robert witherspoon']
# SAME:  ['71,robert witherspoon']
# TRUE:  ["72,he's a liar"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["72,he's a liar"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['73,oj, svijetla majska zoro']
# PRED:  ['73,oj']
# SAME:  []
# NONE_TRUE_EQUAL:  ['73,oj, svijetla majska zoro']
# NONE_PRED_EQUAL:  ['73,oj']
# TRUE:  ['74,allen walker']
# PRED:  ['74,allen walker']
# SAME:  ['74,allen walker']
# TRUE:  ['75,marcus calpurnius bibulus', '75,publius servilius vatia isauricus']
# PRED:  ['75,publius servilius vatia isauricus', '75,marcus calpurnius']
# SAME:  ['75,publius servilius vatia isauricus']
# PARTIAL:  ['75,publius servilius vatia isauricus']
# TRUE:  ['76,edmund john', '76,saima chowdhury']
# PRED:  ['76,chowdhury']
# NONE_TRUE_LESS:  ['76,edmund john', '76,saima chowdhury']
# NONE_PRED_LESS:  ['76,chowdhury']
# TRUE:  ['77,mount hoffmann', '77,cathedral peak']
# PRED:  ['77,mount hoffmann']
# LESS:  ['77,mount hoffmann']
# TRUE:  ['78,indiana']
# PRED:  ['78,indiana']
# SAME:  ['78,indiana']
# TRUE:  ['79,swedish covenant hospital']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['79,swedish covenant hospital']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['80,moondog matinee', '80,girl from the north country']
# PRED:  ['80,the north country', '80,the moondog matinee']
# SAME:  []
# NONE_TRUE_EQUAL:  ['80,moondog matinee', '80,girl from the north country']
# NONE_PRED_EQUAL:  ['80,the north country', '80,the moondog matinee']
# TRUE:  ['81,april stewart', '81,mona marshall']
# PRED:  ['81, ', '81,april stewart', '81,mona marshall']
# MORE:  ['81,april stewart', '81,mona marshall']
# TRUE:  ['82,trinity house', '82,freedom']
# PRED:  ['82, ', '82,trinity house']
# SAME:  ['82,trinity house']
# PARTIAL:  ['82,trinity house']
# TRUE:  ['83,iran', '83,reza amrollahi']
# PRED:  ['83,reza amrollahi', '83,iran']
# SAME:  ['83,reza amrollahi', '83,iran']
# TRUE:  ['84,zaman shah durrani', '84,salahuddin']
# PRED:  ['84,zaman shah durrani', '84,salahuddin']
# SAME:  ['84,zaman shah durrani', '84,salahuddin']
# TRUE:  ['85,roh tae woo', '85,lee leffingwell']
# PRED:  ['85,roh tae woo', '85,lee leffingwell']
# SAME:  ['85,roh tae woo', '85,lee leffingwell']
# TRUE:  ['86,rosemarie dewitt']
# PRED:  ['86,rosemarie dewitt']
# SAME:  ['86,rosemarie dewitt']
# TRUE:  ['87,sapindales']
# PRED:  ['87,sapindales']
# SAME:  ['87,sapindales']
# TRUE:  ['88,lewis hamilton']
# PRED:  ['88,lewis hamilton']
# SAME:  ['88,lewis hamilton']
# TRUE:  ['89,giorgos kaminis']
# PRED:  ['89,giorgos kaminis']
# SAME:  ['89,giorgos kaminis']
# TRUE:  ['90,michael hahn']
# PRED:  ['90,michael']
# SAME:  []
# NONE_TRUE_EQUAL:  ['90,michael hahn']
# NONE_PRED_EQUAL:  ['90,michael']
# TRUE:  ['91,berlin']
# PRED:  ['91,berlin']
# SAME:  ['91,berlin']
# TRUE:  ['92,india']
# PRED:  ['92,india']
# SAME:  ['92,india']
# TRUE:  ['93,the simpsons ride']
# PRED:  ['93,the simpsons ride']
# SAME:  ['93,the simpsons ride']
# TRUE:  ['94,o.co coliseum']
# PRED:  ['94, ']
# SAME:  []
# NONE_TRUE_EQUAL:  ['94,o.co coliseum']
# NONE_PRED_EQUAL:  ['94, ']
# TRUE:  ['95,mams taylor', '95,the mating habits of the earthbound humans']
# PRED:  ['95,mams']
# NONE_TRUE_LESS:  ['95,mams taylor', '95,the mating habits of the earthbound humans']
# NONE_PRED_LESS:  ['95,mams']
# TRUE:  ['96,playboy enterprises']
# PRED:  ['96,playboy enterprises']
# SAME:  ['96,playboy enterprises']
# TRUE:  ['97,gwo ka', '97,western africa']
# PRED:  ['97,gwo ka', '97,western africa']
# SAME:  ['97,gwo ka', '97,western africa']
# TRUE:  ['98,send it on']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['98,send it on']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['99,onedrive', '99,visual studio']
# PRED:  ['99,visual studio']
# LESS:  ['99,visual studio']
# TRUE:  ['100,roundhead']
# PRED:  ['100,wyandot']
# SAME:  []
# NONE_TRUE_EQUAL:  ['100,roundhead']
# NONE_PRED_EQUAL:  ['100,wyandot']
# TRUE:  ['101,michigan stadium']
# PRED:  ['101,the michigan stadium']
# SAME:  []
# NONE_TRUE_EQUAL:  ['101,michigan stadium']
# NONE_PRED_EQUAL:  ['101,the michigan stadium']
# TRUE:  ['102,david johnston']
# PRED:  ['102,david johnston']
# SAME:  ['102,david johnston']
# TRUE:  ['103,francois marie le marchand de lignery']
# PRED:  ['103,francois marie le', '103,marchand de lignery']
# NONE_TRUE_MORE:  ['103,francois marie le marchand de lignery']
# NONE_PRED_MORE:  ['103,francois marie le', '103,marchand de lignery']
# TRUE:  ['104,myntdu river']
# PRED:  ['104,myntdu']
# SAME:  []
# NONE_TRUE_EQUAL:  ['104,myntdu river']
# NONE_PRED_EQUAL:  ['104,myntdu']
# TRUE:  ['105,london']
# PRED:  ['105,london']
# SAME:  ['105,london']
# TRUE:  ['106,ann lewis', '106,al gore presidential campaign, 2000']
# PRED:  ['106,al gore', '106,2000', '106,ann lewis']
# MORE:  ['106,ann lewis']
# TRUE:  ['107,darius i']
# PRED:  ['107,darius i']
# SAME:  ['107,darius i']
# TRUE:  ['108,airtours international airways', '108,kim sawchuk']
# PRED:  ['108,kim sawchuk', '108,the airtours international airways']
# SAME:  ['108,kim sawchuk']
# PARTIAL:  ['108,kim sawchuk']
# TRUE:  ['109,antonio giannini']
# PRED:  ['109,antonio giannini']
# SAME:  ['109,antonio giannini']
# TRUE:  ['110,david scherman']
# PRED:  ['110,david scherman']
# SAME:  ['110,david scherman']
# TRUE:  ['111,outlook.com', '111,onedrive']
# PRED:  ['111,outlook.com', '111,onedrive']
# SAME:  ['111,outlook.com', '111,onedrive']
# TRUE:  ['112,rouen business school']
# PRED:  ['112,rouen business school']
# SAME:  ['112,rouen business school']
# TRUE:  ['113,minjoo party']
# PRED:  ['113,the korean minjoo party']
# SAME:  []
# NONE_TRUE_EQUAL:  ['113,minjoo party']
# NONE_PRED_EQUAL:  ['113,the korean minjoo party']
# TRUE:  ['114,mcdonnell aircraft']
# PRED:  ['114,one', '114,mcdonnell aircraft']
# MORE:  ['114,mcdonnell aircraft']
# TRUE:  ['115,gales ferry, connecticut']
# PRED:  ['115,gales ferry', '115,connecticut']
# NONE_TRUE_MORE:  ['115,gales ferry, connecticut']
# NONE_PRED_MORE:  ['115,gales ferry', '115,connecticut']
# TRUE:  ['116,live in detroit, mi']
# PRED:  ['116,detroit', '116,mi']
# NONE_TRUE_MORE:  ['116,live in detroit, mi']
# NONE_PRED_MORE:  ['116,detroit', '116,mi']
# TRUE:  ['117,english under twenty one football team']
# PRED:  ['117,english', '117,under twenty']
# NONE_TRUE_MORE:  ['117,english under twenty one football team']
# NONE_PRED_MORE:  ['117,english', '117,under twenty']
# TRUE:  ['118,helsinki', '118,danish straits']
# PRED:  ['118,helsinki', '118,one', '118,danish']
# MORE:  ['118,helsinki']
# TRUE:  ['119,timmy time']
# PRED:  ['119,timmy time']
# SAME:  ['119,timmy time']
# TRUE:  ['120,fort heath radar station']
# PRED:  ['120,fort heath']
# SAME:  []
# NONE_TRUE_EQUAL:  ['120,fort heath radar station']
# NONE_PRED_EQUAL:  ['120,fort heath']
# TRUE:  ['121,lyons township high school', '121,harding academy']
# PRED:  ['121,harding', '121,lyons']
# SAME:  []
# NONE_TRUE_EQUAL:  ['121,lyons township high school', '121,harding academy']
# NONE_PRED_EQUAL:  ['121,harding', '121,lyons']
# TRUE:  ['122,rosario, santa fe']
# PRED:  ['122,rosario', '122,santa fe']
# NONE_TRUE_MORE:  ['122,rosario, santa fe']
# NONE_PRED_MORE:  ['122,rosario', '122,santa fe']
# TRUE:  ['123,animal']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['123,animal']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['124,oahu railway and land company', '124,chris myers']
# PRED:  ['124,new jersey', '124,oahu railway and land company', '124,chris myers']
# MORE:  ['124,oahu railway and land company', '124,chris myers']
# TRUE:  ['125,ngos']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['125,ngos']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['126,brian graden', '126,isaac hayes']
# PRED:  ['126,brian graden', '126,isaac hayes']
# SAME:  ['126,brian graden', '126,isaac hayes']
# TRUE:  ['127,cars']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['127,cars']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['128,steve sampson', '128,santa clara university']
# PRED:  ['128,steve sampson', '128,santa clara']
# SAME:  ['128,steve sampson']
# PARTIAL:  ['128,steve sampson']
# TRUE:  ['129,schibsted']
# PRED:  ['129,schibsted']
# SAME:  ['129,schibsted']
# TRUE:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# PRED:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# SAME:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# TRUE:  ['131,joan laporta']
# PRED:  ['131,joan laporta']
# SAME:  ['131,joan laporta']
# TRUE:  ['132,four-wheel-drive layout']
# PRED:  ['132,four']
# SAME:  []
# NONE_TRUE_EQUAL:  ['132,four-wheel-drive layout']
# NONE_PRED_EQUAL:  ['132,four']
# TRUE:  ['133,pong pha']
# PRED:  ['133,pong pha']
# SAME:  ['133,pong pha']
# TRUE:  ['134,charles ayres', '134,angela trusty']
# PRED:  ['134,the angela trusty', '134,charles ayres']
# SAME:  ['134,charles ayres']
# PARTIAL:  ['134,charles ayres']
# TRUE:  ['135,the conglomerate', '135,before i let you go']
# PRED:  ['135,conglomerate']
# NONE_TRUE_LESS:  ['135,the conglomerate', '135,before i let you go']
# NONE_PRED_LESS:  ['135,conglomerate']
# TRUE:  ['136,lagnacha dhumdhadaka']
# PRED:  ['136,lagnacha']
# SAME:  []
# NONE_TRUE_EQUAL:  ['136,lagnacha dhumdhadaka']
# NONE_PRED_EQUAL:  ['136,lagnacha']
# TRUE:  ['137,english']
# PRED:  ['137,english']
# SAME:  ['137,english']
# TRUE:  ['138,el sobrante, california']
# PRED:  ['138,el sobrante', '138,california']
# NONE_TRUE_MORE:  ['138,el sobrante, california']
# NONE_PRED_MORE:  ['138,el sobrante', '138,california']
# TRUE:  ["139,daniel o'regan"]
# PRED:  ["139,the nickname of daniel o'regan"]
# SAME:  []
# NONE_TRUE_EQUAL:  ["139,daniel o'regan"]
# NONE_PRED_EQUAL:  ["139,the nickname of daniel o'regan"]
# TRUE:  ['140,aureus', '140,solidus']
# PRED:  ['140,solidus']
# LESS:  ['140,solidus']
# TRUE:  ['141,cardiovascular disease']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['141,cardiovascular disease']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['142,mammal', '142,chestnut white bellied rat']
# PRED:  ['']
# NONE_TRUE_LESS:  ['142,mammal', '142,chestnut white bellied rat']
# NONE_PRED_LESS:  ['']
# TRUE:  ['143,the broken code', '143,tim gunn']
# PRED:  ['143,tim gunn', '143,the broken code']
# SAME:  ['143,tim gunn', '143,the broken code']
# TRUE:  ['144,shallot']
# PRED:  ['144,shallot']
# SAME:  ['144,shallot']
# TRUE:  ['145,oktoc, mississippi']
# PRED:  ['145,oktoc', '145,mississippi']
# NONE_TRUE_MORE:  ['145,oktoc, mississippi']
# NONE_PRED_MORE:  ['145,oktoc', '145,mississippi']
# TRUE:  ['146,nord', '146,the beauty inside']
# PRED:  ['146,nord']
# LESS:  ['146,nord']
# TRUE:  ['147,tirana', '147,albania']
# PRED:  ['147,tirana', '147,albania']
# SAME:  ['147,tirana', '147,albania']
# TRUE:  ['148,vishwajyot high school', '148,fr agnel multipurpose school']
# PRED:  ['148,vishwajyot high school', '148,fr agnel multipurpose school']
# SAME:  ['148,vishwajyot high school', '148,fr agnel multipurpose school']
# TRUE:  ['149,bob hawke']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['149,bob hawke']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['150,cbs corporation']
# PRED:  ['150,the cbs corporation']
# SAME:  []
# NONE_TRUE_EQUAL:  ['150,cbs corporation']
# NONE_PRED_EQUAL:  ['150,the cbs corporation']
# TRUE:  ['151,taguig']
# PRED:  ['151,taguig']
# SAME:  ['151,taguig']
# TRUE:  ['152,joe hahn']
# PRED:  ['152,joe hahn']
# SAME:  ['152,joe hahn']
# TRUE:  ['153,comedy central', '153,isaac hayes']
# PRED:  ['153,isaac hayes']
# LESS:  ['153,isaac hayes']
# TRUE:  ['154,raymond johansen']
# PRED:  ['154,raymond johansen']
# SAME:  ['154,raymond johansen']
# TRUE:  ['155,ikaros smederna']
# PRED:  ['155,ikaros smederna']
# SAME:  ['155,ikaros smederna']
# TRUE:  ['156,windows']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['156,windows']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['157,hockey']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['157,hockey']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['158,washington dc']
# PRED:  ['158,washington dc']
# SAME:  ['158,washington dc']
# TRUE:  ['159,temenos group']
# PRED:  ['159,temenos group']
# SAME:  ['159,temenos group']
# TRUE:  ['160,to know him is to love him']
# PRED:  ['160,love']
# SAME:  []
# NONE_TRUE_EQUAL:  ['160,to know him is to love him']
# NONE_PRED_EQUAL:  ['160,love']
# TRUE:  ['161,spain...']
# PRED:  ['161,spain']
# SAME:  []
# NONE_TRUE_EQUAL:  ['161,spain...']
# NONE_PRED_EQUAL:  ['161,spain']
# TRUE:  ['162,chris marve', '162,neria douglass']
# PRED:  ['162,chris marve', '162,neria douglass']
# SAME:  ['162,chris marve', '162,neria douglass']
# TRUE:  ['163,monticello, maine']
# PRED:  ['163,monticello', '163,maine']
# NONE_TRUE_MORE:  ['163,monticello, maine']
# NONE_PRED_MORE:  ['163,monticello', '163,maine']
# TRUE:  ['164,josiah idowu-fearon', '164,john']
# PRED:  ['164,josiah idowu-fearon', '164,damasucs']
# SAME:  ['164,josiah idowu-fearon']
# PARTIAL:  ['164,josiah idowu-fearon']
# TRUE:  ['165,paramount television', '165,judy hart angelo']
# PRED:  ['165,judy hart angelo', '165,paramount']
# SAME:  ['165,judy hart angelo']
# PARTIAL:  ['165,judy hart angelo']
# TRUE:  ['166,caspian']
# PRED:  ['166,caspian']
# SAME:  ['166,caspian']
# TRUE:  ['167,united states department of defense', '167,arlington county, virginia']
# PRED:  ['167,arlington county', '167,virginia', '167,united states department of defense']
# MORE:  ['167,united states department of defense']
# TRUE:  ['168,thongsuk samdaengpan']
# PRED:  ['168,thongsuk samdaengpan']
# SAME:  ['168,thongsuk samdaengpan']
# TRUE:  ['169,asus']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['169,asus']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['170,ncaa']
# PRED:  ['170,ncaa']
# SAME:  ['170,ncaa']
# TRUE:  ['171,afrika baby bam', '171,queen latifah']
# PRED:  ['171,queen latifah', '171,afrika baby bam']
# SAME:  ['171,queen latifah', '171,afrika baby bam']
# TRUE:  ['172,kazuo hirai']
# PRED:  ['172,kazuo hirai']
# SAME:  ['172,kazuo hirai']
# TRUE:  ['173,patts college of aeronautics']
# PRED:  ['173,patts college of aeronautics']
# SAME:  ['173,patts college of aeronautics']
# TRUE:  ['174,dan shamash', '174,ever bank field']
# PRED:  ['174,dan shamash']
# LESS:  ['174,dan shamash']
# TRUE:  ['175,thanong bidaya']
# PRED:  ['175,thanong bidaya']
# SAME:  ['175,thanong bidaya']
# TRUE:  ['176,san marcos river']
# PRED:  ['176,san marcos river']
# SAME:  ['176,san marcos river']
# TRUE:  ['177,jazz fusion']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['177,jazz fusion']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['178,bogumilus']
# PRED:  ['178,bogumilus']
# SAME:  ['178,bogumilus']
# TRUE:  ['179,screen actors guild life achievement award', '179,henry e. catto, jr.']
# PRED:  ['179,henry e. catto']
# NONE_TRUE_LESS:  ['179,screen actors guild life achievement award', '179,henry e. catto, jr.']
# NONE_PRED_LESS:  ['179,henry e. catto']
# TRUE:  ['180,pope gregory i']
# PRED:  ['180,pope gregory']
# SAME:  []
# NONE_TRUE_EQUAL:  ['180,pope gregory i']
# NONE_PRED_EQUAL:  ['180,pope gregory']
# TRUE:  ['181,human rights party']
# PRED:  ['181,cambodian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['181,human rights party']
# NONE_PRED_EQUAL:  ['181,cambodian']
# TRUE:  ['182,czech extraliga']
# PRED:  ['182,the czech extraliga']
# SAME:  []
# NONE_TRUE_EQUAL:  ['182,czech extraliga']
# NONE_PRED_EQUAL:  ['182,the czech extraliga']
# TRUE:  ['183,croix de guerre']
# PRED:  ['183,the croix de guerre']
# SAME:  []
# NONE_TRUE_EQUAL:  ['183,croix de guerre']
# NONE_PRED_EQUAL:  ['183,the croix de guerre']
# TRUE:  ['184,azam f.c.']
# PRED:  ['184,azam f.c.']
# SAME:  ['184,azam f.c.']
# TRUE:  ['185,inkas', '185,t.i. ahmadiyya senior high school, kumasi']
# PRED:  ['185, inkas', '185, t.i. ahmadiyya senior high school', '185,kumasi']
# NONE_TRUE_MORE:  ['185,inkas', '185,t.i. ahmadiyya senior high school, kumasi']
# NONE_PRED_MORE:  ['185, inkas', '185, t.i. ahmadiyya senior high school', '185,kumasi']
# TRUE:  ['186,mausoleum of augustus', '186,rome']
# PRED:  ['186, rome', '186,mausoleum of augustus']
# SAME:  ['186,mausoleum of augustus']
# PARTIAL:  ['186,mausoleum of augustus']
# TRUE:  ['187,1st free french division']
# PRED:  ['187,1st free french division']
# SAME:  ['187,1st free french division']
# TRUE:  ['188,mediterranean sea']
# PRED:  ['188,the mediterranean sea']
# SAME:  []
# NONE_TRUE_EQUAL:  ['188,mediterranean sea']
# NONE_PRED_EQUAL:  ['188,the mediterranean sea']
# TRUE:  ['189,zambia', '189,ikelenge district']
# PRED:  ['189,zambia', '189,ikelenge']
# SAME:  ['189,zambia']
# PARTIAL:  ['189,zambia']
# TRUE:  ['190,royal society']
# PRED:  ['190,royal society']
# SAME:  ['190,royal society']
# TRUE:  ['191,acer nigrum']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['191,acer nigrum']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['192,filipinos']
# PRED:  ['192,filipinos']
# SAME:  ['192,filipinos']
# TRUE:  ['193,neil brown', '193,andrew peacock']
# PRED:  ['193,neil brown', '193,andrew peacock']
# SAME:  ['193,neil brown', '193,andrew peacock']
# TRUE:  ['194,wizards vs aliens', '194,into the dalek']
# PRED:  ['194,into the dalek', '194,wizards']
# SAME:  ['194,into the dalek']
# PARTIAL:  ['194,into the dalek']
# TRUE:  ['195,charles pinckney']
# PRED:  ['195,charles pinckney']
# SAME:  ['195,charles pinckney']
# TRUE:  ["196,us men's national soccer team"]
# PRED:  ['196,us']
# SAME:  []
# NONE_TRUE_EQUAL:  ["196,us men's national soccer team"]
# NONE_PRED_EQUAL:  ['196,us']
# TRUE:  ['197,tessa dahl']
# PRED:  ['197,tessa dahl']
# SAME:  ['197,tessa dahl']
# TRUE:  ['198,eu broadcasting union']
# PRED:  ['198,eu broadcasting union']
# SAME:  ['198,eu broadcasting union']
# TRUE:  ['199,jack ryan', '199,us senate']
# PRED:  ['199,jack ryan', '199,us senate']
# SAME:  ['199,jack ryan', '199,us senate']
# TRUE:  ['200,ananda college']
# PRED:  ['200,ananda college']
# SAME:  ['200,ananda college']
# TRUE:  ['201,mediterranean sea', '201,panionios g.s.s. season']
# PRED:  ['201,mediterranean sea', '201,panionios g.s.s.']
# SAME:  ['201,mediterranean sea']
# PARTIAL:  ['201,mediterranean sea']
# TRUE:  ['202,murray mouth', '202,cowombat flat']
# PRED:  ['202,murray mouth', '202,cowombat  flat']
# SAME:  ['202,murray mouth']
# PARTIAL:  ['202,murray mouth']
# TRUE:  ['203,wbcq']
# PRED:  ['203,wbcq', '203,sw']
# MORE:  ['203,wbcq']
# TRUE:  ['204,2015 argentine primera division']
# PRED:  ['204,2015', '204,argentine primera division']
# NONE_TRUE_MORE:  ['204,2015 argentine primera division']
# NONE_PRED_MORE:  ['204,2015', '204,argentine primera division']
# TRUE:  ['205,florida']
# PRED:  ['205,florida']
# SAME:  ['205,florida']
# TRUE:  ['206,god defend new zealand']
# PRED:  ['206,new zealand']
# SAME:  []
# NONE_TRUE_EQUAL:  ['206,god defend new zealand']
# NONE_PRED_EQUAL:  ['206,new zealand']
# TRUE:  ['207,vangelis', '207,jordan cronenweth']
# PRED:  ['207,jordan cronenweth', '207,vangelis']
# SAME:  ['207,jordan cronenweth', '207,vangelis']
# TRUE:  ['208,klang valley']
# PRED:  ['208,the klang valley']
# SAME:  []
# NONE_TRUE_EQUAL:  ['208,klang valley']
# NONE_PRED_EQUAL:  ['208,the klang valley']
# TRUE:  ['209,discovery communications']
# PRED:  ['209,discovery communications']
# SAME:  ['209,discovery communications']
# TRUE:  ['210,queer as folk']
# PRED:  ['210,queer']
# SAME:  []
# NONE_TRUE_EQUAL:  ['210,queer as folk']
# NONE_PRED_EQUAL:  ['210,queer']
# TRUE:  ['211,high desert']
# PRED:  ['211,oregon']
# SAME:  []
# NONE_TRUE_EQUAL:  ['211,high desert']
# NONE_PRED_EQUAL:  ['211,oregon']
# TRUE:  ['212,paramount domestic television']
# PRED:  ['212,paramount domestic television']
# SAME:  ['212,paramount domestic television']
# TRUE:  ['213,city of new orleans']
# PRED:  ['213,city of new orleans']
# SAME:  ['213,city of new orleans']
# TRUE:  ['214,get tv', '214,the galleria']
# PRED:  ['214,get tv', '214,galleria']
# SAME:  ['214,get tv']
# PARTIAL:  ['214,get tv']
# TRUE:  ['215,madagascar: operation penguin', "215,he's a pirate"]
# PRED:  ['215,pirate', '215,madagascar: operation penguin']
# SAME:  ['215,madagascar: operation penguin']
# PARTIAL:  ['215,madagascar: operation penguin']
# TRUE:  ['216,goran cengic']
# PRED:  ['216,goran cengic']
# SAME:  ['216,goran cengic']
# TRUE:  ['217,zhorstoke nebo']
# PRED:  ['217,zhorstoke']
# SAME:  []
# NONE_TRUE_EQUAL:  ['217,zhorstoke nebo']
# NONE_PRED_EQUAL:  ['217,zhorstoke']
# TRUE:  ['218,louis dunbar', '218,jeff munn']
# PRED:  ['218,louis dunbar', '218,jeff munn']
# SAME:  ['218,louis dunbar', '218,jeff munn']
# TRUE:  ['219,populous']
# PRED:  ['219,populous']
# SAME:  ['219,populous']
# TRUE:  ['220,chumash people']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['220,chumash people']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['221,pavel moroz', '221,helena of moscow']
# PRED:  ['221,moroz', '221,helena', '221,moscow']
# NONE_TRUE_MORE:  ['221,pavel moroz', '221,helena of moscow']
# NONE_PRED_MORE:  ['221,moroz', '221,helena', '221,moscow']
# TRUE:  ['222,christopher franke', '222,j. michael straczynski']
# PRED:  ['222,j. michael stracznski', '222,christopher franke']
# SAME:  ['222,christopher franke']
# PARTIAL:  ['222,christopher franke']
# TRUE:  ['223,cy-fair high school']
# PRED:  ['223,a cy-fair high school']
# SAME:  []
# NONE_TRUE_EQUAL:  ['223,cy-fair high school']
# NONE_PRED_EQUAL:  ['223,a cy-fair high school']
# TRUE:  ['224,senser']
# PRED:  ['224,senser']
# SAME:  ['224,senser']
# TRUE:  ['225,teddy riley', '225,blayse']
# PRED:  ['225,blayse', '225,teddy riley']
# SAME:  ['225,blayse', '225,teddy riley']
# TRUE:  ['226,to where you are']
# PRED:  ['226,to you are']
# SAME:  []
# NONE_TRUE_EQUAL:  ['226,to where you are']
# NONE_PRED_EQUAL:  ['226,to you are']
# TRUE:  ['227,merlin express', '227,cibano international airport']
# PRED:  ['']
# NONE_TRUE_LESS:  ['227,merlin express', '227,cibano international airport']
# NONE_PRED_LESS:  ['']
# TRUE:  ['228,wilton, connecticut']
# PRED:  ['228,wilton', '228,connecticut']
# NONE_TRUE_MORE:  ['228,wilton, connecticut']
# NONE_PRED_MORE:  ['228,wilton', '228,connecticut']
# TRUE:  ['229,ontariana']
# PRED:  ['229,ontarians']
# SAME:  []
# NONE_TRUE_EQUAL:  ['229,ontariana']
# NONE_PRED_EQUAL:  ['229,ontarians']
# TRUE:  ['230,ryan seacrest', '230,fox']
# PRED:  ['230,fox', '230,ryan seacrest']
# SAME:  ['230,fox', '230,ryan seacrest']
# TRUE:  ['231,box girder bridges']
# PRED:  ['231,box girder']
# SAME:  []
# NONE_TRUE_EQUAL:  ['231,box girder bridges']
# NONE_PRED_EQUAL:  ['231,box girder']
# TRUE:  ["232,the god who wasn't there"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["232,the god who wasn't there"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['233,public transport authority']
# PRED:  ['233,western australian public transport authority']
# SAME:  []
# NONE_TRUE_EQUAL:  ['233,public transport authority']
# NONE_PRED_EQUAL:  ['233,western australian public transport authority']
# TRUE:  ['234,thomas meehan']
# PRED:  ['234,thomas meehan']
# SAME:  ['234,thomas meehan']
# TRUE:  ['235,municipal council']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['235,municipal council']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['236,jacques-dsir laval']
# PRED:  ['236,jacques-dsir laval']
# SAME:  ['236,jacques-dsir laval']
# TRUE:  ['237,mecklenburg-vorpommern']
# PRED:  ['237,mecklenburg-vorpommern']
# SAME:  ['237,mecklenburg-vorpommern']
# TRUE:  ['238,herzogenaurach']
# PRED:  ['238,herzogenaurach']
# SAME:  ['238,herzogenaurach']
# TRUE:  ['239,lucy sullivan is getting married']
# PRED:  ['239,lucy sullivan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['239,lucy sullivan is getting married']
# NONE_PRED_EQUAL:  ['239,lucy sullivan']
# TRUE:  ['240,blizzard entertainment']
# PRED:  ['240,blizzard entertainment']
# SAME:  ['240,blizzard entertainment']
# TRUE:  ['241,alexander downer', '241,neil brown']
# PRED:  ['241,alexander downer', '241,neil brown']
# SAME:  ['241,alexander downer', '241,neil brown']
# TRUE:  ['242,costa rica national football team']
# PRED:  ['242,costa rica']
# SAME:  []
# NONE_TRUE_EQUAL:  ['242,costa rica national football team']
# NONE_PRED_EQUAL:  ['242,costa rica']
# TRUE:  ['243,amitava datta']
# PRED:  ['243,amitava']
# SAME:  []
# NONE_TRUE_EQUAL:  ['243,amitava datta']
# NONE_PRED_EQUAL:  ['243,amitava']
# TRUE:  ['244,londo mollari']
# PRED:  ['244,londo mollari']
# SAME:  ['244,londo mollari']
# TRUE:  ['245,scientologists']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['245,scientologists']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# PRED:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# SAME:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# TRUE:  ['247,qadir huseynov', '247,liudmila privivkova']
# PRED:  ['247,liudmila privivkova', '247,qadir huseynov']
# SAME:  ['247,liudmila privivkova', '247,qadir huseynov']
# TRUE:  ['248,cadillac fleetwood']
# PRED:  ['248,cadillac', '248,fleetwood']
# NONE_TRUE_MORE:  ['248,cadillac fleetwood']
# NONE_PRED_MORE:  ['248,cadillac', '248,fleetwood']
# TRUE:  ['249,commodore cdtv']
# PRED:  ['249,cdtv']
# SAME:  []
# NONE_TRUE_EQUAL:  ['249,commodore cdtv']
# NONE_PRED_EQUAL:  ['249,cdtv']
# TRUE:  ['250,mark johnson']
# PRED:  ['250,mark johnson']
# SAME:  ['250,mark johnson']
# TRUE:  ['251,canary islands']
# PRED:  ['251,canary islands']
# SAME:  ['251,canary islands']
# TRUE:  ['252,fusil gras mile 1874']
# PRED:  ['252,fusil gras mile', '252,1874']
# NONE_TRUE_MORE:  ['252,fusil gras mile 1874']
# NONE_PRED_MORE:  ['252,fusil gras mile', '252,1874']
# TRUE:  ['253,claiborne pell', '253,ralph flanders']
# PRED:  ['253,the ralph flanders', '253, claiborne pell']
# SAME:  []
# NONE_TRUE_EQUAL:  ['253,claiborne pell', '253,ralph flanders']
# NONE_PRED_EQUAL:  ['253,the ralph flanders', '253, claiborne pell']
# TRUE:  ['254,ontario']
# PRED:  ['254,ontario']
# SAME:  ['254,ontario']
# TRUE:  ['255,san antonio', '255,us route 281']
# PRED:  ['255,us', '255,281', '255,san antonio']
# MORE:  ['255,san antonio']
# TRUE:  ['256,cnn']
# PRED:  ['256,cnn']
# SAME:  ['256,cnn']
# TRUE:  ['257,norfolk southern railway']
# PRED:  ['257,norfolk southern railway']
# SAME:  ['257,norfolk southern railway']
# TRUE:  ['258,edwin catmull', '258,pixar image computer']
# PRED:  ['258,one', '258,pixar image computer', '258,one', '258,edwin catmull']
# MORE:  ['258,pixar image computer', '258,edwin catmull']
# TRUE:  ['259,beverly hills', '259,colts neck township']
# PRED:  ['259,beverly hills', '259,colts neck township']
# SAME:  ['259,beverly hills', '259,colts neck township']
# TRUE:  ['260,rome']
# PRED:  ['260,rome']
# SAME:  ['260,rome']
# TRUE:  ['261,rhode island route 15']
# PRED:  ['261,rhode island route 15']
# SAME:  ['261,rhode island route 15']
# TRUE:  ['262,trump productions', '262,the ultimate merger']
# PRED:  ['262,trump productions']
# LESS:  ['262,trump productions']
# TRUE:  ['263,komc-fm', '263,komc']
# PRED:  ['263,komc-fm', '263,komc (am']
# SAME:  ['263,komc-fm']
# PARTIAL:  ['263,komc-fm']
# TRUE:  ['264,asiana airlines', '264,jeju airport']
# PRED:  ['264,jeju']
# NONE_TRUE_LESS:  ['264,asiana airlines', '264,jeju airport']
# NONE_PRED_LESS:  ['264,jeju']
# TRUE:  ['265,swedish academy']
# PRED:  ['265,swedish academy']
# SAME:  ['265,swedish academy']
# TRUE:  ['266,tennessee state museum']
# PRED:  ['266,tennessee state museum']
# SAME:  ['266,tennessee state museum']
# TRUE:  ['267,ishir honda']
# PRED:  ['267,ishir honda']
# SAME:  ['267,ishir honda']
# TRUE:  ["268,alpine skiing at the 1964 winter olympics men's slalom"]
# PRED:  ['268,1964', '268,winter olympics']
# NONE_TRUE_MORE:  ["268,alpine skiing at the 1964 winter olympics men's slalom"]
# NONE_PRED_MORE:  ['268,1964', '268,winter olympics']
# TRUE:  ['269,virgin radio']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['269,virgin radio']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['270,tani university']
# PRED:  ['270,university']
# SAME:  []
# NONE_TRUE_EQUAL:  ['270,tani university']
# NONE_PRED_EQUAL:  ['270,university']
# TRUE:  ['271,dowra']
# PRED:  ['271,dowra']
# SAME:  ['271,dowra']
# TRUE:  ['272,pittsburgh pirates']
# PRED:  ['272,the pittsburgh pirates']
# SAME:  []
# NONE_TRUE_EQUAL:  ['272,pittsburgh pirates']
# NONE_PRED_EQUAL:  ['272,the pittsburgh pirates']
# TRUE:  ['273,simon fuller']
# PRED:  ['273,simon fuller']
# SAME:  ['273,simon fuller']
# TRUE:  ['274,the producers', '274,next thing']
# PRED:  ['274,the the producers (', '274,2005']
# SAME:  []
# NONE_TRUE_EQUAL:  ['274,the producers', '274,next thing']
# NONE_PRED_EQUAL:  ['274,the the producers (', '274,2005']
# TRUE:  ['275,henry ford', '275,ford model c']
# PRED:  ['275,henry ford']
# LESS:  ['275,henry ford']
# TRUE:  ["276,dragons' den"]
# PRED:  ['276,dragons']
# SAME:  []
# NONE_TRUE_EQUAL:  ["276,dragons' den"]
# NONE_PRED_EQUAL:  ['276,dragons']
# TRUE:  ['277,joseph case high school', '277,providence chapel, charlwood']
# PRED:  ['277,the providence chapel', '277,charlwood', '277,joseph case high school']
# MORE:  ['277,joseph case high school']
# TRUE:  ['278,norbert wiener award for social and professional responsibility', '278,john robert woodyard']
# PRED:  ['278,john robert woodyard', '278,norbert wiener award']
# SAME:  ['278,john robert woodyard']
# PARTIAL:  ['278,john robert woodyard']
# TRUE:  ['279,leroy collins', '279,george siebels jr']
# PRED:  ['279,leroy collins', '279,george siebels jr']
# SAME:  ['279,leroy collins', '279,george siebels jr']
# TRUE:  ['280,germany']
# PRED:  ['280,germany']
# SAME:  ['280,germany']
# TRUE:  ['281,downtown athletic club', '281,yale club']
# PRED:  ['281,downtown athletic club', '281,yale club nycity']
# SAME:  ['281,downtown athletic club']
# PARTIAL:  ['281,downtown athletic club']
# TRUE:  ['282,victor hope, 2nd marquess of linlithgow']
# PRED:  ['282,victor hope', '282,2nd marquess of linlithgow']
# NONE_TRUE_MORE:  ['282,victor hope, 2nd marquess of linlithgow']
# NONE_PRED_MORE:  ['282,victor hope', '282,2nd marquess of linlithgow']
# TRUE:  ['283,ashton historic district']
# PRED:  ['283,ashton historic']
# SAME:  []
# NONE_TRUE_EQUAL:  ['283,ashton historic district']
# NONE_PRED_EQUAL:  ['283,ashton historic']
# TRUE:  ['284,greater napanee']
# PRED:  ['284,greater napanee']
# SAME:  ['284,greater napanee']
# TRUE:  ['285,channel district']
# PRED:  ['285,channel']
# SAME:  []
# NONE_TRUE_EQUAL:  ['285,channel district']
# NONE_PRED_EQUAL:  ['285,channel']
# TRUE:  ['286,vagif aliyev']
# PRED:  ['286,vagif aliyev']
# SAME:  ['286,vagif aliyev']
# TRUE:  ['287,onedrive', '287,us']
# PRED:  ['287,us', '287,onedrive']
# SAME:  ['287,us', '287,onedrive']
# TRUE:  ['288,james l. mcconaughy']
# PRED:  ['288,james l. mcconaughy']
# SAME:  ['288,james l. mcconaughy']
# TRUE:  ['289,catwoman']
# PRED:  ['289,one', '289,catwoman']
# MORE:  ['289,catwoman']
# TRUE:  ['290,mediterranean sea']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['290,mediterranean sea']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['291,bacillus', '291,bacteria']
# PRED:  ['291,bacteria']
# LESS:  ['291,bacteria']
# TRUE:  ['292,french']
# PRED:  ['292,french']
# SAME:  ['292,french']
# TRUE:  ['293,baraily', '293,jowai']
# PRED:  ['293,baraily', '293,jowai']
# SAME:  ['293,baraily', '293,jowai']
# TRUE:  ['294,siege of fort recovery']
# PRED:  ['294,siege of fort recovery']
# SAME:  ['294,siege of fort recovery']
# TRUE:  ['295,germanic']
# PRED:  ['295,germanic']
# SAME:  ['295,germanic']
# TRUE:  ['296,duane allman', '296,les paul']
# PRED:  ['296,duanne allman', '296,the les paul']
# SAME:  []
# NONE_TRUE_EQUAL:  ['296,duane allman', '296,les paul']
# NONE_PRED_EQUAL:  ['296,duanne allman', '296,the les paul']
# TRUE:  ['297,tanzanian national football team']
# PRED:  ['297,tanzanian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['297,tanzanian national football team']
# NONE_PRED_EQUAL:  ['297,tanzanian']
# TRUE:  ['298,bloomberg markets']
# PRED:  ['298,bloomberg markets']
# SAME:  ['298,bloomberg markets']
# TRUE:  ['299,motor vehicles']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['299,motor vehicles']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['300,holmes colbert', '300,linda hogan']
# PRED:  ['300,linda hogan', '300,the holmes colbert']
# SAME:  ['300,linda hogan']
# PARTIAL:  ['300,linda hogan']
# TRUE:  ['301,jon speelman']
# PRED:  ['301,jon speelman']
# SAME:  ['301,jon speelman']
# TRUE:  ['302,ella loves cole']
# PRED:  ['302,ella loves cole']
# SAME:  ['302,ella loves cole']
# TRUE:  ['303,prime time entertainment network']
# PRED:  ['303,prime time entertainment network']
# SAME:  ['303,prime time entertainment network']
# TRUE:  ['304,auto shankar']
# PRED:  ['304,auto shankar']
# SAME:  ['304,auto shankar']
# TRUE:  ['305,burr truss']
# PRED:  ['305,burr truss']
# SAME:  ['305,burr truss']
# TRUE:  ['306,tonle sap']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['306,tonle sap']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['307,cheryl teigs']
# PRED:  ['307,cheryl teigs']
# SAME:  ['307,cheryl teigs']
# TRUE:  ['308,ndonga mianga']
# PRED:  ['308,ndonga mianga']
# SAME:  ['308,ndonga mianga']
# TRUE:  ['309,papeete']
# PRED:  ['309,papeete']
# SAME:  ['309,papeete']
# TRUE:  ['310,lake victoria']
# PRED:  ['310, lake victoria']
# SAME:  []
# NONE_TRUE_EQUAL:  ['310,lake victoria']
# NONE_PRED_EQUAL:  ['310, lake victoria']
# TRUE:  ['311,domenico modugno']
# PRED:  ['311,domenico modugno']
# SAME:  ['311,domenico modugno']
# TRUE:  ['312,grameen bank']
# PRED:  ['312,grameen bank']
# SAME:  ['312,grameen bank']
# TRUE:  ['313,benjamin franklin terry', '313,us route 59']
# PRED:  ['313,benjamin franklin terry', '313,us route 59']
# SAME:  ['313,benjamin franklin terry', '313,us route 59']
# TRUE:  ['314,james langer']
# PRED:  ['314,james langer']
# SAME:  ['314,james langer']
# TRUE:  ['315,john trumbull', '315,a foreign policy']
# PRED:  ['315,john trumbull']
# LESS:  ['315,john trumbull']
# TRUE:  ['316,peter-john vettese']
# PRED:  ['316,peter-john vettese']
# SAME:  ['316,peter-john vettese']
# TRUE:  ['317,edwin catmull']
# PRED:  ['317,edwin catmull']
# SAME:  ['317,edwin catmull']
# TRUE:  ['318,eric roth']
# PRED:  ['318,eric roth']
# SAME:  ['318,eric roth']
# TRUE:  ['319,coneygree', '319,martin molony']
# PRED:  ['319,the martin molony', '319,coneygree']
# SAME:  ['319,coneygree']
# PARTIAL:  ['319,coneygree']
# TRUE:  ['320,dallas']
# PRED:  ['320,dallas']
# SAME:  ['320,dallas']
# TRUE:  ['321,royal society']
# PRED:  ['321,the royal society']
# SAME:  []
# NONE_TRUE_EQUAL:  ['321,royal society']
# NONE_PRED_EQUAL:  ['321,the royal society']
# TRUE:  ['322,philosophy', '322,stephen law']
# PRED:  ['322,stephen law']
# LESS:  ['322,stephen law']
# TRUE:  ['323,gervase helwys']
# PRED:  ['323,gervase helwys']
# SAME:  ['323,gervase helwys']
# TRUE:  ['324,raamlaxman']
# PRED:  ['324,raamlaxman']
# SAME:  ['324,raamlaxman']
# TRUE:  ['325,jose cha cha jimenez']
# PRED:  ['325,jose cha cha jimenez']
# SAME:  ['325,jose cha cha jimenez']
# TRUE:  ['326,bernard herrmann', '326,rko pictures']
# PRED:  ['326,rko pictures', '326,bernard herrmann']
# SAME:  ['326,rko pictures', '326,bernard herrmann']
# TRUE:  ['327,red ahead']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['327,red ahead']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['328,kore presbyterian theological seminar', '328,celal bayar university']
# PRED:  ['328,celal bayer', '328,presbyterian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['328,kore presbyterian theological seminar', '328,celal bayar university']
# NONE_PRED_EQUAL:  ['328,celal bayer', '328,presbyterian']
# TRUE:  ['329,hamline avenue']
# PRED:  ['329,quarters', '329,hamline avenue']
# MORE:  ['329,hamline avenue']
# TRUE:  ['330,yasmin paige']
# PRED:  ['330,yasmin paige']
# SAME:  ['330,yasmin paige']
# TRUE:  ['331,heinz kokott']
# PRED:  ['331,heinz kokott', '331,nazi army']
# MORE:  ['331,heinz kokott']
# TRUE:  ['332,jann wenner', '332,ralph j. gleason']
# PRED:  ['332,jann wenner', '332,ralph j. gleason']
# SAME:  ['332,jann wenner', '332,ralph j. gleason']
# TRUE:  ['333,nevado de toluca', '333,sierra nevada']
# PRED:  ['333,sierra nevada', '333,u.s.', '333,nevado de toluca']
# MORE:  ['333,sierra nevada', '333,nevado de toluca']
# TRUE:  ['334,bbc hd', '334,doctor who confidential']
# PRED:  ['334,bbc hd']
# LESS:  ['334,bbc hd']
# TRUE:  ['335,milk cow blues', '335,sings kristofferson']
# PRED:  ['335,sings kristofferson', '335,milk cow blues']
# SAME:  ['335,sings kristofferson', '335,milk cow blues']
# TRUE:  ['336,thesaban']
# PRED:  ['336,thesaban']
# SAME:  ['336,thesaban']
# TRUE:  ['337,micronesia']
# PRED:  ['337,micronesia']
# SAME:  ['337,micronesia']
# TRUE:  ['338,stephen e. ambrose']
# PRED:  ['338,stephen e. ambrose']
# SAME:  ['338,stephen e. ambrose']
# TRUE:  ['339,central european summer time']
# PRED:  ['339,central european', '339,summer time']
# NONE_TRUE_MORE:  ['339,central european summer time']
# NONE_PRED_MORE:  ['339,central european', '339,summer time']
# TRUE:  ['340,steven peterman', '340,the best of both worlds']
# PRED:  ['340,the best of both worlds', '340,steven peterman']
# SAME:  ['340,the best of both worlds', '340,steven peterman']
# TRUE:  ['341,ralph j. gleason']
# PRED:  ['341,ralph j. gleason']
# SAME:  ['341,ralph j. gleason']
# TRUE:  ['342,paul morphy']
# PRED:  ['342,paul morphy']
# SAME:  ['342,paul morphy']
# TRUE:  ['343,thames estuary', '343,north sea']
# PRED:  ['343, thames estuary', '343,north sea']
# SAME:  ['343,north sea']
# PARTIAL:  ['343,north sea']
# TRUE:  ['344,ganefo']
# PRED:  ['344,ganefo']
# SAME:  ['344,ganefo']
# TRUE:  ['345,matt williams']
# PRED:  ['345,matt williams']
# SAME:  ['345,matt williams']
# TRUE:  ['346,massachusetts house of representatives', '346,samuel w. mccall']
# PRED:  ['346,samuel w. mccall', '346,massachusetts house of representatives']
# SAME:  ['346,samuel w. mccall', '346,massachusetts house of representatives']
# TRUE:  ['347,golden globe']
# PRED:  ['347,the golden globe']
# SAME:  []
# NONE_TRUE_EQUAL:  ['347,golden globe']
# NONE_PRED_EQUAL:  ['347,the golden globe']
# TRUE:  ['348,pizza', "348,mr. jim's pizza"]
# PRED:  ['348,jim']
# NONE_TRUE_LESS:  ['348,pizza', "348,mr. jim's pizza"]
# NONE_PRED_LESS:  ['348,jim']
# TRUE:  ['349,even-toed ungulate']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['349,even-toed ungulate']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['350,mathematics']
# PRED:  ['350,one']
# SAME:  []
# NONE_TRUE_EQUAL:  ['350,mathematics']
# NONE_PRED_EQUAL:  ['350,one']
# TRUE:  ['351,winston bryant', '351,joe purcell']
# PRED:  ['351,joe purcell', '351,winston bryant']
# SAME:  ['351,joe purcell', '351,winston bryant']
# TRUE:  ['352,jim harris']
# PRED:  ['352,jim harris']
# SAME:  ['352,jim harris']
# TRUE:  ['353,corringham railway station']
# PRED:  ['353,corringham']
# SAME:  []
# NONE_TRUE_EQUAL:  ['353,corringham railway station']
# NONE_PRED_EQUAL:  ['353,corringham']
# TRUE:  ['354,stan lee', '354,the incredible hulk']
# PRED:  ['']
# NONE_TRUE_LESS:  ['354,stan lee', '354,the incredible hulk']
# NONE_PRED_LESS:  ['']
# TRUE:  ['355,emanuel de guzman']
# PRED:  ['355,emanuel de guzman']
# SAME:  ['355,emanuel de guzman']
# TRUE:  ['356,al khaleejiya 100.9']
# PRED:  ['356,al khaleejiya 100.9']
# SAME:  ['356,al khaleejiya 100.9']
# TRUE:  ['357,harvest christian center']
# PRED:  ['357,the harvest christian center']
# SAME:  []
# NONE_TRUE_EQUAL:  ['357,harvest christian center']
# NONE_PRED_EQUAL:  ['357,the harvest christian center']
# TRUE:  ["358,master's sun"]
# PRED:  ["358,master's sun"]
# SAME:  ["358,master's sun"]
# TRUE:  ['359,virtual kasparov', '359,fr agnel school and jr college']
# PRED:  ['359,fr agnel school', '359,jr', '359,virtual kasparov']
# MORE:  ['359,virtual kasparov']
# TRUE:  ['360,colts neck township', '360,beverly hills']
# PRED:  ['360,colts neck township', '360,beverly hills']
# SAME:  ['360,colts neck township', '360,beverly hills']
# TRUE:  ['361,blizzard']
# PRED:  ['361,blizzard']
# SAME:  ['361,blizzard']
# TRUE:  ['362,shannon pot', '362,limerick']
# PRED:  ['362,shannon pot', '362,limerick']
# SAME:  ['362,shannon pot', '362,limerick']
# TRUE:  ['363,gloucestershire', '363,reading']
# PRED:  ['363,gloucestershire']
# LESS:  ['363,gloucestershire']
# TRUE:  ['364,gelnhausen', '364,pepperdine university']
# PRED:  ['364,gelnhausen', '364,pepperdine university']
# SAME:  ['364,gelnhausen', '364,pepperdine university']
# TRUE:  ['365,frontaccounting', '365,nubuntu']
# PRED:  ['365,frontaccounting', '365,nubuntu']
# SAME:  ['365,frontaccounting', '365,nubuntu']
# TRUE:  ['366,brian graden', '366,broadcast syndication']
# PRED:  ['366,brian graden']
# LESS:  ['366,brian graden']
# TRUE:  ['367,fort barrancas', '367,gadsden']
# PRED:  ['367,fort barrancas', '367,gadsden']
# SAME:  ['367,fort barrancas', '367,gadsden']
# TRUE:  ['368,richard h immerman', '368,franklin w olin']
# PRED:  ['368,richard h immerman', '368,franklin w olin']
# SAME:  ['368,richard h immerman', '368,franklin w olin']
# TRUE:  ['369,occupation of japan']
# PRED:  ['369,japan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['369,occupation of japan']
# NONE_PRED_EQUAL:  ['369,japan']
# ...
# PRED:  ['4884,kaliningrad', '4884,gdask']
# SAME:  ['4884,kaliningrad', '4884,gdask']
# TRUE:  ['4885,alexander lippisch']
# PRED:  ['4885,alexander lippisch']
# SAME:  ['4885,alexander lippisch']
# TRUE:  ['4886,david lewis', '4886,thorington railway station']
# PRED:  ['4886,thorington', '4886, david lewis']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4886,david lewis', '4886,thorington railway station']
# NONE_PRED_EQUAL:  ['4886,thorington', '4886, david lewis']
# TRUE:  ['4887,nasa']
# PRED:  ['4887,nasa']
# SAME:  ['4887,nasa']
# TRUE:  ['4888,gibson les paul']
# PRED:  ['4888,gibson les paul']
# SAME:  ['4888,gibson les paul']
# TRUE:  ['4889,haight-ashbury', '4889,castro district']
# PRED:  ['4889,castro district', '4889,haight-ashbury']
# SAME:  ['4889,castro district', '4889,haight-ashbury']
# TRUE:  ['4890,uk']
# PRED:  ['4890,uk']
# SAME:  ['4890,uk']
# TRUE:  ['4891,motorpsycho nitemare', '4891,moondog matinee']
# PRED:  ['4891,moondog matinee', '4891,motorpsycho nitemare']
# SAME:  ['4891,moondog matinee', '4891,motorpsycho nitemare']
# TRUE:  ['4892,schutzstaffels']
# PRED:  ['4892,schutzstaffels']
# SAME:  ['4892,schutzstaffels']
# TRUE:  ['4893,kron ngoy', '4893,hang chuon naron']
# PRED:  ['4893,kron ngoy']
# LESS:  ['4893,kron ngoy']
# TRUE:  ['4894,william w brien']
# PRED:  ['4894,william w brien']
# SAME:  ['4894,william w brien']
# TRUE:  ['4895,ios']
# PRED:  ['4895,ios']
# SAME:  ['4895,ios']
# TRUE:  ['4896,the incredible hulk']
# PRED:  ['4896,1982']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4896,the incredible hulk']
# NONE_PRED_EQUAL:  ['4896,1982']
# TRUE:  ['4897,carl sanders']
# PRED:  ['4897,one', '4897,carl sanders']
# MORE:  ['4897,carl sanders']
# TRUE:  ['4898,william c p breckinridge']
# PRED:  ['4898,william c p']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4898,william c p breckinridge']
# NONE_PRED_EQUAL:  ['4898,william c p']
# TRUE:  ["4899,st. peter's basilica"]
# PRED:  ["4899,st. peter's basilica"]
# SAME:  ["4899,st. peter's basilica"]
# TRUE:  ['4900,dreamworks television', '4900,stephen e. ambrose']
# PRED:  ['4900,stephen e. ambrose', '4900,dreamworks television']
# SAME:  ['4900,stephen e. ambrose', '4900,dreamworks television']
# TRUE:  ['4901,lake washington']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4901,lake washington']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4902,fedexfield']
# PRED:  ['4902,fedexfield']
# SAME:  ['4902,fedexfield']
# TRUE:  ['4903,edsel villager']
# PRED:  ['4903,edsel']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4903,edsel villager']
# NONE_PRED_EQUAL:  ['4903,edsel']
# TRUE:  ['4904,sierra madre de chiapas']
# PRED:  ['4904,the sierra madre de chiapas']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4904,sierra madre de chiapas']
# NONE_PRED_EQUAL:  ['4904,the sierra madre de chiapas']
# TRUE:  ['4905,cherokee']
# PRED:  ['4905,cherokee']
# SAME:  ['4905,cherokee']
# TRUE:  ["4906,he's a liar"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["4906,he's a liar"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4907,bbc multimedia', '4907,mazes of time']
# PRED:  ['4907,mazes', '4907,bbc']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4907,bbc multimedia', '4907,mazes of time']
# NONE_PRED_EQUAL:  ['4907,mazes', '4907,bbc']
# TRUE:  ['4908,doonesbury']
# PRED:  ['4908,doonesbury']
# SAME:  ['4908,doonesbury']
# TRUE:  ['4909,aachen cathedral']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4909,aachen cathedral']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4910,robert a. taft', '4910,charles phelps taft ii']
# PRED:  ['4910,robert a. taft', '4910,charles phelps taft ii']
# SAME:  ['4910,robert a. taft', '4910,charles phelps taft ii']
# TRUE:  ['4911,giorgos kaminis']
# PRED:  ['4911,giorgos kaminis']
# SAME:  ['4911,giorgos kaminis']
# TRUE:  ['4912,linda jenness']
# PRED:  ['4912,linda jenness']
# SAME:  ['4912,linda jenness']
# TRUE:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# PRED:  ['4913,the plymouth savoy', '4913,the northsouth transport corridor']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# NONE_PRED_EQUAL:  ['4913,the plymouth savoy', '4913,the northsouth transport corridor']
# TRUE:  ['4914,fender stratocaster']
# PRED:  ['4914,one', '4914,the fender stratocaster']
# NONE_TRUE_MORE:  ['4914,fender stratocaster']
# NONE_PRED_MORE:  ['4914,one', '4914,the fender stratocaster']
# TRUE:  ['4915,primate']
# PRED:  ['4915,primate']
# SAME:  ['4915,primate']
# TRUE:  ['4916,willem-alexander']
# PRED:  ['4916,willem-alexander', '4916,netherlands']
# MORE:  ['4916,willem-alexander']
# TRUE:  ['4917,chelsea f.c.']
# PRED:  ['4917,chelsea f.c.']
# SAME:  ['4917,chelsea f.c.']
# TRUE:  ['4918,kingdom']
# PRED:  ['4918,israelite', '4918,united monarch']
# NONE_TRUE_MORE:  ['4918,kingdom']
# NONE_PRED_MORE:  ['4918,israelite', '4918,united monarch']
# TRUE:  ['4919,malaysian pwd']
# PRED:  ['4919,pwd']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4919,malaysian pwd']
# NONE_PRED_EQUAL:  ['4919,pwd']
# TRUE:  ['4920,king county, washington', '4920,phil lumpkin']
# PRED:  ['4920,the king county', '4920,washington', '4920,phil lumpkin']
# MORE:  ['4920,phil lumpkin']
# TRUE:  ['4921,old lyme, connecticut']
# PRED:  ['4921,old lyme', '4921,connecticut']
# NONE_TRUE_MORE:  ['4921,old lyme, connecticut']
# NONE_PRED_MORE:  ['4921,old lyme', '4921,connecticut']
# TRUE:  ['4922,mac os', '4922,microsoft windows']
# PRED:  ['4922,os', '4922,microsoft', '4922,windows', '4922,mac os']
# MORE:  ['4922,mac os']
# TRUE:  ['4923,ike clanton']
# PRED:  ['4923,ike clanton']
# SAME:  ['4923,ike clanton']
# TRUE:  ['4924,indian general election, 2004']
# PRED:  ['4924,indian', '4924,2004', '4924,andhra pradesh']
# NONE_TRUE_MORE:  ['4924,indian general election, 2004']
# NONE_PRED_MORE:  ['4924,indian', '4924,2004', '4924,andhra pradesh']
# TRUE:  ['4925,miao people', '4925,palang dharma party']
# PRED:  ['4925,the palang dharma party', '4925, ']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4925,miao people', '4925,palang dharma party']
# NONE_PRED_EQUAL:  ['4925,the palang dharma party', '4925, ']
# TRUE:  ["4926,brown's corners, toronto", '4926,krista kelly']
# PRED:  ["4926,the brown's corners", '4926,krista kelly']
# SAME:  ['4926,krista kelly']
# PARTIAL:  ['4926,krista kelly']
# TRUE:  ['4927,judge advocate general corps']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4927,judge advocate general corps']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4928,pope pius xi']
# PRED:  ['4928,pope']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4928,pope pius xi']
# NONE_PRED_EQUAL:  ['4928,pope']
# TRUE:  ['4929,brown']
# PRED:  ['4929,brown']
# SAME:  ['4929,brown']
# TRUE:  ['4930,solon spencer beman']
# PRED:  ['4930,solon spencer beman']
# SAME:  ['4930,solon spencer beman']
# TRUE:  ['4931,1967 mexican grand prix', '4931,1971 us']
# PRED:  ['4931,first', '4931,the 1967 mexican grand prix', '4931,1971', '4931,us']
# NONE_TRUE_MORE:  ['4931,1967 mexican grand prix', '4931,1971 us']
# NONE_PRED_MORE:  ['4931,first', '4931,the 1967 mexican grand prix', '4931,1971', '4931,us']
# TRUE:  ['4932,sam sen railway station']
# PRED:  ['4932,sam sen railway station']
# SAME:  ['4932,sam sen railway station']
# TRUE:  ['4933,newcastle']
# PRED:  ['4933,newcastle']
# SAME:  ['4933,newcastle']
# TRUE:  ['4934,tehran']
# PRED:  ['4934,tehran']
# SAME:  ['4934,tehran']
# TRUE:  ['4935,wxme']
# PRED:  ['4935,wxme']
# SAME:  ['4935,wxme']
# TRUE:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# PRED:  ['4936,mickey', '4936,mellerdrammer', "4936,tommy tucker's"]
# NONE_TRUE_MORE:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# NONE_PRED_MORE:  ['4936,mickey', '4936,mellerdrammer', "4936,tommy tucker's"]
# TRUE:  ['4937,quich department']
# PRED:  ['4937,quich department', '4937,one']
# MORE:  ['4937,quich department']
# TRUE:  ['4938,apollo 11', '4938,gemini 8']
# PRED:  ['4938,apollo 11', '4938,gemini']
# SAME:  ['4938,apollo 11']
# PARTIAL:  ['4938,apollo 11']
# TRUE:  ['4939,seattle great wheel']
# PRED:  ['4939,seattle great wheel']
# SAME:  ['4939,seattle great wheel']
# TRUE:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# PRED:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# SAME:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# TRUE:  ['4941,the bleeding heart band']
# PRED:  ['4941,the bleeding heart band']
# SAME:  ['4941,the bleeding heart band']
# TRUE:  ['4942,russian railways']
# PRED:  ['4942,russian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4942,russian railways']
# NONE_PRED_EQUAL:  ['4942,russian']
# TRUE:  ['4943,russell t davies', '4943,wizards and the aliens']
# PRED:  ['4943,wizards']
# NONE_TRUE_LESS:  ['4943,russell t davies', '4943,wizards and the aliens']
# NONE_PRED_LESS:  ['4943,wizards']
# TRUE:  ['4944,arkansas']
# PRED:  ['4944,arkansas']
# SAME:  ['4944,arkansas']
# TRUE:  ['4945,ceratosoma tenue']
# PRED:  ['4945,ceratosoma']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4945,ceratosoma tenue']
# NONE_PRED_EQUAL:  ['4945,ceratosoma']
# TRUE:  ['4946,riley reid', '4946,holmes colbert']
# PRED:  ['4946, riley reid', '4946,holmes colbert']
# SAME:  ['4946,holmes colbert']
# PARTIAL:  ['4946,holmes colbert']
# TRUE:  ['4947,girls']
# PRED:  ['4947,prodigy']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4947,girls']
# NONE_PRED_EQUAL:  ['4947,prodigy']
# TRUE:  ['4948,indira gandhi']
# PRED:  ['4948,indira gandhi']
# SAME:  ['4948,indira gandhi']
# TRUE:  ['4949,manhattan project']
# PRED:  ['4949,the manhattan project']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4949,manhattan project']
# NONE_PRED_EQUAL:  ['4949,the manhattan project']
# TRUE:  ['4950,secrets and lies']
# PRED:  ['4950,lies']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4950,secrets and lies']
# NONE_PRED_EQUAL:  ['4950,lies']
# TRUE:  ['4951,ohio']
# PRED:  ['4951,ohio']
# SAME:  ['4951,ohio']
# TRUE:  ['4952,john o conner']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4952,john o conner']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4953,charlie justice', '4953,bobby hoppe']
# PRED:  ['4953,american', '4953,bobby hoppe']
# SAME:  ['4953,bobby hoppe']
# PARTIAL:  ['4953,bobby hoppe']
# TRUE:  ['4954,jimmy wales']
# PRED:  ['4954,jimmy']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4954,jimmy wales']
# NONE_PRED_EQUAL:  ['4954,jimmy']
# TRUE:  ['4955,ted williams tunnel', '4955,leonard memorial']
# PRED:  ['4955,ted williams', '4955,leonard memorial']
# SAME:  ['4955,leonard memorial']
# PARTIAL:  ['4955,leonard memorial']
# TRUE:  ['4956,michaelhouse']
# PRED:  ['4956,michaelhouse']
# SAME:  ['4956,michaelhouse']
# TRUE:  ['4957,yosemite park']
# PRED:  ['4957,first', '4957,yosemite park']
# MORE:  ['4957,yosemite park']
# TRUE:  ['4958,levant']
# PRED:  ['4958,levant']
# SAME:  ['4958,levant']
# TRUE:  ['4959,fifety five days at peking', '4959,awakening']
# PRED:  ['4959,awakening', '4959,five days']
# SAME:  ['4959,awakening']
# PARTIAL:  ['4959,awakening']
# TRUE:  ['4960,huey, dewey, and louie', '4960,clan mcduck']
# PRED:  ['4960,clan mcduck', '4960,huey', '4960,dewey', '4960,louie']
# MORE:  ['4960,clan mcduck']
# TRUE:  ['4961,ennejma ezzahra', '4961,boga']
# PRED:  ['4961,ennejma ezzahra', '4961,boga']
# SAME:  ['4961,ennejma ezzahra', '4961,boga']
# TRUE:  ['4962,charles gordon']
# PRED:  ['4962,charles gordon']
# SAME:  ['4962,charles gordon']
# TRUE:  ['4963,maryanne trump barry', '4963,le cirque']
# PRED:  ['4963,le cirque', '4963,maryanne trump']
# SAME:  ['4963,le cirque']
# PARTIAL:  ['4963,le cirque']
# TRUE:  ['4964,toronto']
# PRED:  ['4964,toronto']
# SAME:  ['4964,toronto']
# TRUE:  ['4965,laurie johnson', '4965,stanley kubrick']
# PRED:  ["4965,the stanley kubrick's", '4965,laurie johnson']
# SAME:  ['4965,laurie johnson']
# PARTIAL:  ['4965,laurie johnson']
# TRUE:  ['4966,uss kittiwake', '4966,haight-ashbury']
# PRED:  ['4966,haight-ashbury', '4966,uss kittiwake']
# SAME:  ['4966,haight-ashbury', '4966,uss kittiwake']
# TRUE:  ['4967,motorpsycho nitemare']
# PRED:  ['4967,motorpsycho nitemare']
# SAME:  ['4967,motorpsycho nitemare']
# TRUE:  ['4968,hbo', '4968,erik jendresen']
# PRED:  ['4968,erik jendresen', '4968,hbo']
# SAME:  ['4968,erik jendresen', '4968,hbo']
# TRUE:  ['4969,battle']
# PRED:  ['4969,battle of the bulge']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4969,battle']
# NONE_PRED_EQUAL:  ['4969,battle of the bulge']
# TRUE:  ['4970,israel', '4970,colin powell']
# PRED:  ['4970,colin powell']
# LESS:  ['4970,colin powell']
# TRUE:  ['4971,the ultimate fighter: team rousey vs. team tate']
# PRED:  ['4971,the ultimate fighter', '4971,team tate']
# NONE_TRUE_MORE:  ['4971,the ultimate fighter: team rousey vs. team tate']
# NONE_PRED_MORE:  ['4971,the ultimate fighter', '4971,team tate']
# TRUE:  ['4972,alexa scimeca']
# PRED:  ['4972,alexa']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4972,alexa scimeca']
# NONE_PRED_EQUAL:  ['4972,alexa']
# TRUE:  ['4973,south african class 11e', '4973,renfe class 333']
# PRED:  ['4973,south african', '4973,11e', '4973,renfe', '4973,333']
# NONE_TRUE_MORE:  ['4973,south african class 11e', '4973,renfe class 333']
# NONE_PRED_MORE:  ['4973,south african', '4973,11e', '4973,renfe', '4973,333']
# TRUE:  ['4974,erich bagge', '4974,erban ieica']
# PRED:  ['4974,erich bagge']
# LESS:  ['4974,erich bagge']
# TRUE:  ['4975,apollo 11', '4975,nasa']
# PRED:  ['4975,nasa', '4975,apollo 11']
# SAME:  ['4975,nasa', '4975,apollo 11']
# TRUE:  ['4976,ape', '4976,primate']
# PRED:  ['4976,ape', '4976,primate']
# SAME:  ['4976,ape', '4976,primate']
# TRUE:  ['4977,goethe prize']
# PRED:  ['4977,goethe prize']
# SAME:  ['4977,goethe prize']
# TRUE:  ['4978,amiga']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4978,amiga']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4979,william henry harrison tomb state memorial', '4979,john scott harrison']
# PRED:  ['4979,william henry harrison', '4979,john scott harrison']
# SAME:  ['4979,john scott harrison']
# PARTIAL:  ['4979,john scott harrison']
# TRUE:  ['4980,muhammad yunus']
# PRED:  ['4980,muhammad yunus']
# SAME:  ['4980,muhammad yunus']
# TRUE:  ['4981,saunders county']
# PRED:  ['4981,saunders']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4981,saunders county']
# NONE_PRED_EQUAL:  ['4981,saunders']
# TRUE:  ['4982,miao rebellion']
# PRED:  ['4982,miao']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4982,miao rebellion']
# NONE_PRED_EQUAL:  ['4982,miao']
# TRUE:  ['4983,italic']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4983,italic']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4984,bbc multimedia', '4984,visions']
# PRED:  ['4984,bbc']
# NONE_TRUE_LESS:  ['4984,bbc multimedia', '4984,visions']
# NONE_PRED_LESS:  ['4984,bbc']
# TRUE:  ['4985,donna shalala']
# PRED:  ['4985,donna shalala']
# SAME:  ['4985,donna shalala']
# TRUE:  ['4986,french southern and antarctic lands', '4986,kerguelen islands']
# PRED:  ['4986,kerguelen', '4986,french']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4986,french southern and antarctic lands', '4986,kerguelen islands']
# NONE_PRED_EQUAL:  ['4986,kerguelen', '4986,french']
# TRUE:  ['4987,weber thompson']
# PRED:  ['4987,weber thompson']
# SAME:  ['4987,weber thompson']
# TRUE:  ['4988,edith vonnegut']
# PRED:  ['4988,edith vonnegut']
# SAME:  ['4988,edith vonnegut']
# TRUE:  ['4989,iyoas i']
# PRED:  ['4989,iyoas']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4989,iyoas i']
# NONE_PRED_EQUAL:  ['4989,iyoas']
# TRUE:  ['4990,wcw mayhem']
# PRED:  ['4990,wcw mayhem']
# SAME:  ['4990,wcw mayhem']
# TRUE:  ['4991,rca records']
# PRED:  ['4991,rca']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4991,rca records']
# NONE_PRED_EQUAL:  ['4991,rca']
# TRUE:  ['4992,nick diaz', '4992,brazilian jiu-jitsu']
# PRED:  ['4992,brazilian', '4992,nick diaz']
# SAME:  ['4992,nick diaz']
# PARTIAL:  ['4992,nick diaz']
# TRUE:  ['4993,amstelveen']
# PRED:  ['4993,amstelveen']
# SAME:  ['4993,amstelveen']
# TRUE:  ['4994,choctaw']
# PRED:  ['4994,choctaw']
# SAME:  ['4994,choctaw']
# TRUE:  ['4995,larry j. franco']
# PRED:  ['4995,larry j. franco']
# SAME:  ['4995,larry j. franco']
# TRUE:  ['4996,tnt', '4996,j. michael stroczynski']
# PRED:  ['4996,j. michael stroczynski', '4996,tnt']
# SAME:  ['4996,j. michael stroczynski', '4996,tnt']
# TRUE:  ['4997,varsity stadium']
# PRED:  ['4997,varsity stadium']
# SAME:  ['4997,varsity stadium']
# TRUE:  ['4998,robin kovacs', '4998,nyrangers']
# PRED:  ['4998,ny rangers', '4998,robin kovacs']
# SAME:  ['4998,robin kovacs']
# PARTIAL:  ['4998,robin kovacs']
# TRUE:  ["4999,marquette golden eagles men's basketball team, 2008-09", "4999,marquette golden eagles men's basketball team"]
# PRED:  ['4999,marquette golden eagles', '4999,2008-09', '4999,marquette golden eagles']
# NONE_TRUE_MORE:  ["4999,marquette golden eagles men's basketball team, 2008-09", "4999,marquette golden eagles men's basketball team"]
# NONE_PRED_MORE:  ['4999,marquette golden eagles', '4999,2008-09', '4999,marquette golden eagles']
# 2511
# 352
# 187
# 274
# 1175
# 156
# 345
# 4446

# %%
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# 2511
# 352
# 187
# 274
# 1175
# 156
# 345
# 4446
# 0.6693766937669376

# %%
# flair + spaCy

# %%
flair_spacy = ['']*n

for i in range(0, n):
    if len(ner_ner12[i])==len(ner_md[i]):
        if all(elem in ner_md[i] for elem in ner_ner12[i]) == True:
            flair_spacy[i] = ner_ner12[i]
        else:

            if ner_ner12[i] == ['']:
                flair_spacy[i] = ner_md[i]            
            else:
                flair_spacy[i] = ner_ner12[i]            
    elif len(ner_ner12[i])<len(ner_md[i]):
        if all(elem in ner_md[i] for elem in ner_ner12[i]) == True:
            flair_spacy[i] = ner_md[i]           
        else:
            if ner_ner12[i] == ['']:
                flair_spacy[i] = ner_md[i]            
            else:
                inter = list(set(ner_ner12[i]) & set(ner_md[i]))
                dif = list(set(ner_ner12[i]) - set(ner_md[i]))
                flair_spacy[i] = inter+dif
                
    elif len(ner_ner12[i])>len(ner_md[i]):
        if all(elem in ner_ner12[i] for elem in ner_md[i]) == True:
            flair_spacy[i] = ner_ner12[i]
        else:
            if ner_md[i] == ['']:
                flair_spacy[i] = ner_ner12[i]
            else:
                inter = list(set(ner_ner12[i]) & set(ner_md[i]))
                dif = list(set(ner_md[i]) - set(ner_ner12[i]))
                flair_spacy[i] = inter+dif
# Out:
# [['0,Bill Finger'], ['1,winston churchill', '1,Selwyn Lloyd'], ['2,Gestapo'], ['3,Mumbai North'], ['4,Roberto Clemente Bridge'], ['5,Theos Philopator', '5,Cleopatra'], ['6,Li Si'], ['7,PAvel Moroz', '7,Yakov Estrin'], ['8,Broadmeadows, Victoria'], ['9,ASC Creative Services'], ['10,Ernest Rutherford', '10,Charles Drummond Ellis'], ['11,REP Parasol'], ["12,Monroe Carell Jr. Children's Hospital", '12,Vanderbilt', '12,Duncan U. Fletcher'], ['13,Nader Guirat,', '13,Josef Johansson'], ['14,sarah jane'], ['15,HBO'], ['16,Nikolai Morozov', '16,Stanislav Morozov'], ['17,Abhijit Kunte', '17,Kasparov'], ['18,MSX Basics'], ['19,seasons', '19,Ronaldo'], ['20,SamurAbsheron', '20,Anar Salmanov'], ['21,2nd Foreign Infantry Regiment'], ['22,SR'], ['23,Kevin Jonas', '23,Joe Jonas'], ['24,Timm Gunn', '24,Sunrise', '24,HIMYM'], ['25,O.co Coliseum'], ['26,Rishkiesh'], ['27,america'], ['28,PhDs', '28,National Medal of Science'], ['29,Middlesbrough F.C.', '29,Aston Villa'], ['30,William Harper.'], ['31,PCL'], ['32,Kevin Jonas', '32,Jonas'], ["33,Sagan's Cosmos,"], ['34,Rosemont, Illinois'], ['35,Greenup County High School'], ['36,Bobby Hoppe'], ['37,The Second Coming'], ['38,Miguel de Cervantes'], [''], ['40,Reading, Berkshire'], ['41,Crystal Harris'], ['42,Essex'], ['43,Niederkirchnerstrae'], ['44,Steven Moffat'], ['45,Dagenham', '45,Ford Falcon Cobra'], ['46,San Francisco International Airport'], ['47,San Diego'], ['48,Sarah Walker', '48,Trinity School, Brentwood'], ['49,21Vianet'], ['50,Johann Gottfired', '50,Urbain Le Verrier'], ['51,Elmer Burkett'], ['52,Hensley Meulens', '52,Steve Ontiveros'], ['53,Lucy Sullivan'], ['54,Society Islands', '54,Faaa'], ['55,1997', '55,94'], ['56,Richard Winn'], ['57,Sherlock', '57,Arthur Levinson'], ['58,Master Card', '58,Sam Carrrick'], ['59,Fremantle Media'], ['60,South Loop Printing House District'], ['61,Outlook', '61,Visual Studio'], ['62,Ombla', '62,Croatia'], ['63,Newin Chidchob'], ['64,Dave Bing', '64,Ron Reed'], ['65,Ganymede', '65,Galileo Galilei'], [''], ['67,Elizabeth: The Golden Age'], ['68,OneDrive'], ['69,Washington, D.C.'], ['70,Jordan', '70,one'], ['71,Robert Witherspoon'], ["72,He's a Liar"], ['73,Oj'], ['74,Allen Walker'], ['75,Publius Servilius Vatia Isauricus', '75,Marcus Calpurnius Bibulus'], ['76,chowdhury'], ['77,Cathedral Peak', '77,Mount Hoffmann'], ['78,Indiana'], ['79,swedish'], ['80,the Moondog Matinee', '80,Girl from the North Country'], ['81,Mona Marshall', '81,April Stewart'], ['82,Freedom of the City', '82,Trinity House'], ['83,Reza Amrollahi', '83,Iran'], ['84,Zaman Shah Durrani', '84,Salahuddin'], ['85,Roh Tae Woo', '85,Lee Leffingwell'], ['86,Rosemarie DeWitt'], ['87,Sapindales'], ['88,Lewis Hamilton'], ['89,Giorgos Kaminis'], ['90,Michael hahn'], ['91,Berlin'], ['92,India'], ['93,The Simpsons Ride'], ['94,american', '94,O.co Coliseum'], ['95,Mams'], ['96,Playboy Enterprises'], ['97,Gwo Ka', '97,Western Africa'], [''], ['99,Visual Studio', '99,One Drive'], ['100,Roundhead'], ['101,Michigan Stadium'], ['102,David Johnston'], ['103,Francois Marie Le Marchand de Lignery'], ['104,Myntdu'], ['105,London.'], ['106,Al Gore', '106,2000', '106,Ann Lewis'], ['107,Darius I'], ['108,Kim Sawchuk', '108,Airtours International Airways'], ['109,Antonio Giannini'], ['110,David Scherman'], ['111,Outlook.com', '111,OneDrive'], ['112,Rouen Business School'], ['113,Korean Minjoo Party'], ['114,one', '114,McDonnell Aircraft'], ['115,Gales Ferry, Connecticut'], ['116,Detroit,'], ['117,english', '117,under twenty'], ['118,Helsinki', '118,one', '118,Danish'], ['119,Timmy Time'], ['120,Fort Heath'], ['121,Harding', '121,Lyons'], ['122,Rosario, Santa Fe'], [''], ['124,Oahu Railway and Land Company', '124,Chris Myers (New Jersey)'], [''], ['126,Brian Graden', '126,Isaac Hayes'], [''], ['128,Steve Sampson', '128,Santa Clara'], ['129,Schibsted'], ['130,WPC Dynamo Moscow', '130,Tigran Petrosian'], ['131,Joan Laporta.'], ['132,four'], ['133,Pong Pha'], ['134,Angela Trusty', '134,Charles Ayres'], ['135,The Con ...

# %%
### compare flair (ner+ner12) + spaCy(md) predictions

match, partial, less, more, none_match, none_less, none_more, predicted = compare_predictions(real, flair_spacy)
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# TRUE:  ['0,bill finger']
# PRED:  ['0,bill finger']
# SAME:  ['0,bill finger']
# TRUE:  ['1,selwyn lloyd', '1,winston churchill']
# PRED:  ['1,winston churchill', '1,selwyn lloyd']
# SAME:  ['1,winston churchill', '1,selwyn lloyd']
# TRUE:  ['2,gestapo']
# PRED:  ['2,gestapo']
# SAME:  ['2,gestapo']
# TRUE:  ['3,mumbai north']
# PRED:  ['3,mumbai north']
# SAME:  ['3,mumbai north']
# TRUE:  ['4,roberto clemente bridge']
# PRED:  ['4,roberto clemente bridge']
# SAME:  ['4,roberto clemente bridge']
# TRUE:  ['5,ptolemy xiii theos philopator', '5,cleopatra v']
# PRED:  ['5,theos philopator', '5,cleopatra']
# SAME:  []
# NONE_TRUE_EQUAL:  ['5,ptolemy xiii theos philopator', '5,cleopatra v']
# NONE_PRED_EQUAL:  ['5,theos philopator', '5,cleopatra']
# TRUE:  ['6,li si']
# PRED:  ['6,li si']
# SAME:  ['6,li si']
# TRUE:  ['7,pavel moroz', '7,yakov estrin']
# PRED:  ['7,pavel moroz', '7,yakov estrin']
# SAME:  ['7,pavel moroz', '7,yakov estrin']
# TRUE:  ['8,broadmeadows, victoria']
# PRED:  ['8,broadmeadows, victoria']
# SAME:  ['8,broadmeadows, victoria']
# TRUE:  ['9,asc creative services']
# PRED:  ['9,asc creative services']
# SAME:  ['9,asc creative services']
# TRUE:  ['10,ernest rutherford', '10,charles drummond ellis']
# PRED:  ['10,ernest rutherford', '10,charles drummond ellis']
# SAME:  ['10,ernest rutherford', '10,charles drummond ellis']
# TRUE:  ['11,rep parasol']
# PRED:  ['11,rep parasol']
# SAME:  ['11,rep parasol']
# TRUE:  ["12,monroe carell jr. children's hospital", '12,vanderbilt', '12,duncan u. fletcher']
# PRED:  ["12,monroe carell jr. children's hospital", '12,vanderbilt', '12,duncan u. fletcher']
# SAME:  ["12,monroe carell jr. children's hospital", '12,vanderbilt', '12,duncan u. fletcher']
# TRUE:  ['13,josef johansson', '13,nader guirat']
# PRED:  ['13,nader guirat,', '13,josef johansson']
# SAME:  ['13,josef johansson']
# PARTIAL:  ['13,josef johansson']
# TRUE:  ['14,dr who confidential', '14,the sara jane adventure']
# PRED:  ['14,sarah jane']
# NONE_TRUE_LESS:  ['14,dr who confidential', '14,the sara jane adventure']
# NONE_PRED_LESS:  ['14,sarah jane']
# TRUE:  ['15,hbo']
# PRED:  ['15,hbo']
# SAME:  ['15,hbo']
# TRUE:  ['16,stanislav morozov', '16,nikolai morozov']
# PRED:  ['16,nikolai morozov', '16,stanislav morozov']
# SAME:  ['16,nikolai morozov', '16,stanislav morozov']
# TRUE:  ['17,abhijit kunte', '17,kasparov']
# PRED:  ['17,abhijit kunte', '17,kasparov']
# SAME:  ['17,abhijit kunte', '17,kasparov']
# TRUE:  ['18,outlook', '18,msx basics']
# PRED:  ['18,msx basics']
# LESS:  ['18,msx basics']
# TRUE:  ['19,ronaldo']
# PRED:  ['19,seasons', '19,ronaldo']
# MORE:  ['19,ronaldo']
# TRUE:  ['20,samurabsheron channel', '20,anar salmanov']
# PRED:  ['20,samurabsheron', '20,anar salmanov']
# SAME:  ['20,anar salmanov']
# PARTIAL:  ['20,anar salmanov']
# TRUE:  ['21,2nd foreign infantry regiment']
# PRED:  ['21,2nd foreign infantry regiment']
# SAME:  ['21,2nd foreign infantry regiment']
# TRUE:  ['22,sr class 3sub']
# PRED:  ['22,sr']
# SAME:  []
# NONE_TRUE_EQUAL:  ['22,sr class 3sub']
# NONE_PRED_EQUAL:  ['22,sr']
# TRUE:  ['23,kevin jonas', '23,joe jonas']
# PRED:  ['23,kevin jonas', '23,joe jonas']
# SAME:  ['23,kevin jonas', '23,joe jonas']
# TRUE:  ['24,sunrise (himym)', '24,timm gunn']
# PRED:  ['24,timm gunn', '24,sunrise', '24,himym']
# MORE:  ['24,timm gunn']
# TRUE:  ['25,o.co coliseum']
# PRED:  ['25,o.co coliseum']
# SAME:  ['25,o.co coliseum']
# TRUE:  ['26,rishkiesh']
# PRED:  ['26,rishkiesh']
# SAME:  ['26,rishkiesh']
# TRUE:  ['27,north america', '27,airtours airways']
# PRED:  ['27,america']
# NONE_TRUE_LESS:  ['27,north america', '27,airtours airways']
# NONE_PRED_LESS:  ['27,america']
# TRUE:  ['28,national medal of science']
# PRED:  ['28,phds', '28,national medal of science']
# MORE:  ['28,national medal of science']
# TRUE:  ['29,aston villa 2000-02 season', '29,middlesbrough f.c. season 2009-10']
# PRED:  ['29,middlesbrough f.c.', '29,aston villa']
# SAME:  []
# NONE_TRUE_EQUAL:  ['29,aston villa 2000-02 season', '29,middlesbrough f.c. season 2009-10']
# NONE_PRED_EQUAL:  ['29,middlesbrough f.c.', '29,aston villa']
# TRUE:  ['30,william harper']
# PRED:  ['30,william harper.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['30,william harper']
# NONE_PRED_EQUAL:  ['30,william harper.']
# TRUE:  ['31,pcl constructures']
# PRED:  ['31,pcl']
# SAME:  []
# NONE_TRUE_EQUAL:  ['31,pcl constructures']
# NONE_PRED_EQUAL:  ['31,pcl']
# TRUE:  ['32,jonas brothers', '32,kevin jonas']
# PRED:  ['32,kevin jonas', '32,jonas']
# SAME:  ['32,kevin jonas']
# PARTIAL:  ['32,kevin jonas']
# TRUE:  ['33,cosmos']
# PRED:  ["33,sagan's cosmos,"]
# SAME:  []
# NONE_TRUE_EQUAL:  ['33,cosmos']
# NONE_PRED_EQUAL:  ["33,sagan's cosmos,"]
# TRUE:  ['34,rosemont, illinois']
# PRED:  ['34,rosemont, illinois']
# SAME:  ['34,rosemont, illinois']
# TRUE:  ['35,greenup county high school']
# PRED:  ['35,greenup county high school']
# SAME:  ['35,greenup county high school']
# TRUE:  ['36,bobby hoppe']
# PRED:  ['36,bobby hoppe']
# SAME:  ['36,bobby hoppe']
# TRUE:  ['37,the second coming']
# PRED:  ['37,the second coming']
# SAME:  ['37,the second coming']
# TRUE:  ['38,miguel de cervantes']
# PRED:  ['38,miguel de cervantes']
# SAME:  ['38,miguel de cervantes']
# TRUE:  ['39,progressive rock']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['39,progressive rock']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['40,reading, berkshire']
# PRED:  ['40,reading, berkshire']
# SAME:  ['40,reading, berkshire']
# TRUE:  ['41,crystal harris']
# PRED:  ['41,crystal harris']
# SAME:  ['41,crystal harris']
# TRUE:  ['42,west thurrock', '42,essex']
# PRED:  ['42,essex']
# LESS:  ['42,essex']
# TRUE:  ['43,niederkirchnerstrae']
# PRED:  ['43,niederkirchnerstrae']
# SAME:  ['43,niederkirchnerstrae']
# TRUE:  ['44,steven moffat']
# PRED:  ['44,steven moffat']
# SAME:  ['44,steven moffat']
# TRUE:  ['45,ford falcon cobra', '45,dagenham wind turbines']
# PRED:  ['45,dagenham', '45,ford falcon cobra']
# SAME:  ['45,ford falcon cobra']
# PARTIAL:  ['45,ford falcon cobra']
# TRUE:  ['46,san francisco international airport']
# PRED:  ['46,san francisco international airport']
# SAME:  ['46,san francisco international airport']
# TRUE:  ['47,maritime museum of san diego']
# PRED:  ['47,san diego']
# SAME:  []
# NONE_TRUE_EQUAL:  ['47,maritime museum of san diego']
# NONE_PRED_EQUAL:  ['47,san diego']
# TRUE:  ['48,sarah walker', '48,trinity school, brentwood']
# PRED:  ['48,sarah walker', '48,trinity school, brentwood']
# SAME:  ['48,sarah walker', '48,trinity school, brentwood']
# TRUE:  ['49,21vianet']
# PRED:  ['49,21vianet']
# SAME:  ['49,21vianet']
# TRUE:  ['50,urbain le verrier', '50,johann gottfried']
# PRED:  ['50,johann gottfired', '50,urbain le verrier']
# SAME:  ['50,urbain le verrier']
# PARTIAL:  ['50,urbain le verrier']
# TRUE:  ['51,elmer burkett']
# PRED:  ['51,elmer burkett']
# SAME:  ['51,elmer burkett']
# TRUE:  ['52,hensley meulens', '52,steve ontiveros']
# PRED:  ['52,hensley meulens', '52,steve ontiveros']
# SAME:  ['52,hensley meulens', '52,steve ontiveros']
# TRUE:  ['53,lucy sullivan is getting married']
# PRED:  ['53,lucy sullivan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['53,lucy sullivan is getting married']
# NONE_PRED_EQUAL:  ['53,lucy sullivan']
# TRUE:  ['54,faaa', '54,society islands']
# PRED:  ['54,society islands', '54,faaa']
# SAME:  ['54,society islands', '54,faaa']
# TRUE:  ['55,1997 canadian grand prix', '55,94 spanish']
# PRED:  ['55,1997', '55,94']
# SAME:  []
# NONE_TRUE_EQUAL:  ['55,1997 canadian grand prix', '55,94 spanish']
# NONE_PRED_EQUAL:  ['55,1997', '55,94']
# TRUE:  ['56,richard winn']
# PRED:  ['56,richard winn']
# SAME:  ['56,richard winn']
# TRUE:  ['57,sherlock', '57,arthur levinson']
# PRED:  ['57,sherlock', '57,arthur levinson']
# SAME:  ['57,sherlock', '57,arthur levinson']
# TRUE:  ['58,master card center', '58,sam carrrick']
# PRED:  ['58,master card', '58,sam carrrick']
# SAME:  ['58,sam carrrick']
# PARTIAL:  ['58,sam carrrick']
# TRUE:  ['59,fremantle media']
# PRED:  ['59,fremantle media']
# SAME:  ['59,fremantle media']
# TRUE:  ['60,south loop printing house district']
# PRED:  ['60,south loop printing house district']
# SAME:  ['60,south loop printing house district']
# TRUE:  ['61,outlook', '61,visual studio']
# PRED:  ['61,outlook', '61,visual studio']
# SAME:  ['61,outlook', '61,visual studio']
# TRUE:  ['62,croatia', '62,ombla']
# PRED:  ['62,ombla', '62,croatia']
# SAME:  ['62,ombla', '62,croatia']
# TRUE:  ['63,newin chidchob']
# PRED:  ['63,newin chidchob']
# SAME:  ['63,newin chidchob']
# TRUE:  ['64,ron reed', '64,dave bing']
# PRED:  ['64,dave bing', '64,ron reed']
# SAME:  ['64,dave bing', '64,ron reed']
# TRUE:  ['65,galileo galilei', '65,ganymede']
# PRED:  ['65,ganymede', '65,galileo galilei']
# SAME:  ['65,ganymede', '65,galileo galilei']
# TRUE:  ['66,guitar']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['66,guitar']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['67,elizabeth: the golden age']
# PRED:  ['67,elizabeth: the golden age']
# SAME:  ['67,elizabeth: the golden age']
# TRUE:  ['68,onedrive']
# PRED:  ['68,onedrive']
# SAME:  ['68,onedrive']
# TRUE:  ['69,washington, d.c.']
# PRED:  ['69,washington, d.c.']
# SAME:  ['69,washington, d.c.']
# TRUE:  ['70,queen noor of jordan']
# PRED:  ['70,jordan', '70,one']
# NONE_TRUE_MORE:  ['70,queen noor of jordan']
# NONE_PRED_MORE:  ['70,jordan', '70,one']
# TRUE:  ['71,robert witherspoon']
# PRED:  ['71,robert witherspoon']
# SAME:  ['71,robert witherspoon']
# TRUE:  ["72,he's a liar"]
# PRED:  ["72,he's a liar"]
# SAME:  ["72,he's a liar"]
# TRUE:  ['73,oj, svijetla majska zoro']
# PRED:  ['73,oj']
# SAME:  []
# NONE_TRUE_EQUAL:  ['73,oj, svijetla majska zoro']
# NONE_PRED_EQUAL:  ['73,oj']
# TRUE:  ['74,allen walker']
# PRED:  ['74,allen walker']
# SAME:  ['74,allen walker']
# TRUE:  ['75,marcus calpurnius bibulus', '75,publius servilius vatia isauricus']
# PRED:  ['75,publius servilius vatia isauricus', '75,marcus calpurnius bibulus']
# SAME:  ['75,publius servilius vatia isauricus', '75,marcus calpurnius bibulus']
# TRUE:  ['76,edmund john', '76,saima chowdhury']
# PRED:  ['76,chowdhury']
# NONE_TRUE_LESS:  ['76,edmund john', '76,saima chowdhury']
# NONE_PRED_LESS:  ['76,chowdhury']
# TRUE:  ['77,mount hoffmann', '77,cathedral peak']
# PRED:  ['77,cathedral peak', '77,mount hoffmann']
# SAME:  ['77,cathedral peak', '77,mount hoffmann']
# TRUE:  ['78,indiana']
# PRED:  ['78,indiana']
# SAME:  ['78,indiana']
# TRUE:  ['79,swedish covenant hospital']
# PRED:  ['79,swedish']
# SAME:  []
# NONE_TRUE_EQUAL:  ['79,swedish covenant hospital']
# NONE_PRED_EQUAL:  ['79,swedish']
# TRUE:  ['80,moondog matinee', '80,girl from the north country']
# PRED:  ['80,the moondog matinee', '80,girl from the north country']
# SAME:  ['80,girl from the north country']
# PARTIAL:  ['80,girl from the north country']
# TRUE:  ['81,april stewart', '81,mona marshall']
# PRED:  ['81,mona marshall', '81,april stewart']
# SAME:  ['81,mona marshall', '81,april stewart']
# TRUE:  ['82,trinity house', '82,freedom']
# PRED:  ['82,freedom of the city', '82,trinity house']
# SAME:  ['82,trinity house']
# PARTIAL:  ['82,trinity house']
# TRUE:  ['83,iran', '83,reza amrollahi']
# PRED:  ['83,reza amrollahi', '83,iran']
# SAME:  ['83,reza amrollahi', '83,iran']
# TRUE:  ['84,zaman shah durrani', '84,salahuddin']
# PRED:  ['84,zaman shah durrani', '84,salahuddin']
# SAME:  ['84,zaman shah durrani', '84,salahuddin']
# TRUE:  ['85,roh tae woo', '85,lee leffingwell']
# PRED:  ['85,roh tae woo', '85,lee leffingwell']
# SAME:  ['85,roh tae woo', '85,lee leffingwell']
# TRUE:  ['86,rosemarie dewitt']
# PRED:  ['86,rosemarie dewitt']
# SAME:  ['86,rosemarie dewitt']
# TRUE:  ['87,sapindales']
# PRED:  ['87,sapindales']
# SAME:  ['87,sapindales']
# TRUE:  ['88,lewis hamilton']
# PRED:  ['88,lewis hamilton']
# SAME:  ['88,lewis hamilton']
# TRUE:  ['89,giorgos kaminis']
# PRED:  ['89,giorgos kaminis']
# SAME:  ['89,giorgos kaminis']
# TRUE:  ['90,michael hahn']
# PRED:  ['90,michael hahn']
# SAME:  ['90,michael hahn']
# TRUE:  ['91,berlin']
# PRED:  ['91,berlin']
# SAME:  ['91,berlin']
# TRUE:  ['92,india']
# PRED:  ['92,india']
# SAME:  ['92,india']
# TRUE:  ['93,the simpsons ride']
# PRED:  ['93,the simpsons ride']
# SAME:  ['93,the simpsons ride']
# TRUE:  ['94,o.co coliseum']
# PRED:  ['94,american', '94,o.co coliseum']
# MORE:  ['94,o.co coliseum']
# TRUE:  ['95,mams taylor', '95,the mating habits of the earthbound humans']
# PRED:  ['95,mams']
# NONE_TRUE_LESS:  ['95,mams taylor', '95,the mating habits of the earthbound humans']
# NONE_PRED_LESS:  ['95,mams']
# TRUE:  ['96,playboy enterprises']
# PRED:  ['96,playboy enterprises']
# SAME:  ['96,playboy enterprises']
# TRUE:  ['97,gwo ka', '97,western africa']
# PRED:  ['97,gwo ka', '97,western africa']
# SAME:  ['97,gwo ka', '97,western africa']
# TRUE:  ['98,send it on']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['98,send it on']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['99,onedrive', '99,visual studio']
# PRED:  ['99,visual studio', '99,one drive']
# SAME:  ['99,visual studio']
# PARTIAL:  ['99,visual studio']
# TRUE:  ['100,roundhead']
# PRED:  ['100,roundhead']
# SAME:  ['100,roundhead']
# TRUE:  ['101,michigan stadium']
# PRED:  ['101,michigan stadium']
# SAME:  ['101,michigan stadium']
# TRUE:  ['102,david johnston']
# PRED:  ['102,david johnston']
# SAME:  ['102,david johnston']
# TRUE:  ['103,francois marie le marchand de lignery']
# PRED:  ['103,francois marie le marchand de lignery']
# SAME:  ['103,francois marie le marchand de lignery']
# TRUE:  ['104,myntdu river']
# PRED:  ['104,myntdu']
# SAME:  []
# NONE_TRUE_EQUAL:  ['104,myntdu river']
# NONE_PRED_EQUAL:  ['104,myntdu']
# TRUE:  ['105,london']
# PRED:  ['105,london.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['105,london']
# NONE_PRED_EQUAL:  ['105,london.']
# TRUE:  ['106,ann lewis', '106,al gore presidential campaign, 2000']
# PRED:  ['106,al gore', '106,2000', '106,ann lewis']
# MORE:  ['106,ann lewis']
# TRUE:  ['107,darius i']
# PRED:  ['107,darius i']
# SAME:  ['107,darius i']
# TRUE:  ['108,airtours international airways', '108,kim sawchuk']
# PRED:  ['108,kim sawchuk', '108,airtours international airways']
# SAME:  ['108,kim sawchuk', '108,airtours international airways']
# TRUE:  ['109,antonio giannini']
# PRED:  ['109,antonio giannini']
# SAME:  ['109,antonio giannini']
# TRUE:  ['110,david scherman']
# PRED:  ['110,david scherman']
# SAME:  ['110,david scherman']
# TRUE:  ['111,outlook.com', '111,onedrive']
# PRED:  ['111,outlook.com', '111,onedrive']
# SAME:  ['111,outlook.com', '111,onedrive']
# TRUE:  ['112,rouen business school']
# PRED:  ['112,rouen business school']
# SAME:  ['112,rouen business school']
# TRUE:  ['113,minjoo party']
# PRED:  ['113,korean minjoo party']
# SAME:  []
# NONE_TRUE_EQUAL:  ['113,minjoo party']
# NONE_PRED_EQUAL:  ['113,korean minjoo party']
# TRUE:  ['114,mcdonnell aircraft']
# PRED:  ['114,one', '114,mcdonnell aircraft']
# MORE:  ['114,mcdonnell aircraft']
# TRUE:  ['115,gales ferry, connecticut']
# PRED:  ['115,gales ferry, connecticut']
# SAME:  ['115,gales ferry, connecticut']
# TRUE:  ['116,live in detroit, mi']
# PRED:  ['116,detroit,']
# SAME:  []
# NONE_TRUE_EQUAL:  ['116,live in detroit, mi']
# NONE_PRED_EQUAL:  ['116,detroit,']
# TRUE:  ['117,english under twenty one football team']
# PRED:  ['117,english', '117,under twenty']
# NONE_TRUE_MORE:  ['117,english under twenty one football team']
# NONE_PRED_MORE:  ['117,english', '117,under twenty']
# TRUE:  ['118,helsinki', '118,danish straits']
# PRED:  ['118,helsinki', '118,one', '118,danish']
# MORE:  ['118,helsinki']
# TRUE:  ['119,timmy time']
# PRED:  ['119,timmy time']
# SAME:  ['119,timmy time']
# TRUE:  ['120,fort heath radar station']
# PRED:  ['120,fort heath']
# SAME:  []
# NONE_TRUE_EQUAL:  ['120,fort heath radar station']
# NONE_PRED_EQUAL:  ['120,fort heath']
# TRUE:  ['121,lyons township high school', '121,harding academy']
# PRED:  ['121,harding', '121,lyons']
# SAME:  []
# NONE_TRUE_EQUAL:  ['121,lyons township high school', '121,harding academy']
# NONE_PRED_EQUAL:  ['121,harding', '121,lyons']
# TRUE:  ['122,rosario, santa fe']
# PRED:  ['122,rosario, santa fe']
# SAME:  ['122,rosario, santa fe']
# TRUE:  ['123,animal']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['123,animal']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['124,oahu railway and land company', '124,chris myers']
# PRED:  ['124,oahu railway and land company', '124,chris myers (new jersey)']
# SAME:  ['124,oahu railway and land company']
# PARTIAL:  ['124,oahu railway and land company']
# TRUE:  ['125,ngos']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['125,ngos']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['126,brian graden', '126,isaac hayes']
# PRED:  ['126,brian graden', '126,isaac hayes']
# SAME:  ['126,brian graden', '126,isaac hayes']
# TRUE:  ['127,cars']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['127,cars']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['128,steve sampson', '128,santa clara university']
# PRED:  ['128,steve sampson', '128,santa clara']
# SAME:  ['128,steve sampson']
# PARTIAL:  ['128,steve sampson']
# TRUE:  ['129,schibsted']
# PRED:  ['129,schibsted']
# SAME:  ['129,schibsted']
# TRUE:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# PRED:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# SAME:  ['130,wpc dynamo moscow', '130,tigran petrosian']
# TRUE:  ['131,joan laporta']
# PRED:  ['131,joan laporta.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['131,joan laporta']
# NONE_PRED_EQUAL:  ['131,joan laporta.']
# TRUE:  ['132,four-wheel-drive layout']
# PRED:  ['132,four']
# SAME:  []
# NONE_TRUE_EQUAL:  ['132,four-wheel-drive layout']
# NONE_PRED_EQUAL:  ['132,four']
# TRUE:  ['133,pong pha']
# PRED:  ['133,pong pha']
# SAME:  ['133,pong pha']
# TRUE:  ['134,charles ayres', '134,angela trusty']
# PRED:  ['134,angela trusty', '134,charles ayres']
# SAME:  ['134,angela trusty', '134,charles ayres']
# TRUE:  ['135,the conglomerate', '135,before i let you go']
# PRED:  ['135,the conglomerate,']
# NONE_TRUE_LESS:  ['135,the conglomerate', '135,before i let you go']
# NONE_PRED_LESS:  ['135,the conglomerate,']
# TRUE:  ['136,lagnacha dhumdhadaka']
# PRED:  ['136,lagnacha dhumdhadaka']
# SAME:  ['136,lagnacha dhumdhadaka']
# TRUE:  ['137,english']
# PRED:  ['137,english']
# SAME:  ['137,english']
# TRUE:  ['138,el sobrante, california']
# PRED:  ['138,el sobrante, california']
# SAME:  ['138,el sobrante, california']
# TRUE:  ["139,daniel o'regan"]
# PRED:  ['139, ', "139,daniel o'regan"]
# MORE:  ["139,daniel o'regan"]
# TRUE:  ['140,aureus', '140,solidus']
# PRED:  ['140,aureus and solidus']
# NONE_TRUE_LESS:  ['140,aureus', '140,solidus']
# NONE_PRED_LESS:  ['140,aureus and solidus']
# TRUE:  ['141,cardiovascular disease']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['141,cardiovascular disease']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['142,mammal', '142,chestnut white bellied rat']
# PRED:  ['']
# NONE_TRUE_LESS:  ['142,mammal', '142,chestnut white bellied rat']
# NONE_PRED_LESS:  ['']
# TRUE:  ['143,the broken code', '143,tim gunn']
# PRED:  ['143,tim gunn', '143,the broken code']
# SAME:  ['143,tim gunn', '143,the broken code']
# TRUE:  ['144,shallot']
# PRED:  ['144,shallot']
# SAME:  ['144,shallot']
# TRUE:  ['145,oktoc, mississippi']
# PRED:  ['145,american', '145,oktoc, mississippi']
# MORE:  ['145,oktoc, mississippi']
# TRUE:  ['146,nord', '146,the beauty inside']
# PRED:  ['146,nord']
# LESS:  ['146,nord']
# TRUE:  ['147,tirana', '147,albania']
# PRED:  ['147,tirana', '147,albania']
# SAME:  ['147,tirana', '147,albania']
# TRUE:  ['148,vishwajyot high school', '148,fr agnel multipurpose school']
# PRED:  ['148,vishwajyot high school', '148,fr agnel multipurpose']
# SAME:  ['148,vishwajyot high school']
# PARTIAL:  ['148,vishwajyot high school']
# TRUE:  ['149,bob hawke']
# PRED:  ['149,bob hawke']
# SAME:  ['149,bob hawke']
# TRUE:  ['150,cbs corporation']
# PRED:  ['150,cbs corporation']
# SAME:  ['150,cbs corporation']
# TRUE:  ['151,taguig']
# PRED:  ['151,taguig']
# SAME:  ['151,taguig']
# TRUE:  ['152,joe hahn']
# PRED:  ['152,joe hahn']
# SAME:  ['152,joe hahn']
# TRUE:  ['153,comedy central', '153,isaac hayes']
# PRED:  ['153,isaac']
# NONE_TRUE_LESS:  ['153,comedy central', '153,isaac hayes']
# NONE_PRED_LESS:  ['153,isaac']
# TRUE:  ['154,raymond johansen']
# PRED:  ['154,raymond johansen']
# SAME:  ['154,raymond johansen']
# TRUE:  ['155,ikaros smederna']
# PRED:  ['155,ikaros smederna']
# SAME:  ['155,ikaros smederna']
# TRUE:  ['156,windows']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['156,windows']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['157,hockey']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['157,hockey']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['158,washington dc']
# PRED:  ['158,washington dc']
# SAME:  ['158,washington dc']
# TRUE:  ['159,temenos group']
# PRED:  ['159,temenos group']
# SAME:  ['159,temenos group']
# TRUE:  ['160,to know him is to love him']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['160,to know him is to love him']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['161,spain...']
# PRED:  ['161,spain', '161,road again']
# NONE_TRUE_MORE:  ['161,spain...']
# NONE_PRED_MORE:  ['161,spain', '161,road again']
# TRUE:  ['162,chris marve', '162,neria douglass']
# PRED:  ['162,chris marve', '162,neria douglass']
# SAME:  ['162,chris marve', '162,neria douglass']
# TRUE:  ['163,monticello, maine']
# PRED:  ['163,monticello, maine']
# SAME:  ['163,monticello, maine']
# TRUE:  ['164,josiah idowu-fearon', '164,john']
# PRED:  ['164,josiah idowu-fearon', '164,damasucs']
# SAME:  ['164,josiah idowu-fearon']
# PARTIAL:  ['164,josiah idowu-fearon']
# TRUE:  ['165,paramount television', '165,judy hart angelo']
# PRED:  ['165,judy hart angelo', '165,paramount television']
# SAME:  ['165,judy hart angelo', '165,paramount television']
# TRUE:  ['166,caspian']
# PRED:  ['166,caspian']
# SAME:  ['166,caspian']
# TRUE:  ['167,united states department of defense', '167,arlington county, virginia']
# PRED:  ['167,united states department of defense', '167,arlington county, virginia']
# SAME:  ['167,united states department of defense', '167,arlington county, virginia']
# TRUE:  ['168,thongsuk samdaengpan']
# PRED:  ['168,thongsuk samdaengpan']
# SAME:  ['168,thongsuk samdaengpan']
# TRUE:  ['169,asus']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['169,asus']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['170,ncaa']
# PRED:  ['170,ncaa']
# SAME:  ['170,ncaa']
# TRUE:  ['171,afrika baby bam', '171,queen latifah']
# PRED:  ['171,queen latifah', '171,afrika baby bam']
# SAME:  ['171,queen latifah', '171,afrika baby bam']
# TRUE:  ['172,kazuo hirai']
# PRED:  ['172,kazuo hirai']
# SAME:  ['172,kazuo hirai']
# TRUE:  ['173,patts college of aeronautics']
# PRED:  ['173,patts college of aeronautics']
# SAME:  ['173,patts college of aeronautics']
# TRUE:  ['174,dan shamash', '174,ever bank field']
# PRED:  ['174,ever', '174,dan shamash']
# SAME:  ['174,dan shamash']
# PARTIAL:  ['174,dan shamash']
# TRUE:  ['175,thanong bidaya']
# PRED:  ['175,thanong bidaya']
# SAME:  ['175,thanong bidaya']
# TRUE:  ['176,san marcos river']
# PRED:  ['176,san marcos river']
# SAME:  ['176,san marcos river']
# TRUE:  ['177,jazz fusion']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['177,jazz fusion']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['178,bogumilus']
# PRED:  ['178,bogumilus']
# SAME:  ['178,bogumilus']
# TRUE:  ['179,screen actors guild life achievement award', '179,henry e. catto, jr.']
# PRED:  ['179,henry e. catto']
# NONE_TRUE_LESS:  ['179,screen actors guild life achievement award', '179,henry e. catto, jr.']
# NONE_PRED_LESS:  ['179,henry e. catto']
# TRUE:  ['180,pope gregory i']
# PRED:  ['180,pope gregory i']
# SAME:  ['180,pope gregory i']
# TRUE:  ['181,human rights party']
# PRED:  ['181,cambodian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['181,human rights party']
# NONE_PRED_EQUAL:  ['181,cambodian']
# TRUE:  ['182,czech extraliga']
# PRED:  ['182,czech extraliga']
# SAME:  ['182,czech extraliga']
# TRUE:  ['183,croix de guerre']
# PRED:  ['183,croix de guerre']
# SAME:  ['183,croix de guerre']
# TRUE:  ['184,azam f.c.']
# PRED:  ['184,azam f.c.']
# SAME:  ['184,azam f.c.']
# TRUE:  ['185,inkas', '185,t.i. ahmadiyya senior high school, kumasi']
# PRED:  ['185,inkas', '185,t.i. ahmadiyya', '185,kumasi']
# MORE:  ['185,inkas']
# TRUE:  ['186,mausoleum of augustus', '186,rome']
# PRED:  ['186,rome', '186,augustus']
# SAME:  ['186,rome']
# PARTIAL:  ['186,rome']
# TRUE:  ['187,1st free french division']
# PRED:  ['187,1st free french division']
# SAME:  ['187,1st free french division']
# TRUE:  ['188,mediterranean sea']
# PRED:  ['188,mediterranean sea']
# SAME:  ['188,mediterranean sea']
# TRUE:  ['189,zambia', '189,ikelenge district']
# PRED:  ['189,zambia', '189,ikelenge district']
# SAME:  ['189,zambia', '189,ikelenge district']
# TRUE:  ['190,royal society']
# PRED:  ['190,royal society']
# SAME:  ['190,royal society']
# TRUE:  ['191,acer nigrum']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['191,acer nigrum']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['192,filipinos']
# PRED:  ['192,filipinos']
# SAME:  ['192,filipinos']
# TRUE:  ['193,neil brown', '193,andrew peacock']
# PRED:  ['193,neil brown', '193,andrew peacock']
# SAME:  ['193,neil brown', '193,andrew peacock']
# TRUE:  ['194,wizards vs aliens', '194,into the dalek']
# PRED:  ['194,into the dalek', '194,wizards', '194,aliens']
# MORE:  ['194,into the dalek']
# TRUE:  ['195,charles pinckney']
# PRED:  ['195,charles pinckney']
# SAME:  ['195,charles pinckney']
# TRUE:  ["196,us men's national soccer team"]
# PRED:  ['196,us']
# SAME:  []
# NONE_TRUE_EQUAL:  ["196,us men's national soccer team"]
# NONE_PRED_EQUAL:  ['196,us']
# TRUE:  ['197,tessa dahl']
# PRED:  ['197,tessa dahl']
# SAME:  ['197,tessa dahl']
# TRUE:  ['198,eu broadcasting union']
# PRED:  ['198,eu broadcasting union']
# SAME:  ['198,eu broadcasting union']
# TRUE:  ['199,jack ryan', '199,us senate']
# PRED:  ['199,jack ryan', '199,us senate']
# SAME:  ['199,jack ryan', '199,us senate']
# TRUE:  ['200,ananda college']
# PRED:  ['200,ananda college.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['200,ananda college']
# NONE_PRED_EQUAL:  ['200,ananda college.']
# TRUE:  ['201,mediterranean sea', '201,panionios g.s.s. season']
# PRED:  ['201,mediterranean sea', '201,panionios g.s.s.']
# SAME:  ['201,mediterranean sea']
# PARTIAL:  ['201,mediterranean sea']
# TRUE:  ['202,murray mouth', '202,cowombat flat']
# PRED:  ['202,cowombat flat', '202,murray mouth']
# SAME:  ['202,cowombat flat', '202,murray mouth']
# TRUE:  ['203,wbcq']
# PRED:  ['203,wbcq', '203,sw']
# MORE:  ['203,wbcq']
# TRUE:  ['204,2015 argentine primera division']
# PRED:  ['204,2015', '204,argentine primera division']
# NONE_TRUE_MORE:  ['204,2015 argentine primera division']
# NONE_PRED_MORE:  ['204,2015', '204,argentine primera division']
# TRUE:  ['205,florida']
# PRED:  ['205,florida']
# SAME:  ['205,florida']
# TRUE:  ['206,god defend new zealand']
# PRED:  ['206,god', '206,new zealand']
# NONE_TRUE_MORE:  ['206,god defend new zealand']
# NONE_PRED_MORE:  ['206,god', '206,new zealand']
# TRUE:  ['207,vangelis', '207,jordan cronenweth']
# PRED:  ['207,jordan cronenweth', '207,vangelis']
# SAME:  ['207,jordan cronenweth', '207,vangelis']
# TRUE:  ['208,klang valley']
# PRED:  ['208,klang valley']
# SAME:  ['208,klang valley']
# TRUE:  ['209,discovery communications']
# PRED:  ['209,discovery communications']
# SAME:  ['209,discovery communications']
# TRUE:  ['210,queer as folk']
# PRED:  ['210,queer', '210,folk']
# NONE_TRUE_MORE:  ['210,queer as folk']
# NONE_PRED_MORE:  ['210,queer', '210,folk']
# TRUE:  ['211,high desert']
# PRED:  ['211,high desert']
# SAME:  ['211,high desert']
# TRUE:  ['212,paramount domestic television']
# PRED:  ['212,paramount domestic television']
# SAME:  ['212,paramount domestic television']
# TRUE:  ['213,city of new orleans']
# PRED:  ['213,city of new orleans']
# SAME:  ['213,city of new orleans']
# TRUE:  ['214,get tv', '214,the galleria']
# PRED:  ['214,get tv', '214,galleria']
# SAME:  ['214,get tv']
# PARTIAL:  ['214,get tv']
# TRUE:  ['215,madagascar: operation penguin', "215,he's a pirate"]
# PRED:  ["215,he's a pirate", '215,madagascar: operation penguin']
# SAME:  ["215,he's a pirate", '215,madagascar: operation penguin']
# TRUE:  ['216,goran cengic']
# PRED:  ['216,goran cengic']
# SAME:  ['216,goran cengic']
# TRUE:  ['217,zhorstoke nebo']
# PRED:  ['217,zhorstoke']
# SAME:  []
# NONE_TRUE_EQUAL:  ['217,zhorstoke nebo']
# NONE_PRED_EQUAL:  ['217,zhorstoke']
# TRUE:  ['218,louis dunbar', '218,jeff munn']
# PRED:  ['218,louis dunbar', '218,jeff munn']
# SAME:  ['218,louis dunbar', '218,jeff munn']
# TRUE:  ['219,populous']
# PRED:  ['219,populous']
# SAME:  ['219,populous']
# TRUE:  ['220,chumash people']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['220,chumash people']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['221,pavel moroz', '221,helena of moscow']
# PRED:  ['221,moroz', '221,helena', '221,moscow']
# NONE_TRUE_MORE:  ['221,pavel moroz', '221,helena of moscow']
# NONE_PRED_MORE:  ['221,moroz', '221,helena', '221,moscow']
# TRUE:  ['222,christopher franke', '222,j. michael straczynski']
# PRED:  ['222,j. michael stracznski', '222,christopher franke']
# SAME:  ['222,christopher franke']
# PARTIAL:  ['222,christopher franke']
# TRUE:  ['223,cy-fair high school']
# PRED:  ['223,cy-fair high school.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['223,cy-fair high school']
# NONE_PRED_EQUAL:  ['223,cy-fair high school.']
# TRUE:  ['224,senser']
# PRED:  ['224,senser']
# SAME:  ['224,senser']
# TRUE:  ['225,teddy riley', '225,blayse']
# PRED:  ['225,blayse', '225,teddy riley']
# SAME:  ['225,blayse', '225,teddy riley']
# TRUE:  ['226,to where you are']
# PRED:  ['226,to where you are']
# SAME:  ['226,to where you are']
# TRUE:  ['227,merlin express', '227,cibano international airport']
# PRED:  ['']
# NONE_TRUE_LESS:  ['227,merlin express', '227,cibano international airport']
# NONE_PRED_LESS:  ['']
# TRUE:  ['228,wilton, connecticut']
# PRED:  ['228,wilton, connecticut']
# SAME:  ['228,wilton, connecticut']
# TRUE:  ['229,ontariana']
# PRED:  ['229,ontarians']
# SAME:  []
# NONE_TRUE_EQUAL:  ['229,ontariana']
# NONE_PRED_EQUAL:  ['229,ontarians']
# TRUE:  ['230,ryan seacrest', '230,fox']
# PRED:  ['230,fox', '230,ryan seacrest']
# SAME:  ['230,fox', '230,ryan seacrest']
# TRUE:  ['231,box girder bridges']
# PRED:  ['231,box girder']
# SAME:  []
# NONE_TRUE_EQUAL:  ['231,box girder bridges']
# NONE_PRED_EQUAL:  ['231,box girder']
# TRUE:  ["232,the god who wasn't there"]
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ["232,the god who wasn't there"]
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['233,public transport authority']
# PRED:  ['233,western australian public transport authority']
# SAME:  []
# NONE_TRUE_EQUAL:  ['233,public transport authority']
# NONE_PRED_EQUAL:  ['233,western australian public transport authority']
# TRUE:  ['234,thomas meehan']
# PRED:  ['234,thomas meehan']
# SAME:  ['234,thomas meehan']
# TRUE:  ['235,municipal council']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['235,municipal council']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['236,jacques-dsir laval']
# PRED:  ['236,jacques-dsir laval']
# SAME:  ['236,jacques-dsir laval']
# TRUE:  ['237,mecklenburg-vorpommern']
# PRED:  ['237,mecklenburg-vorpommern.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['237,mecklenburg-vorpommern']
# NONE_PRED_EQUAL:  ['237,mecklenburg-vorpommern.']
# TRUE:  ['238,herzogenaurach']
# PRED:  ['238,herzogenaurach']
# SAME:  ['238,herzogenaurach']
# TRUE:  ['239,lucy sullivan is getting married']
# PRED:  ['239,lucy sullivan']
# SAME:  []
# NONE_TRUE_EQUAL:  ['239,lucy sullivan is getting married']
# NONE_PRED_EQUAL:  ['239,lucy sullivan']
# TRUE:  ['240,blizzard entertainment']
# PRED:  ['240,blizzard entertainment']
# SAME:  ['240,blizzard entertainment']
# TRUE:  ['241,alexander downer', '241,neil brown']
# PRED:  ['241,alexander downer', '241,neil brown']
# SAME:  ['241,alexander downer', '241,neil brown']
# TRUE:  ['242,costa rica national football team']
# PRED:  ['242,costa rica']
# SAME:  []
# NONE_TRUE_EQUAL:  ['242,costa rica national football team']
# NONE_PRED_EQUAL:  ['242,costa rica']
# TRUE:  ['243,amitava datta']
# PRED:  ['243,amitava datta']
# SAME:  ['243,amitava datta']
# TRUE:  ['244,londo mollari']
# PRED:  ['244,londo mollari']
# SAME:  ['244,londo mollari']
# TRUE:  ['245,scientologists']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['245,scientologists']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['246,rashid behbudov state song theatre', '246,baku puppet theatre']
# PRED:  ['246,rashid behbudov', '246,baku puppet theatre']
# SAME:  ['246,baku puppet theatre']
# PARTIAL:  ['246,baku puppet theatre']
# TRUE:  ['247,qadir huseynov', '247,liudmila privivkova']
# PRED:  ['247,liudmila privivkova', '247,qadir huseynov']
# SAME:  ['247,liudmila privivkova', '247,qadir huseynov']
# TRUE:  ['248,cadillac fleetwood']
# PRED:  ['248,cadillac fleetwood']
# SAME:  ['248,cadillac fleetwood']
# TRUE:  ['249,commodore cdtv']
# PRED:  ['249,cdtv']
# SAME:  []
# NONE_TRUE_EQUAL:  ['249,commodore cdtv']
# NONE_PRED_EQUAL:  ['249,cdtv']
# TRUE:  ['250,mark johnson']
# PRED:  ['250,mark johnson.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['250,mark johnson']
# NONE_PRED_EQUAL:  ['250,mark johnson.']
# TRUE:  ['251,canary islands']
# PRED:  ['251,canary islands']
# SAME:  ['251,canary islands']
# TRUE:  ['252,fusil gras mile 1874']
# PRED:  ['252,fusil gras mile 1874']
# SAME:  ['252,fusil gras mile 1874']
# TRUE:  ['253,claiborne pell', '253,ralph flanders']
# PRED:  ['253,ralph flanders', '253,claiborne pell']
# SAME:  ['253,ralph flanders', '253,claiborne pell']
# TRUE:  ['254,ontario']
# PRED:  ['254,ontario']
# SAME:  ['254,ontario']
# TRUE:  ['255,san antonio', '255,us route 281']
# PRED:  ['255,us', '255,281', '255,san antonio']
# MORE:  ['255,san antonio']
# TRUE:  ['256,cnn']
# PRED:  ['256,cnn']
# SAME:  ['256,cnn']
# TRUE:  ['257,norfolk southern railway']
# PRED:  ['257,norfolk southern railway']
# SAME:  ['257,norfolk southern railway']
# TRUE:  ['258,edwin catmull', '258,pixar image computer']
# PRED:  ['258,one', '258,pixar image computer', '258,one', '258,edwin catmull']
# MORE:  ['258,pixar image computer', '258,edwin catmull']
# TRUE:  ['259,beverly hills', '259,colts neck township']
# PRED:  ['259,beverly hills', '259,colts neck township']
# SAME:  ['259,beverly hills', '259,colts neck township']
# TRUE:  ['260,rome']
# PRED:  ['260,rome']
# SAME:  ['260,rome']
# TRUE:  ['261,rhode island route 15']
# PRED:  ['261,rhode island route']
# SAME:  []
# NONE_TRUE_EQUAL:  ['261,rhode island route 15']
# NONE_PRED_EQUAL:  ['261,rhode island route']
# TRUE:  ['262,trump productions', '262,the ultimate merger']
# PRED:  ['262,trump productions']
# LESS:  ['262,trump productions']
# TRUE:  ['263,komc-fm', '263,komc']
# PRED:  ['263,komc-fm', '263,komc (am)']
# SAME:  ['263,komc-fm']
# PARTIAL:  ['263,komc-fm']
# TRUE:  ['264,asiana airlines', '264,jeju airport']
# PRED:  ['264,asiana', '264,jeju']
# SAME:  []
# NONE_TRUE_EQUAL:  ['264,asiana airlines', '264,jeju airport']
# NONE_PRED_EQUAL:  ['264,asiana', '264,jeju']
# TRUE:  ['265,swedish academy']
# PRED:  ['265,swedish academy']
# SAME:  ['265,swedish academy']
# TRUE:  ['266,tennessee state museum']
# PRED:  ['266,tennessee state museum']
# SAME:  ['266,tennessee state museum']
# TRUE:  ['267,ishir honda']
# PRED:  ['267,ishir honda']
# SAME:  ['267,ishir honda']
# TRUE:  ["268,alpine skiing at the 1964 winter olympics men's slalom"]
# PRED:  ['268,alpine', "268,winter olympics men's"]
# NONE_TRUE_MORE:  ["268,alpine skiing at the 1964 winter olympics men's slalom"]
# NONE_PRED_MORE:  ['268,alpine', "268,winter olympics men's"]
# TRUE:  ['269,virgin radio']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['269,virgin radio']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['270,tani university']
# PRED:  ['270,tani university']
# SAME:  ['270,tani university']
# TRUE:  ['271,dowra']
# PRED:  ['271,dowra']
# SAME:  ['271,dowra']
# TRUE:  ['272,pittsburgh pirates']
# PRED:  ['272,pittsburgh pirates']
# SAME:  ['272,pittsburgh pirates']
# TRUE:  ['273,simon fuller']
# PRED:  ['273,simon fuller']
# SAME:  ['273,simon fuller']
# TRUE:  ['274,the producers', '274,next thing']
# PRED:  ['274,next thing', '274,the producers']
# SAME:  ['274,next thing', '274,the producers']
# TRUE:  ['275,henry ford', '275,ford model c']
# PRED:  ['275,henry ford', '275,model c']
# SAME:  ['275,henry ford']
# PARTIAL:  ['275,henry ford']
# TRUE:  ["276,dragons' den"]
# PRED:  ["276,dragons' den"]
# SAME:  ["276,dragons' den"]
# TRUE:  ['277,joseph case high school', '277,providence chapel, charlwood']
# PRED:  ['277,the providence chapel, charlwood']
# NONE_TRUE_LESS:  ['277,joseph case high school', '277,providence chapel, charlwood']
# NONE_PRED_LESS:  ['277,the providence chapel, charlwood']
# TRUE:  ['278,norbert wiener award for social and professional responsibility', '278,john robert woodyard']
# PRED:  ['278,john robert woodyard', '278,norbert wiener award for social and professional responsibility']
# SAME:  ['278,john robert woodyard', '278,norbert wiener award for social and professional responsibility']
# TRUE:  ['279,leroy collins', '279,george siebels jr']
# PRED:  ['279,leroy collins', '279,george siebels jr']
# SAME:  ['279,leroy collins', '279,george siebels jr']
# TRUE:  ['280,germany']
# PRED:  ['280,germany']
# SAME:  ['280,germany']
# TRUE:  ['281,downtown athletic club', '281,yale club']
# PRED:  ['281,downtown athletic club', '281,yale club nycity']
# SAME:  ['281,downtown athletic club']
# PARTIAL:  ['281,downtown athletic club']
# TRUE:  ['282,victor hope, 2nd marquess of linlithgow']
# PRED:  ['282,linlithgow', '282,victor hope,']
# NONE_TRUE_MORE:  ['282,victor hope, 2nd marquess of linlithgow']
# NONE_PRED_MORE:  ['282,linlithgow', '282,victor hope,']
# TRUE:  ['283,ashton historic district']
# PRED:  ['283,ashton historic']
# SAME:  []
# NONE_TRUE_EQUAL:  ['283,ashton historic district']
# NONE_PRED_EQUAL:  ['283,ashton historic']
# TRUE:  ['284,greater napanee']
# PRED:  ['284,greater napanee']
# SAME:  ['284,greater napanee']
# TRUE:  ['285,channel district']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['285,channel district']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['286,vagif aliyev']
# PRED:  ['286,vagif aliyev']
# SAME:  ['286,vagif aliyev']
# TRUE:  ['287,onedrive', '287,us']
# PRED:  ['287,us', '287,onedrive']
# SAME:  ['287,us', '287,onedrive']
# TRUE:  ['288,james l. mcconaughy']
# PRED:  ['288,james l. mcconaughy']
# SAME:  ['288,james l. mcconaughy']
# TRUE:  ['289,catwoman']
# PRED:  ['289,one', '289,catwoman']
# MORE:  ['289,catwoman']
# TRUE:  ['290,mediterranean sea']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['290,mediterranean sea']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['291,bacillus', '291,bacteria']
# PRED:  ['291,bacillus']
# LESS:  ['291,bacillus']
# TRUE:  ['292,french']
# PRED:  ['292,french']
# SAME:  ['292,french']
# TRUE:  ['293,baraily', '293,jowai']
# PRED:  ['293,baraily,mp', '293,jowai']
# SAME:  ['293,jowai']
# PARTIAL:  ['293,jowai']
# TRUE:  ['294,siege of fort recovery']
# PRED:  ['294,siege of fort recovery']
# SAME:  ['294,siege of fort recovery']
# TRUE:  ['295,germanic']
# PRED:  ['295,germanic']
# SAME:  ['295,germanic']
# TRUE:  ['296,duane allman', '296,les paul']
# PRED:  ['296,duanne allman', '296,les paul']
# SAME:  ['296,les paul']
# PARTIAL:  ['296,les paul']
# TRUE:  ['297,tanzanian national football team']
# PRED:  ['297,tanzanian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['297,tanzanian national football team']
# NONE_PRED_EQUAL:  ['297,tanzanian']
# TRUE:  ['298,bloomberg markets']
# PRED:  ['298,bloomberg markets']
# SAME:  ['298,bloomberg markets']
# TRUE:  ['299,motor vehicles']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['299,motor vehicles']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['300,holmes colbert', '300,linda hogan']
# PRED:  ['300,linda hogan', '300,holmes colbert']
# SAME:  ['300,linda hogan', '300,holmes colbert']
# TRUE:  ['301,jon speelman']
# PRED:  ['301,jon speelman']
# SAME:  ['301,jon speelman']
# TRUE:  ['302,ella loves cole']
# PRED:  ['302,ella loves cole']
# SAME:  ['302,ella loves cole']
# TRUE:  ['303,prime time entertainment network']
# PRED:  ['303,prime time entertainment network']
# SAME:  ['303,prime time entertainment network']
# TRUE:  ['304,auto shankar']
# PRED:  ['304,auto shankar']
# SAME:  ['304,auto shankar']
# TRUE:  ['305,burr truss']
# PRED:  ['305,burr truss']
# SAME:  ['305,burr truss']
# TRUE:  ['306,tonle sap']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['306,tonle sap']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['307,cheryl teigs']
# PRED:  ['307,cheryl teigs']
# SAME:  ['307,cheryl teigs']
# TRUE:  ['308,ndonga mianga']
# PRED:  ['308,ndonga mianga']
# SAME:  ['308,ndonga mianga']
# TRUE:  ['309,papeete']
# PRED:  ['309,papeete']
# SAME:  ['309,papeete']
# TRUE:  ['310,lake victoria']
# PRED:  ['310,lake victoria']
# SAME:  ['310,lake victoria']
# TRUE:  ['311,domenico modugno']
# PRED:  ['311,domenico modugno']
# SAME:  ['311,domenico modugno']
# TRUE:  ['312,grameen bank']
# PRED:  ['312,grameen bank']
# SAME:  ['312,grameen bank']
# TRUE:  ['313,benjamin franklin terry', '313,us route 59']
# PRED:  ['313,benjamin franklin terry', '313,us route 59']
# SAME:  ['313,benjamin franklin terry', '313,us route 59']
# TRUE:  ['314,james langer']
# PRED:  ['314,james langer']
# SAME:  ['314,james langer']
# TRUE:  ['315,john trumbull', '315,a foreign policy']
# PRED:  ['315,john trumbull']
# LESS:  ['315,john trumbull']
# TRUE:  ['316,peter-john vettese']
# PRED:  ['316,peter-john vettese']
# SAME:  ['316,peter-john vettese']
# TRUE:  ['317,edwin catmull']
# PRED:  ['317,edwin catmull']
# SAME:  ['317,edwin catmull']
# TRUE:  ['318,eric roth']
# PRED:  ['318,eric']
# SAME:  []
# NONE_TRUE_EQUAL:  ['318,eric roth']
# NONE_PRED_EQUAL:  ['318,eric']
# TRUE:  ['319,coneygree', '319,martin molony']
# PRED:  ['319,the martin molony']
# NONE_TRUE_LESS:  ['319,coneygree', '319,martin molony']
# NONE_PRED_LESS:  ['319,the martin molony']
# TRUE:  ['320,dallas']
# PRED:  ['320,dallas jurisdiction']
# SAME:  []
# NONE_TRUE_EQUAL:  ['320,dallas']
# NONE_PRED_EQUAL:  ['320,dallas jurisdiction']
# TRUE:  ['321,royal society']
# PRED:  ['321,royal society']
# SAME:  ['321,royal society']
# TRUE:  ['322,philosophy', '322,stephen law']
# PRED:  ['322,stephen law']
# LESS:  ['322,stephen law']
# TRUE:  ['323,gervase helwys']
# PRED:  ['323,gervase helwys']
# SAME:  ['323,gervase helwys']
# TRUE:  ['324,raamlaxman']
# PRED:  ['324,raamlaxman']
# SAME:  ['324,raamlaxman']
# TRUE:  ['325,jose cha cha jimenez']
# PRED:  ['325,jose cha cha jimenez']
# SAME:  ['325,jose cha cha jimenez']
# TRUE:  ['326,bernard herrmann', '326,rko pictures']
# PRED:  ['326,rko pictures', '326,bernard herrmann']
# SAME:  ['326,rko pictures', '326,bernard herrmann']
# TRUE:  ['327,red ahead']
# PRED:  ['327,red ahead']
# SAME:  ['327,red ahead']
# TRUE:  ['328,kore presbyterian theological seminar', '328,celal bayar university']
# PRED:  ['328,celal bayer', '328,presbyterian theological seminar']
# SAME:  []
# NONE_TRUE_EQUAL:  ['328,kore presbyterian theological seminar', '328,celal bayar university']
# NONE_PRED_EQUAL:  ['328,celal bayer', '328,presbyterian theological seminar']
# TRUE:  ['329,hamline avenue']
# PRED:  ['329,quarters', '329,hamline avenue']
# MORE:  ['329,hamline avenue']
# TRUE:  ['330,yasmin paige']
# PRED:  ['330,yasmin paige']
# SAME:  ['330,yasmin paige']
# TRUE:  ['331,heinz kokott']
# PRED:  ['331,heinz kokott', '331,nazi army']
# MORE:  ['331,heinz kokott']
# TRUE:  ['332,jann wenner', '332,ralph j. gleason']
# PRED:  ['332,jann wenner', '332,ralph j. gleason']
# SAME:  ['332,jann wenner', '332,ralph j. gleason']
# TRUE:  ['333,nevado de toluca', '333,sierra nevada']
# PRED:  ['333,sierra nevada', '333,u.s.', '333,nevado de toluca']
# MORE:  ['333,sierra nevada', '333,nevado de toluca']
# TRUE:  ['334,bbc hd', '334,doctor who confidential']
# PRED:  ['334,bbc']
# NONE_TRUE_LESS:  ['334,bbc hd', '334,doctor who confidential']
# NONE_PRED_LESS:  ['334,bbc']
# TRUE:  ['335,milk cow blues', '335,sings kristofferson']
# PRED:  ['335,sings kristofferson', '335,milk cow blues']
# SAME:  ['335,sings kristofferson', '335,milk cow blues']
# TRUE:  ['336,thesaban']
# PRED:  ['336,thesaban']
# SAME:  ['336,thesaban']
# TRUE:  ['337,micronesia']
# PRED:  ['337,micronesia']
# SAME:  ['337,micronesia']
# TRUE:  ['338,stephen e. ambrose']
# PRED:  ['338,stephen e. ambrose']
# SAME:  ['338,stephen e. ambrose']
# TRUE:  ['339,central european summer time']
# PRED:  ['339,central european summer time.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['339,central european summer time']
# NONE_PRED_EQUAL:  ['339,central european summer time.']
# TRUE:  ['340,steven peterman', '340,the best of both worlds']
# PRED:  ['340,the best of both worlds', '340,steven peterman']
# SAME:  ['340,the best of both worlds', '340,steven peterman']
# TRUE:  ['341,ralph j. gleason']
# PRED:  ['341,ralph j. gleason']
# SAME:  ['341,ralph j. gleason']
# TRUE:  ['342,paul morphy']
# PRED:  ['342,paul morphy']
# SAME:  ['342,paul morphy']
# TRUE:  ['343,thames estuary', '343,north sea']
# PRED:  ['343,thames estuary', '343,north sea']
# SAME:  ['343,thames estuary', '343,north sea']
# TRUE:  ['344,ganefo']
# PRED:  ['344,ganefo']
# SAME:  ['344,ganefo']
# TRUE:  ['345,matt williams']
# PRED:  ['345,matt williams']
# SAME:  ['345,matt williams']
# TRUE:  ['346,massachusetts house of representatives', '346,samuel w. mccall']
# PRED:  ['346,samuel w. mccall', '346,massachusetts house of representatives']
# SAME:  ['346,samuel w. mccall', '346,massachusetts house of representatives']
# TRUE:  ['347,golden globe']
# PRED:  ['347,golden globe']
# SAME:  ['347,golden globe']
# TRUE:  ['348,pizza', "348,mr. jim's pizza"]
# PRED:  ["348,jim's pizza"]
# NONE_TRUE_LESS:  ['348,pizza', "348,mr. jim's pizza"]
# NONE_PRED_LESS:  ["348,jim's pizza"]
# TRUE:  ['349,even-toed ungulate']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['349,even-toed ungulate']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['350,mathematics']
# PRED:  ['350,mathematics']
# SAME:  ['350,mathematics']
# TRUE:  ['351,winston bryant', '351,joe purcell']
# PRED:  ['351,joe purcell', '351,winston bryant']
# SAME:  ['351,joe purcell', '351,winston bryant']
# TRUE:  ['352,jim harris']
# PRED:  ['352,jim harris']
# SAME:  ['352,jim harris']
# TRUE:  ['353,corringham railway station']
# PRED:  ['353,corringham']
# SAME:  []
# NONE_TRUE_EQUAL:  ['353,corringham railway station']
# NONE_PRED_EQUAL:  ['353,corringham']
# TRUE:  ['354,stan lee', '354,the incredible hulk']
# PRED:  ['354,stan lee']
# LESS:  ['354,stan lee']
# TRUE:  ['355,emanuel de guzman']
# PRED:  ['355,emanuel de guzman']
# SAME:  ['355,emanuel de guzman']
# TRUE:  ['356,al khaleejiya 100.9']
# PRED:  ['356,al khaleejiya', '356,100.9 play']
# NONE_TRUE_MORE:  ['356,al khaleejiya 100.9']
# NONE_PRED_MORE:  ['356,al khaleejiya', '356,100.9 play']
# TRUE:  ['357,harvest christian center']
# PRED:  ['357,harvest christian center']
# SAME:  ['357,harvest christian center']
# TRUE:  ["358,master's sun"]
# PRED:  ["358,master's sun>"]
# SAME:  []
# NONE_TRUE_EQUAL:  ["358,master's sun"]
# NONE_PRED_EQUAL:  ["358,master's sun>"]
# TRUE:  ['359,virtual kasparov', '359,fr agnel school and jr college']
# PRED:  ['359,virtual kasparov', '359,fr agnel']
# SAME:  ['359,virtual kasparov']
# PARTIAL:  ['359,virtual kasparov']
# TRUE:  ['360,colts neck township', '360,beverly hills']
# PRED:  ['360,colts neck township', '360,beverly hills']
# SAME:  ['360,colts neck township', '360,beverly hills']
# TRUE:  ['361,blizzard']
# PRED:  ['361,blizzard']
# SAME:  ['361,blizzard']
# TRUE:  ['362,shannon pot', '362,limerick']
# PRED:  ['362,shannon pot', '362,limerick']
# SAME:  ['362,shannon pot', '362,limerick']
# TRUE:  ['363,gloucestershire', '363,reading']
# PRED:  ['363,reading', '363,gloucestershire']
# SAME:  ['363,reading', '363,gloucestershire']
# TRUE:  ['364,gelnhausen', '364,pepperdine university']
# PRED:  ['364,gelnhausen', '364,pepperdine university']
# SAME:  ['364,gelnhausen', '364,pepperdine university']
# TRUE:  ['365,frontaccounting', '365,nubuntu']
# PRED:  ['365,frontaccounting', '365,nubuntu']
# SAME:  ['365,frontaccounting', '365,nubuntu']
# TRUE:  ['366,brian graden', '366,broadcast syndication']
# PRED:  ['366,brian graden']
# LESS:  ['366,brian graden']
# TRUE:  ['367,fort barrancas', '367,gadsden']
# PRED:  ['367,fort barrancas', '367,gadsden']
# SAME:  ['367,fort barrancas', '367,gadsden']
# TRUE:  ['368,richard h immerman', '368,franklin w olin']
# PRED:  ['368,richard h immerman', '368,franklin w olin']
# SAME:  ['368,richard h immerman', '368,franklin w olin']
# TRUE:  ['369,occupation of japan']
# PRED:  ['369,occupation of japan']
# SAME:  ['369,occupation of japan']
# TRUE:  ['370,vanderbilt university medical center', '370,monroe carell jr children hospital']
# PRED:  ['370,vanderbilt university medical center', '370,monrow carell jr children hospital']
# SAME:  ['370,vanderbilt university medical center']
# PARTIAL:  ['370,vanderbilt university medical center']
# TRUE:  ['371,gm b']
# PRED:  ['371,gm b']
# SAME:  ['371,gm b']
# TRUE:  ['372,texas']
# PRED:  ['372,texas']
# SAME:  ['372,texas']
# TRUE:  ['373,counterpoint']
# PRED:  ['373,counterpoint']
# SAME:  ['373,counterpoint']
# TRUE:  ['374,pc 9800']
# PRED:  ['374,9800']
# SAME:  []
# NONE_TRUE_EQUAL:  ['374,pc 9800']
# NONE_PRED_EQUAL:  ['374,9800']
# TRUE:  ['375,anglo-frisian']
# PRED:  ['375,anglo-frisian']
# SAME:  ['375,anglo-frisian']
# TRUE:  ['376,tony bennett']
# PRED:  ['376,tony bennett']
# SAME:  ['376,tony bennett']
# TRUE:  ['377,charles willing byrd', '377,north bend, ohio']
# PRED:  ['377,charles willing byrd', '377,north bend, ohio']
# SAME:  ['377,charles willing byrd', '377,north bend, ohio']
# TRUE:  ['378,novelas ejemplares']
# PRED:  ['378,novelas']
# SAME:  []
# NONE_TRUE_EQUAL:  ['378,novelas ejemplares']
# NONE_PRED_EQUAL:  ['378,novelas']
# TRUE:  ['379,anne spielberg']
# PRED:  ['379,whos', '379,anne spielberg']
# MORE:  ['379,anne spielberg']
# TRUE:  ['380,nbc', '380,frasier']
# PRED:  ['380,nbc', '380,fraiser']
# SAME:  ['380,nbc']
# PARTIAL:  ['380,nbc']
# TRUE:  ['381,washington station', '381,cta blue line']
# PRED:  ['381,washington', '381,the cta blue line']
# SAME:  []
# NONE_TRUE_EQUAL:  ['381,washington station', '381,cta blue line']
# ...
# PRED:  ['4876,grand bahama']
# LESS:  ['4876,grand bahama']
# TRUE:  ['4877,battle chess']
# PRED:  ['4877,battle chess']
# SAME:  ['4877,battle chess']
# TRUE:  ['4878,colonel', '4878,colony of virginia']
# PRED:  ['4878,colony', '4878,virginia']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4878,colonel', '4878,colony of virginia']
# NONE_PRED_EQUAL:  ['4878,colony', '4878,virginia']
# TRUE:  ['4879,the states']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4879,the states']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4880,kobalt label services']
# PRED:  ['4880,kobalt label services']
# SAME:  ['4880,kobalt label services']
# TRUE:  ['4881,cfrb']
# PRED:  ['4881,cfrb']
# SAME:  ['4881,cfrb']
# TRUE:  ['4882,warner bros. animation']
# PRED:  ['4882,warner bros. animation.']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4882,warner bros. animation']
# NONE_PRED_EQUAL:  ['4882,warner bros. animation.']
# TRUE:  ['4883,paul demiville']
# PRED:  ['4883,namt', '4883,paul demiville']
# MORE:  ['4883,paul demiville']
# TRUE:  ['4884,gdask', '4884,kaliningrad']
# PRED:  ['4884,kaliningrad', '4884,gdask']
# SAME:  ['4884,kaliningrad', '4884,gdask']
# TRUE:  ['4885,alexander lippisch']
# PRED:  ['4885,alexander lippisch']
# SAME:  ['4885,alexander lippisch']
# TRUE:  ['4886,david lewis', '4886,thorington railway station']
# PRED:  ['4886,thorington', '4886,david lewis']
# SAME:  ['4886,david lewis']
# PARTIAL:  ['4886,david lewis']
# TRUE:  ['4887,nasa']
# PRED:  ['4887,nasa']
# SAME:  ['4887,nasa']
# TRUE:  ['4888,gibson les paul']
# PRED:  ['4888,gibson les paul']
# SAME:  ['4888,gibson les paul']
# TRUE:  ['4889,haight-ashbury', '4889,castro district']
# PRED:  ['4889,castro', '4889,haight-ashbury']
# SAME:  ['4889,haight-ashbury']
# PARTIAL:  ['4889,haight-ashbury']
# TRUE:  ['4890,uk']
# PRED:  ['4890,uk']
# SAME:  ['4890,uk']
# TRUE:  ['4891,motorpsycho nitemare', '4891,moondog matinee']
# PRED:  ['4891,moondog matinee', '4891,motorpsycho nitemare']
# SAME:  ['4891,moondog matinee', '4891,motorpsycho nitemare']
# TRUE:  ['4892,schutzstaffels']
# PRED:  ['4892,schutzstaffels']
# SAME:  ['4892,schutzstaffels']
# TRUE:  ['4893,kron ngoy', '4893,hang chuon naron']
# PRED:  ['4893,kron ngoy']
# LESS:  ['4893,kron ngoy']
# TRUE:  ['4894,william w brien']
# PRED:  ['4894,william w brien']
# SAME:  ['4894,william w brien']
# TRUE:  ['4895,ios']
# PRED:  ['4895,ios']
# SAME:  ['4895,ios']
# TRUE:  ['4896,the incredible hulk']
# PRED:  ['4896,the incredible hulk']
# SAME:  ['4896,the incredible hulk']
# TRUE:  ['4897,carl sanders']
# PRED:  ['4897,one', '4897,carl sanders']
# MORE:  ['4897,carl sanders']
# TRUE:  ['4898,william c p breckinridge']
# PRED:  ['4898,william c p breckinridge']
# SAME:  ['4898,william c p breckinridge']
# TRUE:  ["4899,st. peter's basilica"]
# PRED:  ["4899,st. peter's basilica"]
# SAME:  ["4899,st. peter's basilica"]
# TRUE:  ['4900,dreamworks television', '4900,stephen e. ambrose']
# PRED:  ['4900,stephen e. ambrose', '4900,dreamworks television']
# SAME:  ['4900,stephen e. ambrose', '4900,dreamworks television']
# TRUE:  ['4901,lake washington']
# PRED:  ['4901,washington']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4901,lake washington']
# NONE_PRED_EQUAL:  ['4901,washington']
# TRUE:  ['4902,fedexfield']
# PRED:  ['4902,fedexfield']
# SAME:  ['4902,fedexfield']
# TRUE:  ['4903,edsel villager']
# PRED:  ['4903,edsel villager']
# SAME:  ['4903,edsel villager']
# TRUE:  ['4904,sierra madre de chiapas']
# PRED:  ['4904,sierra madre de chiapas']
# SAME:  ['4904,sierra madre de chiapas']
# TRUE:  ['4905,cherokee']
# PRED:  ['4905,cherokee']
# SAME:  ['4905,cherokee']
# TRUE:  ["4906,he's a liar"]
# PRED:  ["4906,he's a liar"]
# SAME:  ["4906,he's a liar"]
# TRUE:  ['4907,bbc multimedia', '4907,mazes of time']
# PRED:  ['4907,mazes of time', '4907,bbc multimedia']
# SAME:  ['4907,mazes of time', '4907,bbc multimedia']
# TRUE:  ['4908,doonesbury']
# PRED:  ['4908,doonesbury']
# SAME:  ['4908,doonesbury']
# TRUE:  ['4909,aachen cathedral']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4909,aachen cathedral']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4910,robert a. taft', '4910,charles phelps taft ii']
# PRED:  ['4910,robert a. taft', '4910,charles phelps taft ii']
# SAME:  ['4910,robert a. taft', '4910,charles phelps taft ii']
# TRUE:  ['4911,giorgos kaminis']
# PRED:  ['4911,giorgos kaminis']
# SAME:  ['4911,giorgos kaminis']
# TRUE:  ['4912,linda jenness']
# PRED:  ['4912,linda jenness']
# SAME:  ['4912,linda jenness']
# TRUE:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# PRED:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# SAME:  ['4913,plymouth savoy', '4913,northsouth transport corridor']
# TRUE:  ['4914,fender stratocaster']
# PRED:  ['4914,fender stratocaster']
# SAME:  ['4914,fender stratocaster']
# TRUE:  ['4915,primate']
# PRED:  ['4915,primate']
# SAME:  ['4915,primate']
# TRUE:  ['4916,willem-alexander']
# PRED:  ['4916,willem-alexander', '4916,netherlands']
# MORE:  ['4916,willem-alexander']
# TRUE:  ['4917,chelsea f.c.']
# PRED:  ['4917,chelsea f.c.']
# SAME:  ['4917,chelsea f.c.']
# TRUE:  ['4918,kingdom']
# PRED:  ['4918,israelite', '4918,united monarch']
# NONE_TRUE_MORE:  ['4918,kingdom']
# NONE_PRED_MORE:  ['4918,israelite', '4918,united monarch']
# TRUE:  ['4919,malaysian pwd']
# PRED:  ['4919,pwd']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4919,malaysian pwd']
# NONE_PRED_EQUAL:  ['4919,pwd']
# TRUE:  ['4920,king county, washington', '4920,phil lumpkin']
# PRED:  ['4920,phil lumpkin', '4920,county, washington']
# SAME:  ['4920,phil lumpkin']
# PARTIAL:  ['4920,phil lumpkin']
# TRUE:  ['4921,old lyme, connecticut']
# PRED:  ['4921,old lyme, connecticut']
# SAME:  ['4921,old lyme, connecticut']
# TRUE:  ['4922,mac os', '4922,microsoft windows']
# PRED:  ['4922,mac']
# NONE_TRUE_LESS:  ['4922,mac os', '4922,microsoft windows']
# NONE_PRED_LESS:  ['4922,mac']
# TRUE:  ['4923,ike clanton']
# PRED:  ['4923,ike clanton']
# SAME:  ['4923,ike clanton']
# TRUE:  ['4924,indian general election, 2004']
# PRED:  ['4924,indian', '4924,(andhra pradesh)']
# NONE_TRUE_MORE:  ['4924,indian general election, 2004']
# NONE_PRED_MORE:  ['4924,indian', '4924,(andhra pradesh)']
# TRUE:  ['4925,miao people', '4925,palang dharma party']
# PRED:  ['4925,palang dharma party', '4925,miao']
# SAME:  ['4925,palang dharma party']
# PARTIAL:  ['4925,palang dharma party']
# TRUE:  ["4926,brown's corners, toronto", '4926,krista kelly']
# PRED:  ['4926,krista kelly', "4926,brown's corners,"]
# SAME:  ['4926,krista kelly']
# PARTIAL:  ['4926,krista kelly']
# TRUE:  ['4927,judge advocate general corps']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4927,judge advocate general corps']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4928,pope pius xi']
# PRED:  ['4928,pius xi']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4928,pope pius xi']
# NONE_PRED_EQUAL:  ['4928,pius xi']
# TRUE:  ['4929,brown']
# PRED:  ['4929,brown']
# SAME:  ['4929,brown']
# TRUE:  ['4930,solon spencer beman']
# PRED:  ['4930,solon spencer beman']
# SAME:  ['4930,solon spencer beman']
# TRUE:  ['4931,1967 mexican grand prix', '4931,1971 us']
# PRED:  ['4931,us', '4931,mexican grand prix']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4931,1967 mexican grand prix', '4931,1971 us']
# NONE_PRED_EQUAL:  ['4931,us', '4931,mexican grand prix']
# TRUE:  ['4932,sam sen railway station']
# PRED:  ['4932,sam sen railway station']
# SAME:  ['4932,sam sen railway station']
# TRUE:  ['4933,newcastle']
# PRED:  ['4933,newcastle']
# SAME:  ['4933,newcastle']
# TRUE:  ['4934,tehran']
# PRED:  ['4934,tehran']
# SAME:  ['4934,tehran']
# TRUE:  ['4935,wxme']
# PRED:  ['4935,wxme']
# SAME:  ['4935,wxme']
# TRUE:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# PRED:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# SAME:  ["4936,tommy tucker's tooth", "4936,mickey's mellerdrammer"]
# TRUE:  ['4937,quich department']
# PRED:  ['4937,quich department', '4937,one']
# MORE:  ['4937,quich department']
# TRUE:  ['4938,apollo 11', '4938,gemini 8']
# PRED:  ['4938,apollo 11', '4938,gemini']
# SAME:  ['4938,apollo 11']
# PARTIAL:  ['4938,apollo 11']
# TRUE:  ['4939,seattle great wheel']
# PRED:  ['4939,seattle great wheel']
# SAME:  ['4939,seattle great wheel']
# TRUE:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# PRED:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# SAME:  ['4940,harvard-westlake school', '4940,alta mesa memorial park']
# TRUE:  ['4941,the bleeding heart band']
# PRED:  ['4941,the bleeding heart band']
# SAME:  ['4941,the bleeding heart band']
# TRUE:  ['4942,russian railways']
# PRED:  ['4942,russian']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4942,russian railways']
# NONE_PRED_EQUAL:  ['4942,russian']
# TRUE:  ['4943,russell t davies', '4943,wizards and the aliens']
# PRED:  ['4943,wizards', '4943,russell t davies']
# SAME:  ['4943,russell t davies']
# PARTIAL:  ['4943,russell t davies']
# TRUE:  ['4944,arkansas']
# PRED:  ['4944,rivers', '4944,arkansas']
# MORE:  ['4944,arkansas']
# TRUE:  ['4945,ceratosoma tenue']
# PRED:  ['4945,ceratosoma']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4945,ceratosoma tenue']
# NONE_PRED_EQUAL:  ['4945,ceratosoma']
# TRUE:  ['4946,riley reid', '4946,holmes colbert']
# PRED:  ['4946,riley reid', '4946,holmes colbert']
# SAME:  ['4946,riley reid', '4946,holmes colbert']
# TRUE:  ['4947,girls']
# PRED:  ['4947,girls (the prodigy']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4947,girls']
# NONE_PRED_EQUAL:  ['4947,girls (the prodigy']
# TRUE:  ['4948,indira gandhi']
# PRED:  ['4948,indira gandhi']
# SAME:  ['4948,indira gandhi']
# TRUE:  ['4949,manhattan project']
# PRED:  ['4949,manhattan project']
# SAME:  ['4949,manhattan project']
# TRUE:  ['4950,secrets and lies']
# PRED:  ['4950,secrets and lies']
# SAME:  ['4950,secrets and lies']
# TRUE:  ['4951,ohio']
# PRED:  ['4951,ohio']
# SAME:  ['4951,ohio']
# TRUE:  ['4952,john o conner']
# PRED:  ['4952,john o conner']
# SAME:  ['4952,john o conner']
# TRUE:  ['4953,charlie justice', '4953,bobby hoppe']
# PRED:  ['4953,charlie justice (american', '4953,bobby hoppe']
# SAME:  ['4953,bobby hoppe']
# PARTIAL:  ['4953,bobby hoppe']
# TRUE:  ['4954,jimmy wales']
# PRED:  ['4954,jimmy']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4954,jimmy wales']
# NONE_PRED_EQUAL:  ['4954,jimmy']
# TRUE:  ['4955,ted williams tunnel', '4955,leonard memorial']
# PRED:  ['4955,ted williams', '4955,leonard memorial']
# SAME:  ['4955,leonard memorial']
# PARTIAL:  ['4955,leonard memorial']
# TRUE:  ['4956,michaelhouse']
# PRED:  ['4956,michaelhouse']
# SAME:  ['4956,michaelhouse']
# TRUE:  ['4957,yosemite park']
# PRED:  ['4957,yosemite park']
# SAME:  ['4957,yosemite park']
# TRUE:  ['4958,levant']
# PRED:  ['4958,levant']
# SAME:  ['4958,levant']
# TRUE:  ['4959,fifety five days at peking', '4959,awakening']
# PRED:  ['4959,awakening']
# LESS:  ['4959,awakening']
# TRUE:  ['4960,huey, dewey, and louie', '4960,clan mcduck']
# PRED:  ['4960,clan mcduck', '4960,louie', '4960,huey, dewey,']
# MORE:  ['4960,clan mcduck']
# TRUE:  ['4961,ennejma ezzahra', '4961,boga']
# PRED:  ['4961,ennejma ezzahra', '4961,boga']
# SAME:  ['4961,ennejma ezzahra', '4961,boga']
# TRUE:  ['4962,charles gordon']
# PRED:  ['4962,charles gordon']
# SAME:  ['4962,charles gordon']
# TRUE:  ['4963,maryanne trump barry', '4963,le cirque']
# PRED:  ['4963,le cirque', '4963,maryanne trump']
# SAME:  ['4963,le cirque']
# PARTIAL:  ['4963,le cirque']
# TRUE:  ['4964,toronto']
# PRED:  ['4964,toronto']
# SAME:  ['4964,toronto']
# TRUE:  ['4965,laurie johnson', '4965,stanley kubrick']
# PRED:  ["4965,stanley kubrick's", '4965,laurie johnson']
# SAME:  ['4965,laurie johnson']
# PARTIAL:  ['4965,laurie johnson']
# TRUE:  ['4966,uss kittiwake', '4966,haight-ashbury']
# PRED:  ['4966,haight-ashbury', '4966,uss kittiwake']
# SAME:  ['4966,haight-ashbury', '4966,uss kittiwake']
# TRUE:  ['4967,motorpsycho nitemare']
# PRED:  ['4967,motorpsycho nitemare']
# SAME:  ['4967,motorpsycho nitemare']
# TRUE:  ['4968,hbo', '4968,erik jendresen']
# PRED:  ['4968,erik jendresen', '4968,hbo']
# SAME:  ['4968,erik jendresen', '4968,hbo']
# TRUE:  ['4969,battle']
# PRED:  ['4969,battle of the bulge']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4969,battle']
# NONE_PRED_EQUAL:  ['4969,battle of the bulge']
# TRUE:  ['4970,israel', '4970,colin powell']
# PRED:  ['4970,colin powell', '4970,israel']
# SAME:  ['4970,colin powell', '4970,israel']
# TRUE:  ['4971,the ultimate fighter: team rousey vs. team tate']
# PRED:  ['4971,the ultimate fighter: team rousey', '4971,team tate']
# NONE_TRUE_MORE:  ['4971,the ultimate fighter: team rousey vs. team tate']
# NONE_PRED_MORE:  ['4971,the ultimate fighter: team rousey', '4971,team tate']
# TRUE:  ['4972,alexa scimeca']
# PRED:  ['4972,alexa scimeca']
# SAME:  ['4972,alexa scimeca']
# TRUE:  ['4973,south african class 11e', '4973,renfe class 333']
# PRED:  ['4973,south african', '4973,11e', '4973,renfe', '4973,333']
# NONE_TRUE_MORE:  ['4973,south african class 11e', '4973,renfe class 333']
# NONE_PRED_MORE:  ['4973,south african', '4973,11e', '4973,renfe', '4973,333']
# TRUE:  ['4974,erich bagge', '4974,erban ieica']
# PRED:  ['4974,erich bagge', '4974,erban ieica']
# SAME:  ['4974,erich bagge', '4974,erban ieica']
# TRUE:  ['4975,apollo 11', '4975,nasa']
# PRED:  ['4975,nasa', '4975,apollo 11']
# SAME:  ['4975,nasa', '4975,apollo 11']
# TRUE:  ['4976,ape', '4976,primate']
# PRED:  ['4976,ape', '4976,primate']
# SAME:  ['4976,ape', '4976,primate']
# TRUE:  ['4977,goethe prize']
# PRED:  ['4977,goethe prize']
# SAME:  ['4977,goethe prize']
# TRUE:  ['4978,amiga']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4978,amiga']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4979,william henry harrison tomb state memorial', '4979,john scott harrison']
# PRED:  ['4979,john scott harrison', '4979,william henry harrison tomb state memorial']
# SAME:  ['4979,john scott harrison', '4979,william henry harrison tomb state memorial']
# TRUE:  ['4980,muhammad yunus']
# PRED:  ['4980,muhammad yunus']
# SAME:  ['4980,muhammad yunus']
# TRUE:  ['4981,saunders county']
# PRED:  ['4981,saunders']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4981,saunders county']
# NONE_PRED_EQUAL:  ['4981,saunders']
# TRUE:  ['4982,miao rebellion']
# PRED:  ['4982,miao']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4982,miao rebellion']
# NONE_PRED_EQUAL:  ['4982,miao']
# TRUE:  ['4983,italic']
# PRED:  ['']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4983,italic']
# NONE_PRED_EQUAL:  ['']
# TRUE:  ['4984,bbc multimedia', '4984,visions']
# PRED:  ['4984,bbc multimedia']
# LESS:  ['4984,bbc multimedia']
# TRUE:  ['4985,donna shalala']
# PRED:  ['4985,donna shalala']
# SAME:  ['4985,donna shalala']
# TRUE:  ['4986,french southern and antarctic lands', '4986,kerguelen islands']
# PRED:  ['4986,kerguelen', '4986,french']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4986,french southern and antarctic lands', '4986,kerguelen islands']
# NONE_PRED_EQUAL:  ['4986,kerguelen', '4986,french']
# TRUE:  ['4987,weber thompson']
# PRED:  ['4987,weber thompson']
# SAME:  ['4987,weber thompson']
# TRUE:  ['4988,edith vonnegut']
# PRED:  ['4988,edith vonnegut']
# SAME:  ['4988,edith vonnegut']
# TRUE:  ['4989,iyoas i']
# PRED:  ['4989,iyoas']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4989,iyoas i']
# NONE_PRED_EQUAL:  ['4989,iyoas']
# TRUE:  ['4990,wcw mayhem']
# PRED:  ['4990,wcw mayhem']
# SAME:  ['4990,wcw mayhem']
# TRUE:  ['4991,rca records']
# PRED:  ['4991,rca']
# SAME:  []
# NONE_TRUE_EQUAL:  ['4991,rca records']
# NONE_PRED_EQUAL:  ['4991,rca']
# TRUE:  ['4992,nick diaz', '4992,brazilian jiu-jitsu']
# PRED:  ['4992,brazilian', '4992,nick diaz']
# SAME:  ['4992,nick diaz']
# PARTIAL:  ['4992,nick diaz']
# TRUE:  ['4993,amstelveen']
# PRED:  ['4993,amstelveen']
# SAME:  ['4993,amstelveen']
# TRUE:  ['4994,choctaw']
# PRED:  ['4994,choctaw']
# SAME:  ['4994,choctaw']
# TRUE:  ['4995,larry j. franco']
# PRED:  ['4995,larry j. franco']
# SAME:  ['4995,larry j. franco']
# TRUE:  ['4996,tnt', '4996,j. michael stroczynski']
# PRED:  ['4996,j. michael stroczynski', '4996,tnt']
# SAME:  ['4996,j. michael stroczynski', '4996,tnt']
# TRUE:  ['4997,varsity stadium']
# PRED:  ['4997,varsity stadium']
# SAME:  ['4997,varsity stadium']
# TRUE:  ['4998,robin kovacs', '4998,nyrangers']
# PRED:  ['4998,ny rangers', '4998,robin kovacs']
# SAME:  ['4998,robin kovacs']
# PARTIAL:  ['4998,robin kovacs']
# TRUE:  ["4999,marquette golden eagles men's basketball team, 2008-09", "4999,marquette golden eagles men's basketball team"]
# PRED:  ['4999,marquette golden eagles', '4999,2008-09', '4999,marquette golden eagles']
# NONE_TRUE_MORE:  ["4999,marquette golden eagles men's basketball team, 2008-09", "4999,marquette golden eagles men's basketball team"]
# NONE_PRED_MORE:  ['4999,marquette golden eagles', '4999,2008-09', '4999,marquette golden eagles']
# 3190
# 330
# 135
# 229
# 872
# 110
# 134
# 5206

# %%
print(match)
print(partial)
print(less)
print(more)
print(none_match)
print(none_less)
print(none_more)
print(predicted)
print(predicted/len(real_entities))
# Out:
# 3190
# 330
# 135
# 229
# 872
# 110
# 134
# 5206
# 0.7838000602228244
